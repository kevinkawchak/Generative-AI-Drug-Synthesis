# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 1024)              3072
#
#  dense_41 (Dense)            (None, 1024)              1049600
#
#  dense_42 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_43 (Dense)            (None, 1024)              3072
#
#  tn_layer_24 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_25 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_26 (TNLayer)       (None, 1024)              5120
#
#  dense_44 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(40, 2) + np.array([3, 3]),
                    np.random.randn(40, 2) + np.array([-3, -3]),
                    np.random.randn(40, 2) + np.array([-3, 3]),
                    np.random.randn(40, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((80)), -np.ones((80))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710200757.5331707
# Mon Mar 11 23:45:57 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 5/5 - 2s - loss: 1.0015 - 2s/epoch - 347ms/step
# Epoch 2/300
# 5/5 - 0s - loss: 0.9998 - 29ms/epoch - 6ms/step
# Epoch 3/300
# 5/5 - 0s - loss: 1.0002 - 26ms/epoch - 5ms/step
# Epoch 4/300
# 5/5 - 0s - loss: 0.9987 - 26ms/epoch - 5ms/step
# Epoch 5/300
# 5/5 - 0s - loss: 0.9940 - 26ms/epoch - 5ms/step
# Epoch 6/300
# 5/5 - 0s - loss: 0.9788 - 24ms/epoch - 5ms/step
# Epoch 7/300
# 5/5 - 0s - loss: 0.9270 - 28ms/epoch - 6ms/step
# Epoch 8/300
# 5/5 - 0s - loss: 0.7700 - 28ms/epoch - 6ms/step
# Epoch 9/300
# 5/5 - 0s - loss: 0.3898 - 25ms/epoch - 5ms/step
# Epoch 10/300
# 5/5 - 0s - loss: 0.0969 - 27ms/epoch - 5ms/step
# Epoch 11/300
# 5/5 - 0s - loss: 0.0832 - 25ms/epoch - 5ms/step
# Epoch 12/300
# 5/5 - 0s - loss: 0.0510 - 27ms/epoch - 5ms/step
# Epoch 13/300
# 5/5 - 0s - loss: 0.0480 - 26ms/epoch - 5ms/step
# Epoch 14/300
# 5/5 - 0s - loss: 0.0222 - 27ms/epoch - 5ms/step
# Epoch 15/300
# 5/5 - 0s - loss: 0.0236 - 26ms/epoch - 5ms/step
# Epoch 16/300
# 5/5 - 0s - loss: 0.0172 - 26ms/epoch - 5ms/step
# Epoch 17/300
# 5/5 - 0s - loss: 0.0164 - 25ms/epoch - 5ms/step
# Epoch 18/300
# 5/5 - 0s - loss: 0.0151 - 26ms/epoch - 5ms/step
# Epoch 19/300
# 5/5 - 0s - loss: 0.0132 - 25ms/epoch - 5ms/step
# Epoch 20/300
# 5/5 - 0s - loss: 0.0131 - 26ms/epoch - 5ms/step
# Epoch 21/300
# 5/5 - 0s - loss: 0.0114 - 25ms/epoch - 5ms/step
# Epoch 22/300
# 5/5 - 0s - loss: 0.0110 - 26ms/epoch - 5ms/step
# Epoch 23/300
# 5/5 - 0s - loss: 0.0106 - 23ms/epoch - 5ms/step
# Epoch 24/300
# 5/5 - 0s - loss: 0.0096 - 26ms/epoch - 5ms/step
# Epoch 25/300
# 5/5 - 0s - loss: 0.0091 - 27ms/epoch - 5ms/step
# Epoch 26/300
# 5/5 - 0s - loss: 0.0086 - 27ms/epoch - 5ms/step
# Epoch 27/300
# 5/5 - 0s - loss: 0.0081 - 26ms/epoch - 5ms/step
# Epoch 28/300
# 5/5 - 0s - loss: 0.0076 - 24ms/epoch - 5ms/step
# Epoch 29/300
# 5/5 - 0s - loss: 0.0072 - 24ms/epoch - 5ms/step
# Epoch 30/300
# 5/5 - 0s - loss: 0.0067 - 26ms/epoch - 5ms/step
# Epoch 31/300
# 5/5 - 0s - loss: 0.0063 - 27ms/epoch - 5ms/step
# Epoch 32/300
# 5/5 - 0s - loss: 0.0061 - 26ms/epoch - 5ms/step
# Epoch 33/300
# 5/5 - 0s - loss: 0.0054 - 25ms/epoch - 5ms/step
# Epoch 34/300
# 5/5 - 0s - loss: 0.0052 - 23ms/epoch - 5ms/step
# Epoch 35/300
# 5/5 - 0s - loss: 0.0047 - 26ms/epoch - 5ms/step
# Epoch 36/300
# 5/5 - 0s - loss: 0.0043 - 27ms/epoch - 5ms/step
# Epoch 37/300
# 5/5 - 0s - loss: 0.0041 - 27ms/epoch - 5ms/step
# Epoch 38/300
# 5/5 - 0s - loss: 0.0037 - 26ms/epoch - 5ms/step
# Epoch 39/300
# 5/5 - 0s - loss: 0.0034 - 28ms/epoch - 6ms/step
# Epoch 40/300
# 5/5 - 0s - loss: 0.0031 - 26ms/epoch - 5ms/step
# Epoch 41/300
# 5/5 - 0s - loss: 0.0029 - 28ms/epoch - 6ms/step
# Epoch 42/300
# 5/5 - 0s - loss: 0.0027 - 28ms/epoch - 6ms/step
# Epoch 43/300
# 5/5 - 0s - loss: 0.0023 - 26ms/epoch - 5ms/step
# Epoch 44/300
# 5/5 - 0s - loss: 0.0021 - 26ms/epoch - 5ms/step
# Epoch 45/300
# 5/5 - 0s - loss: 0.0019 - 25ms/epoch - 5ms/step
# Epoch 46/300
# 5/5 - 0s - loss: 0.0017 - 24ms/epoch - 5ms/step
# Epoch 47/300
# 5/5 - 0s - loss: 0.0015 - 26ms/epoch - 5ms/step
# Epoch 48/300
# 5/5 - 0s - loss: 0.0014 - 29ms/epoch - 6ms/step
# Epoch 49/300
# 5/5 - 0s - loss: 0.0011 - 27ms/epoch - 5ms/step
# Epoch 50/300
# 5/5 - 0s - loss: 0.0010 - 27ms/epoch - 5ms/step
# Epoch 51/300
# 5/5 - 0s - loss: 9.0691e-04 - 26ms/epoch - 5ms/step
# Epoch 52/300
# 5/5 - 0s - loss: 8.0082e-04 - 26ms/epoch - 5ms/step
# Epoch 53/300
# 5/5 - 0s - loss: 6.7503e-04 - 29ms/epoch - 6ms/step
# Epoch 54/300
# 5/5 - 0s - loss: 5.8645e-04 - 28ms/epoch - 6ms/step
# Epoch 55/300
# 5/5 - 0s - loss: 5.0179e-04 - 25ms/epoch - 5ms/step
# Epoch 56/300
# 5/5 - 0s - loss: 4.5317e-04 - 28ms/epoch - 6ms/step
# Epoch 57/300
# 5/5 - 0s - loss: 3.7519e-04 - 26ms/epoch - 5ms/step
# Epoch 58/300
# 5/5 - 0s - loss: 3.1200e-04 - 25ms/epoch - 5ms/step
# Epoch 59/300
# 5/5 - 0s - loss: 2.7301e-04 - 28ms/epoch - 6ms/step
# Epoch 60/300
# 5/5 - 0s - loss: 2.3963e-04 - 24ms/epoch - 5ms/step
# Epoch 61/300
# 5/5 - 0s - loss: 2.0636e-04 - 24ms/epoch - 5ms/step
# Epoch 62/300
# 5/5 - 0s - loss: 1.5804e-04 - 27ms/epoch - 5ms/step
# Epoch 63/300
# 5/5 - 0s - loss: 1.3676e-04 - 26ms/epoch - 5ms/step
# Epoch 64/300
# 5/5 - 0s - loss: 1.0720e-04 - 27ms/epoch - 5ms/step
# Epoch 65/300
# 5/5 - 0s - loss: 8.9355e-05 - 24ms/epoch - 5ms/step
# Epoch 66/300
# 5/5 - 0s - loss: 7.5043e-05 - 27ms/epoch - 5ms/step
# Epoch 67/300
# 5/5 - 0s - loss: 6.6101e-05 - 26ms/epoch - 5ms/step
# Epoch 68/300
# 5/5 - 0s - loss: 5.3283e-05 - 28ms/epoch - 6ms/step
# Epoch 69/300
# 5/5 - 0s - loss: 4.1829e-05 - 27ms/epoch - 5ms/step
# Epoch 70/300
# 5/5 - 0s - loss: 3.6624e-05 - 27ms/epoch - 5ms/step
# Epoch 71/300
# 5/5 - 0s - loss: 3.1451e-05 - 24ms/epoch - 5ms/step
# Epoch 72/300
# 5/5 - 0s - loss: 2.4561e-05 - 26ms/epoch - 5ms/step
# Epoch 73/300
# 5/5 - 0s - loss: 2.2030e-05 - 27ms/epoch - 5ms/step
# Epoch 74/300
# 5/5 - 0s - loss: 1.7126e-05 - 25ms/epoch - 5ms/step
# Epoch 75/300
# 5/5 - 0s - loss: 1.4697e-05 - 27ms/epoch - 5ms/step
# Epoch 76/300
# 5/5 - 0s - loss: 1.3189e-05 - 27ms/epoch - 5ms/step
# Epoch 77/300
# 5/5 - 0s - loss: 1.1944e-05 - 24ms/epoch - 5ms/step
# Epoch 78/300
# 5/5 - 0s - loss: 1.0383e-05 - 24ms/epoch - 5ms/step
# Epoch 79/300
# 5/5 - 0s - loss: 9.4981e-06 - 25ms/epoch - 5ms/step
# Epoch 80/300
# 5/5 - 0s - loss: 8.0653e-06 - 23ms/epoch - 5ms/step
# Epoch 81/300
# 5/5 - 0s - loss: 7.5667e-06 - 23ms/epoch - 5ms/step
# Epoch 82/300
# 5/5 - 0s - loss: 7.3320e-06 - 26ms/epoch - 5ms/step
# Epoch 83/300
# 5/5 - 0s - loss: 6.4201e-06 - 25ms/epoch - 5ms/step
# Epoch 84/300
# 5/5 - 0s - loss: 5.9889e-06 - 24ms/epoch - 5ms/step
# Epoch 85/300
# 5/5 - 0s - loss: 5.6173e-06 - 24ms/epoch - 5ms/step
# Epoch 86/300
# 5/5 - 0s - loss: 4.9802e-06 - 26ms/epoch - 5ms/step
# Epoch 87/300
# 5/5 - 0s - loss: 5.2195e-06 - 26ms/epoch - 5ms/step
# Epoch 88/300
# 5/5 - 0s - loss: 4.3427e-06 - 27ms/epoch - 5ms/step
# Epoch 89/300
# 5/5 - 0s - loss: 4.1799e-06 - 27ms/epoch - 5ms/step
# Epoch 90/300
# 5/5 - 0s - loss: 3.9048e-06 - 25ms/epoch - 5ms/step
# Epoch 91/300
# 5/5 - 0s - loss: 3.7584e-06 - 28ms/epoch - 6ms/step
# Epoch 92/300
# 5/5 - 0s - loss: 4.1484e-06 - 27ms/epoch - 5ms/step
# Epoch 93/300
# 5/5 - 0s - loss: 4.0613e-06 - 28ms/epoch - 6ms/step
# Epoch 94/300
# 5/5 - 0s - loss: 3.7491e-06 - 31ms/epoch - 6ms/step
# Epoch 95/300
# 5/5 - 0s - loss: 3.9945e-06 - 27ms/epoch - 5ms/step
# Epoch 96/300
# 5/5 - 0s - loss: 3.3789e-06 - 25ms/epoch - 5ms/step
# Epoch 97/300
# 5/5 - 0s - loss: 3.2795e-06 - 28ms/epoch - 6ms/step
# Epoch 98/300
# 5/5 - 0s - loss: 2.8691e-06 - 28ms/epoch - 6ms/step
# Epoch 99/300
# 5/5 - 0s - loss: 2.6297e-06 - 30ms/epoch - 6ms/step
# Epoch 100/300
# 5/5 - 0s - loss: 2.7042e-06 - 29ms/epoch - 6ms/step
# Epoch 101/300
# 5/5 - 0s - loss: 2.6423e-06 - 28ms/epoch - 6ms/step
# Epoch 102/300
# 5/5 - 0s - loss: 2.4258e-06 - 26ms/epoch - 5ms/step
# Epoch 103/300
# 5/5 - 0s - loss: 2.4423e-06 - 25ms/epoch - 5ms/step
# Epoch 104/300
# 5/5 - 0s - loss: 2.2203e-06 - 26ms/epoch - 5ms/step
# Epoch 105/300
# 5/5 - 0s - loss: 2.0986e-06 - 25ms/epoch - 5ms/step
# Epoch 106/300
# 5/5 - 0s - loss: 2.1456e-06 - 24ms/epoch - 5ms/step
# Epoch 107/300
# 5/5 - 0s - loss: 1.9309e-06 - 27ms/epoch - 5ms/step
# Epoch 108/300
# 5/5 - 0s - loss: 1.9350e-06 - 25ms/epoch - 5ms/step
# Epoch 109/300
# 5/5 - 0s - loss: 1.8958e-06 - 26ms/epoch - 5ms/step
# Epoch 110/300
# 5/5 - 0s - loss: 1.8650e-06 - 27ms/epoch - 5ms/step
# Epoch 111/300
# 5/5 - 0s - loss: 1.7533e-06 - 27ms/epoch - 5ms/step
# Epoch 112/300
# 5/5 - 0s - loss: 1.7389e-06 - 28ms/epoch - 6ms/step
# Epoch 113/300
# 5/5 - 0s - loss: 1.6901e-06 - 26ms/epoch - 5ms/step
# Epoch 114/300
# 5/5 - 0s - loss: 1.6121e-06 - 28ms/epoch - 6ms/step
# Epoch 115/300
# 5/5 - 0s - loss: 1.6668e-06 - 25ms/epoch - 5ms/step
# Epoch 116/300
# 5/5 - 0s - loss: 1.9010e-06 - 24ms/epoch - 5ms/step
# Epoch 117/300
# 5/5 - 0s - loss: 1.5653e-06 - 24ms/epoch - 5ms/step
# Epoch 118/300
# 5/5 - 0s - loss: 1.6493e-06 - 24ms/epoch - 5ms/step
# Epoch 119/300
# 5/5 - 0s - loss: 1.3183e-06 - 25ms/epoch - 5ms/step
# Epoch 120/300
# 5/5 - 0s - loss: 1.3345e-06 - 26ms/epoch - 5ms/step
# Epoch 121/300
# 5/5 - 0s - loss: 1.2736e-06 - 27ms/epoch - 5ms/step
# Epoch 122/300
# 5/5 - 0s - loss: 1.3069e-06 - 28ms/epoch - 6ms/step
# Epoch 123/300
# 5/5 - 0s - loss: 1.2626e-06 - 31ms/epoch - 6ms/step
# Epoch 124/300
# 5/5 - 0s - loss: 1.1161e-06 - 31ms/epoch - 6ms/step
# Epoch 125/300
# 5/5 - 0s - loss: 1.1378e-06 - 27ms/epoch - 5ms/step
# Epoch 126/300
# 5/5 - 0s - loss: 1.1742e-06 - 27ms/epoch - 5ms/step
# Epoch 127/300
# 5/5 - 0s - loss: 1.4679e-06 - 26ms/epoch - 5ms/step
# Epoch 128/300
# 5/5 - 0s - loss: 1.3641e-06 - 25ms/epoch - 5ms/step
# Epoch 129/300
# 5/5 - 0s - loss: 1.5349e-06 - 27ms/epoch - 5ms/step
# Epoch 130/300
# 5/5 - 0s - loss: 1.3226e-06 - 26ms/epoch - 5ms/step
# Epoch 131/300
# 5/5 - 0s - loss: 1.0903e-06 - 26ms/epoch - 5ms/step
# Epoch 132/300
# 5/5 - 0s - loss: 1.0760e-06 - 28ms/epoch - 6ms/step
# Epoch 133/300
# 5/5 - 0s - loss: 1.1209e-06 - 27ms/epoch - 5ms/step
# Epoch 134/300
# 5/5 - 0s - loss: 1.0920e-06 - 28ms/epoch - 6ms/step
# Epoch 135/300
# 5/5 - 0s - loss: 9.3342e-07 - 29ms/epoch - 6ms/step
# Epoch 136/300
# 5/5 - 0s - loss: 1.1304e-06 - 26ms/epoch - 5ms/step
# Epoch 137/300
# 5/5 - 0s - loss: 1.1282e-06 - 25ms/epoch - 5ms/step
# Epoch 138/300
# 5/5 - 0s - loss: 9.4176e-07 - 27ms/epoch - 5ms/step
# Epoch 139/300
# 5/5 - 0s - loss: 8.5473e-07 - 25ms/epoch - 5ms/step
# Epoch 140/300
# 5/5 - 0s - loss: 9.8136e-07 - 26ms/epoch - 5ms/step
# Epoch 141/300
# 5/5 - 0s - loss: 8.8674e-07 - 24ms/epoch - 5ms/step
# Epoch 142/300
# 5/5 - 0s - loss: 1.0144e-06 - 25ms/epoch - 5ms/step
# Epoch 143/300
# 5/5 - 0s - loss: 1.1034e-06 - 27ms/epoch - 5ms/step
# Epoch 144/300
# 5/5 - 0s - loss: 1.0984e-06 - 26ms/epoch - 5ms/step
# Epoch 145/300
# 5/5 - 0s - loss: 8.5724e-07 - 29ms/epoch - 6ms/step
# Epoch 146/300
# 5/5 - 0s - loss: 8.2154e-07 - 30ms/epoch - 6ms/step
# Epoch 147/300
# 5/5 - 0s - loss: 7.5246e-07 - 27ms/epoch - 5ms/step
# Epoch 148/300
# 5/5 - 0s - loss: 6.5978e-07 - 27ms/epoch - 5ms/step
# Epoch 149/300
# 5/5 - 0s - loss: 6.2498e-07 - 27ms/epoch - 5ms/step
# Epoch 150/300
# 5/5 - 0s - loss: 6.5908e-07 - 25ms/epoch - 5ms/step
# Epoch 151/300
# 5/5 - 0s - loss: 6.8851e-07 - 27ms/epoch - 5ms/step
# Epoch 152/300
# 5/5 - 0s - loss: 7.0800e-07 - 28ms/epoch - 6ms/step
# Epoch 153/300
# 5/5 - 0s - loss: 7.1528e-07 - 27ms/epoch - 5ms/step
# Epoch 154/300
# 5/5 - 0s - loss: 7.0521e-07 - 27ms/epoch - 5ms/step
# Epoch 155/300
# 5/5 - 0s - loss: 7.5810e-07 - 29ms/epoch - 6ms/step
# Epoch 156/300
# 5/5 - 0s - loss: 6.1296e-07 - 29ms/epoch - 6ms/step
# Epoch 157/300
# 5/5 - 0s - loss: 5.7564e-07 - 28ms/epoch - 6ms/step
# Epoch 158/300
# 5/5 - 0s - loss: 5.3981e-07 - 28ms/epoch - 6ms/step
# Epoch 159/300
# 5/5 - 0s - loss: 5.4141e-07 - 28ms/epoch - 6ms/step
# Epoch 160/300
# 5/5 - 0s - loss: 6.1455e-07 - 28ms/epoch - 6ms/step
# Epoch 161/300
# 5/5 - 0s - loss: 7.1499e-07 - 27ms/epoch - 5ms/step
# Epoch 162/300
# 5/5 - 0s - loss: 6.2613e-07 - 28ms/epoch - 6ms/step
# Epoch 163/300
# 5/5 - 0s - loss: 5.0069e-07 - 27ms/epoch - 5ms/step
# Epoch 164/300
# 5/5 - 0s - loss: 4.9883e-07 - 27ms/epoch - 5ms/step
# Epoch 165/300
# 5/5 - 0s - loss: 5.3732e-07 - 26ms/epoch - 5ms/step
# Epoch 166/300
# 5/5 - 0s - loss: 4.8564e-07 - 26ms/epoch - 5ms/step
# Epoch 167/300
# 5/5 - 0s - loss: 5.1448e-07 - 27ms/epoch - 5ms/step
# Epoch 168/300
# 5/5 - 0s - loss: 4.9843e-07 - 27ms/epoch - 5ms/step
# Epoch 169/300
# 5/5 - 0s - loss: 5.4077e-07 - 26ms/epoch - 5ms/step
# Epoch 170/300
# 5/5 - 0s - loss: 4.4763e-07 - 27ms/epoch - 5ms/step
# Epoch 171/300
# 5/5 - 0s - loss: 5.2394e-07 - 25ms/epoch - 5ms/step
# Epoch 172/300
# 5/5 - 0s - loss: 4.8791e-07 - 27ms/epoch - 5ms/step
# Epoch 173/300
# 5/5 - 0s - loss: 4.9809e-07 - 24ms/epoch - 5ms/step
# Epoch 174/300
# 5/5 - 0s - loss: 4.5782e-07 - 28ms/epoch - 6ms/step
# Epoch 175/300
# 5/5 - 0s - loss: 3.9888e-07 - 23ms/epoch - 5ms/step
# Epoch 176/300
# 5/5 - 0s - loss: 3.7722e-07 - 25ms/epoch - 5ms/step
# Epoch 177/300
# 5/5 - 0s - loss: 3.9792e-07 - 24ms/epoch - 5ms/step
# Epoch 178/300
# 5/5 - 0s - loss: 3.8475e-07 - 25ms/epoch - 5ms/step
# Epoch 179/300
# 5/5 - 0s - loss: 3.6865e-07 - 25ms/epoch - 5ms/step
# Epoch 180/300
# 5/5 - 0s - loss: 3.7711e-07 - 26ms/epoch - 5ms/step
# Epoch 181/300
# 5/5 - 0s - loss: 4.6789e-07 - 26ms/epoch - 5ms/step
# Epoch 182/300
# 5/5 - 0s - loss: 4.5524e-07 - 24ms/epoch - 5ms/step
# Epoch 183/300
# 5/5 - 0s - loss: 3.9292e-07 - 29ms/epoch - 6ms/step
# Epoch 184/300
# 5/5 - 0s - loss: 3.7616e-07 - 30ms/epoch - 6ms/step
# Epoch 185/300
# 5/5 - 0s - loss: 4.3788e-07 - 28ms/epoch - 6ms/step
# Epoch 186/300
# 5/5 - 0s - loss: 5.3166e-07 - 26ms/epoch - 5ms/step
# Epoch 187/300
# 5/5 - 0s - loss: 5.0606e-07 - 24ms/epoch - 5ms/step
# Epoch 188/300
# 5/5 - 0s - loss: 4.5534e-07 - 26ms/epoch - 5ms/step
# Epoch 189/300
# 5/5 - 0s - loss: 4.0217e-07 - 25ms/epoch - 5ms/step
# Epoch 190/300
# 5/5 - 0s - loss: 4.9981e-07 - 25ms/epoch - 5ms/step
# Epoch 191/300
# 5/5 - 0s - loss: 4.4383e-07 - 25ms/epoch - 5ms/step
# Epoch 192/300
# 5/5 - 0s - loss: 3.5734e-07 - 24ms/epoch - 5ms/step
# Epoch 193/300
# 5/5 - 0s - loss: 4.4640e-07 - 26ms/epoch - 5ms/step
# Epoch 194/300
# 5/5 - 0s - loss: 4.4431e-07 - 27ms/epoch - 5ms/step
# Epoch 195/300
# 5/5 - 0s - loss: 3.5462e-07 - 28ms/epoch - 6ms/step
# Epoch 196/300
# 5/5 - 0s - loss: 4.6351e-07 - 28ms/epoch - 6ms/step
# Epoch 197/300
# 5/5 - 0s - loss: 3.8793e-07 - 27ms/epoch - 5ms/step
# Epoch 198/300
# 5/5 - 0s - loss: 3.3312e-07 - 29ms/epoch - 6ms/step
# Epoch 199/300
# 5/5 - 0s - loss: 3.4492e-07 - 24ms/epoch - 5ms/step
# Epoch 200/300
# 5/5 - 0s - loss: 3.1025e-07 - 25ms/epoch - 5ms/step
# Epoch 201/300
# 5/5 - 0s - loss: 2.9262e-07 - 27ms/epoch - 5ms/step
# Epoch 202/300
# 5/5 - 0s - loss: 3.2544e-07 - 27ms/epoch - 5ms/step
# Epoch 203/300
# 5/5 - 0s - loss: 4.1766e-07 - 28ms/epoch - 6ms/step
# Epoch 204/300
# 5/5 - 0s - loss: 3.7724e-07 - 24ms/epoch - 5ms/step
# Epoch 205/300
# 5/5 - 0s - loss: 4.0828e-07 - 28ms/epoch - 6ms/step
# Epoch 206/300
# 5/5 - 0s - loss: 5.4049e-07 - 28ms/epoch - 6ms/step
# Epoch 207/300
# 5/5 - 0s - loss: 5.1590e-07 - 25ms/epoch - 5ms/step
# Epoch 208/300
# 5/5 - 0s - loss: 5.5099e-07 - 26ms/epoch - 5ms/step
# Epoch 209/300
# 5/5 - 0s - loss: 3.1373e-07 - 27ms/epoch - 5ms/step
# Epoch 210/300
# 5/5 - 0s - loss: 3.8812e-07 - 28ms/epoch - 6ms/step
# Epoch 211/300
# 5/5 - 0s - loss: 4.1871e-07 - 27ms/epoch - 5ms/step
# Epoch 212/300
# 5/5 - 0s - loss: 3.3410e-07 - 28ms/epoch - 6ms/step
# Epoch 213/300
# 5/5 - 0s - loss: 2.9929e-07 - 28ms/epoch - 6ms/step
# Epoch 214/300
# 5/5 - 0s - loss: 2.5788e-07 - 27ms/epoch - 5ms/step
# Epoch 215/300
# 5/5 - 0s - loss: 2.4197e-07 - 26ms/epoch - 5ms/step
# Epoch 216/300
# 5/5 - 0s - loss: 2.7884e-07 - 25ms/epoch - 5ms/step
# Epoch 217/300
# 5/5 - 0s - loss: 2.3084e-07 - 26ms/epoch - 5ms/step
# Epoch 218/300
# 5/5 - 0s - loss: 2.4504e-07 - 24ms/epoch - 5ms/step
# Epoch 219/300
# 5/5 - 0s - loss: 2.3375e-07 - 26ms/epoch - 5ms/step
# Epoch 220/300
# 5/5 - 0s - loss: 2.2151e-07 - 25ms/epoch - 5ms/step
# Epoch 221/300
# 5/5 - 0s - loss: 2.5833e-07 - 27ms/epoch - 5ms/step
# Epoch 222/300
# 5/5 - 0s - loss: 2.4699e-07 - 27ms/epoch - 5ms/step
# Epoch 223/300
# 5/5 - 0s - loss: 2.8714e-07 - 24ms/epoch - 5ms/step
# Epoch 224/300
# 5/5 - 0s - loss: 2.9584e-07 - 24ms/epoch - 5ms/step
# Epoch 225/300
# 5/5 - 0s - loss: 2.3999e-07 - 26ms/epoch - 5ms/step
# Epoch 226/300
# 5/5 - 0s - loss: 2.9493e-07 - 25ms/epoch - 5ms/step
# Epoch 227/300
# 5/5 - 0s - loss: 3.1231e-07 - 25ms/epoch - 5ms/step
# Epoch 228/300
# 5/5 - 0s - loss: 3.6971e-07 - 27ms/epoch - 5ms/step
# Epoch 229/300
# 5/5 - 0s - loss: 2.5639e-07 - 29ms/epoch - 6ms/step
# Epoch 230/300
# 5/5 - 0s - loss: 2.2809e-07 - 26ms/epoch - 5ms/step
# Epoch 231/300
# 5/5 - 0s - loss: 2.4736e-07 - 26ms/epoch - 5ms/step
# Epoch 232/300
# 5/5 - 0s - loss: 2.3400e-07 - 25ms/epoch - 5ms/step
# Epoch 233/300
# 5/5 - 0s - loss: 2.7889e-07 - 25ms/epoch - 5ms/step
# Epoch 234/300
# 5/5 - 0s - loss: 3.0827e-07 - 27ms/epoch - 5ms/step
# Epoch 235/300
# 5/5 - 0s - loss: 2.3545e-07 - 29ms/epoch - 6ms/step
# Epoch 236/300
# 5/5 - 0s - loss: 2.6544e-07 - 27ms/epoch - 5ms/step
# Epoch 237/300
# 5/5 - 0s - loss: 2.4905e-07 - 27ms/epoch - 5ms/step
# Epoch 238/300
# 5/5 - 0s - loss: 2.0527e-07 - 29ms/epoch - 6ms/step
# Epoch 239/300
# 5/5 - 0s - loss: 2.3071e-07 - 30ms/epoch - 6ms/step
# Epoch 240/300
# 5/5 - 0s - loss: 1.9440e-07 - 25ms/epoch - 5ms/step
# Epoch 241/300
# 5/5 - 0s - loss: 2.4956e-07 - 27ms/epoch - 5ms/step
# Epoch 242/300
# 5/5 - 0s - loss: 2.3885e-07 - 28ms/epoch - 6ms/step
# Epoch 243/300
# 5/5 - 0s - loss: 2.0695e-07 - 28ms/epoch - 6ms/step
# Epoch 244/300
# 5/5 - 0s - loss: 2.2304e-07 - 27ms/epoch - 5ms/step
# Epoch 245/300
# 5/5 - 0s - loss: 2.4794e-07 - 30ms/epoch - 6ms/step
# Epoch 246/300
# 5/5 - 0s - loss: 1.9909e-07 - 28ms/epoch - 6ms/step
# Epoch 247/300
# 5/5 - 0s - loss: 2.6486e-07 - 27ms/epoch - 5ms/step
# Epoch 248/300
# 5/5 - 0s - loss: 2.4371e-07 - 28ms/epoch - 6ms/step
# Epoch 249/300
# 5/5 - 0s - loss: 3.0709e-07 - 26ms/epoch - 5ms/step
# Epoch 250/300
# 5/5 - 0s - loss: 2.1369e-07 - 27ms/epoch - 5ms/step
# Epoch 251/300
# 5/5 - 0s - loss: 2.7289e-07 - 29ms/epoch - 6ms/step
# Epoch 252/300
# 5/5 - 0s - loss: 2.5819e-07 - 29ms/epoch - 6ms/step
# Epoch 253/300
# 5/5 - 0s - loss: 1.9571e-07 - 31ms/epoch - 6ms/step
# Epoch 254/300
# 5/5 - 0s - loss: 2.0208e-07 - 29ms/epoch - 6ms/step
# Epoch 255/300
# 5/5 - 0s - loss: 2.3755e-07 - 27ms/epoch - 5ms/step
# Epoch 256/300
# 5/5 - 0s - loss: 2.7347e-07 - 28ms/epoch - 6ms/step
# Epoch 257/300
# 5/5 - 0s - loss: 2.6635e-07 - 30ms/epoch - 6ms/step
# Epoch 258/300
# 5/5 - 0s - loss: 2.7615e-07 - 30ms/epoch - 6ms/step
# Epoch 259/300
# 5/5 - 0s - loss: 2.3105e-07 - 30ms/epoch - 6ms/step
# Epoch 260/300
# 5/5 - 0s - loss: 1.7952e-07 - 30ms/epoch - 6ms/step
# Epoch 261/300
# 5/5 - 0s - loss: 1.4728e-07 - 29ms/epoch - 6ms/step
# Epoch 262/300
# 5/5 - 0s - loss: 1.4358e-07 - 29ms/epoch - 6ms/step
# Epoch 263/300
# 5/5 - 0s - loss: 1.4256e-07 - 29ms/epoch - 6ms/step
# Epoch 264/300
# 5/5 - 0s - loss: 1.6017e-07 - 32ms/epoch - 6ms/step
# Epoch 265/300
# 5/5 - 0s - loss: 1.6481e-07 - 32ms/epoch - 6ms/step
# Epoch 266/300
# 5/5 - 0s - loss: 1.4861e-07 - 28ms/epoch - 6ms/step
# Epoch 267/300
# 5/5 - 0s - loss: 1.8801e-07 - 30ms/epoch - 6ms/step
# Epoch 268/300
# 5/5 - 0s - loss: 2.6004e-07 - 26ms/epoch - 5ms/step
# Epoch 269/300
# 5/5 - 0s - loss: 3.7611e-07 - 26ms/epoch - 5ms/step
# Epoch 270/300
# 5/5 - 0s - loss: 1.8970e-07 - 27ms/epoch - 5ms/step
# Epoch 271/300
# 5/5 - 0s - loss: 1.8704e-07 - 27ms/epoch - 5ms/step
# Epoch 272/300
# 5/5 - 0s - loss: 1.8827e-07 - 29ms/epoch - 6ms/step
# Epoch 273/300
# 5/5 - 0s - loss: 2.0758e-07 - 28ms/epoch - 6ms/step
# Epoch 274/300
# 5/5 - 0s - loss: 1.6717e-07 - 30ms/epoch - 6ms/step
# Epoch 275/300
# 5/5 - 0s - loss: 1.2847e-07 - 26ms/epoch - 5ms/step
# Epoch 276/300
# 5/5 - 0s - loss: 1.2280e-07 - 28ms/epoch - 6ms/step
# Epoch 277/300
# 5/5 - 0s - loss: 1.2385e-07 - 29ms/epoch - 6ms/step
# Epoch 278/300
# 5/5 - 0s - loss: 1.4562e-07 - 30ms/epoch - 6ms/step
# Epoch 279/300
# 5/5 - 0s - loss: 1.9968e-07 - 29ms/epoch - 6ms/step
# Epoch 280/300
# 5/5 - 0s - loss: 1.6009e-07 - 31ms/epoch - 6ms/step
# Epoch 281/300
# 5/5 - 0s - loss: 1.2530e-07 - 29ms/epoch - 6ms/step
# Epoch 282/300
# 5/5 - 0s - loss: 1.3327e-07 - 25ms/epoch - 5ms/step
# Epoch 283/300
# 5/5 - 0s - loss: 1.2833e-07 - 29ms/epoch - 6ms/step
# Epoch 284/300
# 5/5 - 0s - loss: 1.4030e-07 - 27ms/epoch - 5ms/step
# Epoch 285/300
# 5/5 - 0s - loss: 1.3684e-07 - 27ms/epoch - 5ms/step
# Epoch 286/300
# 5/5 - 0s - loss: 1.4395e-07 - 26ms/epoch - 5ms/step
# Epoch 287/300
# 5/5 - 0s - loss: 1.3577e-07 - 25ms/epoch - 5ms/step
# Epoch 288/300
# 5/5 - 0s - loss: 1.2965e-07 - 27ms/epoch - 5ms/step
# Epoch 289/300
# 5/5 - 0s - loss: 1.7138e-07 - 27ms/epoch - 5ms/step
# Epoch 290/300
# 5/5 - 0s - loss: 1.3260e-07 - 26ms/epoch - 5ms/step
# Epoch 291/300
# 5/5 - 0s - loss: 1.5672e-07 - 27ms/epoch - 5ms/step
# Epoch 292/300
# 5/5 - 0s - loss: 1.7977e-07 - 28ms/epoch - 6ms/step
# Epoch 293/300
# 5/5 - 0s - loss: 1.6675e-07 - 27ms/epoch - 5ms/step
# Epoch 294/300
# 5/5 - 0s - loss: 1.3655e-07 - 27ms/epoch - 5ms/step
# Epoch 295/300
# 5/5 - 0s - loss: 1.5521e-07 - 26ms/epoch - 5ms/step
# Epoch 296/300
# 5/5 - 0s - loss: 1.9500e-07 - 25ms/epoch - 5ms/step
# Epoch 297/300
# 5/5 - 0s - loss: 1.5364e-07 - 26ms/epoch - 5ms/step
# Epoch 298/300
# 5/5 - 0s - loss: 1.1990e-07 - 24ms/epoch - 5ms/step
# Epoch 299/300
# 5/5 - 0s - loss: 1.3366e-07 - 27ms/epoch - 5ms/step
# Epoch 300/300
# 5/5 - 0s - loss: 1.2080e-07 - 25ms/epoch - 5ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 15/15 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710200768.8761303
# Mon Mar 11 23:46:08 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710200768.8857803
# Mon Mar 11 23:46:08 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 5/5 - 1s - loss: 0.4025 - 629ms/epoch - 126ms/step
# Epoch 2/300
# 5/5 - 0s - loss: 0.1661 - 37ms/epoch - 7ms/step
# Epoch 3/300
# 5/5 - 0s - loss: 0.1227 - 37ms/epoch - 7ms/step
# Epoch 4/300
# 5/5 - 0s - loss: 0.0913 - 42ms/epoch - 8ms/step
# Epoch 5/300
# 5/5 - 0s - loss: 0.0844 - 38ms/epoch - 8ms/step
# Epoch 6/300
# 5/5 - 0s - loss: 0.0849 - 36ms/epoch - 7ms/step
# Epoch 7/300
# 5/5 - 0s - loss: 0.0701 - 39ms/epoch - 8ms/step
# Epoch 8/300
# 5/5 - 0s - loss: 0.0684 - 46ms/epoch - 9ms/step
# Epoch 9/300
# 5/5 - 0s - loss: 0.0633 - 38ms/epoch - 8ms/step
# Epoch 10/300
# 5/5 - 0s - loss: 0.0717 - 38ms/epoch - 8ms/step
# Epoch 11/300
# 5/5 - 0s - loss: 0.0609 - 38ms/epoch - 8ms/step
# Epoch 12/300
# 5/5 - 0s - loss: 0.0657 - 43ms/epoch - 9ms/step
# Epoch 13/300
# 5/5 - 0s - loss: 0.0565 - 34ms/epoch - 7ms/step
# Epoch 14/300
# 5/5 - 0s - loss: 0.0511 - 39ms/epoch - 8ms/step
# Epoch 15/300
# 5/5 - 0s - loss: 0.0540 - 41ms/epoch - 8ms/step
# Epoch 16/300
# 5/5 - 0s - loss: 0.0522 - 38ms/epoch - 8ms/step
# Epoch 17/300
# 5/5 - 0s - loss: 0.0484 - 37ms/epoch - 7ms/step
# Epoch 18/300
# 5/5 - 0s - loss: 0.0484 - 36ms/epoch - 7ms/step
# Epoch 19/300
# 5/5 - 0s - loss: 0.0494 - 36ms/epoch - 7ms/step
# Epoch 20/300
# 5/5 - 0s - loss: 0.0534 - 36ms/epoch - 7ms/step
# Epoch 21/300
# 5/5 - 0s - loss: 0.0527 - 34ms/epoch - 7ms/step
# Epoch 22/300
# 5/5 - 0s - loss: 0.0515 - 40ms/epoch - 8ms/step
# Epoch 23/300
# 5/5 - 0s - loss: 0.0528 - 41ms/epoch - 8ms/step
# Epoch 24/300
# 5/5 - 0s - loss: 0.0515 - 39ms/epoch - 8ms/step
# Epoch 25/300
# 5/5 - 0s - loss: 0.0473 - 39ms/epoch - 8ms/step
# Epoch 26/300
# 5/5 - 0s - loss: 0.0372 - 44ms/epoch - 9ms/step
# Epoch 27/300
# 5/5 - 0s - loss: 0.0350 - 35ms/epoch - 7ms/step
# Epoch 28/300
# 5/5 - 0s - loss: 0.0316 - 39ms/epoch - 8ms/step
# Epoch 29/300
# 5/5 - 0s - loss: 0.0294 - 38ms/epoch - 8ms/step
# Epoch 30/300
# 5/5 - 0s - loss: 0.0359 - 41ms/epoch - 8ms/step
# Epoch 31/300
# 5/5 - 0s - loss: 0.0311 - 35ms/epoch - 7ms/step
# Epoch 32/300
# 5/5 - 0s - loss: 0.0343 - 37ms/epoch - 7ms/step
# Epoch 33/300
# 5/5 - 0s - loss: 0.0439 - 38ms/epoch - 8ms/step
# Epoch 34/300
# 5/5 - 0s - loss: 0.0348 - 37ms/epoch - 7ms/step
# Epoch 35/300
# 5/5 - 0s - loss: 0.0327 - 41ms/epoch - 8ms/step
# Epoch 36/300
# 5/5 - 0s - loss: 0.0339 - 38ms/epoch - 8ms/step
# Epoch 37/300
# 5/5 - 0s - loss: 0.0338 - 35ms/epoch - 7ms/step
# Epoch 38/300
# 5/5 - 0s - loss: 0.0205 - 37ms/epoch - 7ms/step
# Epoch 39/300
# 5/5 - 0s - loss: 0.0181 - 42ms/epoch - 8ms/step
# Epoch 40/300
# 5/5 - 0s - loss: 0.0165 - 36ms/epoch - 7ms/step
# Epoch 41/300
# 5/5 - 0s - loss: 0.0148 - 39ms/epoch - 8ms/step
# Epoch 42/300
# 5/5 - 0s - loss: 0.0150 - 39ms/epoch - 8ms/step
# Epoch 43/300
# 5/5 - 0s - loss: 0.0151 - 44ms/epoch - 9ms/step
# Epoch 44/300
# 5/5 - 0s - loss: 0.0126 - 38ms/epoch - 8ms/step
# Epoch 45/300
# 5/5 - 0s - loss: 0.0100 - 41ms/epoch - 8ms/step
# Epoch 46/300
# 5/5 - 0s - loss: 0.0092 - 42ms/epoch - 8ms/step
# Epoch 47/300
# 5/5 - 0s - loss: 0.0086 - 43ms/epoch - 9ms/step
# Epoch 48/300
# 5/5 - 0s - loss: 0.0088 - 40ms/epoch - 8ms/step
# Epoch 49/300
# 5/5 - 0s - loss: 0.0098 - 40ms/epoch - 8ms/step
# Epoch 50/300
# 5/5 - 0s - loss: 0.0154 - 38ms/epoch - 8ms/step
# Epoch 51/300
# 5/5 - 0s - loss: 0.0131 - 38ms/epoch - 8ms/step
# Epoch 52/300
# 5/5 - 0s - loss: 0.0097 - 38ms/epoch - 8ms/step
# Epoch 53/300
# 5/5 - 0s - loss: 0.0119 - 43ms/epoch - 9ms/step
# Epoch 54/300
# 5/5 - 0s - loss: 0.0109 - 37ms/epoch - 7ms/step
# Epoch 55/300
# 5/5 - 0s - loss: 0.0114 - 39ms/epoch - 8ms/step
# Epoch 56/300
# 5/5 - 0s - loss: 0.0107 - 41ms/epoch - 8ms/step
# Epoch 57/300
# 5/5 - 0s - loss: 0.0073 - 39ms/epoch - 8ms/step
# Epoch 58/300
# 5/5 - 0s - loss: 0.0059 - 36ms/epoch - 7ms/step
# Epoch 59/300
# 5/5 - 0s - loss: 0.0048 - 39ms/epoch - 8ms/step
# Epoch 60/300
# 5/5 - 0s - loss: 0.0030 - 37ms/epoch - 7ms/step
# Epoch 61/300
# 5/5 - 0s - loss: 0.0040 - 45ms/epoch - 9ms/step
# Epoch 62/300
# 5/5 - 0s - loss: 0.0047 - 39ms/epoch - 8ms/step
# Epoch 63/300
# 5/5 - 0s - loss: 0.0054 - 38ms/epoch - 8ms/step
# Epoch 64/300
# 5/5 - 0s - loss: 0.0045 - 34ms/epoch - 7ms/step
# Epoch 65/300
# 5/5 - 0s - loss: 0.0036 - 40ms/epoch - 8ms/step
# Epoch 66/300
# 5/5 - 0s - loss: 0.0029 - 37ms/epoch - 7ms/step
# Epoch 67/300
# 5/5 - 0s - loss: 0.0024 - 37ms/epoch - 7ms/step
# Epoch 68/300
# 5/5 - 0s - loss: 0.0023 - 42ms/epoch - 8ms/step
# Epoch 69/300
# 5/5 - 0s - loss: 0.0017 - 40ms/epoch - 8ms/step
# Epoch 70/300
# 5/5 - 0s - loss: 0.0017 - 40ms/epoch - 8ms/step
# Epoch 71/300
# 5/5 - 0s - loss: 8.8684e-04 - 42ms/epoch - 8ms/step
# Epoch 72/300
# 5/5 - 0s - loss: 8.3815e-04 - 43ms/epoch - 9ms/step
# Epoch 73/300
# 5/5 - 0s - loss: 7.3529e-04 - 40ms/epoch - 8ms/step
# Epoch 74/300
# 5/5 - 0s - loss: 0.0011 - 44ms/epoch - 9ms/step
# Epoch 75/300
# 5/5 - 0s - loss: 0.0011 - 39ms/epoch - 8ms/step
# Epoch 76/300
# 5/5 - 0s - loss: 9.7415e-04 - 42ms/epoch - 8ms/step
# Epoch 77/300
# 5/5 - 0s - loss: 0.0012 - 35ms/epoch - 7ms/step
# Epoch 78/300
# 5/5 - 0s - loss: 9.6849e-04 - 36ms/epoch - 7ms/step
# Epoch 79/300
# 5/5 - 0s - loss: 0.0017 - 41ms/epoch - 8ms/step
# Epoch 80/300
# 5/5 - 0s - loss: 0.0017 - 44ms/epoch - 9ms/step
# Epoch 81/300
# 5/5 - 0s - loss: 0.0014 - 41ms/epoch - 8ms/step
# Epoch 82/300
# 5/5 - 0s - loss: 0.0014 - 41ms/epoch - 8ms/step
# Epoch 83/300
# 5/5 - 0s - loss: 0.0011 - 39ms/epoch - 8ms/step
# Epoch 84/300
# 5/5 - 0s - loss: 8.4316e-04 - 39ms/epoch - 8ms/step
# Epoch 85/300
# 5/5 - 0s - loss: 6.7846e-04 - 43ms/epoch - 9ms/step
# Epoch 86/300
# 5/5 - 0s - loss: 7.1561e-04 - 37ms/epoch - 7ms/step
# Epoch 87/300
# 5/5 - 0s - loss: 7.2385e-04 - 39ms/epoch - 8ms/step
# Epoch 88/300
# 5/5 - 0s - loss: 0.0012 - 37ms/epoch - 7ms/step
# Epoch 89/300
# 5/5 - 0s - loss: 0.0015 - 38ms/epoch - 8ms/step
# Epoch 90/300
# 5/5 - 0s - loss: 0.0011 - 38ms/epoch - 8ms/step
# Epoch 91/300
# 5/5 - 0s - loss: 0.0012 - 40ms/epoch - 8ms/step
# Epoch 92/300
# 5/5 - 0s - loss: 0.0016 - 41ms/epoch - 8ms/step
# Epoch 93/300
# 5/5 - 0s - loss: 0.0015 - 37ms/epoch - 7ms/step
# Epoch 94/300
# 5/5 - 0s - loss: 0.0011 - 38ms/epoch - 8ms/step
# Epoch 95/300
# 5/5 - 0s - loss: 7.0848e-04 - 42ms/epoch - 8ms/step
# Epoch 96/300
# 5/5 - 0s - loss: 5.1028e-04 - 39ms/epoch - 8ms/step
# Epoch 97/300
# 5/5 - 0s - loss: 6.5056e-04 - 38ms/epoch - 8ms/step
# Epoch 98/300
# 5/5 - 0s - loss: 0.0010 - 38ms/epoch - 8ms/step
# Epoch 99/300
# 5/5 - 0s - loss: 8.8861e-04 - 37ms/epoch - 7ms/step
# Epoch 100/300
# 5/5 - 0s - loss: 3.1759e-04 - 36ms/epoch - 7ms/step
# Epoch 101/300
# 5/5 - 0s - loss: 2.2859e-04 - 41ms/epoch - 8ms/step
# Epoch 102/300
# 5/5 - 0s - loss: 2.6968e-04 - 35ms/epoch - 7ms/step
# Epoch 103/300
# 5/5 - 0s - loss: 5.9288e-04 - 38ms/epoch - 8ms/step
# Epoch 104/300
# 5/5 - 0s - loss: 4.1114e-04 - 36ms/epoch - 7ms/step
# Epoch 105/300
# 5/5 - 0s - loss: 5.5242e-04 - 36ms/epoch - 7ms/step
# Epoch 106/300
# 5/5 - 0s - loss: 5.1729e-04 - 36ms/epoch - 7ms/step
# Epoch 107/300
# 5/5 - 0s - loss: 4.7530e-04 - 35ms/epoch - 7ms/step
# Epoch 108/300
# 5/5 - 0s - loss: 5.4243e-04 - 37ms/epoch - 7ms/step
# Epoch 109/300
# 5/5 - 0s - loss: 5.4875e-04 - 38ms/epoch - 8ms/step
# Epoch 110/300
# 5/5 - 0s - loss: 4.9487e-04 - 40ms/epoch - 8ms/step
# Epoch 111/300
# 5/5 - 0s - loss: 4.8111e-04 - 37ms/epoch - 7ms/step
# Epoch 112/300
# 5/5 - 0s - loss: 4.8826e-04 - 41ms/epoch - 8ms/step
# Epoch 113/300
# 5/5 - 0s - loss: 4.5489e-04 - 35ms/epoch - 7ms/step
# Epoch 114/300
# 5/5 - 0s - loss: 6.8214e-04 - 38ms/epoch - 8ms/step
# Epoch 115/300
# 5/5 - 0s - loss: 5.3234e-04 - 39ms/epoch - 8ms/step
# Epoch 116/300
# 5/5 - 0s - loss: 0.0010 - 37ms/epoch - 7ms/step
# Epoch 117/300
# 5/5 - 0s - loss: 4.8438e-04 - 36ms/epoch - 7ms/step
# Epoch 118/300
# 5/5 - 0s - loss: 9.3212e-04 - 37ms/epoch - 7ms/step
# Epoch 119/300
# 5/5 - 0s - loss: 8.5014e-04 - 36ms/epoch - 7ms/step
# Epoch 120/300
# 5/5 - 0s - loss: 5.2957e-04 - 39ms/epoch - 8ms/step
# Epoch 121/300
# 5/5 - 0s - loss: 4.7643e-04 - 35ms/epoch - 7ms/step
# Epoch 122/300
# 5/5 - 0s - loss: 2.9868e-04 - 39ms/epoch - 8ms/step
# Epoch 123/300
# 5/5 - 0s - loss: 1.9553e-04 - 37ms/epoch - 7ms/step
# Epoch 124/300
# 5/5 - 0s - loss: 1.6554e-04 - 42ms/epoch - 8ms/step
# Epoch 125/300
# 5/5 - 0s - loss: 1.4848e-04 - 34ms/epoch - 7ms/step
# Epoch 126/300
# 5/5 - 0s - loss: 1.1843e-04 - 36ms/epoch - 7ms/step
# Epoch 127/300
# 5/5 - 0s - loss: 2.0567e-04 - 35ms/epoch - 7ms/step
# Epoch 128/300
# 5/5 - 0s - loss: 1.4261e-04 - 33ms/epoch - 7ms/step
# Epoch 129/300
# 5/5 - 0s - loss: 1.8103e-04 - 37ms/epoch - 7ms/step
# Epoch 130/300
# 5/5 - 0s - loss: 3.5980e-04 - 37ms/epoch - 7ms/step
# Epoch 131/300
# 5/5 - 0s - loss: 3.5810e-04 - 38ms/epoch - 8ms/step
# Epoch 132/300
# 5/5 - 0s - loss: 2.1620e-04 - 35ms/epoch - 7ms/step
# Epoch 133/300
# 5/5 - 0s - loss: 2.3734e-04 - 37ms/epoch - 7ms/step
# Epoch 134/300
# 5/5 - 0s - loss: 3.3868e-04 - 35ms/epoch - 7ms/step
# Epoch 135/300
# 5/5 - 0s - loss: 2.2803e-04 - 40ms/epoch - 8ms/step
# Epoch 136/300
# 5/5 - 0s - loss: 1.9608e-04 - 35ms/epoch - 7ms/step
# Epoch 137/300
# 5/5 - 0s - loss: 4.9563e-04 - 39ms/epoch - 8ms/step
# Epoch 138/300
# 5/5 - 0s - loss: 4.1741e-04 - 39ms/epoch - 8ms/step
# Epoch 139/300
# 5/5 - 0s - loss: 1.7479e-04 - 38ms/epoch - 8ms/step
# Epoch 140/300
# 5/5 - 0s - loss: 2.2509e-04 - 38ms/epoch - 8ms/step
# Epoch 141/300
# 5/5 - 0s - loss: 1.5293e-04 - 40ms/epoch - 8ms/step
# Epoch 142/300
# 5/5 - 0s - loss: 2.2748e-04 - 39ms/epoch - 8ms/step
# Epoch 143/300
# 5/5 - 0s - loss: 2.0908e-04 - 39ms/epoch - 8ms/step
# Epoch 144/300
# 5/5 - 0s - loss: 4.8878e-04 - 38ms/epoch - 8ms/step
# Epoch 145/300
# 5/5 - 0s - loss: 7.2402e-04 - 36ms/epoch - 7ms/step
# Epoch 146/300
# 5/5 - 0s - loss: 5.8272e-04 - 37ms/epoch - 7ms/step
# Epoch 147/300
# 5/5 - 0s - loss: 3.9600e-04 - 39ms/epoch - 8ms/step
# Epoch 148/300
# 5/5 - 0s - loss: 2.8399e-04 - 40ms/epoch - 8ms/step
# Epoch 149/300
# 5/5 - 0s - loss: 2.6591e-04 - 37ms/epoch - 7ms/step
# Epoch 150/300
# 5/5 - 0s - loss: 4.3648e-04 - 33ms/epoch - 7ms/step
# Epoch 151/300
# 5/5 - 0s - loss: 3.6926e-04 - 38ms/epoch - 8ms/step
# Epoch 152/300
# 5/5 - 0s - loss: 3.3253e-04 - 33ms/epoch - 7ms/step
# Epoch 153/300
# 5/5 - 0s - loss: 3.2788e-04 - 39ms/epoch - 8ms/step
# Epoch 154/300
# 5/5 - 0s - loss: 3.6019e-04 - 37ms/epoch - 7ms/step
# Epoch 155/300
# 5/5 - 0s - loss: 8.0373e-04 - 36ms/epoch - 7ms/step
# Epoch 156/300
# 5/5 - 0s - loss: 7.7017e-04 - 40ms/epoch - 8ms/step
# Epoch 157/300
# 5/5 - 0s - loss: 7.5282e-04 - 40ms/epoch - 8ms/step
# Epoch 158/300
# 5/5 - 0s - loss: 8.1920e-04 - 40ms/epoch - 8ms/step
# Epoch 159/300
# 5/5 - 0s - loss: 0.0011 - 39ms/epoch - 8ms/step
# Epoch 160/300
# 5/5 - 0s - loss: 0.0011 - 34ms/epoch - 7ms/step
# Epoch 161/300
# 5/5 - 0s - loss: 8.8258e-04 - 37ms/epoch - 7ms/step
# Epoch 162/300
# 5/5 - 0s - loss: 0.0013 - 37ms/epoch - 7ms/step
# Epoch 163/300
# 5/5 - 0s - loss: 0.0016 - 38ms/epoch - 8ms/step
# Epoch 164/300
# 5/5 - 0s - loss: 0.0017 - 40ms/epoch - 8ms/step
# Epoch 165/300
# 5/5 - 0s - loss: 0.0015 - 36ms/epoch - 7ms/step
# Epoch 166/300
# 5/5 - 0s - loss: 0.0015 - 40ms/epoch - 8ms/step
# Epoch 167/300
# 5/5 - 0s - loss: 0.0015 - 37ms/epoch - 7ms/step
# Epoch 168/300
# 5/5 - 0s - loss: 0.0011 - 36ms/epoch - 7ms/step
# Epoch 169/300
# 5/5 - 0s - loss: 0.0015 - 42ms/epoch - 8ms/step
# Epoch 170/300
# 5/5 - 0s - loss: 0.0024 - 43ms/epoch - 9ms/step
# Epoch 171/300
# 5/5 - 0s - loss: 0.0031 - 37ms/epoch - 7ms/step
# Epoch 172/300
# 5/5 - 0s - loss: 0.0048 - 41ms/epoch - 8ms/step
# Epoch 173/300
# 5/5 - 0s - loss: 0.0037 - 38ms/epoch - 8ms/step
# Epoch 174/300
# 5/5 - 0s - loss: 0.0043 - 41ms/epoch - 8ms/step
# Epoch 175/300
# 5/5 - 0s - loss: 0.0024 - 43ms/epoch - 9ms/step
# Epoch 176/300
# 5/5 - 0s - loss: 0.0022 - 43ms/epoch - 9ms/step
# Epoch 177/300
# 5/5 - 0s - loss: 0.0016 - 38ms/epoch - 8ms/step
# Epoch 178/300
# 5/5 - 0s - loss: 0.0016 - 41ms/epoch - 8ms/step
# Epoch 179/300
# 5/5 - 0s - loss: 0.0017 - 41ms/epoch - 8ms/step
# Epoch 180/300
# 5/5 - 0s - loss: 0.0015 - 39ms/epoch - 8ms/step
# Epoch 181/300
# 5/5 - 0s - loss: 0.0016 - 39ms/epoch - 8ms/step
# Epoch 182/300
# 5/5 - 0s - loss: 0.0011 - 39ms/epoch - 8ms/step
# Epoch 183/300
# 5/5 - 0s - loss: 0.0018 - 37ms/epoch - 7ms/step
# Epoch 184/300
# 5/5 - 0s - loss: 0.0016 - 37ms/epoch - 7ms/step
# Epoch 185/300
# 5/5 - 0s - loss: 0.0017 - 37ms/epoch - 7ms/step
# Epoch 186/300
# 5/5 - 0s - loss: 0.0019 - 35ms/epoch - 7ms/step
# Epoch 187/300
# 5/5 - 0s - loss: 0.0019 - 37ms/epoch - 7ms/step
# Epoch 188/300
# 5/5 - 0s - loss: 0.0033 - 40ms/epoch - 8ms/step
# Epoch 189/300
# 5/5 - 0s - loss: 0.0082 - 39ms/epoch - 8ms/step
# Epoch 190/300
# 5/5 - 0s - loss: 0.0124 - 37ms/epoch - 7ms/step
# Epoch 191/300
# 5/5 - 0s - loss: 0.0139 - 38ms/epoch - 8ms/step
# Epoch 192/300
# 5/5 - 0s - loss: 0.0187 - 35ms/epoch - 7ms/step
# Epoch 193/300
# 5/5 - 0s - loss: 0.0147 - 42ms/epoch - 8ms/step
# Epoch 194/300
# 5/5 - 0s - loss: 0.0145 - 38ms/epoch - 8ms/step
# Epoch 195/300
# 5/5 - 0s - loss: 0.0161 - 43ms/epoch - 9ms/step
# Epoch 196/300
# 5/5 - 0s - loss: 0.0132 - 44ms/epoch - 9ms/step
# Epoch 197/300
# 5/5 - 0s - loss: 0.0146 - 39ms/epoch - 8ms/step
# Epoch 198/300
# 5/5 - 0s - loss: 0.0092 - 36ms/epoch - 7ms/step
# Epoch 199/300
# 5/5 - 0s - loss: 0.0090 - 41ms/epoch - 8ms/step
# Epoch 200/300
# 5/5 - 0s - loss: 0.0092 - 38ms/epoch - 8ms/step
# Epoch 201/300
# 5/5 - 0s - loss: 0.0060 - 36ms/epoch - 7ms/step
# Epoch 202/300
# 5/5 - 0s - loss: 0.0090 - 43ms/epoch - 9ms/step
# Epoch 203/300
# 5/5 - 0s - loss: 0.0050 - 44ms/epoch - 9ms/step
# Epoch 204/300
# 5/5 - 0s - loss: 0.0029 - 41ms/epoch - 8ms/step
# Epoch 205/300
# 5/5 - 0s - loss: 0.0019 - 44ms/epoch - 9ms/step
# Epoch 206/300
# 5/5 - 0s - loss: 0.0019 - 42ms/epoch - 8ms/step
# Epoch 207/300
# 5/5 - 0s - loss: 0.0025 - 36ms/epoch - 7ms/step
# Epoch 208/300
# 5/5 - 0s - loss: 0.0033 - 39ms/epoch - 8ms/step
# Epoch 209/300
# 5/5 - 0s - loss: 0.0037 - 44ms/epoch - 9ms/step
# Epoch 210/300
# 5/5 - 0s - loss: 0.0018 - 46ms/epoch - 9ms/step
# Epoch 211/300
# 5/5 - 0s - loss: 0.0018 - 42ms/epoch - 8ms/step
# Epoch 212/300
# 5/5 - 0s - loss: 0.0016 - 37ms/epoch - 7ms/step
# Epoch 213/300
# 5/5 - 0s - loss: 0.0013 - 40ms/epoch - 8ms/step
# Epoch 214/300
# 5/5 - 0s - loss: 0.0013 - 40ms/epoch - 8ms/step
# Epoch 215/300
# 5/5 - 0s - loss: 9.1248e-04 - 39ms/epoch - 8ms/step
# Epoch 216/300
# 5/5 - 0s - loss: 4.6237e-04 - 34ms/epoch - 7ms/step
# Epoch 217/300
# 5/5 - 0s - loss: 2.8055e-04 - 41ms/epoch - 8ms/step
# Epoch 218/300
# 5/5 - 0s - loss: 2.2941e-04 - 36ms/epoch - 7ms/step
# Epoch 219/300
# 5/5 - 0s - loss: 1.9586e-04 - 40ms/epoch - 8ms/step
# Epoch 220/300
# 5/5 - 0s - loss: 2.7826e-04 - 39ms/epoch - 8ms/step
# Epoch 221/300
# 5/5 - 0s - loss: 2.1041e-04 - 36ms/epoch - 7ms/step
# Epoch 222/300
# 5/5 - 0s - loss: 2.2594e-04 - 40ms/epoch - 8ms/step
# Epoch 223/300
# 5/5 - 0s - loss: 1.6647e-04 - 43ms/epoch - 9ms/step
# Epoch 224/300
# 5/5 - 0s - loss: 1.7308e-04 - 39ms/epoch - 8ms/step
# Epoch 225/300
# 5/5 - 0s - loss: 1.3469e-04 - 46ms/epoch - 9ms/step
# Epoch 226/300
# 5/5 - 0s - loss: 9.6634e-05 - 39ms/epoch - 8ms/step
# Epoch 227/300
# 5/5 - 0s - loss: 7.2390e-05 - 42ms/epoch - 8ms/step
# Epoch 228/300
# 5/5 - 0s - loss: 7.7106e-05 - 42ms/epoch - 8ms/step
# Epoch 229/300
# 5/5 - 0s - loss: 8.3282e-05 - 45ms/epoch - 9ms/step
# Epoch 230/300
# 5/5 - 0s - loss: 9.1292e-05 - 40ms/epoch - 8ms/step
# Epoch 231/300
# 5/5 - 0s - loss: 7.1752e-05 - 38ms/epoch - 8ms/step
# Epoch 232/300
# 5/5 - 0s - loss: 6.6475e-05 - 44ms/epoch - 9ms/step
# Epoch 233/300
# 5/5 - 0s - loss: 7.6236e-05 - 39ms/epoch - 8ms/step
# Epoch 234/300
# 5/5 - 0s - loss: 8.0789e-05 - 43ms/epoch - 9ms/step
# Epoch 235/300
# 5/5 - 0s - loss: 6.7239e-05 - 37ms/epoch - 7ms/step
# Epoch 236/300
# 5/5 - 0s - loss: 6.8696e-05 - 41ms/epoch - 8ms/step
# Epoch 237/300
# 5/5 - 0s - loss: 1.3556e-04 - 40ms/epoch - 8ms/step
# Epoch 238/300
# 5/5 - 0s - loss: 1.3688e-04 - 42ms/epoch - 8ms/step
# Epoch 239/300
# 5/5 - 0s - loss: 9.9645e-05 - 46ms/epoch - 9ms/step
# Epoch 240/300
# 5/5 - 0s - loss: 9.8944e-05 - 38ms/epoch - 8ms/step
# Epoch 241/300
# 5/5 - 0s - loss: 1.2356e-04 - 39ms/epoch - 8ms/step
# Epoch 242/300
# 5/5 - 0s - loss: 1.4629e-04 - 39ms/epoch - 8ms/step
# Epoch 243/300
# 5/5 - 0s - loss: 9.9293e-05 - 36ms/epoch - 7ms/step
# Epoch 244/300
# 5/5 - 0s - loss: 8.9467e-05 - 41ms/epoch - 8ms/step
# Epoch 245/300
# 5/5 - 0s - loss: 1.1232e-04 - 40ms/epoch - 8ms/step
# Epoch 246/300
# 5/5 - 0s - loss: 1.5706e-04 - 39ms/epoch - 8ms/step
# Epoch 247/300
# 5/5 - 0s - loss: 1.6858e-04 - 42ms/epoch - 8ms/step
# Epoch 248/300
# 5/5 - 0s - loss: 1.8259e-04 - 36ms/epoch - 7ms/step
# Epoch 249/300
# 5/5 - 0s - loss: 1.0264e-04 - 39ms/epoch - 8ms/step
# Epoch 250/300
# 5/5 - 0s - loss: 1.2579e-04 - 39ms/epoch - 8ms/step
# Epoch 251/300
# 5/5 - 0s - loss: 1.3693e-04 - 36ms/epoch - 7ms/step
# Epoch 252/300
# 5/5 - 0s - loss: 9.0537e-05 - 41ms/epoch - 8ms/step
# Epoch 253/300
# 5/5 - 0s - loss: 4.8692e-05 - 40ms/epoch - 8ms/step
# Epoch 254/300
# 5/5 - 0s - loss: 6.1000e-05 - 39ms/epoch - 8ms/step
# Epoch 255/300
# 5/5 - 0s - loss: 6.4108e-05 - 40ms/epoch - 8ms/step
# Epoch 256/300
# 5/5 - 0s - loss: 6.4827e-05 - 37ms/epoch - 7ms/step
# Epoch 257/300
# 5/5 - 0s - loss: 4.9862e-05 - 37ms/epoch - 7ms/step
# Epoch 258/300
# 5/5 - 0s - loss: 5.3651e-05 - 44ms/epoch - 9ms/step
# Epoch 259/300
# 5/5 - 0s - loss: 4.4113e-05 - 37ms/epoch - 7ms/step
# Epoch 260/300
# 5/5 - 0s - loss: 3.5916e-05 - 41ms/epoch - 8ms/step
# Epoch 261/300
# 5/5 - 0s - loss: 2.9828e-05 - 36ms/epoch - 7ms/step
# Epoch 262/300
# 5/5 - 0s - loss: 3.2185e-05 - 38ms/epoch - 8ms/step
# Epoch 263/300
# 5/5 - 0s - loss: 4.5438e-05 - 36ms/epoch - 7ms/step
# Epoch 264/300
# 5/5 - 0s - loss: 5.0587e-05 - 39ms/epoch - 8ms/step
# Epoch 265/300
# 5/5 - 0s - loss: 1.0733e-04 - 40ms/epoch - 8ms/step
# Epoch 266/300
# 5/5 - 0s - loss: 1.0877e-04 - 37ms/epoch - 7ms/step
# Epoch 267/300
# 5/5 - 0s - loss: 9.3757e-05 - 39ms/epoch - 8ms/step
# Epoch 268/300
# 5/5 - 0s - loss: 7.9907e-05 - 41ms/epoch - 8ms/step
# Epoch 269/300
# 5/5 - 0s - loss: 8.5595e-05 - 41ms/epoch - 8ms/step
# Epoch 270/300
# 5/5 - 0s - loss: 5.4063e-05 - 39ms/epoch - 8ms/step
# Epoch 271/300
# 5/5 - 0s - loss: 1.0481e-04 - 40ms/epoch - 8ms/step
# Epoch 272/300
# 5/5 - 0s - loss: 1.0777e-04 - 40ms/epoch - 8ms/step
# Epoch 273/300
# 5/5 - 0s - loss: 1.0688e-04 - 35ms/epoch - 7ms/step
# Epoch 274/300
# 5/5 - 0s - loss: 1.0293e-04 - 35ms/epoch - 7ms/step
# Epoch 275/300
# 5/5 - 0s - loss: 1.0053e-04 - 41ms/epoch - 8ms/step
# Epoch 276/300
# 5/5 - 0s - loss: 9.8715e-05 - 36ms/epoch - 7ms/step
# Epoch 277/300
# 5/5 - 0s - loss: 6.2233e-05 - 38ms/epoch - 8ms/step
# Epoch 278/300
# 5/5 - 0s - loss: 3.3145e-05 - 40ms/epoch - 8ms/step
# Epoch 279/300
# 5/5 - 0s - loss: 2.6083e-05 - 39ms/epoch - 8ms/step
# Epoch 280/300
# 5/5 - 0s - loss: 2.3545e-05 - 38ms/epoch - 8ms/step
# Epoch 281/300
# 5/5 - 0s - loss: 2.1037e-05 - 41ms/epoch - 8ms/step
# Epoch 282/300
# 5/5 - 0s - loss: 2.3514e-05 - 35ms/epoch - 7ms/step
# Epoch 283/300
# 5/5 - 0s - loss: 1.9658e-05 - 41ms/epoch - 8ms/step
# Epoch 284/300
# 5/5 - 0s - loss: 2.7499e-05 - 42ms/epoch - 8ms/step
# Epoch 285/300
# 5/5 - 0s - loss: 3.4891e-05 - 38ms/epoch - 8ms/step
# Epoch 286/300
# 5/5 - 0s - loss: 3.0151e-05 - 39ms/epoch - 8ms/step
# Epoch 287/300
# 5/5 - 0s - loss: 2.8795e-05 - 41ms/epoch - 8ms/step
# Epoch 288/300
# 5/5 - 0s - loss: 1.8509e-05 - 40ms/epoch - 8ms/step
# Epoch 289/300
# 5/5 - 0s - loss: 2.4112e-05 - 39ms/epoch - 8ms/step
# Epoch 290/300
# 5/5 - 0s - loss: 1.9998e-05 - 37ms/epoch - 7ms/step
# Epoch 291/300
# 5/5 - 0s - loss: 1.2522e-05 - 40ms/epoch - 8ms/step
# Epoch 292/300
# 5/5 - 0s - loss: 1.1336e-05 - 38ms/epoch - 8ms/step
# Epoch 293/300
# 5/5 - 0s - loss: 1.1026e-05 - 40ms/epoch - 8ms/step
# Epoch 294/300
# 5/5 - 0s - loss: 1.2264e-05 - 41ms/epoch - 8ms/step
# Epoch 295/300
# 5/5 - 0s - loss: 1.0864e-05 - 42ms/epoch - 8ms/step
# Epoch 296/300
# 5/5 - 0s - loss: 3.2343e-05 - 44ms/epoch - 9ms/step
# Epoch 297/300
# 5/5 - 0s - loss: 2.6924e-05 - 40ms/epoch - 8ms/step
# Epoch 298/300
# 5/5 - 0s - loss: 1.6224e-05 - 41ms/epoch - 8ms/step
# Epoch 299/300
# 5/5 - 0s - loss: 1.3313e-05 - 40ms/epoch - 8ms/step
# Epoch 300/300
# 5/5 - 0s - loss: 1.2549e-05 - 38ms/epoch - 8ms/step
# 15/15 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710200782.3518057
# Mon Mar 11 23:46:22 2024
