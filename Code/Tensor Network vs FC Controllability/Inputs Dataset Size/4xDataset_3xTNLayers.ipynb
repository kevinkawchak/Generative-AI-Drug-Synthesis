# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_70 (Dense)            (None, 1024)              3072
#
#  dense_71 (Dense)            (None, 1024)              1049600
#
#  dense_72 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_73 (Dense)            (None, 1024)              3072
#
#  tn_layer_42 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_43 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_44 (TNLayer)       (None, 1024)              5120
#
#  dense_74 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(80, 2) + np.array([3, 3]),
                    np.random.randn(80, 2) + np.array([-3, -3]),
                    np.random.randn(80, 2) + np.array([-3, 3]),
                    np.random.randn(80, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((160)), -np.ones((160))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710201969.1948123
# Tue Mar 12 00:06:09 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 10/10 - 2s - loss: 1.0048 - 2s/epoch - 171ms/step
# Epoch 2/300
# 10/10 - 0s - loss: 1.0003 - 52ms/epoch - 5ms/step
# Epoch 3/300
# 10/10 - 0s - loss: 0.9962 - 53ms/epoch - 5ms/step
# Epoch 4/300
# 10/10 - 0s - loss: 0.9360 - 52ms/epoch - 5ms/step
# Epoch 5/300
# 10/10 - 0s - loss: 0.4928 - 49ms/epoch - 5ms/step
# Epoch 6/300
# 10/10 - 0s - loss: 0.1222 - 65ms/epoch - 6ms/step
# Epoch 7/300
# 10/10 - 0s - loss: 0.0572 - 55ms/epoch - 6ms/step
# Epoch 8/300
# 10/10 - 0s - loss: 0.0364 - 50ms/epoch - 5ms/step
# Epoch 9/300
# 10/10 - 0s - loss: 0.0315 - 53ms/epoch - 5ms/step
# Epoch 10/300
# 10/10 - 0s - loss: 0.0281 - 56ms/epoch - 6ms/step
# Epoch 11/300
# 10/10 - 0s - loss: 0.0277 - 50ms/epoch - 5ms/step
# Epoch 12/300
# 10/10 - 0s - loss: 0.0253 - 55ms/epoch - 5ms/step
# Epoch 13/300
# 10/10 - 0s - loss: 0.0242 - 51ms/epoch - 5ms/step
# Epoch 14/300
# 10/10 - 0s - loss: 0.0226 - 54ms/epoch - 5ms/step
# Epoch 15/300
# 10/10 - 0s - loss: 0.0223 - 60ms/epoch - 6ms/step
# Epoch 16/300
# 10/10 - 0s - loss: 0.0215 - 56ms/epoch - 6ms/step
# Epoch 17/300
# 10/10 - 0s - loss: 0.0205 - 56ms/epoch - 6ms/step
# Epoch 18/300
# 10/10 - 0s - loss: 0.0194 - 55ms/epoch - 6ms/step
# Epoch 19/300
# 10/10 - 0s - loss: 0.0211 - 57ms/epoch - 6ms/step
# Epoch 20/300
# 10/10 - 0s - loss: 0.0193 - 55ms/epoch - 5ms/step
# Epoch 21/300
# 10/10 - 0s - loss: 0.0189 - 55ms/epoch - 6ms/step
# Epoch 22/300
# 10/10 - 0s - loss: 0.0178 - 53ms/epoch - 5ms/step
# Epoch 23/300
# 10/10 - 0s - loss: 0.0174 - 53ms/epoch - 5ms/step
# Epoch 24/300
# 10/10 - 0s - loss: 0.0161 - 55ms/epoch - 6ms/step
# Epoch 25/300
# 10/10 - 0s - loss: 0.0173 - 54ms/epoch - 5ms/step
# Epoch 26/300
# 10/10 - 0s - loss: 0.0160 - 52ms/epoch - 5ms/step
# Epoch 27/300
# 10/10 - 0s - loss: 0.0157 - 54ms/epoch - 5ms/step
# Epoch 28/300
# 10/10 - 0s - loss: 0.0163 - 49ms/epoch - 5ms/step
# Epoch 29/300
# 10/10 - 0s - loss: 0.0174 - 50ms/epoch - 5ms/step
# Epoch 30/300
# 10/10 - 0s - loss: 0.0167 - 49ms/epoch - 5ms/step
# Epoch 31/300
# 10/10 - 0s - loss: 0.0158 - 54ms/epoch - 5ms/step
# Epoch 32/300
# 10/10 - 0s - loss: 0.0143 - 56ms/epoch - 6ms/step
# Epoch 33/300
# 10/10 - 0s - loss: 0.0175 - 51ms/epoch - 5ms/step
# Epoch 34/300
# 10/10 - 0s - loss: 0.0170 - 56ms/epoch - 6ms/step
# Epoch 35/300
# 10/10 - 0s - loss: 0.0155 - 53ms/epoch - 5ms/step
# Epoch 36/300
# 10/10 - 0s - loss: 0.0144 - 56ms/epoch - 6ms/step
# Epoch 37/300
# 10/10 - 0s - loss: 0.0135 - 56ms/epoch - 6ms/step
# Epoch 38/300
# 10/10 - 0s - loss: 0.0140 - 60ms/epoch - 6ms/step
# Epoch 39/300
# 10/10 - 0s - loss: 0.0115 - 56ms/epoch - 6ms/step
# Epoch 40/300
# 10/10 - 0s - loss: 0.0115 - 61ms/epoch - 6ms/step
# Epoch 41/300
# 10/10 - 0s - loss: 0.0121 - 60ms/epoch - 6ms/step
# Epoch 42/300
# 10/10 - 0s - loss: 0.0165 - 54ms/epoch - 5ms/step
# Epoch 43/300
# 10/10 - 0s - loss: 0.0146 - 51ms/epoch - 5ms/step
# Epoch 44/300
# 10/10 - 0s - loss: 0.0116 - 50ms/epoch - 5ms/step
# Epoch 45/300
# 10/10 - 0s - loss: 0.0112 - 51ms/epoch - 5ms/step
# Epoch 46/300
# 10/10 - 0s - loss: 0.0105 - 48ms/epoch - 5ms/step
# Epoch 47/300
# 10/10 - 0s - loss: 0.0115 - 51ms/epoch - 5ms/step
# Epoch 48/300
# 10/10 - 0s - loss: 0.0159 - 48ms/epoch - 5ms/step
# Epoch 49/300
# 10/10 - 0s - loss: 0.0144 - 49ms/epoch - 5ms/step
# Epoch 50/300
# 10/10 - 0s - loss: 0.0125 - 52ms/epoch - 5ms/step
# Epoch 51/300
# 10/10 - 0s - loss: 0.0111 - 53ms/epoch - 5ms/step
# Epoch 52/300
# 10/10 - 0s - loss: 0.0123 - 50ms/epoch - 5ms/step
# Epoch 53/300
# 10/10 - 0s - loss: 0.0117 - 48ms/epoch - 5ms/step
# Epoch 54/300
# 10/10 - 0s - loss: 0.0130 - 49ms/epoch - 5ms/step
# Epoch 55/300
# 10/10 - 0s - loss: 0.0102 - 50ms/epoch - 5ms/step
# Epoch 56/300
# 10/10 - 0s - loss: 0.0102 - 49ms/epoch - 5ms/step
# Epoch 57/300
# 10/10 - 0s - loss: 0.0085 - 51ms/epoch - 5ms/step
# Epoch 58/300
# 10/10 - 0s - loss: 0.0157 - 47ms/epoch - 5ms/step
# Epoch 59/300
# 10/10 - 0s - loss: 0.0127 - 51ms/epoch - 5ms/step
# Epoch 60/300
# 10/10 - 0s - loss: 0.0075 - 51ms/epoch - 5ms/step
# Epoch 61/300
# 10/10 - 0s - loss: 0.0133 - 48ms/epoch - 5ms/step
# Epoch 62/300
# 10/10 - 0s - loss: 0.0097 - 49ms/epoch - 5ms/step
# Epoch 63/300
# 10/10 - 0s - loss: 0.0119 - 49ms/epoch - 5ms/step
# Epoch 64/300
# 10/10 - 0s - loss: 0.0084 - 45ms/epoch - 5ms/step
# Epoch 65/300
# 10/10 - 0s - loss: 0.0110 - 47ms/epoch - 5ms/step
# Epoch 66/300
# 10/10 - 0s - loss: 0.0076 - 50ms/epoch - 5ms/step
# Epoch 67/300
# 10/10 - 0s - loss: 0.0090 - 45ms/epoch - 4ms/step
# Epoch 68/300
# 10/10 - 0s - loss: 0.0083 - 48ms/epoch - 5ms/step
# Epoch 69/300
# 10/10 - 0s - loss: 0.0111 - 50ms/epoch - 5ms/step
# Epoch 70/300
# 10/10 - 0s - loss: 0.0087 - 51ms/epoch - 5ms/step
# Epoch 71/300
# 10/10 - 0s - loss: 0.0100 - 48ms/epoch - 5ms/step
# Epoch 72/300
# 10/10 - 0s - loss: 0.0069 - 49ms/epoch - 5ms/step
# Epoch 73/300
# 10/10 - 0s - loss: 0.0090 - 50ms/epoch - 5ms/step
# Epoch 74/300
# 10/10 - 0s - loss: 0.0070 - 48ms/epoch - 5ms/step
# Epoch 75/300
# 10/10 - 0s - loss: 0.0077 - 48ms/epoch - 5ms/step
# Epoch 76/300
# 10/10 - 0s - loss: 0.0078 - 53ms/epoch - 5ms/step
# Epoch 77/300
# 10/10 - 0s - loss: 0.0082 - 52ms/epoch - 5ms/step
# Epoch 78/300
# 10/10 - 0s - loss: 0.0062 - 52ms/epoch - 5ms/step
# Epoch 79/300
# 10/10 - 0s - loss: 0.0138 - 51ms/epoch - 5ms/step
# Epoch 80/300
# 10/10 - 0s - loss: 0.0179 - 56ms/epoch - 6ms/step
# Epoch 81/300
# 10/10 - 0s - loss: 0.0083 - 52ms/epoch - 5ms/step
# Epoch 82/300
# 10/10 - 0s - loss: 0.0079 - 51ms/epoch - 5ms/step
# Epoch 83/300
# 10/10 - 0s - loss: 0.0077 - 50ms/epoch - 5ms/step
# Epoch 84/300
# 10/10 - 0s - loss: 0.0061 - 48ms/epoch - 5ms/step
# Epoch 85/300
# 10/10 - 0s - loss: 0.0128 - 48ms/epoch - 5ms/step
# Epoch 86/300
# 10/10 - 0s - loss: 0.0317 - 49ms/epoch - 5ms/step
# Epoch 87/300
# 10/10 - 0s - loss: 0.0025 - 50ms/epoch - 5ms/step
# Epoch 88/300
# 10/10 - 0s - loss: 0.0195 - 50ms/epoch - 5ms/step
# Epoch 89/300
# 10/10 - 0s - loss: 0.0186 - 51ms/epoch - 5ms/step
# Epoch 90/300
# 10/10 - 0s - loss: 0.0118 - 49ms/epoch - 5ms/step
# Epoch 91/300
# 10/10 - 0s - loss: 0.0108 - 48ms/epoch - 5ms/step
# Epoch 92/300
# 10/10 - 0s - loss: 0.0085 - 50ms/epoch - 5ms/step
# Epoch 93/300
# 10/10 - 0s - loss: 0.0099 - 49ms/epoch - 5ms/step
# Epoch 94/300
# 10/10 - 0s - loss: 0.0094 - 48ms/epoch - 5ms/step
# Epoch 95/300
# 10/10 - 0s - loss: 0.0073 - 48ms/epoch - 5ms/step
# Epoch 96/300
# 10/10 - 0s - loss: 0.0067 - 46ms/epoch - 5ms/step
# Epoch 97/300
# 10/10 - 0s - loss: 0.0069 - 46ms/epoch - 5ms/step
# Epoch 98/300
# 10/10 - 0s - loss: 0.0057 - 51ms/epoch - 5ms/step
# Epoch 99/300
# 10/10 - 0s - loss: 0.0064 - 47ms/epoch - 5ms/step
# Epoch 100/300
# 10/10 - 0s - loss: 0.0066 - 48ms/epoch - 5ms/step
# Epoch 101/300
# 10/10 - 0s - loss: 0.0053 - 47ms/epoch - 5ms/step
# Epoch 102/300
# 10/10 - 0s - loss: 0.0058 - 47ms/epoch - 5ms/step
# Epoch 103/300
# 10/10 - 0s - loss: 0.0072 - 44ms/epoch - 4ms/step
# Epoch 104/300
# 10/10 - 0s - loss: 0.0052 - 43ms/epoch - 4ms/step
# Epoch 105/300
# 10/10 - 0s - loss: 0.0044 - 43ms/epoch - 4ms/step
# Epoch 106/300
# 10/10 - 0s - loss: 0.0056 - 45ms/epoch - 5ms/step
# Epoch 107/300
# 10/10 - 0s - loss: 0.0072 - 45ms/epoch - 5ms/step
# Epoch 108/300
# 10/10 - 0s - loss: 0.0063 - 50ms/epoch - 5ms/step
# Epoch 109/300
# 10/10 - 0s - loss: 0.0025 - 46ms/epoch - 5ms/step
# Epoch 110/300
# 10/10 - 0s - loss: 0.0062 - 51ms/epoch - 5ms/step
# Epoch 111/300
# 10/10 - 0s - loss: 0.0231 - 49ms/epoch - 5ms/step
# Epoch 112/300
# 10/10 - 0s - loss: 0.0121 - 48ms/epoch - 5ms/step
# Epoch 113/300
# 10/10 - 0s - loss: 0.0134 - 47ms/epoch - 5ms/step
# Epoch 114/300
# 10/10 - 0s - loss: 0.0122 - 51ms/epoch - 5ms/step
# Epoch 115/300
# 10/10 - 0s - loss: 0.0107 - 48ms/epoch - 5ms/step
# Epoch 116/300
# 10/10 - 0s - loss: 0.0076 - 49ms/epoch - 5ms/step
# Epoch 117/300
# 10/10 - 0s - loss: 0.0068 - 46ms/epoch - 5ms/step
# Epoch 118/300
# 10/10 - 0s - loss: 0.0028 - 49ms/epoch - 5ms/step
# Epoch 119/300
# 10/10 - 0s - loss: 0.0120 - 49ms/epoch - 5ms/step
# Epoch 120/300
# 10/10 - 0s - loss: 0.0113 - 50ms/epoch - 5ms/step
# Epoch 121/300
# 10/10 - 0s - loss: 0.0084 - 48ms/epoch - 5ms/step
# Epoch 122/300
# 10/10 - 0s - loss: 0.0047 - 45ms/epoch - 5ms/step
# Epoch 123/300
# 10/10 - 0s - loss: 0.0062 - 44ms/epoch - 4ms/step
# Epoch 124/300
# 10/10 - 0s - loss: 0.0057 - 44ms/epoch - 4ms/step
# Epoch 125/300
# 10/10 - 0s - loss: 0.0033 - 48ms/epoch - 5ms/step
# Epoch 126/300
# 10/10 - 0s - loss: 0.0058 - 45ms/epoch - 5ms/step
# Epoch 127/300
# 10/10 - 0s - loss: 0.0046 - 48ms/epoch - 5ms/step
# Epoch 128/300
# 10/10 - 0s - loss: 0.0044 - 45ms/epoch - 5ms/step
# Epoch 129/300
# 10/10 - 0s - loss: 0.0061 - 46ms/epoch - 5ms/step
# Epoch 130/300
# 10/10 - 0s - loss: 0.0051 - 46ms/epoch - 5ms/step
# Epoch 131/300
# 10/10 - 0s - loss: 0.0124 - 46ms/epoch - 5ms/step
# Epoch 132/300
# 10/10 - 0s - loss: 0.0133 - 49ms/epoch - 5ms/step
# Epoch 133/300
# 10/10 - 0s - loss: 0.0141 - 48ms/epoch - 5ms/step
# Epoch 134/300
# 10/10 - 0s - loss: 0.0111 - 46ms/epoch - 5ms/step
# Epoch 135/300
# 10/10 - 0s - loss: 0.0107 - 49ms/epoch - 5ms/step
# Epoch 136/300
# 10/10 - 0s - loss: 0.0070 - 50ms/epoch - 5ms/step
# Epoch 137/300
# 10/10 - 0s - loss: 0.0069 - 44ms/epoch - 4ms/step
# Epoch 138/300
# 10/10 - 0s - loss: 0.0169 - 51ms/epoch - 5ms/step
# Epoch 139/300
# 10/10 - 0s - loss: 0.0171 - 51ms/epoch - 5ms/step
# Epoch 140/300
# 10/10 - 0s - loss: 0.0207 - 49ms/epoch - 5ms/step
# Epoch 141/300
# 10/10 - 0s - loss: 0.0228 - 47ms/epoch - 5ms/step
# Epoch 142/300
# 10/10 - 0s - loss: 0.0209 - 48ms/epoch - 5ms/step
# Epoch 143/300
# 10/10 - 0s - loss: 0.0149 - 45ms/epoch - 4ms/step
# Epoch 144/300
# 10/10 - 0s - loss: 0.0097 - 46ms/epoch - 5ms/step
# Epoch 145/300
# 10/10 - 0s - loss: 0.0106 - 46ms/epoch - 5ms/step
# Epoch 146/300
# 10/10 - 0s - loss: 0.0052 - 46ms/epoch - 5ms/step
# Epoch 147/300
# 10/10 - 0s - loss: 0.0066 - 47ms/epoch - 5ms/step
# Epoch 148/300
# 10/10 - 0s - loss: 0.0064 - 47ms/epoch - 5ms/step
# Epoch 149/300
# 10/10 - 0s - loss: 0.0047 - 49ms/epoch - 5ms/step
# Epoch 150/300
# 10/10 - 0s - loss: 0.0044 - 48ms/epoch - 5ms/step
# Epoch 151/300
# 10/10 - 0s - loss: 0.0101 - 48ms/epoch - 5ms/step
# Epoch 152/300
# 10/10 - 0s - loss: 0.0037 - 49ms/epoch - 5ms/step
# Epoch 153/300
# 10/10 - 0s - loss: 0.0023 - 50ms/epoch - 5ms/step
# Epoch 154/300
# 10/10 - 0s - loss: 0.0073 - 48ms/epoch - 5ms/step
# Epoch 155/300
# 10/10 - 0s - loss: 0.0010 - 48ms/epoch - 5ms/step
# Epoch 156/300
# 10/10 - 0s - loss: 0.0121 - 52ms/epoch - 5ms/step
# Epoch 157/300
# 10/10 - 0s - loss: 0.0139 - 48ms/epoch - 5ms/step
# Epoch 158/300
# 10/10 - 0s - loss: 0.0132 - 47ms/epoch - 5ms/step
# Epoch 159/300
# 10/10 - 0s - loss: 0.0127 - 49ms/epoch - 5ms/step
# Epoch 160/300
# 10/10 - 0s - loss: 0.0117 - 46ms/epoch - 5ms/step
# Epoch 161/300
# 10/10 - 0s - loss: 0.0111 - 45ms/epoch - 5ms/step
# Epoch 162/300
# 10/10 - 0s - loss: 0.0100 - 47ms/epoch - 5ms/step
# Epoch 163/300
# 10/10 - 0s - loss: 0.0049 - 44ms/epoch - 4ms/step
# Epoch 164/300
# 10/10 - 0s - loss: 0.0043 - 43ms/epoch - 4ms/step
# Epoch 165/300
# 10/10 - 0s - loss: 0.0028 - 44ms/epoch - 4ms/step
# Epoch 166/300
# 10/10 - 0s - loss: 0.0103 - 43ms/epoch - 4ms/step
# Epoch 167/300
# 10/10 - 0s - loss: 0.0035 - 43ms/epoch - 4ms/step
# Epoch 168/300
# 10/10 - 0s - loss: 0.0074 - 46ms/epoch - 5ms/step
# Epoch 169/300
# 10/10 - 0s - loss: 0.0060 - 44ms/epoch - 4ms/step
# Epoch 170/300
# 10/10 - 0s - loss: 0.0060 - 47ms/epoch - 5ms/step
# Epoch 171/300
# 10/10 - 0s - loss: 0.0022 - 50ms/epoch - 5ms/step
# Epoch 172/300
# 10/10 - 0s - loss: 0.0035 - 45ms/epoch - 4ms/step
# Epoch 173/300
# 10/10 - 0s - loss: 0.0038 - 47ms/epoch - 5ms/step
# Epoch 174/300
# 10/10 - 0s - loss: 0.0018 - 47ms/epoch - 5ms/step
# Epoch 175/300
# 10/10 - 0s - loss: 0.0016 - 52ms/epoch - 5ms/step
# Epoch 176/300
# 10/10 - 0s - loss: 7.0176e-04 - 45ms/epoch - 5ms/step
# Epoch 177/300
# 10/10 - 0s - loss: 0.0098 - 50ms/epoch - 5ms/step
# Epoch 178/300
# 10/10 - 0s - loss: 0.0065 - 50ms/epoch - 5ms/step
# Epoch 179/300
# 10/10 - 0s - loss: 0.0160 - 48ms/epoch - 5ms/step
# Epoch 180/300
# 10/10 - 0s - loss: 0.0125 - 50ms/epoch - 5ms/step
# Epoch 181/300
# 10/10 - 0s - loss: 0.0138 - 50ms/epoch - 5ms/step
# Epoch 182/300
# 10/10 - 0s - loss: 0.0202 - 51ms/epoch - 5ms/step
# Epoch 183/300
# 10/10 - 0s - loss: 0.0164 - 58ms/epoch - 6ms/step
# Epoch 184/300
# 10/10 - 0s - loss: 0.0122 - 48ms/epoch - 5ms/step
# Epoch 185/300
# 10/10 - 0s - loss: 0.0107 - 47ms/epoch - 5ms/step
# Epoch 186/300
# 10/10 - 0s - loss: 0.0049 - 45ms/epoch - 4ms/step
# Epoch 187/300
# 10/10 - 0s - loss: 0.0031 - 46ms/epoch - 5ms/step
# Epoch 188/300
# 10/10 - 0s - loss: 0.0016 - 47ms/epoch - 5ms/step
# Epoch 189/300
# 10/10 - 0s - loss: 0.0028 - 44ms/epoch - 4ms/step
# Epoch 190/300
# 10/10 - 0s - loss: 0.0020 - 46ms/epoch - 5ms/step
# Epoch 191/300
# 10/10 - 0s - loss: 0.0109 - 48ms/epoch - 5ms/step
# Epoch 192/300
# 10/10 - 0s - loss: 0.0084 - 48ms/epoch - 5ms/step
# Epoch 193/300
# 10/10 - 0s - loss: 0.0051 - 49ms/epoch - 5ms/step
# Epoch 194/300
# 10/10 - 0s - loss: 0.0071 - 46ms/epoch - 5ms/step
# Epoch 195/300
# 10/10 - 0s - loss: 8.9823e-04 - 48ms/epoch - 5ms/step
# Epoch 196/300
# 10/10 - 0s - loss: 0.0015 - 46ms/epoch - 5ms/step
# Epoch 197/300
# 10/10 - 0s - loss: 0.0016 - 50ms/epoch - 5ms/step
# Epoch 198/300
# 10/10 - 0s - loss: 0.0016 - 49ms/epoch - 5ms/step
# Epoch 199/300
# 10/10 - 0s - loss: 0.0031 - 45ms/epoch - 4ms/step
# Epoch 200/300
# 10/10 - 0s - loss: 3.1925e-04 - 44ms/epoch - 4ms/step
# Epoch 201/300
# 10/10 - 0s - loss: 4.1459e-04 - 45ms/epoch - 4ms/step
# Epoch 202/300
# 10/10 - 0s - loss: 2.7872e-04 - 50ms/epoch - 5ms/step
# Epoch 203/300
# 10/10 - 0s - loss: 3.3039e-04 - 48ms/epoch - 5ms/step
# Epoch 204/300
# 10/10 - 0s - loss: 1.7596e-04 - 47ms/epoch - 5ms/step
# Epoch 205/300
# 10/10 - 0s - loss: 1.1320e-04 - 50ms/epoch - 5ms/step
# Epoch 206/300
# 10/10 - 0s - loss: 9.6023e-05 - 46ms/epoch - 5ms/step
# Epoch 207/300
# 10/10 - 0s - loss: 1.0721e-04 - 50ms/epoch - 5ms/step
# Epoch 208/300
# 10/10 - 0s - loss: 1.1993e-04 - 46ms/epoch - 5ms/step
# Epoch 209/300
# 10/10 - 0s - loss: 8.9136e-05 - 47ms/epoch - 5ms/step
# Epoch 210/300
# 10/10 - 0s - loss: 1.0414e-04 - 49ms/epoch - 5ms/step
# Epoch 211/300
# 10/10 - 0s - loss: 1.0119e-04 - 49ms/epoch - 5ms/step
# Epoch 212/300
# 10/10 - 0s - loss: 7.9928e-05 - 54ms/epoch - 5ms/step
# Epoch 213/300
# 10/10 - 0s - loss: 6.6902e-05 - 54ms/epoch - 5ms/step
# Epoch 214/300
# 10/10 - 0s - loss: 5.0551e-05 - 57ms/epoch - 6ms/step
# Epoch 215/300
# 10/10 - 0s - loss: 5.8418e-05 - 54ms/epoch - 5ms/step
# Epoch 216/300
# 10/10 - 0s - loss: 3.5769e-05 - 52ms/epoch - 5ms/step
# Epoch 217/300
# 10/10 - 0s - loss: 3.6536e-05 - 50ms/epoch - 5ms/step
# Epoch 218/300
# 10/10 - 0s - loss: 5.3608e-05 - 51ms/epoch - 5ms/step
# Epoch 219/300
# 10/10 - 0s - loss: 6.9542e-05 - 50ms/epoch - 5ms/step
# Epoch 220/300
# 10/10 - 0s - loss: 8.6185e-05 - 50ms/epoch - 5ms/step
# Epoch 221/300
# 10/10 - 0s - loss: 1.0871e-04 - 53ms/epoch - 5ms/step
# Epoch 222/300
# 10/10 - 0s - loss: 3.6518e-05 - 54ms/epoch - 5ms/step
# Epoch 223/300
# 10/10 - 0s - loss: 3.3325e-05 - 53ms/epoch - 5ms/step
# Epoch 224/300
# 10/10 - 0s - loss: 3.3653e-05 - 49ms/epoch - 5ms/step
# Epoch 225/300
# 10/10 - 0s - loss: 3.2041e-05 - 49ms/epoch - 5ms/step
# Epoch 226/300
# 10/10 - 0s - loss: 2.4743e-05 - 47ms/epoch - 5ms/step
# Epoch 227/300
# 10/10 - 0s - loss: 2.3538e-05 - 49ms/epoch - 5ms/step
# Epoch 228/300
# 10/10 - 0s - loss: 4.4878e-05 - 52ms/epoch - 5ms/step
# Epoch 229/300
# 10/10 - 0s - loss: 4.5137e-05 - 51ms/epoch - 5ms/step
# Epoch 230/300
# 10/10 - 0s - loss: 6.9800e-05 - 51ms/epoch - 5ms/step
# Epoch 231/300
# 10/10 - 0s - loss: 3.4667e-05 - 50ms/epoch - 5ms/step
# Epoch 232/300
# 10/10 - 0s - loss: 2.8795e-05 - 47ms/epoch - 5ms/step
# Epoch 233/300
# 10/10 - 0s - loss: 2.3310e-05 - 51ms/epoch - 5ms/step
# Epoch 234/300
# 10/10 - 0s - loss: 3.0817e-05 - 55ms/epoch - 6ms/step
# Epoch 235/300
# 10/10 - 0s - loss: 3.9298e-05 - 54ms/epoch - 5ms/step
# Epoch 236/300
# 10/10 - 0s - loss: 5.8649e-05 - 57ms/epoch - 6ms/step
# Epoch 237/300
# 10/10 - 0s - loss: 3.8508e-05 - 50ms/epoch - 5ms/step
# Epoch 238/300
# 10/10 - 0s - loss: 3.4686e-05 - 54ms/epoch - 5ms/step
# Epoch 239/300
# 10/10 - 0s - loss: 1.8670e-05 - 56ms/epoch - 6ms/step
# Epoch 240/300
# 10/10 - 0s - loss: 1.0454e-05 - 53ms/epoch - 5ms/step
# Epoch 241/300
# 10/10 - 0s - loss: 9.8089e-06 - 50ms/epoch - 5ms/step
# Epoch 242/300
# 10/10 - 0s - loss: 8.2525e-06 - 47ms/epoch - 5ms/step
# Epoch 243/300
# 10/10 - 0s - loss: 7.5255e-06 - 46ms/epoch - 5ms/step
# Epoch 244/300
# 10/10 - 0s - loss: 7.9312e-06 - 49ms/epoch - 5ms/step
# Epoch 245/300
# 10/10 - 0s - loss: 8.3759e-06 - 47ms/epoch - 5ms/step
# Epoch 246/300
# 10/10 - 0s - loss: 6.8330e-06 - 48ms/epoch - 5ms/step
# Epoch 247/300
# 10/10 - 0s - loss: 6.3376e-06 - 50ms/epoch - 5ms/step
# Epoch 248/300
# 10/10 - 0s - loss: 6.9072e-06 - 54ms/epoch - 5ms/step
# Epoch 249/300
# 10/10 - 0s - loss: 8.3603e-06 - 55ms/epoch - 6ms/step
# Epoch 250/300
# 10/10 - 0s - loss: 6.6505e-06 - 49ms/epoch - 5ms/step
# Epoch 251/300
# 10/10 - 0s - loss: 6.6625e-06 - 50ms/epoch - 5ms/step
# Epoch 252/300
# 10/10 - 0s - loss: 7.6977e-06 - 53ms/epoch - 5ms/step
# Epoch 253/300
# 10/10 - 0s - loss: 7.0483e-06 - 51ms/epoch - 5ms/step
# Epoch 254/300
# 10/10 - 0s - loss: 8.9844e-06 - 54ms/epoch - 5ms/step
# Epoch 255/300
# 10/10 - 0s - loss: 8.2146e-06 - 56ms/epoch - 6ms/step
# Epoch 256/300
# 10/10 - 0s - loss: 1.1324e-05 - 52ms/epoch - 5ms/step
# Epoch 257/300
# 10/10 - 0s - loss: 3.1830e-05 - 51ms/epoch - 5ms/step
# Epoch 258/300
# 10/10 - 0s - loss: 3.6096e-05 - 54ms/epoch - 5ms/step
# Epoch 259/300
# 10/10 - 0s - loss: 7.6171e-05 - 55ms/epoch - 5ms/step
# Epoch 260/300
# 10/10 - 0s - loss: 5.2090e-05 - 55ms/epoch - 6ms/step
# Epoch 261/300
# 10/10 - 0s - loss: 6.8136e-05 - 50ms/epoch - 5ms/step
# Epoch 262/300
# 10/10 - 0s - loss: 2.9653e-05 - 56ms/epoch - 6ms/step
# Epoch 263/300
# 10/10 - 0s - loss: 5.6453e-05 - 49ms/epoch - 5ms/step
# Epoch 264/300
# 10/10 - 0s - loss: 2.8218e-05 - 58ms/epoch - 6ms/step
# Epoch 265/300
# 10/10 - 0s - loss: 2.7819e-05 - 55ms/epoch - 6ms/step
# Epoch 266/300
# 10/10 - 0s - loss: 5.5778e-05 - 58ms/epoch - 6ms/step
# Epoch 267/300
# 10/10 - 0s - loss: 1.8302e-05 - 52ms/epoch - 5ms/step
# Epoch 268/300
# 10/10 - 0s - loss: 9.6350e-06 - 50ms/epoch - 5ms/step
# Epoch 269/300
# 10/10 - 0s - loss: 1.1064e-05 - 50ms/epoch - 5ms/step
# Epoch 270/300
# 10/10 - 0s - loss: 2.0773e-05 - 49ms/epoch - 5ms/step
# Epoch 271/300
# 10/10 - 0s - loss: 1.4613e-05 - 49ms/epoch - 5ms/step
# Epoch 272/300
# 10/10 - 0s - loss: 3.3941e-05 - 54ms/epoch - 5ms/step
# Epoch 273/300
# 10/10 - 0s - loss: 2.6720e-05 - 53ms/epoch - 5ms/step
# Epoch 274/300
# 10/10 - 0s - loss: 1.4126e-05 - 46ms/epoch - 5ms/step
# Epoch 275/300
# 10/10 - 0s - loss: 1.6042e-05 - 46ms/epoch - 5ms/step
# Epoch 276/300
# 10/10 - 0s - loss: 3.8222e-05 - 49ms/epoch - 5ms/step
# Epoch 277/300
# 10/10 - 0s - loss: 7.4398e-05 - 49ms/epoch - 5ms/step
# Epoch 278/300
# 10/10 - 0s - loss: 3.5205e-05 - 45ms/epoch - 4ms/step
# Epoch 279/300
# 10/10 - 0s - loss: 1.2408e-05 - 45ms/epoch - 4ms/step
# Epoch 280/300
# 10/10 - 0s - loss: 5.8815e-06 - 48ms/epoch - 5ms/step
# Epoch 281/300
# 10/10 - 0s - loss: 4.8464e-06 - 46ms/epoch - 5ms/step
# Epoch 282/300
# 10/10 - 0s - loss: 4.9545e-06 - 45ms/epoch - 4ms/step
# Epoch 283/300
# 10/10 - 0s - loss: 4.1558e-06 - 44ms/epoch - 4ms/step
# Epoch 284/300
# 10/10 - 0s - loss: 1.0568e-05 - 42ms/epoch - 4ms/step
# Epoch 285/300
# 10/10 - 0s - loss: 1.1487e-05 - 45ms/epoch - 4ms/step
# Epoch 286/300
# 10/10 - 0s - loss: 1.9093e-05 - 51ms/epoch - 5ms/step
# Epoch 287/300
# 10/10 - 0s - loss: 9.3048e-06 - 49ms/epoch - 5ms/step
# Epoch 288/300
# 10/10 - 0s - loss: 1.6552e-05 - 47ms/epoch - 5ms/step
# Epoch 289/300
# 10/10 - 0s - loss: 9.8609e-06 - 49ms/epoch - 5ms/step
# Epoch 290/300
# 10/10 - 0s - loss: 1.2036e-05 - 48ms/epoch - 5ms/step
# Epoch 291/300
# 10/10 - 0s - loss: 9.3874e-06 - 48ms/epoch - 5ms/step
# Epoch 292/300
# 10/10 - 0s - loss: 6.9945e-06 - 48ms/epoch - 5ms/step
# Epoch 293/300
# 10/10 - 0s - loss: 3.1794e-05 - 49ms/epoch - 5ms/step
# Epoch 294/300
# 10/10 - 0s - loss: 2.4081e-05 - 43ms/epoch - 4ms/step
# Epoch 295/300
# 10/10 - 0s - loss: 3.5414e-05 - 45ms/epoch - 4ms/step
# Epoch 296/300
# 10/10 - 0s - loss: 4.8434e-05 - 47ms/epoch - 5ms/step
# Epoch 297/300
# 10/10 - 0s - loss: 1.1134e-04 - 50ms/epoch - 5ms/step
# Epoch 298/300
# 10/10 - 0s - loss: 6.0041e-05 - 49ms/epoch - 5ms/step
# Epoch 299/300
# 10/10 - 0s - loss: 1.0975e-05 - 45ms/epoch - 5ms/step
# Epoch 300/300
# 10/10 - 0s - loss: 7.6552e-06 - 46ms/epoch - 5ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 15/15 [==============================] - 0s 4ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710201987.3857408
# Tue Mar 12 00:06:27 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710201987.3977487
# Tue Mar 12 00:06:27 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 10/10 - 1s - loss: 0.2905 - 654ms/epoch - 65ms/step
# Epoch 2/300
# 10/10 - 0s - loss: 0.1035 - 68ms/epoch - 7ms/step
# Epoch 3/300
# 10/10 - 0s - loss: 0.0873 - 78ms/epoch - 8ms/step
# Epoch 4/300
# 10/10 - 0s - loss: 0.0759 - 76ms/epoch - 8ms/step
# Epoch 5/300
# 10/10 - 0s - loss: 0.0765 - 82ms/epoch - 8ms/step
# Epoch 6/300
# 10/10 - 0s - loss: 0.0828 - 70ms/epoch - 7ms/step
# Epoch 7/300
# 10/10 - 0s - loss: 0.0842 - 75ms/epoch - 8ms/step
# Epoch 8/300
# 10/10 - 0s - loss: 0.0722 - 76ms/epoch - 8ms/step
# Epoch 9/300
# 10/10 - 0s - loss: 0.0636 - 72ms/epoch - 7ms/step
# Epoch 10/300
# 10/10 - 0s - loss: 0.0597 - 75ms/epoch - 8ms/step
# Epoch 11/300
# 10/10 - 0s - loss: 0.0682 - 74ms/epoch - 7ms/step
# Epoch 12/300
# 10/10 - 0s - loss: 0.0846 - 81ms/epoch - 8ms/step
# Epoch 13/300
# 10/10 - 0s - loss: 0.0870 - 77ms/epoch - 8ms/step
# Epoch 14/300
# 10/10 - 0s - loss: 0.0811 - 74ms/epoch - 7ms/step
# Epoch 15/300
# 10/10 - 0s - loss: 0.0675 - 73ms/epoch - 7ms/step
# Epoch 16/300
# 10/10 - 0s - loss: 0.0544 - 74ms/epoch - 7ms/step
# Epoch 17/300
# 10/10 - 0s - loss: 0.0520 - 77ms/epoch - 8ms/step
# Epoch 18/300
# 10/10 - 0s - loss: 0.0567 - 72ms/epoch - 7ms/step
# Epoch 19/300
# 10/10 - 0s - loss: 0.0472 - 71ms/epoch - 7ms/step
# Epoch 20/300
# 10/10 - 0s - loss: 0.0405 - 74ms/epoch - 7ms/step
# Epoch 21/300
# 10/10 - 0s - loss: 0.0439 - 75ms/epoch - 7ms/step
# Epoch 22/300
# 10/10 - 0s - loss: 0.0433 - 77ms/epoch - 8ms/step
# Epoch 23/300
# 10/10 - 0s - loss: 0.0350 - 73ms/epoch - 7ms/step
# Epoch 24/300
# 10/10 - 0s - loss: 0.0306 - 70ms/epoch - 7ms/step
# Epoch 25/300
# 10/10 - 0s - loss: 0.0261 - 68ms/epoch - 7ms/step
# Epoch 26/300
# 10/10 - 0s - loss: 0.0271 - 72ms/epoch - 7ms/step
# Epoch 27/300
# 10/10 - 0s - loss: 0.0260 - 75ms/epoch - 7ms/step
# Epoch 28/300
# 10/10 - 0s - loss: 0.0241 - 70ms/epoch - 7ms/step
# Epoch 29/300
# 10/10 - 0s - loss: 0.0286 - 69ms/epoch - 7ms/step
# Epoch 30/300
# 10/10 - 0s - loss: 0.0322 - 72ms/epoch - 7ms/step
# Epoch 31/300
# 10/10 - 0s - loss: 0.0276 - 79ms/epoch - 8ms/step
# Epoch 32/300
# 10/10 - 0s - loss: 0.0196 - 75ms/epoch - 8ms/step
# Epoch 33/300
# 10/10 - 0s - loss: 0.0217 - 76ms/epoch - 8ms/step
# Epoch 34/300
# 10/10 - 0s - loss: 0.0203 - 71ms/epoch - 7ms/step
# Epoch 35/300
# 10/10 - 0s - loss: 0.0212 - 69ms/epoch - 7ms/step
# Epoch 36/300
# 10/10 - 0s - loss: 0.0304 - 76ms/epoch - 8ms/step
# Epoch 37/300
# 10/10 - 0s - loss: 0.0202 - 77ms/epoch - 8ms/step
# Epoch 38/300
# 10/10 - 0s - loss: 0.0222 - 84ms/epoch - 8ms/step
# Epoch 39/300
# 10/10 - 0s - loss: 0.0221 - 76ms/epoch - 8ms/step
# Epoch 40/300
# 10/10 - 0s - loss: 0.0189 - 79ms/epoch - 8ms/step
# Epoch 41/300
# 10/10 - 0s - loss: 0.0176 - 81ms/epoch - 8ms/step
# Epoch 42/300
# 10/10 - 0s - loss: 0.0170 - 74ms/epoch - 7ms/step
# Epoch 43/300
# 10/10 - 0s - loss: 0.0184 - 78ms/epoch - 8ms/step
# Epoch 44/300
# 10/10 - 0s - loss: 0.0173 - 84ms/epoch - 8ms/step
# Epoch 45/300
# 10/10 - 0s - loss: 0.0215 - 84ms/epoch - 8ms/step
# Epoch 46/300
# 10/10 - 0s - loss: 0.0240 - 76ms/epoch - 8ms/step
# Epoch 47/300
# 10/10 - 0s - loss: 0.0183 - 76ms/epoch - 8ms/step
# Epoch 48/300
# 10/10 - 0s - loss: 0.0201 - 73ms/epoch - 7ms/step
# Epoch 49/300
# 10/10 - 0s - loss: 0.0161 - 75ms/epoch - 7ms/step
# Epoch 50/300
# 10/10 - 0s - loss: 0.0168 - 75ms/epoch - 7ms/step
# Epoch 51/300
# 10/10 - 0s - loss: 0.0204 - 76ms/epoch - 8ms/step
# Epoch 52/300
# 10/10 - 0s - loss: 0.0188 - 83ms/epoch - 8ms/step
# Epoch 53/300
# 10/10 - 0s - loss: 0.0189 - 79ms/epoch - 8ms/step
# Epoch 54/300
# 10/10 - 0s - loss: 0.0157 - 71ms/epoch - 7ms/step
# Epoch 55/300
# 10/10 - 0s - loss: 0.0156 - 77ms/epoch - 8ms/step
# Epoch 56/300
# 10/10 - 0s - loss: 0.0171 - 77ms/epoch - 8ms/step
# Epoch 57/300
# 10/10 - 0s - loss: 0.0146 - 75ms/epoch - 8ms/step
# Epoch 58/300
# 10/10 - 0s - loss: 0.0160 - 77ms/epoch - 8ms/step
# Epoch 59/300
# 10/10 - 0s - loss: 0.0146 - 76ms/epoch - 8ms/step
# Epoch 60/300
# 10/10 - 0s - loss: 0.0180 - 75ms/epoch - 7ms/step
# Epoch 61/300
# 10/10 - 0s - loss: 0.0191 - 77ms/epoch - 8ms/step
# Epoch 62/300
# 10/10 - 0s - loss: 0.0192 - 83ms/epoch - 8ms/step
# Epoch 63/300
# 10/10 - 0s - loss: 0.0165 - 77ms/epoch - 8ms/step
# Epoch 64/300
# 10/10 - 0s - loss: 0.0194 - 81ms/epoch - 8ms/step
# Epoch 65/300
# 10/10 - 0s - loss: 0.0230 - 76ms/epoch - 8ms/step
# Epoch 66/300
# 10/10 - 0s - loss: 0.0180 - 85ms/epoch - 8ms/step
# Epoch 67/300
# 10/10 - 0s - loss: 0.0194 - 84ms/epoch - 8ms/step
# Epoch 68/300
# 10/10 - 0s - loss: 0.0210 - 78ms/epoch - 8ms/step
# Epoch 69/300
# 10/10 - 0s - loss: 0.0192 - 77ms/epoch - 8ms/step
# Epoch 70/300
# 10/10 - 0s - loss: 0.0194 - 80ms/epoch - 8ms/step
# Epoch 71/300
# 10/10 - 0s - loss: 0.0184 - 79ms/epoch - 8ms/step
# Epoch 72/300
# 10/10 - 0s - loss: 0.0190 - 82ms/epoch - 8ms/step
# Epoch 73/300
# 10/10 - 0s - loss: 0.0172 - 75ms/epoch - 7ms/step
# Epoch 74/300
# 10/10 - 0s - loss: 0.0193 - 85ms/epoch - 8ms/step
# Epoch 75/300
# 10/10 - 0s - loss: 0.0143 - 78ms/epoch - 8ms/step
# Epoch 76/300
# 10/10 - 0s - loss: 0.0130 - 73ms/epoch - 7ms/step
# Epoch 77/300
# 10/10 - 0s - loss: 0.0145 - 78ms/epoch - 8ms/step
# Epoch 78/300
# 10/10 - 0s - loss: 0.0155 - 72ms/epoch - 7ms/step
# Epoch 79/300
# 10/10 - 0s - loss: 0.0199 - 79ms/epoch - 8ms/step
# Epoch 80/300
# 10/10 - 0s - loss: 0.0176 - 79ms/epoch - 8ms/step
# Epoch 81/300
# 10/10 - 0s - loss: 0.0190 - 77ms/epoch - 8ms/step
# Epoch 82/300
# 10/10 - 0s - loss: 0.0195 - 78ms/epoch - 8ms/step
# Epoch 83/300
# 10/10 - 0s - loss: 0.0174 - 80ms/epoch - 8ms/step
# Epoch 84/300
# 10/10 - 0s - loss: 0.0144 - 72ms/epoch - 7ms/step
# Epoch 85/300
# 10/10 - 0s - loss: 0.0120 - 72ms/epoch - 7ms/step
# Epoch 86/300
# 10/10 - 0s - loss: 0.0156 - 80ms/epoch - 8ms/step
# Epoch 87/300
# 10/10 - 0s - loss: 0.0112 - 75ms/epoch - 7ms/step
# Epoch 88/300
# 10/10 - 0s - loss: 0.0119 - 74ms/epoch - 7ms/step
# Epoch 89/300
# 10/10 - 0s - loss: 0.0140 - 80ms/epoch - 8ms/step
# Epoch 90/300
# 10/10 - 0s - loss: 0.0130 - 78ms/epoch - 8ms/step
# Epoch 91/300
# 10/10 - 0s - loss: 0.0115 - 82ms/epoch - 8ms/step
# Epoch 92/300
# 10/10 - 0s - loss: 0.0113 - 91ms/epoch - 9ms/step
# Epoch 93/300
# 10/10 - 0s - loss: 0.0115 - 87ms/epoch - 9ms/step
# Epoch 94/300
# 10/10 - 0s - loss: 0.0108 - 85ms/epoch - 9ms/step
# Epoch 95/300
# 10/10 - 0s - loss: 0.0120 - 84ms/epoch - 8ms/step
# Epoch 96/300
# 10/10 - 0s - loss: 0.0137 - 75ms/epoch - 8ms/step
# Epoch 97/300
# 10/10 - 0s - loss: 0.0128 - 77ms/epoch - 8ms/step
# Epoch 98/300
# 10/10 - 0s - loss: 0.0116 - 79ms/epoch - 8ms/step
# Epoch 99/300
# 10/10 - 0s - loss: 0.0133 - 75ms/epoch - 7ms/step
# Epoch 100/300
# 10/10 - 0s - loss: 0.0133 - 81ms/epoch - 8ms/step
# Epoch 101/300
# 10/10 - 0s - loss: 0.0150 - 78ms/epoch - 8ms/step
# Epoch 102/300
# 10/10 - 0s - loss: 0.0147 - 82ms/epoch - 8ms/step
# Epoch 103/300
# 10/10 - 0s - loss: 0.0127 - 82ms/epoch - 8ms/step
# Epoch 104/300
# 10/10 - 0s - loss: 0.0127 - 76ms/epoch - 8ms/step
# Epoch 105/300
# 10/10 - 0s - loss: 0.0118 - 85ms/epoch - 8ms/step
# Epoch 106/300
# 10/10 - 0s - loss: 0.0143 - 81ms/epoch - 8ms/step
# Epoch 107/300
# 10/10 - 0s - loss: 0.0130 - 87ms/epoch - 9ms/step
# Epoch 108/300
# 10/10 - 0s - loss: 0.0121 - 76ms/epoch - 8ms/step
# Epoch 109/300
# 10/10 - 0s - loss: 0.0128 - 79ms/epoch - 8ms/step
# Epoch 110/300
# 10/10 - 0s - loss: 0.0103 - 88ms/epoch - 9ms/step
# Epoch 111/300
# 10/10 - 0s - loss: 0.0090 - 83ms/epoch - 8ms/step
# Epoch 112/300
# 10/10 - 0s - loss: 0.0121 - 83ms/epoch - 8ms/step
# Epoch 113/300
# 10/10 - 0s - loss: 0.0123 - 85ms/epoch - 9ms/step
# Epoch 114/300
# 10/10 - 0s - loss: 0.0133 - 87ms/epoch - 9ms/step
# Epoch 115/300
# 10/10 - 0s - loss: 0.0118 - 81ms/epoch - 8ms/step
# Epoch 116/300
# 10/10 - 0s - loss: 0.0132 - 77ms/epoch - 8ms/step
# Epoch 117/300
# 10/10 - 0s - loss: 0.0163 - 76ms/epoch - 8ms/step
# Epoch 118/300
# 10/10 - 0s - loss: 0.0136 - 79ms/epoch - 8ms/step
# Epoch 119/300
# 10/10 - 0s - loss: 0.0121 - 73ms/epoch - 7ms/step
# Epoch 120/300
# 10/10 - 0s - loss: 0.0125 - 74ms/epoch - 7ms/step
# Epoch 121/300
# 10/10 - 0s - loss: 0.0106 - 79ms/epoch - 8ms/step
# Epoch 122/300
# 10/10 - 0s - loss: 0.0097 - 70ms/epoch - 7ms/step
# Epoch 123/300
# 10/10 - 0s - loss: 0.0078 - 74ms/epoch - 7ms/step
# Epoch 124/300
# 10/10 - 0s - loss: 0.0101 - 74ms/epoch - 7ms/step
# Epoch 125/300
# 10/10 - 0s - loss: 0.0089 - 76ms/epoch - 8ms/step
# Epoch 126/300
# 10/10 - 0s - loss: 0.0093 - 71ms/epoch - 7ms/step
# Epoch 127/300
# 10/10 - 0s - loss: 0.0090 - 78ms/epoch - 8ms/step
# Epoch 128/300
# 10/10 - 0s - loss: 0.0086 - 74ms/epoch - 7ms/step
# Epoch 129/300
# 10/10 - 0s - loss: 0.0083 - 76ms/epoch - 8ms/step
# Epoch 130/300
# 10/10 - 0s - loss: 0.0089 - 78ms/epoch - 8ms/step
# Epoch 131/300
# 10/10 - 0s - loss: 0.0099 - 80ms/epoch - 8ms/step
# Epoch 132/300
# 10/10 - 0s - loss: 0.0081 - 75ms/epoch - 7ms/step
# Epoch 133/300
# 10/10 - 0s - loss: 0.0096 - 72ms/epoch - 7ms/step
# Epoch 134/300
# 10/10 - 0s - loss: 0.0115 - 76ms/epoch - 8ms/step
# Epoch 135/300
# 10/10 - 0s - loss: 0.0118 - 80ms/epoch - 8ms/step
# Epoch 136/300
# 10/10 - 0s - loss: 0.0150 - 73ms/epoch - 7ms/step
# Epoch 137/300
# 10/10 - 0s - loss: 0.0134 - 75ms/epoch - 8ms/step
# Epoch 138/300
# 10/10 - 0s - loss: 0.0147 - 83ms/epoch - 8ms/step
# Epoch 139/300
# 10/10 - 0s - loss: 0.0149 - 77ms/epoch - 8ms/step
# Epoch 140/300
# 10/10 - 0s - loss: 0.0104 - 72ms/epoch - 7ms/step
# Epoch 141/300
# 10/10 - 0s - loss: 0.0110 - 77ms/epoch - 8ms/step
# Epoch 142/300
# 10/10 - 0s - loss: 0.0113 - 75ms/epoch - 7ms/step
# Epoch 143/300
# 10/10 - 0s - loss: 0.0136 - 72ms/epoch - 7ms/step
# Epoch 144/300
# 10/10 - 0s - loss: 0.0106 - 74ms/epoch - 7ms/step
# Epoch 145/300
# 10/10 - 0s - loss: 0.0122 - 70ms/epoch - 7ms/step
# Epoch 146/300
# 10/10 - 0s - loss: 0.0160 - 76ms/epoch - 8ms/step
# Epoch 147/300
# 10/10 - 0s - loss: 0.0182 - 71ms/epoch - 7ms/step
# Epoch 148/300
# 10/10 - 0s - loss: 0.0120 - 76ms/epoch - 8ms/step
# Epoch 149/300
# 10/10 - 0s - loss: 0.0136 - 75ms/epoch - 8ms/step
# Epoch 150/300
# 10/10 - 0s - loss: 0.0145 - 71ms/epoch - 7ms/step
# Epoch 151/300
# 10/10 - 0s - loss: 0.0135 - 74ms/epoch - 7ms/step
# Epoch 152/300
# 10/10 - 0s - loss: 0.0107 - 78ms/epoch - 8ms/step
# Epoch 153/300
# 10/10 - 0s - loss: 0.0109 - 73ms/epoch - 7ms/step
# Epoch 154/300
# 10/10 - 0s - loss: 0.0092 - 72ms/epoch - 7ms/step
# Epoch 155/300
# 10/10 - 0s - loss: 0.0059 - 79ms/epoch - 8ms/step
# Epoch 156/300
# 10/10 - 0s - loss: 0.0067 - 76ms/epoch - 8ms/step
# Epoch 157/300
# 10/10 - 0s - loss: 0.0060 - 77ms/epoch - 8ms/step
# Epoch 158/300
# 10/10 - 0s - loss: 0.0060 - 86ms/epoch - 9ms/step
# Epoch 159/300
# 10/10 - 0s - loss: 0.0053 - 76ms/epoch - 8ms/step
# Epoch 160/300
# 10/10 - 0s - loss: 0.0056 - 81ms/epoch - 8ms/step
# Epoch 161/300
# 10/10 - 0s - loss: 0.0058 - 77ms/epoch - 8ms/step
# Epoch 162/300
# 10/10 - 0s - loss: 0.0051 - 71ms/epoch - 7ms/step
# Epoch 163/300
# 10/10 - 0s - loss: 0.0058 - 75ms/epoch - 7ms/step
# Epoch 164/300
# 10/10 - 0s - loss: 0.0059 - 88ms/epoch - 9ms/step
# Epoch 165/300
# 10/10 - 0s - loss: 0.0070 - 71ms/epoch - 7ms/step
# Epoch 166/300
# 10/10 - 0s - loss: 0.0058 - 73ms/epoch - 7ms/step
# Epoch 167/300
# 10/10 - 0s - loss: 0.0043 - 71ms/epoch - 7ms/step
# Epoch 168/300
# 10/10 - 0s - loss: 0.0049 - 79ms/epoch - 8ms/step
# Epoch 169/300
# 10/10 - 0s - loss: 0.0057 - 72ms/epoch - 7ms/step
# Epoch 170/300
# 10/10 - 0s - loss: 0.0056 - 71ms/epoch - 7ms/step
# Epoch 171/300
# 10/10 - 0s - loss: 0.0044 - 75ms/epoch - 8ms/step
# Epoch 172/300
# 10/10 - 0s - loss: 0.0045 - 80ms/epoch - 8ms/step
# Epoch 173/300
# 10/10 - 0s - loss: 0.0033 - 75ms/epoch - 7ms/step
# Epoch 174/300
# 10/10 - 0s - loss: 0.0037 - 73ms/epoch - 7ms/step
# Epoch 175/300
# 10/10 - 0s - loss: 0.0033 - 68ms/epoch - 7ms/step
# Epoch 176/300
# 10/10 - 0s - loss: 0.0039 - 70ms/epoch - 7ms/step
# Epoch 177/300
# 10/10 - 0s - loss: 0.0033 - 79ms/epoch - 8ms/step
# Epoch 178/300
# 10/10 - 0s - loss: 0.0030 - 79ms/epoch - 8ms/step
# Epoch 179/300
# 10/10 - 0s - loss: 0.0042 - 74ms/epoch - 7ms/step
# Epoch 180/300
# 10/10 - 0s - loss: 0.0048 - 71ms/epoch - 7ms/step
# Epoch 181/300
# 10/10 - 0s - loss: 0.0064 - 73ms/epoch - 7ms/step
# Epoch 182/300
# 10/10 - 0s - loss: 0.0039 - 72ms/epoch - 7ms/step
# Epoch 183/300
# 10/10 - 0s - loss: 0.0044 - 66ms/epoch - 7ms/step
# Epoch 184/300
# 10/10 - 0s - loss: 0.0039 - 67ms/epoch - 7ms/step
# Epoch 185/300
# 10/10 - 0s - loss: 0.0036 - 68ms/epoch - 7ms/step
# Epoch 186/300
# 10/10 - 0s - loss: 0.0035 - 69ms/epoch - 7ms/step
# Epoch 187/300
# 10/10 - 0s - loss: 0.0030 - 79ms/epoch - 8ms/step
# Epoch 188/300
# 10/10 - 0s - loss: 0.0038 - 73ms/epoch - 7ms/step
# Epoch 189/300
# 10/10 - 0s - loss: 0.0042 - 69ms/epoch - 7ms/step
# Epoch 190/300
# 10/10 - 0s - loss: 0.0022 - 80ms/epoch - 8ms/step
# Epoch 191/300
# 10/10 - 0s - loss: 0.0023 - 79ms/epoch - 8ms/step
# Epoch 192/300
# 10/10 - 0s - loss: 0.0016 - 76ms/epoch - 8ms/step
# Epoch 193/300
# 10/10 - 0s - loss: 0.0027 - 76ms/epoch - 8ms/step
# Epoch 194/300
# 10/10 - 0s - loss: 0.0034 - 74ms/epoch - 7ms/step
# Epoch 195/300
# 10/10 - 0s - loss: 0.0024 - 72ms/epoch - 7ms/step
# Epoch 196/300
# 10/10 - 0s - loss: 0.0014 - 76ms/epoch - 8ms/step
# Epoch 197/300
# 10/10 - 0s - loss: 0.0022 - 75ms/epoch - 8ms/step
# Epoch 198/300
# 10/10 - 0s - loss: 0.0030 - 76ms/epoch - 8ms/step
# Epoch 199/300
# 10/10 - 0s - loss: 0.0028 - 74ms/epoch - 7ms/step
# Epoch 200/300
# 10/10 - 0s - loss: 0.0043 - 75ms/epoch - 8ms/step
# Epoch 201/300
# 10/10 - 0s - loss: 0.0045 - 75ms/epoch - 7ms/step
# Epoch 202/300
# 10/10 - 0s - loss: 0.0023 - 73ms/epoch - 7ms/step
# Epoch 203/300
# 10/10 - 0s - loss: 0.0033 - 76ms/epoch - 8ms/step
# Epoch 204/300
# 10/10 - 0s - loss: 0.0016 - 74ms/epoch - 7ms/step
# Epoch 205/300
# 10/10 - 0s - loss: 0.0013 - 74ms/epoch - 7ms/step
# Epoch 206/300
# 10/10 - 0s - loss: 0.0012 - 68ms/epoch - 7ms/step
# Epoch 207/300
# 10/10 - 0s - loss: 0.0011 - 71ms/epoch - 7ms/step
# Epoch 208/300
# 10/10 - 0s - loss: 0.0014 - 67ms/epoch - 7ms/step
# Epoch 209/300
# 10/10 - 0s - loss: 8.6285e-04 - 75ms/epoch - 8ms/step
# Epoch 210/300
# 10/10 - 0s - loss: 0.0013 - 77ms/epoch - 8ms/step
# Epoch 211/300
# 10/10 - 0s - loss: 0.0017 - 69ms/epoch - 7ms/step
# Epoch 212/300
# 10/10 - 0s - loss: 0.0011 - 73ms/epoch - 7ms/step
# Epoch 213/300
# 10/10 - 0s - loss: 8.4179e-04 - 74ms/epoch - 7ms/step
# Epoch 214/300
# 10/10 - 0s - loss: 0.0010 - 72ms/epoch - 7ms/step
# Epoch 215/300
# 10/10 - 0s - loss: 7.2071e-04 - 74ms/epoch - 7ms/step
# Epoch 216/300
# 10/10 - 0s - loss: 8.2808e-04 - 80ms/epoch - 8ms/step
# Epoch 217/300
# 10/10 - 0s - loss: 7.0818e-04 - 80ms/epoch - 8ms/step
# Epoch 218/300
# 10/10 - 0s - loss: 5.6460e-04 - 74ms/epoch - 7ms/step
# Epoch 219/300
# 10/10 - 0s - loss: 5.7745e-04 - 73ms/epoch - 7ms/step
# Epoch 220/300
# 10/10 - 0s - loss: 4.9559e-04 - 76ms/epoch - 8ms/step
# Epoch 221/300
# 10/10 - 0s - loss: 4.8182e-04 - 74ms/epoch - 7ms/step
# Epoch 222/300
# 10/10 - 0s - loss: 4.0920e-04 - 74ms/epoch - 7ms/step
# Epoch 223/300
# 10/10 - 0s - loss: 4.4057e-04 - 80ms/epoch - 8ms/step
# Epoch 224/300
# 10/10 - 0s - loss: 0.0013 - 74ms/epoch - 7ms/step
# Epoch 225/300
# 10/10 - 0s - loss: 0.0016 - 75ms/epoch - 7ms/step
# Epoch 226/300
# 10/10 - 0s - loss: 0.0022 - 75ms/epoch - 7ms/step
# Epoch 227/300
# 10/10 - 0s - loss: 0.0011 - 74ms/epoch - 7ms/step
# Epoch 228/300
# 10/10 - 0s - loss: 8.7660e-04 - 79ms/epoch - 8ms/step
# Epoch 229/300
# 10/10 - 0s - loss: 5.0272e-04 - 77ms/epoch - 8ms/step
# Epoch 230/300
# 10/10 - 0s - loss: 2.7000e-04 - 77ms/epoch - 8ms/step
# Epoch 231/300
# 10/10 - 0s - loss: 2.1503e-04 - 75ms/epoch - 7ms/step
# Epoch 232/300
# 10/10 - 0s - loss: 2.6219e-04 - 74ms/epoch - 7ms/step
# Epoch 233/300
# 10/10 - 0s - loss: 2.9820e-04 - 73ms/epoch - 7ms/step
# Epoch 234/300
# 10/10 - 0s - loss: 4.3659e-04 - 72ms/epoch - 7ms/step
# Epoch 235/300
# 10/10 - 0s - loss: 3.9739e-04 - 74ms/epoch - 7ms/step
# Epoch 236/300
# 10/10 - 0s - loss: 2.1074e-04 - 67ms/epoch - 7ms/step
# Epoch 237/300
# 10/10 - 0s - loss: 3.2608e-04 - 79ms/epoch - 8ms/step
# Epoch 238/300
# 10/10 - 0s - loss: 3.9321e-04 - 71ms/epoch - 7ms/step
# Epoch 239/300
# 10/10 - 0s - loss: 2.0392e-04 - 84ms/epoch - 8ms/step
# Epoch 240/300
# 10/10 - 0s - loss: 2.2825e-04 - 84ms/epoch - 8ms/step
# Epoch 241/300
# 10/10 - 0s - loss: 2.3245e-04 - 83ms/epoch - 8ms/step
# Epoch 242/300
# 10/10 - 0s - loss: 1.9726e-04 - 78ms/epoch - 8ms/step
# Epoch 243/300
# 10/10 - 0s - loss: 1.3778e-04 - 78ms/epoch - 8ms/step
# Epoch 244/300
# 10/10 - 0s - loss: 1.0468e-04 - 79ms/epoch - 8ms/step
# Epoch 245/300
# 10/10 - 0s - loss: 1.3340e-04 - 71ms/epoch - 7ms/step
# Epoch 246/300
# 10/10 - 0s - loss: 1.1483e-04 - 74ms/epoch - 7ms/step
# Epoch 247/300
# 10/10 - 0s - loss: 6.8404e-05 - 78ms/epoch - 8ms/step
# Epoch 248/300
# 10/10 - 0s - loss: 1.5110e-04 - 76ms/epoch - 8ms/step
# Epoch 249/300
# 10/10 - 0s - loss: 1.3914e-04 - 75ms/epoch - 7ms/step
# Epoch 250/300
# 10/10 - 0s - loss: 7.7760e-05 - 72ms/epoch - 7ms/step
# Epoch 251/300
# 10/10 - 0s - loss: 2.3548e-04 - 82ms/epoch - 8ms/step
# Epoch 252/300
# 10/10 - 0s - loss: 3.2568e-04 - 78ms/epoch - 8ms/step
# Epoch 253/300
# 10/10 - 0s - loss: 1.7306e-04 - 83ms/epoch - 8ms/step
# Epoch 254/300
# 10/10 - 0s - loss: 2.6474e-04 - 77ms/epoch - 8ms/step
# Epoch 255/300
# 10/10 - 0s - loss: 2.5646e-04 - 78ms/epoch - 8ms/step
# Epoch 256/300
# 10/10 - 0s - loss: 2.4934e-04 - 79ms/epoch - 8ms/step
# Epoch 257/300
# 10/10 - 0s - loss: 1.3844e-04 - 83ms/epoch - 8ms/step
# Epoch 258/300
# 10/10 - 0s - loss: 9.8155e-05 - 74ms/epoch - 7ms/step
# Epoch 259/300
# 10/10 - 0s - loss: 9.1834e-05 - 81ms/epoch - 8ms/step
# Epoch 260/300
# 10/10 - 0s - loss: 9.7918e-05 - 78ms/epoch - 8ms/step
# Epoch 261/300
# 10/10 - 0s - loss: 9.0040e-05 - 72ms/epoch - 7ms/step
# Epoch 262/300
# 10/10 - 0s - loss: 9.9648e-05 - 73ms/epoch - 7ms/step
# Epoch 263/300
# 10/10 - 0s - loss: 1.0182e-04 - 72ms/epoch - 7ms/step
# Epoch 264/300
# 10/10 - 0s - loss: 1.4933e-04 - 74ms/epoch - 7ms/step
# Epoch 265/300
# 10/10 - 0s - loss: 3.1333e-04 - 69ms/epoch - 7ms/step
# Epoch 266/300
# 10/10 - 0s - loss: 4.3702e-04 - 77ms/epoch - 8ms/step
# Epoch 267/300
# 10/10 - 0s - loss: 3.0446e-04 - 80ms/epoch - 8ms/step
# Epoch 268/300
# 10/10 - 0s - loss: 2.3304e-04 - 79ms/epoch - 8ms/step
# Epoch 269/300
# 10/10 - 0s - loss: 1.5151e-04 - 70ms/epoch - 7ms/step
# Epoch 270/300
# 10/10 - 0s - loss: 1.0446e-04 - 72ms/epoch - 7ms/step
# Epoch 271/300
# 10/10 - 0s - loss: 1.1755e-04 - 66ms/epoch - 7ms/step
# Epoch 272/300
# 10/10 - 0s - loss: 1.4671e-04 - 76ms/epoch - 8ms/step
# Epoch 273/300
# 10/10 - 0s - loss: 1.6646e-04 - 71ms/epoch - 7ms/step
# Epoch 274/300
# 10/10 - 0s - loss: 1.5073e-04 - 71ms/epoch - 7ms/step
# Epoch 275/300
# 10/10 - 0s - loss: 1.4935e-04 - 68ms/epoch - 7ms/step
# Epoch 276/300
# 10/10 - 0s - loss: 2.7752e-04 - 72ms/epoch - 7ms/step
# Epoch 277/300
# 10/10 - 0s - loss: 9.2585e-04 - 73ms/epoch - 7ms/step
# Epoch 278/300
# 10/10 - 0s - loss: 0.0020 - 74ms/epoch - 7ms/step
# Epoch 279/300
# 10/10 - 0s - loss: 0.0023 - 75ms/epoch - 7ms/step
# Epoch 280/300
# 10/10 - 0s - loss: 0.0014 - 70ms/epoch - 7ms/step
# Epoch 281/300
# 10/10 - 0s - loss: 6.5896e-04 - 75ms/epoch - 8ms/step
# Epoch 282/300
# 10/10 - 0s - loss: 8.8420e-04 - 74ms/epoch - 7ms/step
# Epoch 283/300
# 10/10 - 0s - loss: 0.0013 - 73ms/epoch - 7ms/step
# Epoch 284/300
# 10/10 - 0s - loss: 0.0061 - 71ms/epoch - 7ms/step
# Epoch 285/300
# 10/10 - 0s - loss: 0.0048 - 74ms/epoch - 7ms/step
# Epoch 286/300
# 10/10 - 0s - loss: 0.0034 - 70ms/epoch - 7ms/step
# Epoch 287/300
# 10/10 - 0s - loss: 0.0027 - 73ms/epoch - 7ms/step
# Epoch 288/300
# 10/10 - 0s - loss: 0.0030 - 69ms/epoch - 7ms/step
# Epoch 289/300
# 10/10 - 0s - loss: 0.0047 - 74ms/epoch - 7ms/step
# Epoch 290/300
# 10/10 - 0s - loss: 0.0075 - 72ms/epoch - 7ms/step
# Epoch 291/300
# 10/10 - 0s - loss: 0.0136 - 74ms/epoch - 7ms/step
# Epoch 292/300
# 10/10 - 0s - loss: 0.0093 - 63ms/epoch - 6ms/step
# Epoch 293/300
# 10/10 - 0s - loss: 0.0087 - 69ms/epoch - 7ms/step
# Epoch 294/300
# 10/10 - 0s - loss: 0.0069 - 72ms/epoch - 7ms/step
# Epoch 295/300
# 10/10 - 0s - loss: 0.0063 - 74ms/epoch - 7ms/step
# Epoch 296/300
# 10/10 - 0s - loss: 0.0068 - 66ms/epoch - 7ms/step
# Epoch 297/300
# 10/10 - 0s - loss: 0.0048 - 70ms/epoch - 7ms/step
# Epoch 298/300
# 10/10 - 0s - loss: 0.0031 - 66ms/epoch - 7ms/step
# Epoch 299/300
# 10/10 - 0s - loss: 0.0030 - 69ms/epoch - 7ms/step
# Epoch 300/300
# 10/10 - 0s - loss: 0.0024 - 73ms/epoch - 7ms/step
# 15/15 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710202011.8621678
# Tue Mar 12 00:06:51 2024
