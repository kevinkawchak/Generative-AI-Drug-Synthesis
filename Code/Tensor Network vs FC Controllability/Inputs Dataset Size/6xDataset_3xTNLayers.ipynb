# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_95 (Dense)            (None, 1024)              3072
#
#  dense_96 (Dense)            (None, 1024)              1049600
#
#  dense_97 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_98 (Dense)            (None, 1024)              3072
#
#  tn_layer_57 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_58 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_59 (TNLayer)       (None, 1024)              5120
#
#  dense_99 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(120, 2) + np.array([3, 3]),
                    np.random.randn(120, 2) + np.array([-3, -3]),
                    np.random.randn(120, 2) + np.array([-3, 3]),
                    np.random.randn(120, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((240)), -np.ones((240))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710202822.548771
# Tue Mar 12 00:20:22 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 15/15 - 2s - loss: 1.0022 - 2s/epoch - 116ms/step
# Epoch 2/300
# 15/15 - 0s - loss: 0.9975 - 71ms/epoch - 5ms/step
# Epoch 3/300
# 15/15 - 0s - loss: 0.8652 - 71ms/epoch - 5ms/step
# Epoch 4/300
# 15/15 - 0s - loss: 0.1288 - 74ms/epoch - 5ms/step
# Epoch 5/300
# 15/15 - 0s - loss: 0.0369 - 71ms/epoch - 5ms/step
# Epoch 6/300
# 15/15 - 0s - loss: 0.0204 - 75ms/epoch - 5ms/step
# Epoch 7/300
# 15/15 - 0s - loss: 0.0122 - 72ms/epoch - 5ms/step
# Epoch 8/300
# 15/15 - 0s - loss: 0.0101 - 69ms/epoch - 5ms/step
# Epoch 9/300
# 15/15 - 0s - loss: 0.0085 - 70ms/epoch - 5ms/step
# Epoch 10/300
# 15/15 - 0s - loss: 0.0074 - 77ms/epoch - 5ms/step
# Epoch 11/300
# 15/15 - 0s - loss: 0.0065 - 71ms/epoch - 5ms/step
# Epoch 12/300
# 15/15 - 0s - loss: 0.0048 - 74ms/epoch - 5ms/step
# Epoch 13/300
# 15/15 - 0s - loss: 0.0043 - 72ms/epoch - 5ms/step
# Epoch 14/300
# 15/15 - 0s - loss: 0.0034 - 69ms/epoch - 5ms/step
# Epoch 15/300
# 15/15 - 0s - loss: 0.0027 - 65ms/epoch - 4ms/step
# Epoch 16/300
# 15/15 - 0s - loss: 0.0017 - 71ms/epoch - 5ms/step
# Epoch 17/300
# 15/15 - 0s - loss: 0.0015 - 68ms/epoch - 5ms/step
# Epoch 18/300
# 15/15 - 0s - loss: 7.7428e-04 - 73ms/epoch - 5ms/step
# Epoch 19/300
# 15/15 - 0s - loss: 5.7264e-04 - 71ms/epoch - 5ms/step
# Epoch 20/300
# 15/15 - 0s - loss: 3.3146e-04 - 77ms/epoch - 5ms/step
# Epoch 21/300
# 15/15 - 0s - loss: 2.1473e-04 - 74ms/epoch - 5ms/step
# Epoch 22/300
# 15/15 - 0s - loss: 1.3760e-04 - 74ms/epoch - 5ms/step
# Epoch 23/300
# 15/15 - 0s - loss: 1.0006e-04 - 73ms/epoch - 5ms/step
# Epoch 24/300
# 15/15 - 0s - loss: 8.2000e-05 - 85ms/epoch - 6ms/step
# Epoch 25/300
# 15/15 - 0s - loss: 5.7012e-05 - 76ms/epoch - 5ms/step
# Epoch 26/300
# 15/15 - 0s - loss: 5.0689e-05 - 85ms/epoch - 6ms/step
# Epoch 27/300
# 15/15 - 0s - loss: 4.4549e-05 - 79ms/epoch - 5ms/step
# Epoch 28/300
# 15/15 - 0s - loss: 3.6514e-05 - 76ms/epoch - 5ms/step
# Epoch 29/300
# 15/15 - 0s - loss: 3.0760e-05 - 79ms/epoch - 5ms/step
# Epoch 30/300
# 15/15 - 0s - loss: 2.7161e-05 - 78ms/epoch - 5ms/step
# Epoch 31/300
# 15/15 - 0s - loss: 2.6549e-05 - 74ms/epoch - 5ms/step
# Epoch 32/300
# 15/15 - 0s - loss: 1.9938e-05 - 85ms/epoch - 6ms/step
# Epoch 33/300
# 15/15 - 0s - loss: 1.9704e-05 - 77ms/epoch - 5ms/step
# Epoch 34/300
# 15/15 - 0s - loss: 1.7462e-05 - 80ms/epoch - 5ms/step
# Epoch 35/300
# 15/15 - 0s - loss: 1.4739e-05 - 81ms/epoch - 5ms/step
# Epoch 36/300
# 15/15 - 0s - loss: 1.4591e-05 - 86ms/epoch - 6ms/step
# Epoch 37/300
# 15/15 - 0s - loss: 1.3860e-05 - 80ms/epoch - 5ms/step
# Epoch 38/300
# 15/15 - 0s - loss: 1.2389e-05 - 85ms/epoch - 6ms/step
# Epoch 39/300
# 15/15 - 0s - loss: 1.1002e-05 - 78ms/epoch - 5ms/step
# Epoch 40/300
# 15/15 - 0s - loss: 9.4399e-06 - 79ms/epoch - 5ms/step
# Epoch 41/300
# 15/15 - 0s - loss: 8.3764e-06 - 80ms/epoch - 5ms/step
# Epoch 42/300
# 15/15 - 0s - loss: 7.6256e-06 - 79ms/epoch - 5ms/step
# Epoch 43/300
# 15/15 - 0s - loss: 7.4507e-06 - 71ms/epoch - 5ms/step
# Epoch 44/300
# 15/15 - 0s - loss: 6.2813e-06 - 73ms/epoch - 5ms/step
# Epoch 45/300
# 15/15 - 0s - loss: 5.7433e-06 - 72ms/epoch - 5ms/step
# Epoch 46/300
# 15/15 - 0s - loss: 5.6464e-06 - 67ms/epoch - 4ms/step
# Epoch 47/300
# 15/15 - 0s - loss: 5.3511e-06 - 73ms/epoch - 5ms/step
# Epoch 48/300
# 15/15 - 0s - loss: 4.9780e-06 - 71ms/epoch - 5ms/step
# Epoch 49/300
# 15/15 - 0s - loss: 5.2470e-06 - 70ms/epoch - 5ms/step
# Epoch 50/300
# 15/15 - 0s - loss: 3.8293e-06 - 65ms/epoch - 4ms/step
# Epoch 51/300
# 15/15 - 0s - loss: 3.9110e-06 - 69ms/epoch - 5ms/step
# Epoch 52/300
# 15/15 - 0s - loss: 4.8758e-06 - 69ms/epoch - 5ms/step
# Epoch 53/300
# 15/15 - 0s - loss: 4.1659e-06 - 67ms/epoch - 4ms/step
# Epoch 54/300
# 15/15 - 0s - loss: 3.4085e-06 - 70ms/epoch - 5ms/step
# Epoch 55/300
# 15/15 - 0s - loss: 2.7639e-06 - 72ms/epoch - 5ms/step
# Epoch 56/300
# 15/15 - 0s - loss: 2.7205e-06 - 75ms/epoch - 5ms/step
# Epoch 57/300
# 15/15 - 0s - loss: 2.8653e-06 - 72ms/epoch - 5ms/step
# Epoch 58/300
# 15/15 - 0s - loss: 2.6704e-06 - 72ms/epoch - 5ms/step
# Epoch 59/300
# 15/15 - 0s - loss: 2.5296e-06 - 70ms/epoch - 5ms/step
# Epoch 60/300
# 15/15 - 0s - loss: 2.2174e-06 - 73ms/epoch - 5ms/step
# Epoch 61/300
# 15/15 - 0s - loss: 1.9724e-06 - 71ms/epoch - 5ms/step
# Epoch 62/300
# 15/15 - 0s - loss: 1.8677e-06 - 69ms/epoch - 5ms/step
# Epoch 63/300
# 15/15 - 0s - loss: 2.1699e-06 - 75ms/epoch - 5ms/step
# Epoch 64/300
# 15/15 - 0s - loss: 1.9064e-06 - 72ms/epoch - 5ms/step
# Epoch 65/300
# 15/15 - 0s - loss: 1.9924e-06 - 76ms/epoch - 5ms/step
# Epoch 66/300
# 15/15 - 0s - loss: 1.5820e-06 - 70ms/epoch - 5ms/step
# Epoch 67/300
# 15/15 - 0s - loss: 1.5932e-06 - 71ms/epoch - 5ms/step
# Epoch 68/300
# 15/15 - 0s - loss: 1.7111e-06 - 68ms/epoch - 5ms/step
# Epoch 69/300
# 15/15 - 0s - loss: 1.8852e-06 - 77ms/epoch - 5ms/step
# Epoch 70/300
# 15/15 - 0s - loss: 1.5959e-06 - 72ms/epoch - 5ms/step
# Epoch 71/300
# 15/15 - 0s - loss: 1.3840e-06 - 71ms/epoch - 5ms/step
# Epoch 72/300
# 15/15 - 0s - loss: 1.4487e-06 - 72ms/epoch - 5ms/step
# Epoch 73/300
# 15/15 - 0s - loss: 1.1719e-06 - 75ms/epoch - 5ms/step
# Epoch 74/300
# 15/15 - 0s - loss: 1.7383e-06 - 66ms/epoch - 4ms/step
# Epoch 75/300
# 15/15 - 0s - loss: 2.1237e-06 - 71ms/epoch - 5ms/step
# Epoch 76/300
# 15/15 - 0s - loss: 2.5542e-06 - 70ms/epoch - 5ms/step
# Epoch 77/300
# 15/15 - 0s - loss: 2.2583e-06 - 71ms/epoch - 5ms/step
# Epoch 78/300
# 15/15 - 0s - loss: 9.1921e-07 - 76ms/epoch - 5ms/step
# Epoch 79/300
# 15/15 - 0s - loss: 8.8630e-07 - 75ms/epoch - 5ms/step
# Epoch 80/300
# 15/15 - 0s - loss: 1.1775e-06 - 70ms/epoch - 5ms/step
# Epoch 81/300
# 15/15 - 0s - loss: 1.0874e-06 - 68ms/epoch - 5ms/step
# Epoch 82/300
# 15/15 - 0s - loss: 1.3367e-06 - 72ms/epoch - 5ms/step
# Epoch 83/300
# 15/15 - 0s - loss: 1.1128e-06 - 72ms/epoch - 5ms/step
# Epoch 84/300
# 15/15 - 0s - loss: 7.4895e-07 - 73ms/epoch - 5ms/step
# Epoch 85/300
# 15/15 - 0s - loss: 1.4896e-06 - 78ms/epoch - 5ms/step
# Epoch 86/300
# 15/15 - 0s - loss: 1.1381e-06 - 75ms/epoch - 5ms/step
# Epoch 87/300
# 15/15 - 0s - loss: 2.1626e-06 - 84ms/epoch - 6ms/step
# Epoch 88/300
# 15/15 - 0s - loss: 7.8387e-07 - 82ms/epoch - 5ms/step
# Epoch 89/300
# 15/15 - 0s - loss: 6.3014e-07 - 81ms/epoch - 5ms/step
# Epoch 90/300
# 15/15 - 0s - loss: 8.5471e-07 - 76ms/epoch - 5ms/step
# Epoch 91/300
# 15/15 - 0s - loss: 9.0703e-07 - 78ms/epoch - 5ms/step
# Epoch 92/300
# 15/15 - 0s - loss: 7.0395e-07 - 75ms/epoch - 5ms/step
# Epoch 93/300
# 15/15 - 0s - loss: 5.7867e-07 - 71ms/epoch - 5ms/step
# Epoch 94/300
# 15/15 - 0s - loss: 7.2649e-07 - 75ms/epoch - 5ms/step
# Epoch 95/300
# 15/15 - 0s - loss: 1.0687e-06 - 80ms/epoch - 5ms/step
# Epoch 96/300
# 15/15 - 0s - loss: 6.7106e-07 - 72ms/epoch - 5ms/step
# Epoch 97/300
# 15/15 - 0s - loss: 5.9278e-07 - 82ms/epoch - 5ms/step
# Epoch 98/300
# 15/15 - 0s - loss: 6.3741e-07 - 81ms/epoch - 5ms/step
# Epoch 99/300
# 15/15 - 0s - loss: 6.1026e-07 - 77ms/epoch - 5ms/step
# Epoch 100/300
# 15/15 - 0s - loss: 5.7936e-07 - 77ms/epoch - 5ms/step
# Epoch 101/300
# 15/15 - 0s - loss: 4.9352e-07 - 81ms/epoch - 5ms/step
# Epoch 102/300
# 15/15 - 0s - loss: 6.1779e-07 - 73ms/epoch - 5ms/step
# Epoch 103/300
# 15/15 - 0s - loss: 5.3917e-07 - 70ms/epoch - 5ms/step
# Epoch 104/300
# 15/15 - 0s - loss: 5.9181e-07 - 69ms/epoch - 5ms/step
# Epoch 105/300
# 15/15 - 0s - loss: 5.0192e-07 - 67ms/epoch - 4ms/step
# Epoch 106/300
# 15/15 - 0s - loss: 4.7190e-07 - 73ms/epoch - 5ms/step
# Epoch 107/300
# 15/15 - 0s - loss: 8.2789e-07 - 69ms/epoch - 5ms/step
# Epoch 108/300
# 15/15 - 0s - loss: 2.2291e-06 - 75ms/epoch - 5ms/step
# Epoch 109/300
# 15/15 - 0s - loss: 1.0042e-06 - 70ms/epoch - 5ms/step
# Epoch 110/300
# 15/15 - 0s - loss: 5.4580e-07 - 72ms/epoch - 5ms/step
# Epoch 111/300
# 15/15 - 0s - loss: 4.6641e-07 - 70ms/epoch - 5ms/step
# Epoch 112/300
# 15/15 - 0s - loss: 7.5457e-07 - 77ms/epoch - 5ms/step
# Epoch 113/300
# 15/15 - 0s - loss: 4.3977e-07 - 78ms/epoch - 5ms/step
# Epoch 114/300
# 15/15 - 0s - loss: 3.2985e-07 - 74ms/epoch - 5ms/step
# Epoch 115/300
# 15/15 - 0s - loss: 3.8665e-07 - 72ms/epoch - 5ms/step
# Epoch 116/300
# 15/15 - 0s - loss: 9.0144e-07 - 78ms/epoch - 5ms/step
# Epoch 117/300
# 15/15 - 0s - loss: 1.1097e-06 - 79ms/epoch - 5ms/step
# Epoch 118/300
# 15/15 - 0s - loss: 5.1193e-07 - 75ms/epoch - 5ms/step
# Epoch 119/300
# 15/15 - 0s - loss: 5.1377e-07 - 72ms/epoch - 5ms/step
# Epoch 120/300
# 15/15 - 0s - loss: 4.0887e-07 - 70ms/epoch - 5ms/step
# Epoch 121/300
# 15/15 - 0s - loss: 3.6115e-07 - 73ms/epoch - 5ms/step
# Epoch 122/300
# 15/15 - 0s - loss: 3.9184e-07 - 72ms/epoch - 5ms/step
# Epoch 123/300
# 15/15 - 0s - loss: 9.5146e-07 - 76ms/epoch - 5ms/step
# Epoch 124/300
# 15/15 - 0s - loss: 3.8475e-07 - 77ms/epoch - 5ms/step
# Epoch 125/300
# 15/15 - 0s - loss: 4.3157e-07 - 73ms/epoch - 5ms/step
# Epoch 126/300
# 15/15 - 0s - loss: 7.3888e-07 - 73ms/epoch - 5ms/step
# Epoch 127/300
# 15/15 - 0s - loss: 9.2998e-07 - 77ms/epoch - 5ms/step
# Epoch 128/300
# 15/15 - 0s - loss: 9.5578e-07 - 78ms/epoch - 5ms/step
# Epoch 129/300
# 15/15 - 0s - loss: 5.0321e-07 - 72ms/epoch - 5ms/step
# Epoch 130/300
# 15/15 - 0s - loss: 3.4135e-07 - 77ms/epoch - 5ms/step
# Epoch 131/300
# 15/15 - 0s - loss: 3.0663e-07 - 77ms/epoch - 5ms/step
# Epoch 132/300
# 15/15 - 0s - loss: 2.9258e-07 - 70ms/epoch - 5ms/step
# Epoch 133/300
# 15/15 - 0s - loss: 2.3231e-07 - 79ms/epoch - 5ms/step
# Epoch 134/300
# 15/15 - 0s - loss: 2.3243e-07 - 75ms/epoch - 5ms/step
# Epoch 135/300
# 15/15 - 0s - loss: 3.7489e-07 - 76ms/epoch - 5ms/step
# Epoch 136/300
# 15/15 - 0s - loss: 4.2009e-07 - 80ms/epoch - 5ms/step
# Epoch 137/300
# 15/15 - 0s - loss: 3.7814e-07 - 71ms/epoch - 5ms/step
# Epoch 138/300
# 15/15 - 0s - loss: 5.6610e-07 - 73ms/epoch - 5ms/step
# Epoch 139/300
# 15/15 - 0s - loss: 7.1424e-07 - 77ms/epoch - 5ms/step
# Epoch 140/300
# 15/15 - 0s - loss: 6.7568e-07 - 74ms/epoch - 5ms/step
# Epoch 141/300
# 15/15 - 0s - loss: 3.0158e-07 - 75ms/epoch - 5ms/step
# Epoch 142/300
# 15/15 - 0s - loss: 5.6709e-07 - 82ms/epoch - 5ms/step
# Epoch 143/300
# 15/15 - 0s - loss: 5.8771e-07 - 76ms/epoch - 5ms/step
# Epoch 144/300
# 15/15 - 0s - loss: 7.0956e-07 - 83ms/epoch - 6ms/step
# Epoch 145/300
# 15/15 - 0s - loss: 5.3598e-07 - 75ms/epoch - 5ms/step
# Epoch 146/300
# 15/15 - 0s - loss: 2.6782e-07 - 76ms/epoch - 5ms/step
# Epoch 147/300
# 15/15 - 0s - loss: 2.2099e-07 - 73ms/epoch - 5ms/step
# Epoch 148/300
# 15/15 - 0s - loss: 2.0515e-07 - 74ms/epoch - 5ms/step
# Epoch 149/300
# 15/15 - 0s - loss: 2.4169e-07 - 78ms/epoch - 5ms/step
# Epoch 150/300
# 15/15 - 0s - loss: 2.4008e-07 - 73ms/epoch - 5ms/step
# Epoch 151/300
# 15/15 - 0s - loss: 2.7253e-07 - 74ms/epoch - 5ms/step
# Epoch 152/300
# 15/15 - 0s - loss: 5.0881e-07 - 74ms/epoch - 5ms/step
# Epoch 153/300
# 15/15 - 0s - loss: 5.0670e-07 - 68ms/epoch - 5ms/step
# Epoch 154/300
# 15/15 - 0s - loss: 8.2449e-07 - 70ms/epoch - 5ms/step
# Epoch 155/300
# 15/15 - 0s - loss: 6.4293e-07 - 82ms/epoch - 5ms/step
# Epoch 156/300
# 15/15 - 0s - loss: 5.0310e-07 - 72ms/epoch - 5ms/step
# Epoch 157/300
# 15/15 - 0s - loss: 6.8505e-07 - 70ms/epoch - 5ms/step
# Epoch 158/300
# 15/15 - 0s - loss: 1.2282e-06 - 74ms/epoch - 5ms/step
# Epoch 159/300
# 15/15 - 0s - loss: 9.4830e-06 - 72ms/epoch - 5ms/step
# Epoch 160/300
# 15/15 - 0s - loss: 1.2833e-05 - 69ms/epoch - 5ms/step
# Epoch 161/300
# 15/15 - 0s - loss: 3.0889e-05 - 76ms/epoch - 5ms/step
# Epoch 162/300
# 15/15 - 0s - loss: 1.2388e-04 - 71ms/epoch - 5ms/step
# Epoch 163/300
# 15/15 - 0s - loss: 6.8117e-05 - 76ms/epoch - 5ms/step
# Epoch 164/300
# 15/15 - 0s - loss: 2.5068e-05 - 71ms/epoch - 5ms/step
# Epoch 165/300
# 15/15 - 0s - loss: 4.2981e-06 - 72ms/epoch - 5ms/step
# Epoch 166/300
# 15/15 - 0s - loss: 2.8857e-06 - 77ms/epoch - 5ms/step
# Epoch 167/300
# 15/15 - 0s - loss: 1.3598e-06 - 79ms/epoch - 5ms/step
# Epoch 168/300
# 15/15 - 0s - loss: 4.3512e-07 - 77ms/epoch - 5ms/step
# Epoch 169/300
# 15/15 - 0s - loss: 8.5053e-07 - 74ms/epoch - 5ms/step
# Epoch 170/300
# 15/15 - 0s - loss: 3.3322e-06 - 74ms/epoch - 5ms/step
# Epoch 171/300
# 15/15 - 0s - loss: 5.7944e-06 - 71ms/epoch - 5ms/step
# Epoch 172/300
# 15/15 - 0s - loss: 6.3112e-06 - 75ms/epoch - 5ms/step
# Epoch 173/300
# 15/15 - 0s - loss: 6.9322e-06 - 73ms/epoch - 5ms/step
# Epoch 174/300
# 15/15 - 0s - loss: 2.4591e-06 - 76ms/epoch - 5ms/step
# Epoch 175/300
# 15/15 - 0s - loss: 1.3589e-06 - 80ms/epoch - 5ms/step
# Epoch 176/300
# 15/15 - 0s - loss: 1.9807e-06 - 80ms/epoch - 5ms/step
# Epoch 177/300
# 15/15 - 0s - loss: 1.6899e-06 - 79ms/epoch - 5ms/step
# Epoch 178/300
# 15/15 - 0s - loss: 1.6188e-06 - 78ms/epoch - 5ms/step
# Epoch 179/300
# 15/15 - 0s - loss: 5.2114e-07 - 80ms/epoch - 5ms/step
# Epoch 180/300
# 15/15 - 0s - loss: 2.8125e-07 - 77ms/epoch - 5ms/step
# Epoch 181/300
# 15/15 - 0s - loss: 6.3773e-07 - 83ms/epoch - 6ms/step
# Epoch 182/300
# 15/15 - 0s - loss: 6.5384e-07 - 84ms/epoch - 6ms/step
# Epoch 183/300
# 15/15 - 0s - loss: 1.8395e-06 - 83ms/epoch - 6ms/step
# Epoch 184/300
# 15/15 - 0s - loss: 1.0620e-06 - 80ms/epoch - 5ms/step
# Epoch 185/300
# 15/15 - 0s - loss: 1.0482e-06 - 83ms/epoch - 6ms/step
# Epoch 186/300
# 15/15 - 0s - loss: 1.0266e-06 - 82ms/epoch - 5ms/step
# Epoch 187/300
# 15/15 - 0s - loss: 1.4980e-06 - 80ms/epoch - 5ms/step
# Epoch 188/300
# 15/15 - 0s - loss: 2.0158e-06 - 77ms/epoch - 5ms/step
# Epoch 189/300
# 15/15 - 0s - loss: 2.3045e-06 - 81ms/epoch - 5ms/step
# Epoch 190/300
# 15/15 - 0s - loss: 4.8637e-06 - 82ms/epoch - 5ms/step
# Epoch 191/300
# 15/15 - 0s - loss: 1.8575e-05 - 88ms/epoch - 6ms/step
# Epoch 192/300
# 15/15 - 0s - loss: 4.1842e-06 - 90ms/epoch - 6ms/step
# Epoch 193/300
# 15/15 - 0s - loss: 1.9794e-05 - 84ms/epoch - 6ms/step
# Epoch 194/300
# 15/15 - 0s - loss: 2.6548e-05 - 73ms/epoch - 5ms/step
# Epoch 195/300
# 15/15 - 0s - loss: 2.2662e-04 - 72ms/epoch - 5ms/step
# Epoch 196/300
# 15/15 - 0s - loss: 2.8601e-04 - 71ms/epoch - 5ms/step
# Epoch 197/300
# 15/15 - 0s - loss: 1.5551e-04 - 75ms/epoch - 5ms/step
# Epoch 198/300
# 15/15 - 0s - loss: 5.4885e-05 - 70ms/epoch - 5ms/step
# Epoch 199/300
# 15/15 - 0s - loss: 1.5340e-05 - 70ms/epoch - 5ms/step
# Epoch 200/300
# 15/15 - 0s - loss: 3.7474e-06 - 67ms/epoch - 4ms/step
# Epoch 201/300
# 15/15 - 0s - loss: 8.6520e-07 - 75ms/epoch - 5ms/step
# Epoch 202/300
# 15/15 - 0s - loss: 5.5302e-07 - 75ms/epoch - 5ms/step
# Epoch 203/300
# 15/15 - 0s - loss: 1.8760e-06 - 75ms/epoch - 5ms/step
# Epoch 204/300
# 15/15 - 0s - loss: 2.0554e-06 - 72ms/epoch - 5ms/step
# Epoch 205/300
# 15/15 - 0s - loss: 7.2052e-07 - 72ms/epoch - 5ms/step
# Epoch 206/300
# 15/15 - 0s - loss: 1.9718e-07 - 69ms/epoch - 5ms/step
# Epoch 207/300
# 15/15 - 0s - loss: 1.7824e-07 - 67ms/epoch - 4ms/step
# Epoch 208/300
# 15/15 - 0s - loss: 2.0956e-07 - 68ms/epoch - 5ms/step
# Epoch 209/300
# 15/15 - 0s - loss: 2.6377e-07 - 70ms/epoch - 5ms/step
# Epoch 210/300
# 15/15 - 0s - loss: 1.3351e-07 - 69ms/epoch - 5ms/step
# Epoch 211/300
# 15/15 - 0s - loss: 1.1963e-07 - 69ms/epoch - 5ms/step
# Epoch 212/300
# 15/15 - 0s - loss: 2.4476e-07 - 68ms/epoch - 5ms/step
# Epoch 213/300
# 15/15 - 0s - loss: 3.1272e-07 - 68ms/epoch - 5ms/step
# Epoch 214/300
# 15/15 - 0s - loss: 1.7961e-07 - 70ms/epoch - 5ms/step
# Epoch 215/300
# 15/15 - 0s - loss: 7.2494e-08 - 68ms/epoch - 5ms/step
# Epoch 216/300
# 15/15 - 0s - loss: 2.0514e-07 - 72ms/epoch - 5ms/step
# Epoch 217/300
# 15/15 - 0s - loss: 3.7687e-07 - 73ms/epoch - 5ms/step
# Epoch 218/300
# 15/15 - 0s - loss: 5.4141e-07 - 72ms/epoch - 5ms/step
# Epoch 219/300
# 15/15 - 0s - loss: 2.6171e-07 - 79ms/epoch - 5ms/step
# Epoch 220/300
# 15/15 - 0s - loss: 1.2962e-07 - 71ms/epoch - 5ms/step
# Epoch 221/300
# 15/15 - 0s - loss: 1.9537e-07 - 70ms/epoch - 5ms/step
# Epoch 222/300
# 15/15 - 0s - loss: 1.4139e-07 - 76ms/epoch - 5ms/step
# Epoch 223/300
# 15/15 - 0s - loss: 1.7045e-07 - 76ms/epoch - 5ms/step
# Epoch 224/300
# 15/15 - 0s - loss: 7.4671e-07 - 70ms/epoch - 5ms/step
# Epoch 225/300
# 15/15 - 0s - loss: 1.4344e-06 - 73ms/epoch - 5ms/step
# Epoch 226/300
# 15/15 - 0s - loss: 3.6853e-06 - 69ms/epoch - 5ms/step
# Epoch 227/300
# 15/15 - 0s - loss: 1.7517e-06 - 70ms/epoch - 5ms/step
# Epoch 228/300
# 15/15 - 0s - loss: 8.3834e-06 - 68ms/epoch - 5ms/step
# Epoch 229/300
# 15/15 - 0s - loss: 7.3088e-06 - 71ms/epoch - 5ms/step
# Epoch 230/300
# 15/15 - 0s - loss: 2.3881e-05 - 70ms/epoch - 5ms/step
# Epoch 231/300
# 15/15 - 0s - loss: 2.9250e-05 - 69ms/epoch - 5ms/step
# Epoch 232/300
# 15/15 - 0s - loss: 1.2428e-05 - 70ms/epoch - 5ms/step
# Epoch 233/300
# 15/15 - 0s - loss: 9.3305e-06 - 75ms/epoch - 5ms/step
# Epoch 234/300
# 15/15 - 0s - loss: 3.0660e-06 - 68ms/epoch - 5ms/step
# Epoch 235/300
# 15/15 - 0s - loss: 2.3645e-06 - 71ms/epoch - 5ms/step
# Epoch 236/300
# 15/15 - 0s - loss: 1.3352e-06 - 76ms/epoch - 5ms/step
# Epoch 237/300
# 15/15 - 0s - loss: 2.9925e-06 - 74ms/epoch - 5ms/step
# Epoch 238/300
# 15/15 - 0s - loss: 1.5411e-06 - 73ms/epoch - 5ms/step
# Epoch 239/300
# 15/15 - 0s - loss: 3.1295e-07 - 70ms/epoch - 5ms/step
# Epoch 240/300
# 15/15 - 0s - loss: 3.7862e-07 - 77ms/epoch - 5ms/step
# Epoch 241/300
# 15/15 - 0s - loss: 1.5217e-07 - 80ms/epoch - 5ms/step
# Epoch 242/300
# 15/15 - 0s - loss: 1.2877e-07 - 77ms/epoch - 5ms/step
# Epoch 243/300
# 15/15 - 0s - loss: 2.4643e-07 - 75ms/epoch - 5ms/step
# Epoch 244/300
# 15/15 - 0s - loss: 1.8884e-07 - 77ms/epoch - 5ms/step
# Epoch 245/300
# 15/15 - 0s - loss: 4.8184e-07 - 78ms/epoch - 5ms/step
# Epoch 246/300
# 15/15 - 0s - loss: 1.3812e-06 - 75ms/epoch - 5ms/step
# Epoch 247/300
# 15/15 - 0s - loss: 5.2470e-07 - 64ms/epoch - 4ms/step
# Epoch 248/300
# 15/15 - 0s - loss: 2.6460e-07 - 70ms/epoch - 5ms/step
# Epoch 249/300
# 15/15 - 0s - loss: 3.7432e-07 - 69ms/epoch - 5ms/step
# Epoch 250/300
# 15/15 - 0s - loss: 1.0917e-06 - 70ms/epoch - 5ms/step
# Epoch 251/300
# 15/15 - 0s - loss: 1.0303e-05 - 67ms/epoch - 4ms/step
# Epoch 252/300
# 15/15 - 0s - loss: 3.2573e-05 - 74ms/epoch - 5ms/step
# Epoch 253/300
# 15/15 - 0s - loss: 5.2345e-05 - 71ms/epoch - 5ms/step
# Epoch 254/300
# 15/15 - 0s - loss: 5.2758e-05 - 71ms/epoch - 5ms/step
# Epoch 255/300
# 15/15 - 0s - loss: 3.4499e-05 - 74ms/epoch - 5ms/step
# Epoch 256/300
# 15/15 - 0s - loss: 1.3457e-05 - 74ms/epoch - 5ms/step
# Epoch 257/300
# 15/15 - 0s - loss: 1.7318e-05 - 82ms/epoch - 5ms/step
# Epoch 258/300
# 15/15 - 0s - loss: 2.8020e-05 - 78ms/epoch - 5ms/step
# Epoch 259/300
# 15/15 - 0s - loss: 8.3900e-06 - 77ms/epoch - 5ms/step
# Epoch 260/300
# 15/15 - 0s - loss: 7.6326e-06 - 74ms/epoch - 5ms/step
# Epoch 261/300
# 15/15 - 0s - loss: 1.0632e-05 - 73ms/epoch - 5ms/step
# Epoch 262/300
# 15/15 - 0s - loss: 3.1862e-05 - 72ms/epoch - 5ms/step
# Epoch 263/300
# 15/15 - 0s - loss: 4.0047e-05 - 70ms/epoch - 5ms/step
# Epoch 264/300
# 15/15 - 0s - loss: 9.7433e-05 - 71ms/epoch - 5ms/step
# Epoch 265/300
# 15/15 - 0s - loss: 6.1929e-05 - 66ms/epoch - 4ms/step
# Epoch 266/300
# 15/15 - 0s - loss: 1.0185e-04 - 70ms/epoch - 5ms/step
# Epoch 267/300
# 15/15 - 0s - loss: 7.7584e-05 - 73ms/epoch - 5ms/step
# Epoch 268/300
# 15/15 - 0s - loss: 9.0837e-05 - 68ms/epoch - 5ms/step
# Epoch 269/300
# 15/15 - 0s - loss: 3.0778e-04 - 67ms/epoch - 4ms/step
# Epoch 270/300
# 15/15 - 0s - loss: 0.0027 - 70ms/epoch - 5ms/step
# Epoch 271/300
# 15/15 - 0s - loss: 0.0179 - 72ms/epoch - 5ms/step
# Epoch 272/300
# 15/15 - 0s - loss: 0.0181 - 73ms/epoch - 5ms/step
# Epoch 273/300
# 15/15 - 0s - loss: 0.0120 - 72ms/epoch - 5ms/step
# Epoch 274/300
# 15/15 - 0s - loss: 0.0021 - 68ms/epoch - 5ms/step
# Epoch 275/300
# 15/15 - 0s - loss: 4.8043e-04 - 66ms/epoch - 4ms/step
# Epoch 276/300
# 15/15 - 0s - loss: 4.4685e-04 - 69ms/epoch - 5ms/step
# Epoch 277/300
# 15/15 - 0s - loss: 1.6702e-04 - 67ms/epoch - 4ms/step
# Epoch 278/300
# 15/15 - 0s - loss: 2.9747e-05 - 67ms/epoch - 4ms/step
# Epoch 279/300
# 15/15 - 0s - loss: 1.2655e-05 - 71ms/epoch - 5ms/step
# Epoch 280/300
# 15/15 - 0s - loss: 7.2795e-06 - 69ms/epoch - 5ms/step
# Epoch 281/300
# 15/15 - 0s - loss: 4.6412e-06 - 72ms/epoch - 5ms/step
# Epoch 282/300
# 15/15 - 0s - loss: 4.7976e-06 - 67ms/epoch - 4ms/step
# Epoch 283/300
# 15/15 - 0s - loss: 6.7132e-06 - 71ms/epoch - 5ms/step
# Epoch 284/300
# 15/15 - 0s - loss: 5.4387e-06 - 78ms/epoch - 5ms/step
# Epoch 285/300
# 15/15 - 0s - loss: 2.4312e-06 - 70ms/epoch - 5ms/step
# Epoch 286/300
# 15/15 - 0s - loss: 2.3516e-06 - 70ms/epoch - 5ms/step
# Epoch 287/300
# 15/15 - 0s - loss: 1.8180e-06 - 71ms/epoch - 5ms/step
# Epoch 288/300
# 15/15 - 0s - loss: 1.6888e-06 - 70ms/epoch - 5ms/step
# Epoch 289/300
# 15/15 - 0s - loss: 1.5891e-06 - 70ms/epoch - 5ms/step
# Epoch 290/300
# 15/15 - 0s - loss: 1.7817e-06 - 68ms/epoch - 5ms/step
# Epoch 291/300
# 15/15 - 0s - loss: 1.9334e-06 - 73ms/epoch - 5ms/step
# Epoch 292/300
# 15/15 - 0s - loss: 1.0758e-06 - 75ms/epoch - 5ms/step
# Epoch 293/300
# 15/15 - 0s - loss: 1.0849e-06 - 70ms/epoch - 5ms/step
# Epoch 294/300
# 15/15 - 0s - loss: 1.0504e-06 - 72ms/epoch - 5ms/step
# Epoch 295/300
# 15/15 - 0s - loss: 1.5150e-06 - 73ms/epoch - 5ms/step
# Epoch 296/300
# 15/15 - 0s - loss: 9.2573e-07 - 71ms/epoch - 5ms/step
# Epoch 297/300
# 15/15 - 0s - loss: 7.0491e-07 - 76ms/epoch - 5ms/step
# Epoch 298/300
# 15/15 - 0s - loss: 7.3950e-07 - 77ms/epoch - 5ms/step
# Epoch 299/300
# 15/15 - 0s - loss: 8.9395e-07 - 67ms/epoch - 4ms/step
# Epoch 300/300
# 15/15 - 0s - loss: 6.4383e-07 - 69ms/epoch - 5ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 16/16 [==============================] - 0s 4ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710202848.026646
# Tue Mar 12 00:20:48 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710202848.038269
# Tue Mar 12 00:20:48 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 15/15 - 1s - loss: 0.2714 - 709ms/epoch - 47ms/step
# Epoch 2/300
# 15/15 - 0s - loss: 0.1293 - 113ms/epoch - 8ms/step
# Epoch 3/300
# 15/15 - 0s - loss: 0.0801 - 114ms/epoch - 8ms/step
# Epoch 4/300
# 15/15 - 0s - loss: 0.0728 - 111ms/epoch - 7ms/step
# Epoch 5/300
# 15/15 - 0s - loss: 0.0682 - 115ms/epoch - 8ms/step
# Epoch 6/300
# 15/15 - 0s - loss: 0.0673 - 126ms/epoch - 8ms/step
# Epoch 7/300
# 15/15 - 0s - loss: 0.0591 - 123ms/epoch - 8ms/step
# Epoch 8/300
# 15/15 - 0s - loss: 0.0578 - 119ms/epoch - 8ms/step
# Epoch 9/300
# 15/15 - 0s - loss: 0.0546 - 115ms/epoch - 8ms/step
# Epoch 10/300
# 15/15 - 0s - loss: 0.0494 - 114ms/epoch - 8ms/step
# Epoch 11/300
# 15/15 - 0s - loss: 0.0442 - 115ms/epoch - 8ms/step
# Epoch 12/300
# 15/15 - 0s - loss: 0.0365 - 113ms/epoch - 8ms/step
# Epoch 13/300
# 15/15 - 0s - loss: 0.0311 - 108ms/epoch - 7ms/step
# Epoch 14/300
# 15/15 - 0s - loss: 0.0271 - 117ms/epoch - 8ms/step
# Epoch 15/300
# 15/15 - 0s - loss: 0.0293 - 120ms/epoch - 8ms/step
# Epoch 16/300
# 15/15 - 0s - loss: 0.0244 - 110ms/epoch - 7ms/step
# Epoch 17/300
# 15/15 - 0s - loss: 0.0192 - 108ms/epoch - 7ms/step
# Epoch 18/300
# 15/15 - 0s - loss: 0.0136 - 107ms/epoch - 7ms/step
# Epoch 19/300
# 15/15 - 0s - loss: 0.0101 - 118ms/epoch - 8ms/step
# Epoch 20/300
# 15/15 - 0s - loss: 0.0085 - 121ms/epoch - 8ms/step
# Epoch 21/300
# 15/15 - 0s - loss: 0.0101 - 109ms/epoch - 7ms/step
# Epoch 22/300
# 15/15 - 0s - loss: 0.0066 - 100ms/epoch - 7ms/step
# Epoch 23/300
# 15/15 - 0s - loss: 0.0064 - 98ms/epoch - 7ms/step
# Epoch 24/300
# 15/15 - 0s - loss: 0.0035 - 109ms/epoch - 7ms/step
# Epoch 25/300
# 15/15 - 0s - loss: 0.0053 - 115ms/epoch - 8ms/step
# Epoch 26/300
# 15/15 - 0s - loss: 0.0050 - 107ms/epoch - 7ms/step
# Epoch 27/300
# 15/15 - 0s - loss: 0.0029 - 106ms/epoch - 7ms/step
# Epoch 28/300
# 15/15 - 0s - loss: 0.0026 - 112ms/epoch - 7ms/step
# Epoch 29/300
# 15/15 - 0s - loss: 0.0020 - 114ms/epoch - 8ms/step
# Epoch 30/300
# 15/15 - 0s - loss: 0.0019 - 121ms/epoch - 8ms/step
# Epoch 31/300
# 15/15 - 0s - loss: 0.0020 - 115ms/epoch - 8ms/step
# Epoch 32/300
# 15/15 - 0s - loss: 0.0027 - 111ms/epoch - 7ms/step
# Epoch 33/300
# 15/15 - 0s - loss: 0.0029 - 104ms/epoch - 7ms/step
# Epoch 34/300
# 15/15 - 0s - loss: 0.0019 - 101ms/epoch - 7ms/step
# Epoch 35/300
# 15/15 - 0s - loss: 0.0025 - 106ms/epoch - 7ms/step
# Epoch 36/300
# 15/15 - 0s - loss: 0.0016 - 102ms/epoch - 7ms/step
# Epoch 37/300
# 15/15 - 0s - loss: 0.0016 - 105ms/epoch - 7ms/step
# Epoch 38/300
# 15/15 - 0s - loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 39/300
# 15/15 - 0s - loss: 0.0012 - 114ms/epoch - 8ms/step
# Epoch 40/300
# 15/15 - 0s - loss: 0.0012 - 101ms/epoch - 7ms/step
# Epoch 41/300
# 15/15 - 0s - loss: 0.0013 - 110ms/epoch - 7ms/step
# Epoch 42/300
# 15/15 - 0s - loss: 0.0011 - 102ms/epoch - 7ms/step
# Epoch 43/300
# 15/15 - 0s - loss: 0.0014 - 115ms/epoch - 8ms/step
# Epoch 44/300
# 15/15 - 0s - loss: 0.0020 - 105ms/epoch - 7ms/step
# Epoch 45/300
# 15/15 - 0s - loss: 0.0026 - 101ms/epoch - 7ms/step
# Epoch 46/300
# 15/15 - 0s - loss: 0.0023 - 105ms/epoch - 7ms/step
# Epoch 47/300
# 15/15 - 0s - loss: 0.0021 - 102ms/epoch - 7ms/step
# Epoch 48/300
# 15/15 - 0s - loss: 0.0016 - 117ms/epoch - 8ms/step
# Epoch 49/300
# 15/15 - 0s - loss: 0.0012 - 111ms/epoch - 7ms/step
# Epoch 50/300
# 15/15 - 0s - loss: 9.2995e-04 - 111ms/epoch - 7ms/step
# Epoch 51/300
# 15/15 - 0s - loss: 5.5202e-04 - 104ms/epoch - 7ms/step
# Epoch 52/300
# 15/15 - 0s - loss: 5.1985e-04 - 106ms/epoch - 7ms/step
# Epoch 53/300
# 15/15 - 0s - loss: 5.1833e-04 - 105ms/epoch - 7ms/step
# Epoch 54/300
# 15/15 - 0s - loss: 6.3941e-04 - 102ms/epoch - 7ms/step
# Epoch 55/300
# 15/15 - 0s - loss: 0.0016 - 105ms/epoch - 7ms/step
# Epoch 56/300
# 15/15 - 0s - loss: 0.0024 - 100ms/epoch - 7ms/step
# Epoch 57/300
# 15/15 - 0s - loss: 0.0013 - 104ms/epoch - 7ms/step
# Epoch 58/300
# 15/15 - 0s - loss: 9.7558e-04 - 105ms/epoch - 7ms/step
# Epoch 59/300
# 15/15 - 0s - loss: 9.5145e-04 - 113ms/epoch - 8ms/step
# Epoch 60/300
# 15/15 - 0s - loss: 0.0013 - 110ms/epoch - 7ms/step
# Epoch 61/300
# 15/15 - 0s - loss: 0.0041 - 107ms/epoch - 7ms/step
# Epoch 62/300
# 15/15 - 0s - loss: 0.0036 - 109ms/epoch - 7ms/step
# Epoch 63/300
# 15/15 - 0s - loss: 0.0016 - 107ms/epoch - 7ms/step
# Epoch 64/300
# 15/15 - 0s - loss: 0.0014 - 110ms/epoch - 7ms/step
# Epoch 65/300
# 15/15 - 0s - loss: 0.0016 - 101ms/epoch - 7ms/step
# Epoch 66/300
# 15/15 - 0s - loss: 0.0024 - 106ms/epoch - 7ms/step
# Epoch 67/300
# 15/15 - 0s - loss: 0.0039 - 99ms/epoch - 7ms/step
# Epoch 68/300
# 15/15 - 0s - loss: 0.0019 - 102ms/epoch - 7ms/step
# Epoch 69/300
# 15/15 - 0s - loss: 0.0011 - 100ms/epoch - 7ms/step
# Epoch 70/300
# 15/15 - 0s - loss: 0.0025 - 100ms/epoch - 7ms/step
# Epoch 71/300
# 15/15 - 0s - loss: 0.0042 - 95ms/epoch - 6ms/step
# Epoch 72/300
# 15/15 - 0s - loss: 0.0078 - 101ms/epoch - 7ms/step
# Epoch 73/300
# 15/15 - 0s - loss: 0.0028 - 100ms/epoch - 7ms/step
# Epoch 74/300
# 15/15 - 0s - loss: 0.0066 - 109ms/epoch - 7ms/step
# Epoch 75/300
# 15/15 - 0s - loss: 0.0086 - 99ms/epoch - 7ms/step
# Epoch 76/300
# 15/15 - 0s - loss: 0.0027 - 98ms/epoch - 7ms/step
# Epoch 77/300
# 15/15 - 0s - loss: 0.0022 - 100ms/epoch - 7ms/step
# Epoch 78/300
# 15/15 - 0s - loss: 5.3993e-04 - 103ms/epoch - 7ms/step
# Epoch 79/300
# 15/15 - 0s - loss: 3.6907e-04 - 147ms/epoch - 10ms/step
# Epoch 80/300
# 15/15 - 0s - loss: 3.0993e-04 - 132ms/epoch - 9ms/step
# Epoch 81/300
# 15/15 - 0s - loss: 4.6522e-04 - 106ms/epoch - 7ms/step
# Epoch 82/300
# 15/15 - 0s - loss: 3.1476e-04 - 103ms/epoch - 7ms/step
# Epoch 83/300
# 15/15 - 0s - loss: 2.7350e-04 - 108ms/epoch - 7ms/step
# Epoch 84/300
# 15/15 - 0s - loss: 4.3034e-04 - 108ms/epoch - 7ms/step
# Epoch 85/300
# 15/15 - 0s - loss: 9.4883e-04 - 118ms/epoch - 8ms/step
# Epoch 86/300
# 15/15 - 0s - loss: 5.7994e-04 - 176ms/epoch - 12ms/step
# Epoch 87/300
# 15/15 - 0s - loss: 4.8697e-04 - 119ms/epoch - 8ms/step
# Epoch 88/300
# 15/15 - 0s - loss: 4.3686e-04 - 111ms/epoch - 7ms/step
# Epoch 89/300
# 15/15 - 0s - loss: 5.0013e-04 - 116ms/epoch - 8ms/step
# Epoch 90/300
# 15/15 - 0s - loss: 3.6536e-04 - 116ms/epoch - 8ms/step
# Epoch 91/300
# 15/15 - 0s - loss: 1.4216e-04 - 117ms/epoch - 8ms/step
# Epoch 92/300
# 15/15 - 0s - loss: 2.2038e-04 - 124ms/epoch - 8ms/step
# Epoch 93/300
# 15/15 - 0s - loss: 2.8359e-04 - 120ms/epoch - 8ms/step
# Epoch 94/300
# 15/15 - 0s - loss: 1.9713e-04 - 110ms/epoch - 7ms/step
# Epoch 95/300
# 15/15 - 0s - loss: 2.6260e-04 - 106ms/epoch - 7ms/step
# Epoch 96/300
# 15/15 - 0s - loss: 5.0641e-04 - 113ms/epoch - 8ms/step
# Epoch 97/300
# 15/15 - 0s - loss: 4.7148e-04 - 119ms/epoch - 8ms/step
# Epoch 98/300
# 15/15 - 0s - loss: 3.1559e-04 - 109ms/epoch - 7ms/step
# Epoch 99/300
# 15/15 - 0s - loss: 1.7535e-04 - 109ms/epoch - 7ms/step
# Epoch 100/300
# 15/15 - 0s - loss: 1.4836e-04 - 123ms/epoch - 8ms/step
# Epoch 101/300
# 15/15 - 0s - loss: 2.0293e-04 - 119ms/epoch - 8ms/step
# Epoch 102/300
# 15/15 - 0s - loss: 2.9763e-04 - 119ms/epoch - 8ms/step
# Epoch 103/300
# 15/15 - 0s - loss: 3.5333e-04 - 108ms/epoch - 7ms/step
# Epoch 104/300
# 15/15 - 0s - loss: 2.2451e-04 - 109ms/epoch - 7ms/step
# Epoch 105/300
# 15/15 - 0s - loss: 7.6894e-04 - 108ms/epoch - 7ms/step
# Epoch 106/300
# 15/15 - 0s - loss: 0.0013 - 109ms/epoch - 7ms/step
# Epoch 107/300
# 15/15 - 0s - loss: 0.0024 - 115ms/epoch - 8ms/step
# Epoch 108/300
# 15/15 - 0s - loss: 0.0049 - 113ms/epoch - 8ms/step
# Epoch 109/300
# 15/15 - 0s - loss: 0.0012 - 105ms/epoch - 7ms/step
# Epoch 110/300
# 15/15 - 0s - loss: 3.2103e-04 - 118ms/epoch - 8ms/step
# Epoch 111/300
# 15/15 - 0s - loss: 6.5651e-04 - 122ms/epoch - 8ms/step
# Epoch 112/300
# 15/15 - 0s - loss: 0.0021 - 116ms/epoch - 8ms/step
# Epoch 113/300
# 15/15 - 0s - loss: 0.0010 - 132ms/epoch - 9ms/step
# Epoch 114/300
# 15/15 - 0s - loss: 8.6184e-04 - 123ms/epoch - 8ms/step
# Epoch 115/300
# 15/15 - 0s - loss: 5.2931e-04 - 112ms/epoch - 7ms/step
# Epoch 116/300
# 15/15 - 0s - loss: 5.8075e-04 - 122ms/epoch - 8ms/step
# Epoch 117/300
# 15/15 - 0s - loss: 2.3575e-04 - 114ms/epoch - 8ms/step
# Epoch 118/300
# 15/15 - 0s - loss: 1.3791e-04 - 113ms/epoch - 8ms/step
# Epoch 119/300
# 15/15 - 0s - loss: 1.1860e-04 - 114ms/epoch - 8ms/step
# Epoch 120/300
# 15/15 - 0s - loss: 1.1957e-04 - 105ms/epoch - 7ms/step
# Epoch 121/300
# 15/15 - 0s - loss: 4.3779e-04 - 112ms/epoch - 7ms/step
# Epoch 122/300
# 15/15 - 0s - loss: 5.8085e-04 - 124ms/epoch - 8ms/step
# Epoch 123/300
# 15/15 - 0s - loss: 7.5188e-04 - 118ms/epoch - 8ms/step
# Epoch 124/300
# 15/15 - 0s - loss: 0.0016 - 114ms/epoch - 8ms/step
# Epoch 125/300
# 15/15 - 0s - loss: 0.0018 - 121ms/epoch - 8ms/step
# Epoch 126/300
# 15/15 - 0s - loss: 0.0019 - 109ms/epoch - 7ms/step
# Epoch 127/300
# 15/15 - 0s - loss: 0.0016 - 108ms/epoch - 7ms/step
# Epoch 128/300
# 15/15 - 0s - loss: 0.0013 - 119ms/epoch - 8ms/step
# Epoch 129/300
# 15/15 - 0s - loss: 0.0011 - 105ms/epoch - 7ms/step
# Epoch 130/300
# 15/15 - 0s - loss: 0.0011 - 117ms/epoch - 8ms/step
# Epoch 131/300
# 15/15 - 0s - loss: 3.7813e-04 - 113ms/epoch - 8ms/step
# Epoch 132/300
# 15/15 - 0s - loss: 0.0021 - 113ms/epoch - 8ms/step
# Epoch 133/300
# 15/15 - 0s - loss: 0.0049 - 108ms/epoch - 7ms/step
# Epoch 134/300
# 15/15 - 0s - loss: 0.0037 - 104ms/epoch - 7ms/step
# Epoch 135/300
# 15/15 - 0s - loss: 0.0049 - 112ms/epoch - 7ms/step
# Epoch 136/300
# 15/15 - 0s - loss: 0.0020 - 106ms/epoch - 7ms/step
# Epoch 137/300
# 15/15 - 0s - loss: 0.0010 - 110ms/epoch - 7ms/step
# Epoch 138/300
# 15/15 - 0s - loss: 6.7387e-04 - 106ms/epoch - 7ms/step
# Epoch 139/300
# 15/15 - 0s - loss: 6.7062e-04 - 104ms/epoch - 7ms/step
# Epoch 140/300
# 15/15 - 0s - loss: 4.7671e-04 - 114ms/epoch - 8ms/step
# Epoch 141/300
# 15/15 - 0s - loss: 2.1845e-04 - 107ms/epoch - 7ms/step
# Epoch 142/300
# 15/15 - 0s - loss: 3.0061e-04 - 97ms/epoch - 6ms/step
# Epoch 143/300
# 15/15 - 0s - loss: 5.7647e-04 - 108ms/epoch - 7ms/step
# Epoch 144/300
# 15/15 - 0s - loss: 0.0040 - 104ms/epoch - 7ms/step
# Epoch 145/300
# 15/15 - 0s - loss: 0.0055 - 120ms/epoch - 8ms/step
# Epoch 146/300
# 15/15 - 0s - loss: 0.0029 - 121ms/epoch - 8ms/step
# Epoch 147/300
# 15/15 - 0s - loss: 0.0023 - 111ms/epoch - 7ms/step
# Epoch 148/300
# 15/15 - 0s - loss: 0.0025 - 111ms/epoch - 7ms/step
# Epoch 149/300
# 15/15 - 0s - loss: 0.0013 - 107ms/epoch - 7ms/step
# Epoch 150/300
# 15/15 - 0s - loss: 7.5661e-04 - 111ms/epoch - 7ms/step
# Epoch 151/300
# 15/15 - 0s - loss: 5.0682e-04 - 108ms/epoch - 7ms/step
# Epoch 152/300
# 15/15 - 0s - loss: 8.7858e-04 - 105ms/epoch - 7ms/step
# Epoch 153/300
# 15/15 - 0s - loss: 8.0860e-04 - 107ms/epoch - 7ms/step
# Epoch 154/300
# 15/15 - 0s - loss: 6.2775e-04 - 116ms/epoch - 8ms/step
# Epoch 155/300
# 15/15 - 0s - loss: 5.6009e-04 - 117ms/epoch - 8ms/step
# Epoch 156/300
# 15/15 - 0s - loss: 1.9755e-04 - 135ms/epoch - 9ms/step
# Epoch 157/300
# 15/15 - 0s - loss: 1.6168e-04 - 114ms/epoch - 8ms/step
# Epoch 158/300
# 15/15 - 0s - loss: 1.5912e-04 - 129ms/epoch - 9ms/step
# Epoch 159/300
# 15/15 - 0s - loss: 1.5580e-04 - 143ms/epoch - 10ms/step
# Epoch 160/300
# 15/15 - 0s - loss: 8.6290e-05 - 123ms/epoch - 8ms/step
# Epoch 161/300
# 15/15 - 0s - loss: 9.8920e-05 - 126ms/epoch - 8ms/step
# Epoch 162/300
# 15/15 - 0s - loss: 1.3624e-04 - 126ms/epoch - 8ms/step
# Epoch 163/300
# 15/15 - 0s - loss: 1.3208e-04 - 118ms/epoch - 8ms/step
# Epoch 164/300
# 15/15 - 0s - loss: 1.5565e-04 - 112ms/epoch - 7ms/step
# Epoch 165/300
# 15/15 - 0s - loss: 1.0946e-04 - 118ms/epoch - 8ms/step
# Epoch 166/300
# 15/15 - 0s - loss: 1.3741e-04 - 113ms/epoch - 8ms/step
# Epoch 167/300
# 15/15 - 0s - loss: 3.3943e-04 - 104ms/epoch - 7ms/step
# Epoch 168/300
# 15/15 - 0s - loss: 2.7558e-04 - 114ms/epoch - 8ms/step
# Epoch 169/300
# 15/15 - 0s - loss: 1.5207e-04 - 108ms/epoch - 7ms/step
# Epoch 170/300
# 15/15 - 0s - loss: 1.4868e-04 - 106ms/epoch - 7ms/step
# Epoch 171/300
# 15/15 - 0s - loss: 1.0364e-04 - 111ms/epoch - 7ms/step
# Epoch 172/300
# 15/15 - 0s - loss: 5.7398e-05 - 113ms/epoch - 8ms/step
# Epoch 173/300
# 15/15 - 0s - loss: 6.2322e-05 - 101ms/epoch - 7ms/step
# Epoch 174/300
# 15/15 - 0s - loss: 2.4368e-05 - 100ms/epoch - 7ms/step
# Epoch 175/300
# 15/15 - 0s - loss: 6.0606e-05 - 107ms/epoch - 7ms/step
# Epoch 176/300
# 15/15 - 0s - loss: 5.1494e-05 - 108ms/epoch - 7ms/step
# Epoch 177/300
# 15/15 - 0s - loss: 6.8778e-05 - 110ms/epoch - 7ms/step
# Epoch 178/300
# 15/15 - 0s - loss: 8.6576e-05 - 106ms/epoch - 7ms/step
# Epoch 179/300
# 15/15 - 0s - loss: 1.3018e-04 - 103ms/epoch - 7ms/step
# Epoch 180/300
# 15/15 - 0s - loss: 1.3210e-04 - 110ms/epoch - 7ms/step
# Epoch 181/300
# 15/15 - 0s - loss: 1.6406e-04 - 104ms/epoch - 7ms/step
# Epoch 182/300
# 15/15 - 0s - loss: 4.5191e-04 - 103ms/epoch - 7ms/step
# Epoch 183/300
# 15/15 - 0s - loss: 3.8078e-04 - 103ms/epoch - 7ms/step
# Epoch 184/300
# 15/15 - 0s - loss: 2.4968e-04 - 107ms/epoch - 7ms/step
# Epoch 185/300
# 15/15 - 0s - loss: 2.9153e-04 - 105ms/epoch - 7ms/step
# Epoch 186/300
# 15/15 - 0s - loss: 9.4619e-04 - 103ms/epoch - 7ms/step
# Epoch 187/300
# 15/15 - 0s - loss: 0.0017 - 111ms/epoch - 7ms/step
# Epoch 188/300
# 15/15 - 0s - loss: 0.0087 - 106ms/epoch - 7ms/step
# Epoch 189/300
# 15/15 - 0s - loss: 0.0073 - 108ms/epoch - 7ms/step
# Epoch 190/300
# 15/15 - 0s - loss: 0.0025 - 109ms/epoch - 7ms/step
# Epoch 191/300
# 15/15 - 0s - loss: 0.0020 - 111ms/epoch - 7ms/step
# Epoch 192/300
# 15/15 - 0s - loss: 0.0021 - 108ms/epoch - 7ms/step
# Epoch 193/300
# 15/15 - 0s - loss: 0.0012 - 107ms/epoch - 7ms/step
# Epoch 194/300
# 15/15 - 0s - loss: 8.0384e-04 - 101ms/epoch - 7ms/step
# Epoch 195/300
# 15/15 - 0s - loss: 0.0014 - 125ms/epoch - 8ms/step
# Epoch 196/300
# 15/15 - 0s - loss: 0.0037 - 112ms/epoch - 7ms/step
# Epoch 197/300
# 15/15 - 0s - loss: 0.0024 - 118ms/epoch - 8ms/step
# Epoch 198/300
# 15/15 - 0s - loss: 0.0011 - 132ms/epoch - 9ms/step
# Epoch 199/300
# 15/15 - 0s - loss: 5.2701e-04 - 128ms/epoch - 9ms/step
# Epoch 200/300
# 15/15 - 0s - loss: 2.2855e-04 - 124ms/epoch - 8ms/step
# Epoch 201/300
# 15/15 - 0s - loss: 1.9588e-04 - 123ms/epoch - 8ms/step
# Epoch 202/300
# 15/15 - 0s - loss: 4.1945e-04 - 112ms/epoch - 7ms/step
# Epoch 203/300
# 15/15 - 0s - loss: 6.7574e-04 - 126ms/epoch - 8ms/step
# Epoch 204/300
# 15/15 - 0s - loss: 3.4286e-04 - 116ms/epoch - 8ms/step
# Epoch 205/300
# 15/15 - 0s - loss: 9.2684e-05 - 125ms/epoch - 8ms/step
# Epoch 206/300
# 15/15 - 0s - loss: 5.5651e-05 - 125ms/epoch - 8ms/step
# Epoch 207/300
# 15/15 - 0s - loss: 4.6390e-05 - 113ms/epoch - 8ms/step
# Epoch 208/300
# 15/15 - 0s - loss: 5.3061e-05 - 115ms/epoch - 8ms/step
# Epoch 209/300
# 15/15 - 0s - loss: 9.3377e-05 - 109ms/epoch - 7ms/step
# Epoch 210/300
# 15/15 - 0s - loss: 5.6887e-05 - 111ms/epoch - 7ms/step
# Epoch 211/300
# 15/15 - 0s - loss: 5.7101e-05 - 119ms/epoch - 8ms/step
# Epoch 212/300
# 15/15 - 0s - loss: 6.2813e-05 - 122ms/epoch - 8ms/step
# Epoch 213/300
# 15/15 - 0s - loss: 8.3683e-05 - 133ms/epoch - 9ms/step
# Epoch 214/300
# 15/15 - 0s - loss: 1.3317e-04 - 123ms/epoch - 8ms/step
# Epoch 215/300
# 15/15 - 0s - loss: 0.0022 - 124ms/epoch - 8ms/step
# Epoch 216/300
# 15/15 - 0s - loss: 0.0028 - 117ms/epoch - 8ms/step
# Epoch 217/300
# 15/15 - 0s - loss: 0.0019 - 109ms/epoch - 7ms/step
# Epoch 218/300
# 15/15 - 0s - loss: 6.6516e-04 - 110ms/epoch - 7ms/step
# Epoch 219/300
# 15/15 - 0s - loss: 4.7113e-04 - 112ms/epoch - 7ms/step
# Epoch 220/300
# 15/15 - 0s - loss: 4.5232e-04 - 107ms/epoch - 7ms/step
# Epoch 221/300
# 15/15 - 0s - loss: 0.0012 - 121ms/epoch - 8ms/step
# Epoch 222/300
# 15/15 - 0s - loss: 0.0013 - 123ms/epoch - 8ms/step
# Epoch 223/300
# 15/15 - 0s - loss: 0.0020 - 120ms/epoch - 8ms/step
# Epoch 224/300
# 15/15 - 0s - loss: 0.0016 - 126ms/epoch - 8ms/step
# Epoch 225/300
# 15/15 - 0s - loss: 7.4526e-04 - 124ms/epoch - 8ms/step
# Epoch 226/300
# 15/15 - 0s - loss: 0.0015 - 123ms/epoch - 8ms/step
# Epoch 227/300
# 15/15 - 0s - loss: 0.0025 - 114ms/epoch - 8ms/step
# Epoch 228/300
# 15/15 - 0s - loss: 0.0030 - 115ms/epoch - 8ms/step
# Epoch 229/300
# 15/15 - 0s - loss: 0.0012 - 118ms/epoch - 8ms/step
# Epoch 230/300
# 15/15 - 0s - loss: 5.7430e-04 - 116ms/epoch - 8ms/step
# Epoch 231/300
# 15/15 - 0s - loss: 6.3237e-04 - 120ms/epoch - 8ms/step
# Epoch 232/300
# 15/15 - 0s - loss: 6.6550e-04 - 111ms/epoch - 7ms/step
# Epoch 233/300
# 15/15 - 0s - loss: 3.0754e-04 - 115ms/epoch - 8ms/step
# Epoch 234/300
# 15/15 - 0s - loss: 5.7810e-04 - 111ms/epoch - 7ms/step
# Epoch 235/300
# 15/15 - 0s - loss: 2.4838e-04 - 120ms/epoch - 8ms/step
# Epoch 236/300
# 15/15 - 0s - loss: 2.0163e-04 - 117ms/epoch - 8ms/step
# Epoch 237/300
# 15/15 - 0s - loss: 1.4305e-04 - 126ms/epoch - 8ms/step
# Epoch 238/300
# 15/15 - 0s - loss: 6.9419e-05 - 111ms/epoch - 7ms/step
# Epoch 239/300
# 15/15 - 0s - loss: 1.0477e-04 - 119ms/epoch - 8ms/step
# Epoch 240/300
# 15/15 - 0s - loss: 1.7483e-04 - 113ms/epoch - 8ms/step
# Epoch 241/300
# 15/15 - 0s - loss: 1.1845e-04 - 111ms/epoch - 7ms/step
# Epoch 242/300
# 15/15 - 0s - loss: 8.5078e-05 - 105ms/epoch - 7ms/step
# Epoch 243/300
# 15/15 - 0s - loss: 4.8006e-05 - 111ms/epoch - 7ms/step
# Epoch 244/300
# 15/15 - 0s - loss: 3.0457e-05 - 116ms/epoch - 8ms/step
# Epoch 245/300
# 15/15 - 0s - loss: 2.4542e-05 - 116ms/epoch - 8ms/step
# Epoch 246/300
# 15/15 - 0s - loss: 5.1910e-05 - 121ms/epoch - 8ms/step
# Epoch 247/300
# 15/15 - 0s - loss: 3.3837e-05 - 119ms/epoch - 8ms/step
# Epoch 248/300
# 15/15 - 0s - loss: 2.2179e-05 - 111ms/epoch - 7ms/step
# Epoch 249/300
# 15/15 - 0s - loss: 2.4238e-05 - 112ms/epoch - 7ms/step
# Epoch 250/300
# 15/15 - 0s - loss: 5.2527e-05 - 114ms/epoch - 8ms/step
# Epoch 251/300
# 15/15 - 0s - loss: 1.2954e-04 - 121ms/epoch - 8ms/step
# Epoch 252/300
# 15/15 - 0s - loss: 5.3541e-05 - 119ms/epoch - 8ms/step
# Epoch 253/300
# 15/15 - 0s - loss: 3.4380e-05 - 118ms/epoch - 8ms/step
# Epoch 254/300
# 15/15 - 0s - loss: 3.7074e-05 - 118ms/epoch - 8ms/step
# Epoch 255/300
# 15/15 - 0s - loss: 2.8959e-05 - 109ms/epoch - 7ms/step
# Epoch 256/300
# 15/15 - 0s - loss: 2.4136e-05 - 109ms/epoch - 7ms/step
# Epoch 257/300
# 15/15 - 0s - loss: 2.5822e-05 - 114ms/epoch - 8ms/step
# Epoch 258/300
# 15/15 - 0s - loss: 6.5054e-05 - 117ms/epoch - 8ms/step
# Epoch 259/300
# 15/15 - 0s - loss: 6.7882e-05 - 117ms/epoch - 8ms/step
# Epoch 260/300
# 15/15 - 0s - loss: 2.3253e-04 - 122ms/epoch - 8ms/step
# Epoch 261/300
# 15/15 - 0s - loss: 2.2135e-04 - 120ms/epoch - 8ms/step
# Epoch 262/300
# 15/15 - 0s - loss: 6.1949e-05 - 122ms/epoch - 8ms/step
# Epoch 263/300
# 15/15 - 0s - loss: 3.6208e-05 - 129ms/epoch - 9ms/step
# Epoch 264/300
# 15/15 - 0s - loss: 7.3460e-05 - 120ms/epoch - 8ms/step
# Epoch 265/300
# 15/15 - 0s - loss: 9.9746e-05 - 118ms/epoch - 8ms/step
# Epoch 266/300
# 15/15 - 0s - loss: 1.5179e-04 - 120ms/epoch - 8ms/step
# Epoch 267/300
# 15/15 - 0s - loss: 1.4573e-04 - 121ms/epoch - 8ms/step
# Epoch 268/300
# 15/15 - 0s - loss: 8.2689e-05 - 113ms/epoch - 8ms/step
# Epoch 269/300
# 15/15 - 0s - loss: 4.8312e-05 - 130ms/epoch - 9ms/step
# Epoch 270/300
# 15/15 - 0s - loss: 5.4235e-05 - 122ms/epoch - 8ms/step
# Epoch 271/300
# 15/15 - 0s - loss: 3.7161e-05 - 129ms/epoch - 9ms/step
# Epoch 272/300
# 15/15 - 0s - loss: 7.1804e-05 - 113ms/epoch - 8ms/step
# Epoch 273/300
# 15/15 - 0s - loss: 6.2009e-05 - 137ms/epoch - 9ms/step
# Epoch 274/300
# 15/15 - 0s - loss: 9.5024e-05 - 135ms/epoch - 9ms/step
# Epoch 275/300
# 15/15 - 0s - loss: 1.3719e-04 - 128ms/epoch - 9ms/step
# Epoch 276/300
# 15/15 - 0s - loss: 1.5540e-04 - 128ms/epoch - 9ms/step
# Epoch 277/300
# 15/15 - 0s - loss: 4.3879e-04 - 122ms/epoch - 8ms/step
# Epoch 278/300
# 15/15 - 0s - loss: 5.5452e-04 - 118ms/epoch - 8ms/step
# Epoch 279/300
# 15/15 - 0s - loss: 0.0053 - 122ms/epoch - 8ms/step
# Epoch 280/300
# 15/15 - 0s - loss: 0.0049 - 119ms/epoch - 8ms/step
# Epoch 281/300
# 15/15 - 0s - loss: 0.0050 - 111ms/epoch - 7ms/step
# Epoch 282/300
# 15/15 - 0s - loss: 0.0067 - 118ms/epoch - 8ms/step
# Epoch 283/300
# 15/15 - 0s - loss: 0.0033 - 115ms/epoch - 8ms/step
# Epoch 284/300
# 15/15 - 0s - loss: 0.0016 - 113ms/epoch - 8ms/step
# Epoch 285/300
# 15/15 - 0s - loss: 0.0011 - 122ms/epoch - 8ms/step
# Epoch 286/300
# 15/15 - 0s - loss: 4.8837e-04 - 132ms/epoch - 9ms/step
# Epoch 287/300
# 15/15 - 0s - loss: 3.1129e-04 - 138ms/epoch - 9ms/step
# Epoch 288/300
# 15/15 - 0s - loss: 1.7765e-04 - 119ms/epoch - 8ms/step
# Epoch 289/300
# 15/15 - 0s - loss: 1.9049e-04 - 118ms/epoch - 8ms/step
# Epoch 290/300
# 15/15 - 0s - loss: 1.4565e-04 - 122ms/epoch - 8ms/step
# Epoch 291/300
# 15/15 - 0s - loss: 1.0397e-04 - 126ms/epoch - 8ms/step
# Epoch 292/300
# 15/15 - 0s - loss: 7.1788e-05 - 117ms/epoch - 8ms/step
# Epoch 293/300
# 15/15 - 0s - loss: 7.6429e-05 - 125ms/epoch - 8ms/step
# Epoch 294/300
# 15/15 - 0s - loss: 5.2940e-05 - 121ms/epoch - 8ms/step
# Epoch 295/300
# 15/15 - 0s - loss: 4.5809e-05 - 133ms/epoch - 9ms/step
# Epoch 296/300
# 15/15 - 0s - loss: 3.2718e-05 - 131ms/epoch - 9ms/step
# Epoch 297/300
# 15/15 - 0s - loss: 2.8993e-05 - 116ms/epoch - 8ms/step
# Epoch 298/300
# 15/15 - 0s - loss: 1.6258e-05 - 115ms/epoch - 8ms/step
# Epoch 299/300
# 15/15 - 0s - loss: 1.2954e-05 - 109ms/epoch - 7ms/step
# Epoch 300/300
# 15/15 - 0s - loss: 1.7251e-05 - 110ms/epoch - 7ms/step
# 16/16 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710202884.0828032
# Tue Mar 12 00:21:24 2024
