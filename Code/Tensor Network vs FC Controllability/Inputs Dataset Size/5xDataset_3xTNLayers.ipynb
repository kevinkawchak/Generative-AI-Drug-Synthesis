# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_80 (Dense)            (None, 1024)              3072
#
#  dense_81 (Dense)            (None, 1024)              1049600
#
#  dense_82 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_83 (Dense)            (None, 1024)              3072
#
#  tn_layer_48 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_49 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_50 (TNLayer)       (None, 1024)              5120
#
#  dense_84 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(100, 2) + np.array([3, 3]),
                    np.random.randn(100, 2) + np.array([-3, -3]),
                    np.random.randn(100, 2) + np.array([-3, 3]),
                    np.random.randn(100, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((200)), -np.ones((200))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710202372.6897938
# Tue Mar 12 00:12:52 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 13/13 - 2s - loss: 1.0027 - 2s/epoch - 169ms/step
# Epoch 2/300
# 13/13 - 0s - loss: 1.0003 - 79ms/epoch - 6ms/step
# Epoch 3/300
# 13/13 - 0s - loss: 0.9535 - 84ms/epoch - 6ms/step
# Epoch 4/300
# 13/13 - 0s - loss: 0.3869 - 78ms/epoch - 6ms/step
# Epoch 5/300
# 13/13 - 0s - loss: 0.0702 - 78ms/epoch - 6ms/step
# Epoch 6/300
# 13/13 - 0s - loss: 0.0334 - 79ms/epoch - 6ms/step
# Epoch 7/300
# 13/13 - 0s - loss: 0.0253 - 75ms/epoch - 6ms/step
# Epoch 8/300
# 13/13 - 0s - loss: 0.0218 - 74ms/epoch - 6ms/step
# Epoch 9/300
# 13/13 - 0s - loss: 0.0221 - 75ms/epoch - 6ms/step
# Epoch 10/300
# 13/13 - 0s - loss: 0.0190 - 73ms/epoch - 6ms/step
# Epoch 11/300
# 13/13 - 0s - loss: 0.0193 - 77ms/epoch - 6ms/step
# Epoch 12/300
# 13/13 - 0s - loss: 0.0187 - 75ms/epoch - 6ms/step
# Epoch 13/300
# 13/13 - 0s - loss: 0.0185 - 76ms/epoch - 6ms/step
# Epoch 14/300
# 13/13 - 0s - loss: 0.0175 - 81ms/epoch - 6ms/step
# Epoch 15/300
# 13/13 - 0s - loss: 0.0161 - 75ms/epoch - 6ms/step
# Epoch 16/300
# 13/13 - 0s - loss: 0.0154 - 77ms/epoch - 6ms/step
# Epoch 17/300
# 13/13 - 0s - loss: 0.0143 - 78ms/epoch - 6ms/step
# Epoch 18/300
# 13/13 - 0s - loss: 0.0147 - 76ms/epoch - 6ms/step
# Epoch 19/300
# 13/13 - 0s - loss: 0.0137 - 70ms/epoch - 5ms/step
# Epoch 20/300
# 13/13 - 0s - loss: 0.0137 - 69ms/epoch - 5ms/step
# Epoch 21/300
# 13/13 - 0s - loss: 0.0136 - 69ms/epoch - 5ms/step
# Epoch 22/300
# 13/13 - 0s - loss: 0.0131 - 75ms/epoch - 6ms/step
# Epoch 23/300
# 13/13 - 0s - loss: 0.0123 - 72ms/epoch - 6ms/step
# Epoch 24/300
# 13/13 - 0s - loss: 0.0115 - 76ms/epoch - 6ms/step
# Epoch 25/300
# 13/13 - 0s - loss: 0.0135 - 66ms/epoch - 5ms/step
# Epoch 26/300
# 13/13 - 0s - loss: 0.0122 - 70ms/epoch - 5ms/step
# Epoch 27/300
# 13/13 - 0s - loss: 0.0123 - 72ms/epoch - 6ms/step
# Epoch 28/300
# 13/13 - 0s - loss: 0.0118 - 68ms/epoch - 5ms/step
# Epoch 29/300
# 13/13 - 0s - loss: 0.0112 - 73ms/epoch - 6ms/step
# Epoch 30/300
# 13/13 - 0s - loss: 0.0111 - 69ms/epoch - 5ms/step
# Epoch 31/300
# 13/13 - 0s - loss: 0.0107 - 69ms/epoch - 5ms/step
# Epoch 32/300
# 13/13 - 0s - loss: 0.0122 - 71ms/epoch - 5ms/step
# Epoch 33/300
# 13/13 - 0s - loss: 0.0113 - 68ms/epoch - 5ms/step
# Epoch 34/300
# 13/13 - 0s - loss: 0.0128 - 75ms/epoch - 6ms/step
# Epoch 35/300
# 13/13 - 0s - loss: 0.0135 - 75ms/epoch - 6ms/step
# Epoch 36/300
# 13/13 - 0s - loss: 0.0107 - 70ms/epoch - 5ms/step
# Epoch 37/300
# 13/13 - 0s - loss: 0.0107 - 71ms/epoch - 5ms/step
# Epoch 38/300
# 13/13 - 0s - loss: 0.0108 - 72ms/epoch - 6ms/step
# Epoch 39/300
# 13/13 - 0s - loss: 0.0123 - 76ms/epoch - 6ms/step
# Epoch 40/300
# 13/13 - 0s - loss: 0.0091 - 70ms/epoch - 5ms/step
# Epoch 41/300
# 13/13 - 0s - loss: 0.0127 - 74ms/epoch - 6ms/step
# Epoch 42/300
# 13/13 - 0s - loss: 0.0126 - 74ms/epoch - 6ms/step
# Epoch 43/300
# 13/13 - 0s - loss: 0.0133 - 74ms/epoch - 6ms/step
# Epoch 44/300
# 13/13 - 0s - loss: 0.0110 - 74ms/epoch - 6ms/step
# Epoch 45/300
# 13/13 - 0s - loss: 0.0116 - 73ms/epoch - 6ms/step
# Epoch 46/300
# 13/13 - 0s - loss: 0.0127 - 72ms/epoch - 6ms/step
# Epoch 47/300
# 13/13 - 0s - loss: 0.0104 - 74ms/epoch - 6ms/step
# Epoch 48/300
# 13/13 - 0s - loss: 0.0120 - 74ms/epoch - 6ms/step
# Epoch 49/300
# 13/13 - 0s - loss: 0.0107 - 71ms/epoch - 5ms/step
# Epoch 50/300
# 13/13 - 0s - loss: 0.0095 - 72ms/epoch - 6ms/step
# Epoch 51/300
# 13/13 - 0s - loss: 0.0094 - 73ms/epoch - 6ms/step
# Epoch 52/300
# 13/13 - 0s - loss: 0.0093 - 70ms/epoch - 5ms/step
# Epoch 53/300
# 13/13 - 0s - loss: 0.0091 - 72ms/epoch - 6ms/step
# Epoch 54/300
# 13/13 - 0s - loss: 0.0097 - 71ms/epoch - 5ms/step
# Epoch 55/300
# 13/13 - 0s - loss: 0.0083 - 71ms/epoch - 5ms/step
# Epoch 56/300
# 13/13 - 0s - loss: 0.0095 - 73ms/epoch - 6ms/step
# Epoch 57/300
# 13/13 - 0s - loss: 0.0091 - 74ms/epoch - 6ms/step
# Epoch 58/300
# 13/13 - 0s - loss: 0.0103 - 75ms/epoch - 6ms/step
# Epoch 59/300
# 13/13 - 0s - loss: 0.0105 - 71ms/epoch - 5ms/step
# Epoch 60/300
# 13/13 - 0s - loss: 0.0165 - 70ms/epoch - 5ms/step
# Epoch 61/300
# 13/13 - 0s - loss: 0.0096 - 67ms/epoch - 5ms/step
# Epoch 62/300
# 13/13 - 0s - loss: 0.0093 - 70ms/epoch - 5ms/step
# Epoch 63/300
# 13/13 - 0s - loss: 0.0098 - 73ms/epoch - 6ms/step
# Epoch 64/300
# 13/13 - 0s - loss: 0.0097 - 73ms/epoch - 6ms/step
# Epoch 65/300
# 13/13 - 0s - loss: 0.0129 - 73ms/epoch - 6ms/step
# Epoch 66/300
# 13/13 - 0s - loss: 0.0088 - 74ms/epoch - 6ms/step
# Epoch 67/300
# 13/13 - 0s - loss: 0.0088 - 73ms/epoch - 6ms/step
# Epoch 68/300
# 13/13 - 0s - loss: 0.0090 - 72ms/epoch - 6ms/step
# Epoch 69/300
# 13/13 - 0s - loss: 0.0100 - 73ms/epoch - 6ms/step
# Epoch 70/300
# 13/13 - 0s - loss: 0.0108 - 74ms/epoch - 6ms/step
# Epoch 71/300
# 13/13 - 0s - loss: 0.0106 - 74ms/epoch - 6ms/step
# Epoch 72/300
# 13/13 - 0s - loss: 0.0097 - 71ms/epoch - 5ms/step
# Epoch 73/300
# 13/13 - 0s - loss: 0.0094 - 76ms/epoch - 6ms/step
# Epoch 74/300
# 13/13 - 0s - loss: 0.0091 - 75ms/epoch - 6ms/step
# Epoch 75/300
# 13/13 - 0s - loss: 0.0088 - 72ms/epoch - 6ms/step
# Epoch 76/300
# 13/13 - 0s - loss: 0.0087 - 69ms/epoch - 5ms/step
# Epoch 77/300
# 13/13 - 0s - loss: 0.0084 - 75ms/epoch - 6ms/step
# Epoch 78/300
# 13/13 - 0s - loss: 0.0088 - 75ms/epoch - 6ms/step
# Epoch 79/300
# 13/13 - 0s - loss: 0.0085 - 72ms/epoch - 6ms/step
# Epoch 80/300
# 13/13 - 0s - loss: 0.0093 - 72ms/epoch - 6ms/step
# Epoch 81/300
# 13/13 - 0s - loss: 0.0091 - 71ms/epoch - 5ms/step
# Epoch 82/300
# 13/13 - 0s - loss: 0.0084 - 75ms/epoch - 6ms/step
# Epoch 83/300
# 13/13 - 0s - loss: 0.0090 - 75ms/epoch - 6ms/step
# Epoch 84/300
# 13/13 - 0s - loss: 0.0089 - 75ms/epoch - 6ms/step
# Epoch 85/300
# 13/13 - 0s - loss: 0.0083 - 70ms/epoch - 5ms/step
# Epoch 86/300
# 13/13 - 0s - loss: 0.0085 - 71ms/epoch - 5ms/step
# Epoch 87/300
# 13/13 - 0s - loss: 0.0085 - 75ms/epoch - 6ms/step
# Epoch 88/300
# 13/13 - 0s - loss: 0.0085 - 75ms/epoch - 6ms/step
# Epoch 89/300
# 13/13 - 0s - loss: 0.0089 - 71ms/epoch - 5ms/step
# Epoch 90/300
# 13/13 - 0s - loss: 0.0083 - 72ms/epoch - 6ms/step
# Epoch 91/300
# 13/13 - 0s - loss: 0.0083 - 74ms/epoch - 6ms/step
# Epoch 92/300
# 13/13 - 0s - loss: 0.0083 - 71ms/epoch - 5ms/step
# Epoch 93/300
# 13/13 - 0s - loss: 0.0084 - 69ms/epoch - 5ms/step
# Epoch 94/300
# 13/13 - 0s - loss: 0.0084 - 74ms/epoch - 6ms/step
# Epoch 95/300
# 13/13 - 0s - loss: 0.0085 - 70ms/epoch - 5ms/step
# Epoch 96/300
# 13/13 - 0s - loss: 0.0085 - 75ms/epoch - 6ms/step
# Epoch 97/300
# 13/13 - 0s - loss: 0.0104 - 79ms/epoch - 6ms/step
# Epoch 98/300
# 13/13 - 0s - loss: 0.0109 - 74ms/epoch - 6ms/step
# Epoch 99/300
# 13/13 - 0s - loss: 0.0105 - 75ms/epoch - 6ms/step
# Epoch 100/300
# 13/13 - 0s - loss: 0.0100 - 73ms/epoch - 6ms/step
# Epoch 101/300
# 13/13 - 0s - loss: 0.0097 - 73ms/epoch - 6ms/step
# Epoch 102/300
# 13/13 - 0s - loss: 0.0097 - 71ms/epoch - 5ms/step
# Epoch 103/300
# 13/13 - 0s - loss: 0.0093 - 73ms/epoch - 6ms/step
# Epoch 104/300
# 13/13 - 0s - loss: 0.0089 - 72ms/epoch - 6ms/step
# Epoch 105/300
# 13/13 - 0s - loss: 0.0095 - 77ms/epoch - 6ms/step
# Epoch 106/300
# 13/13 - 0s - loss: 0.0091 - 75ms/epoch - 6ms/step
# Epoch 107/300
# 13/13 - 0s - loss: 0.0088 - 76ms/epoch - 6ms/step
# Epoch 108/300
# 13/13 - 0s - loss: 0.0091 - 76ms/epoch - 6ms/step
# Epoch 109/300
# 13/13 - 0s - loss: 0.0091 - 74ms/epoch - 6ms/step
# Epoch 110/300
# 13/13 - 0s - loss: 0.0086 - 82ms/epoch - 6ms/step
# Epoch 111/300
# 13/13 - 0s - loss: 0.0087 - 77ms/epoch - 6ms/step
# Epoch 112/300
# 13/13 - 0s - loss: 0.0086 - 74ms/epoch - 6ms/step
# Epoch 113/300
# 13/13 - 0s - loss: 0.0082 - 77ms/epoch - 6ms/step
# Epoch 114/300
# 13/13 - 0s - loss: 0.0086 - 74ms/epoch - 6ms/step
# Epoch 115/300
# 13/13 - 0s - loss: 0.0084 - 75ms/epoch - 6ms/step
# Epoch 116/300
# 13/13 - 0s - loss: 0.0080 - 77ms/epoch - 6ms/step
# Epoch 117/300
# 13/13 - 0s - loss: 0.0081 - 71ms/epoch - 5ms/step
# Epoch 118/300
# 13/13 - 0s - loss: 0.0084 - 73ms/epoch - 6ms/step
# Epoch 119/300
# 13/13 - 0s - loss: 0.0083 - 72ms/epoch - 6ms/step
# Epoch 120/300
# 13/13 - 0s - loss: 0.0093 - 73ms/epoch - 6ms/step
# Epoch 121/300
# 13/13 - 0s - loss: 0.0090 - 70ms/epoch - 5ms/step
# Epoch 122/300
# 13/13 - 0s - loss: 0.0087 - 68ms/epoch - 5ms/step
# Epoch 123/300
# 13/13 - 0s - loss: 0.0085 - 73ms/epoch - 6ms/step
# Epoch 124/300
# 13/13 - 0s - loss: 0.0085 - 72ms/epoch - 6ms/step
# Epoch 125/300
# 13/13 - 0s - loss: 0.0090 - 79ms/epoch - 6ms/step
# Epoch 126/300
# 13/13 - 0s - loss: 0.0081 - 73ms/epoch - 6ms/step
# Epoch 127/300
# 13/13 - 0s - loss: 0.0092 - 73ms/epoch - 6ms/step
# Epoch 128/300
# 13/13 - 0s - loss: 0.0082 - 71ms/epoch - 5ms/step
# Epoch 129/300
# 13/13 - 0s - loss: 0.0083 - 74ms/epoch - 6ms/step
# Epoch 130/300
# 13/13 - 0s - loss: 0.0088 - 74ms/epoch - 6ms/step
# Epoch 131/300
# 13/13 - 0s - loss: 0.0088 - 78ms/epoch - 6ms/step
# Epoch 132/300
# 13/13 - 0s - loss: 0.0161 - 73ms/epoch - 6ms/step
# Epoch 133/300
# 13/13 - 0s - loss: 0.0109 - 74ms/epoch - 6ms/step
# Epoch 134/300
# 13/13 - 0s - loss: 0.0194 - 73ms/epoch - 6ms/step
# Epoch 135/300
# 13/13 - 0s - loss: 0.0091 - 76ms/epoch - 6ms/step
# Epoch 136/300
# 13/13 - 0s - loss: 0.0095 - 75ms/epoch - 6ms/step
# Epoch 137/300
# 13/13 - 0s - loss: 0.0084 - 80ms/epoch - 6ms/step
# Epoch 138/300
# 13/13 - 0s - loss: 0.0086 - 75ms/epoch - 6ms/step
# Epoch 139/300
# 13/13 - 0s - loss: 0.0089 - 75ms/epoch - 6ms/step
# Epoch 140/300
# 13/13 - 0s - loss: 0.0087 - 73ms/epoch - 6ms/step
# Epoch 141/300
# 13/13 - 0s - loss: 0.0085 - 73ms/epoch - 6ms/step
# Epoch 142/300
# 13/13 - 0s - loss: 0.0085 - 73ms/epoch - 6ms/step
# Epoch 143/300
# 13/13 - 0s - loss: 0.0087 - 72ms/epoch - 6ms/step
# Epoch 144/300
# 13/13 - 0s - loss: 0.0087 - 74ms/epoch - 6ms/step
# Epoch 145/300
# 13/13 - 0s - loss: 0.0089 - 74ms/epoch - 6ms/step
# Epoch 146/300
# 13/13 - 0s - loss: 0.0090 - 74ms/epoch - 6ms/step
# Epoch 147/300
# 13/13 - 0s - loss: 0.0098 - 70ms/epoch - 5ms/step
# Epoch 148/300
# 13/13 - 0s - loss: 0.0076 - 69ms/epoch - 5ms/step
# Epoch 149/300
# 13/13 - 0s - loss: 0.0079 - 78ms/epoch - 6ms/step
# Epoch 150/300
# 13/13 - 0s - loss: 0.0077 - 79ms/epoch - 6ms/step
# Epoch 151/300
# 13/13 - 0s - loss: 0.0082 - 79ms/epoch - 6ms/step
# Epoch 152/300
# 13/13 - 0s - loss: 0.0080 - 93ms/epoch - 7ms/step
# Epoch 153/300
# 13/13 - 0s - loss: 0.0086 - 78ms/epoch - 6ms/step
# Epoch 154/300
# 13/13 - 0s - loss: 0.0077 - 78ms/epoch - 6ms/step
# Epoch 155/300
# 13/13 - 0s - loss: 0.0080 - 77ms/epoch - 6ms/step
# Epoch 156/300
# 13/13 - 0s - loss: 0.0078 - 83ms/epoch - 6ms/step
# Epoch 157/300
# 13/13 - 0s - loss: 0.0088 - 79ms/epoch - 6ms/step
# Epoch 158/300
# 13/13 - 0s - loss: 0.0079 - 88ms/epoch - 7ms/step
# Epoch 159/300
# 13/13 - 0s - loss: 0.0076 - 85ms/epoch - 7ms/step
# Epoch 160/300
# 13/13 - 0s - loss: 0.0081 - 84ms/epoch - 6ms/step
# Epoch 161/300
# 13/13 - 0s - loss: 0.0073 - 85ms/epoch - 7ms/step
# Epoch 162/300
# 13/13 - 0s - loss: 0.0100 - 85ms/epoch - 7ms/step
# Epoch 163/300
# 13/13 - 0s - loss: 0.0088 - 84ms/epoch - 6ms/step
# Epoch 164/300
# 13/13 - 0s - loss: 0.0080 - 84ms/epoch - 6ms/step
# Epoch 165/300
# 13/13 - 0s - loss: 0.0080 - 83ms/epoch - 6ms/step
# Epoch 166/300
# 13/13 - 0s - loss: 0.0084 - 78ms/epoch - 6ms/step
# Epoch 167/300
# 13/13 - 0s - loss: 0.0088 - 78ms/epoch - 6ms/step
# Epoch 168/300
# 13/13 - 0s - loss: 0.0086 - 80ms/epoch - 6ms/step
# Epoch 169/300
# 13/13 - 0s - loss: 0.0089 - 80ms/epoch - 6ms/step
# Epoch 170/300
# 13/13 - 0s - loss: 0.0076 - 74ms/epoch - 6ms/step
# Epoch 171/300
# 13/13 - 0s - loss: 0.0076 - 73ms/epoch - 6ms/step
# Epoch 172/300
# 13/13 - 0s - loss: 0.0078 - 70ms/epoch - 5ms/step
# Epoch 173/300
# 13/13 - 0s - loss: 0.0080 - 74ms/epoch - 6ms/step
# Epoch 174/300
# 13/13 - 0s - loss: 0.0078 - 77ms/epoch - 6ms/step
# Epoch 175/300
# 13/13 - 0s - loss: 0.0082 - 69ms/epoch - 5ms/step
# Epoch 176/300
# 13/13 - 0s - loss: 0.0081 - 75ms/epoch - 6ms/step
# Epoch 177/300
# 13/13 - 0s - loss: 0.0074 - 74ms/epoch - 6ms/step
# Epoch 178/300
# 13/13 - 0s - loss: 0.0074 - 71ms/epoch - 5ms/step
# Epoch 179/300
# 13/13 - 0s - loss: 0.0078 - 69ms/epoch - 5ms/step
# Epoch 180/300
# 13/13 - 0s - loss: 0.0078 - 70ms/epoch - 5ms/step
# Epoch 181/300
# 13/13 - 0s - loss: 0.0105 - 72ms/epoch - 6ms/step
# Epoch 182/300
# 13/13 - 0s - loss: 0.0082 - 73ms/epoch - 6ms/step
# Epoch 183/300
# 13/13 - 0s - loss: 0.0079 - 79ms/epoch - 6ms/step
# Epoch 184/300
# 13/13 - 0s - loss: 0.0076 - 74ms/epoch - 6ms/step
# Epoch 185/300
# 13/13 - 0s - loss: 0.0085 - 73ms/epoch - 6ms/step
# Epoch 186/300
# 13/13 - 0s - loss: 0.0080 - 77ms/epoch - 6ms/step
# Epoch 187/300
# 13/13 - 0s - loss: 0.0078 - 71ms/epoch - 5ms/step
# Epoch 188/300
# 13/13 - 0s - loss: 0.0092 - 71ms/epoch - 5ms/step
# Epoch 189/300
# 13/13 - 0s - loss: 0.0073 - 72ms/epoch - 6ms/step
# Epoch 190/300
# 13/13 - 0s - loss: 0.0101 - 71ms/epoch - 5ms/step
# Epoch 191/300
# 13/13 - 0s - loss: 0.0075 - 69ms/epoch - 5ms/step
# Epoch 192/300
# 13/13 - 0s - loss: 0.0073 - 69ms/epoch - 5ms/step
# Epoch 193/300
# 13/13 - 0s - loss: 0.0089 - 73ms/epoch - 6ms/step
# Epoch 194/300
# 13/13 - 0s - loss: 0.0074 - 69ms/epoch - 5ms/step
# Epoch 195/300
# 13/13 - 0s - loss: 0.0073 - 65ms/epoch - 5ms/step
# Epoch 196/300
# 13/13 - 0s - loss: 0.0073 - 71ms/epoch - 5ms/step
# Epoch 197/300
# 13/13 - 0s - loss: 0.0081 - 70ms/epoch - 5ms/step
# Epoch 198/300
# 13/13 - 0s - loss: 0.0075 - 70ms/epoch - 5ms/step
# Epoch 199/300
# 13/13 - 0s - loss: 0.0072 - 72ms/epoch - 6ms/step
# Epoch 200/300
# 13/13 - 0s - loss: 0.0073 - 72ms/epoch - 6ms/step
# Epoch 201/300
# 13/13 - 0s - loss: 0.0080 - 71ms/epoch - 5ms/step
# Epoch 202/300
# 13/13 - 0s - loss: 0.0098 - 72ms/epoch - 6ms/step
# Epoch 203/300
# 13/13 - 0s - loss: 0.0169 - 70ms/epoch - 5ms/step
# Epoch 204/300
# 13/13 - 0s - loss: 0.0172 - 73ms/epoch - 6ms/step
# Epoch 205/300
# 13/13 - 0s - loss: 0.0153 - 69ms/epoch - 5ms/step
# Epoch 206/300
# 13/13 - 0s - loss: 0.0140 - 71ms/epoch - 5ms/step
# Epoch 207/300
# 13/13 - 0s - loss: 0.0121 - 70ms/epoch - 5ms/step
# Epoch 208/300
# 13/13 - 0s - loss: 0.0131 - 73ms/epoch - 6ms/step
# Epoch 209/300
# 13/13 - 0s - loss: 0.0121 - 69ms/epoch - 5ms/step
# Epoch 210/300
# 13/13 - 0s - loss: 0.0104 - 78ms/epoch - 6ms/step
# Epoch 211/300
# 13/13 - 0s - loss: 0.0116 - 68ms/epoch - 5ms/step
# Epoch 212/300
# 13/13 - 0s - loss: 0.0092 - 67ms/epoch - 5ms/step
# Epoch 213/300
# 13/13 - 0s - loss: 0.0094 - 76ms/epoch - 6ms/step
# Epoch 214/300
# 13/13 - 0s - loss: 0.0102 - 75ms/epoch - 6ms/step
# Epoch 215/300
# 13/13 - 0s - loss: 0.0081 - 72ms/epoch - 6ms/step
# Epoch 216/300
# 13/13 - 0s - loss: 0.0129 - 71ms/epoch - 5ms/step
# Epoch 217/300
# 13/13 - 0s - loss: 0.0117 - 77ms/epoch - 6ms/step
# Epoch 218/300
# 13/13 - 0s - loss: 0.0081 - 74ms/epoch - 6ms/step
# Epoch 219/300
# 13/13 - 0s - loss: 0.0076 - 79ms/epoch - 6ms/step
# Epoch 220/300
# 13/13 - 0s - loss: 0.0076 - 78ms/epoch - 6ms/step
# Epoch 221/300
# 13/13 - 0s - loss: 0.0079 - 76ms/epoch - 6ms/step
# Epoch 222/300
# 13/13 - 0s - loss: 0.0075 - 75ms/epoch - 6ms/step
# Epoch 223/300
# 13/13 - 0s - loss: 0.0072 - 79ms/epoch - 6ms/step
# Epoch 224/300
# 13/13 - 0s - loss: 0.0092 - 73ms/epoch - 6ms/step
# Epoch 225/300
# 13/13 - 0s - loss: 0.0095 - 72ms/epoch - 6ms/step
# Epoch 226/300
# 13/13 - 0s - loss: 0.0098 - 85ms/epoch - 7ms/step
# Epoch 227/300
# 13/13 - 0s - loss: 0.0084 - 73ms/epoch - 6ms/step
# Epoch 228/300
# 13/13 - 0s - loss: 0.0078 - 69ms/epoch - 5ms/step
# Epoch 229/300
# 13/13 - 0s - loss: 0.0083 - 74ms/epoch - 6ms/step
# Epoch 230/300
# 13/13 - 0s - loss: 0.0075 - 78ms/epoch - 6ms/step
# Epoch 231/300
# 13/13 - 0s - loss: 0.0076 - 70ms/epoch - 5ms/step
# Epoch 232/300
# 13/13 - 0s - loss: 0.0076 - 74ms/epoch - 6ms/step
# Epoch 233/300
# 13/13 - 0s - loss: 0.0070 - 71ms/epoch - 5ms/step
# Epoch 234/300
# 13/13 - 0s - loss: 0.0069 - 74ms/epoch - 6ms/step
# Epoch 235/300
# 13/13 - 0s - loss: 0.0070 - 75ms/epoch - 6ms/step
# Epoch 236/300
# 13/13 - 0s - loss: 0.0068 - 82ms/epoch - 6ms/step
# Epoch 237/300
# 13/13 - 0s - loss: 0.0069 - 78ms/epoch - 6ms/step
# Epoch 238/300
# 13/13 - 0s - loss: 0.0074 - 77ms/epoch - 6ms/step
# Epoch 239/300
# 13/13 - 0s - loss: 0.0068 - 78ms/epoch - 6ms/step
# Epoch 240/300
# 13/13 - 0s - loss: 0.0070 - 73ms/epoch - 6ms/step
# Epoch 241/300
# 13/13 - 0s - loss: 0.0070 - 76ms/epoch - 6ms/step
# Epoch 242/300
# 13/13 - 0s - loss: 0.0072 - 73ms/epoch - 6ms/step
# Epoch 243/300
# 13/13 - 0s - loss: 0.0072 - 74ms/epoch - 6ms/step
# Epoch 244/300
# 13/13 - 0s - loss: 0.0071 - 68ms/epoch - 5ms/step
# Epoch 245/300
# 13/13 - 0s - loss: 0.0077 - 73ms/epoch - 6ms/step
# Epoch 246/300
# 13/13 - 0s - loss: 0.0071 - 72ms/epoch - 6ms/step
# Epoch 247/300
# 13/13 - 0s - loss: 0.0071 - 70ms/epoch - 5ms/step
# Epoch 248/300
# 13/13 - 0s - loss: 0.0104 - 73ms/epoch - 6ms/step
# Epoch 249/300
# 13/13 - 0s - loss: 0.0101 - 72ms/epoch - 6ms/step
# Epoch 250/300
# 13/13 - 0s - loss: 0.0071 - 73ms/epoch - 6ms/step
# Epoch 251/300
# 13/13 - 0s - loss: 0.0081 - 66ms/epoch - 5ms/step
# Epoch 252/300
# 13/13 - 0s - loss: 0.0079 - 71ms/epoch - 5ms/step
# Epoch 253/300
# 13/13 - 0s - loss: 0.0092 - 69ms/epoch - 5ms/step
# Epoch 254/300
# 13/13 - 0s - loss: 0.0081 - 71ms/epoch - 5ms/step
# Epoch 255/300
# 13/13 - 0s - loss: 0.0183 - 70ms/epoch - 5ms/step
# Epoch 256/300
# 13/13 - 0s - loss: 0.0260 - 72ms/epoch - 6ms/step
# Epoch 257/300
# 13/13 - 0s - loss: 0.0291 - 70ms/epoch - 5ms/step
# Epoch 258/300
# 13/13 - 0s - loss: 0.0211 - 67ms/epoch - 5ms/step
# Epoch 259/300
# 13/13 - 0s - loss: 0.0239 - 68ms/epoch - 5ms/step
# Epoch 260/300
# 13/13 - 0s - loss: 0.0178 - 69ms/epoch - 5ms/step
# Epoch 261/300
# 13/13 - 0s - loss: 0.0163 - 70ms/epoch - 5ms/step
# Epoch 262/300
# 13/13 - 0s - loss: 0.0185 - 71ms/epoch - 5ms/step
# Epoch 263/300
# 13/13 - 0s - loss: 0.0157 - 73ms/epoch - 6ms/step
# Epoch 264/300
# 13/13 - 0s - loss: 0.0164 - 72ms/epoch - 6ms/step
# Epoch 265/300
# 13/13 - 0s - loss: 0.0150 - 72ms/epoch - 6ms/step
# Epoch 266/300
# 13/13 - 0s - loss: 0.0142 - 73ms/epoch - 6ms/step
# Epoch 267/300
# 13/13 - 0s - loss: 0.0127 - 71ms/epoch - 5ms/step
# Epoch 268/300
# 13/13 - 0s - loss: 0.0108 - 71ms/epoch - 5ms/step
# Epoch 269/300
# 13/13 - 0s - loss: 0.0105 - 71ms/epoch - 5ms/step
# Epoch 270/300
# 13/13 - 0s - loss: 0.0087 - 69ms/epoch - 5ms/step
# Epoch 271/300
# 13/13 - 0s - loss: 0.0082 - 70ms/epoch - 5ms/step
# Epoch 272/300
# 13/13 - 0s - loss: 0.0080 - 68ms/epoch - 5ms/step
# Epoch 273/300
# 13/13 - 0s - loss: 0.0071 - 67ms/epoch - 5ms/step
# Epoch 274/300
# 13/13 - 0s - loss: 0.0073 - 72ms/epoch - 6ms/step
# Epoch 275/300
# 13/13 - 0s - loss: 0.0067 - 68ms/epoch - 5ms/step
# Epoch 276/300
# 13/13 - 0s - loss: 0.0063 - 73ms/epoch - 6ms/step
# Epoch 277/300
# 13/13 - 0s - loss: 0.0063 - 71ms/epoch - 5ms/step
# Epoch 278/300
# 13/13 - 0s - loss: 0.0063 - 72ms/epoch - 6ms/step
# Epoch 279/300
# 13/13 - 0s - loss: 0.0070 - 71ms/epoch - 5ms/step
# Epoch 280/300
# 13/13 - 0s - loss: 0.0071 - 75ms/epoch - 6ms/step
# Epoch 281/300
# 13/13 - 0s - loss: 0.0076 - 70ms/epoch - 5ms/step
# Epoch 282/300
# 13/13 - 0s - loss: 0.0066 - 72ms/epoch - 6ms/step
# Epoch 283/300
# 13/13 - 0s - loss: 0.0068 - 72ms/epoch - 6ms/step
# Epoch 284/300
# 13/13 - 0s - loss: 0.0072 - 70ms/epoch - 5ms/step
# Epoch 285/300
# 13/13 - 0s - loss: 0.0081 - 68ms/epoch - 5ms/step
# Epoch 286/300
# 13/13 - 0s - loss: 0.0092 - 70ms/epoch - 5ms/step
# Epoch 287/300
# 13/13 - 0s - loss: 0.0068 - 71ms/epoch - 5ms/step
# Epoch 288/300
# 13/13 - 0s - loss: 0.0063 - 74ms/epoch - 6ms/step
# Epoch 289/300
# 13/13 - 0s - loss: 0.0073 - 71ms/epoch - 5ms/step
# Epoch 290/300
# 13/13 - 0s - loss: 0.0062 - 73ms/epoch - 6ms/step
# Epoch 291/300
# 13/13 - 0s - loss: 0.0067 - 73ms/epoch - 6ms/step
# Epoch 292/300
# 13/13 - 0s - loss: 0.0058 - 70ms/epoch - 5ms/step
# Epoch 293/300
# 13/13 - 0s - loss: 0.0068 - 72ms/epoch - 6ms/step
# Epoch 294/300
# 13/13 - 0s - loss: 0.0069 - 73ms/epoch - 6ms/step
# Epoch 295/300
# 13/13 - 0s - loss: 0.0063 - 75ms/epoch - 6ms/step
# Epoch 296/300
# 13/13 - 0s - loss: 0.0067 - 71ms/epoch - 5ms/step
# Epoch 297/300
# 13/13 - 0s - loss: 0.0067 - 72ms/epoch - 6ms/step
# Epoch 298/300
# 13/13 - 0s - loss: 0.0070 - 71ms/epoch - 5ms/step
# Epoch 299/300
# 13/13 - 0s - loss: 0.0055 - 78ms/epoch - 6ms/step
# Epoch 300/300
# 13/13 - 0s - loss: 0.0069 - 71ms/epoch - 5ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 15/15 [==============================] - 0s 4ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710202398.5243082
# Tue Mar 12 00:13:18 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710202398.5373685
# Tue Mar 12 00:13:18 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 13/13 - 1s - loss: 0.2419 - 750ms/epoch - 58ms/step
# Epoch 2/300
# 13/13 - 0s - loss: 0.1304 - 96ms/epoch - 7ms/step
# Epoch 3/300
# 13/13 - 0s - loss: 0.0936 - 105ms/epoch - 8ms/step
# Epoch 4/300
# 13/13 - 0s - loss: 0.0862 - 96ms/epoch - 7ms/step
# Epoch 5/300
# 13/13 - 0s - loss: 0.0721 - 105ms/epoch - 8ms/step
# Epoch 6/300
# 13/13 - 0s - loss: 0.0638 - 93ms/epoch - 7ms/step
# Epoch 7/300
# 13/13 - 0s - loss: 0.0762 - 90ms/epoch - 7ms/step
# Epoch 8/300
# 13/13 - 0s - loss: 0.0761 - 104ms/epoch - 8ms/step
# Epoch 9/300
# 13/13 - 0s - loss: 0.0634 - 101ms/epoch - 8ms/step
# Epoch 10/300
# 13/13 - 0s - loss: 0.0636 - 97ms/epoch - 7ms/step
# Epoch 11/300
# 13/13 - 0s - loss: 0.0599 - 99ms/epoch - 8ms/step
# Epoch 12/300
# 13/13 - 0s - loss: 0.0557 - 99ms/epoch - 8ms/step
# Epoch 13/300
# 13/13 - 0s - loss: 0.0547 - 98ms/epoch - 8ms/step
# Epoch 14/300
# 13/13 - 0s - loss: 0.0451 - 91ms/epoch - 7ms/step
# Epoch 15/300
# 13/13 - 0s - loss: 0.0445 - 96ms/epoch - 7ms/step
# Epoch 16/300
# 13/13 - 0s - loss: 0.0386 - 91ms/epoch - 7ms/step
# Epoch 17/300
# 13/13 - 0s - loss: 0.0340 - 98ms/epoch - 8ms/step
# Epoch 18/300
# 13/13 - 0s - loss: 0.0286 - 91ms/epoch - 7ms/step
# Epoch 19/300
# 13/13 - 0s - loss: 0.0265 - 100ms/epoch - 8ms/step
# Epoch 20/300
# 13/13 - 0s - loss: 0.0263 - 93ms/epoch - 7ms/step
# Epoch 21/300
# 13/13 - 0s - loss: 0.0216 - 95ms/epoch - 7ms/step
# Epoch 22/300
# 13/13 - 0s - loss: 0.0216 - 98ms/epoch - 8ms/step
# Epoch 23/300
# 13/13 - 0s - loss: 0.0176 - 97ms/epoch - 7ms/step
# Epoch 24/300
# 13/13 - 0s - loss: 0.0153 - 102ms/epoch - 8ms/step
# Epoch 25/300
# 13/13 - 0s - loss: 0.0170 - 99ms/epoch - 8ms/step
# Epoch 26/300
# 13/13 - 0s - loss: 0.0164 - 100ms/epoch - 8ms/step
# Epoch 27/300
# 13/13 - 0s - loss: 0.0147 - 93ms/epoch - 7ms/step
# Epoch 28/300
# 13/13 - 0s - loss: 0.0179 - 107ms/epoch - 8ms/step
# Epoch 29/300
# 13/13 - 0s - loss: 0.0226 - 103ms/epoch - 8ms/step
# Epoch 30/300
# 13/13 - 0s - loss: 0.0176 - 98ms/epoch - 8ms/step
# Epoch 31/300
# 13/13 - 0s - loss: 0.0150 - 97ms/epoch - 7ms/step
# Epoch 32/300
# 13/13 - 0s - loss: 0.0161 - 96ms/epoch - 7ms/step
# Epoch 33/300
# 13/13 - 0s - loss: 0.0173 - 101ms/epoch - 8ms/step
# Epoch 34/300
# 13/13 - 0s - loss: 0.0222 - 102ms/epoch - 8ms/step
# Epoch 35/300
# 13/13 - 0s - loss: 0.0239 - 100ms/epoch - 8ms/step
# Epoch 36/300
# 13/13 - 0s - loss: 0.0189 - 102ms/epoch - 8ms/step
# Epoch 37/300
# 13/13 - 0s - loss: 0.0172 - 99ms/epoch - 8ms/step
# Epoch 38/300
# 13/13 - 0s - loss: 0.0197 - 101ms/epoch - 8ms/step
# Epoch 39/300
# 13/13 - 0s - loss: 0.0344 - 112ms/epoch - 9ms/step
# Epoch 40/300
# 13/13 - 0s - loss: 0.0196 - 104ms/epoch - 8ms/step
# Epoch 41/300
# 13/13 - 0s - loss: 0.0201 - 99ms/epoch - 8ms/step
# Epoch 42/300
# 13/13 - 0s - loss: 0.0167 - 104ms/epoch - 8ms/step
# Epoch 43/300
# 13/13 - 0s - loss: 0.0168 - 104ms/epoch - 8ms/step
# Epoch 44/300
# 13/13 - 0s - loss: 0.0169 - 100ms/epoch - 8ms/step
# Epoch 45/300
# 13/13 - 0s - loss: 0.0152 - 108ms/epoch - 8ms/step
# Epoch 46/300
# 13/13 - 0s - loss: 0.0152 - 99ms/epoch - 8ms/step
# Epoch 47/300
# 13/13 - 0s - loss: 0.0132 - 100ms/epoch - 8ms/step
# Epoch 48/300
# 13/13 - 0s - loss: 0.0142 - 102ms/epoch - 8ms/step
# Epoch 49/300
# 13/13 - 0s - loss: 0.0151 - 93ms/epoch - 7ms/step
# Epoch 50/300
# 13/13 - 0s - loss: 0.0165 - 104ms/epoch - 8ms/step
# Epoch 51/300
# 13/13 - 0s - loss: 0.0143 - 94ms/epoch - 7ms/step
# Epoch 52/300
# 13/13 - 0s - loss: 0.0128 - 101ms/epoch - 8ms/step
# Epoch 53/300
# 13/13 - 0s - loss: 0.0121 - 102ms/epoch - 8ms/step
# Epoch 54/300
# 13/13 - 0s - loss: 0.0129 - 94ms/epoch - 7ms/step
# Epoch 55/300
# 13/13 - 0s - loss: 0.0144 - 92ms/epoch - 7ms/step
# Epoch 56/300
# 13/13 - 0s - loss: 0.0150 - 95ms/epoch - 7ms/step
# Epoch 57/300
# 13/13 - 0s - loss: 0.0167 - 90ms/epoch - 7ms/step
# Epoch 58/300
# 13/13 - 0s - loss: 0.0256 - 96ms/epoch - 7ms/step
# Epoch 59/300
# 13/13 - 0s - loss: 0.0176 - 93ms/epoch - 7ms/step
# Epoch 60/300
# 13/13 - 0s - loss: 0.0168 - 89ms/epoch - 7ms/step
# Epoch 61/300
# 13/13 - 0s - loss: 0.0135 - 96ms/epoch - 7ms/step
# Epoch 62/300
# 13/13 - 0s - loss: 0.0143 - 91ms/epoch - 7ms/step
# Epoch 63/300
# 13/13 - 0s - loss: 0.0145 - 97ms/epoch - 7ms/step
# Epoch 64/300
# 13/13 - 0s - loss: 0.0140 - 95ms/epoch - 7ms/step
# Epoch 65/300
# 13/13 - 0s - loss: 0.0185 - 94ms/epoch - 7ms/step
# Epoch 66/300
# 13/13 - 0s - loss: 0.0158 - 101ms/epoch - 8ms/step
# Epoch 67/300
# 13/13 - 0s - loss: 0.0137 - 98ms/epoch - 8ms/step
# Epoch 68/300
# 13/13 - 0s - loss: 0.0137 - 97ms/epoch - 7ms/step
# Epoch 69/300
# 13/13 - 0s - loss: 0.0155 - 93ms/epoch - 7ms/step
# Epoch 70/300
# 13/13 - 0s - loss: 0.0173 - 91ms/epoch - 7ms/step
# Epoch 71/300
# 13/13 - 0s - loss: 0.0131 - 93ms/epoch - 7ms/step
# Epoch 72/300
# 13/13 - 0s - loss: 0.0130 - 95ms/epoch - 7ms/step
# Epoch 73/300
# 13/13 - 0s - loss: 0.0135 - 100ms/epoch - 8ms/step
# Epoch 74/300
# 13/13 - 0s - loss: 0.0139 - 98ms/epoch - 8ms/step
# Epoch 75/300
# 13/13 - 0s - loss: 0.0124 - 95ms/epoch - 7ms/step
# Epoch 76/300
# 13/13 - 0s - loss: 0.0129 - 98ms/epoch - 8ms/step
# Epoch 77/300
# 13/13 - 0s - loss: 0.0129 - 88ms/epoch - 7ms/step
# Epoch 78/300
# 13/13 - 0s - loss: 0.0147 - 98ms/epoch - 8ms/step
# Epoch 79/300
# 13/13 - 0s - loss: 0.0161 - 96ms/epoch - 7ms/step
# Epoch 80/300
# 13/13 - 0s - loss: 0.0155 - 93ms/epoch - 7ms/step
# Epoch 81/300
# 13/13 - 0s - loss: 0.0133 - 97ms/epoch - 7ms/step
# Epoch 82/300
# 13/13 - 0s - loss: 0.0150 - 99ms/epoch - 8ms/step
# Epoch 83/300
# 13/13 - 0s - loss: 0.0145 - 94ms/epoch - 7ms/step
# Epoch 84/300
# 13/13 - 0s - loss: 0.0136 - 93ms/epoch - 7ms/step
# Epoch 85/300
# 13/13 - 0s - loss: 0.0126 - 99ms/epoch - 8ms/step
# Epoch 86/300
# 13/13 - 0s - loss: 0.0138 - 105ms/epoch - 8ms/step
# Epoch 87/300
# 13/13 - 0s - loss: 0.0132 - 101ms/epoch - 8ms/step
# Epoch 88/300
# 13/13 - 0s - loss: 0.0141 - 96ms/epoch - 7ms/step
# Epoch 89/300
# 13/13 - 0s - loss: 0.0150 - 94ms/epoch - 7ms/step
# Epoch 90/300
# 13/13 - 0s - loss: 0.0138 - 102ms/epoch - 8ms/step
# Epoch 91/300
# 13/13 - 0s - loss: 0.0123 - 100ms/epoch - 8ms/step
# Epoch 92/300
# 13/13 - 0s - loss: 0.0137 - 95ms/epoch - 7ms/step
# Epoch 93/300
# 13/13 - 0s - loss: 0.0139 - 102ms/epoch - 8ms/step
# Epoch 94/300
# 13/13 - 0s - loss: 0.0130 - 99ms/epoch - 8ms/step
# Epoch 95/300
# 13/13 - 0s - loss: 0.0171 - 99ms/epoch - 8ms/step
# Epoch 96/300
# 13/13 - 0s - loss: 0.0143 - 101ms/epoch - 8ms/step
# Epoch 97/300
# 13/13 - 0s - loss: 0.0156 - 94ms/epoch - 7ms/step
# Epoch 98/300
# 13/13 - 0s - loss: 0.0128 - 93ms/epoch - 7ms/step
# Epoch 99/300
# 13/13 - 0s - loss: 0.0109 - 88ms/epoch - 7ms/step
# Epoch 100/300
# 13/13 - 0s - loss: 0.0109 - 93ms/epoch - 7ms/step
# Epoch 101/300
# 13/13 - 0s - loss: 0.0106 - 98ms/epoch - 8ms/step
# Epoch 102/300
# 13/13 - 0s - loss: 0.0118 - 91ms/epoch - 7ms/step
# Epoch 103/300
# 13/13 - 0s - loss: 0.0115 - 101ms/epoch - 8ms/step
# Epoch 104/300
# 13/13 - 0s - loss: 0.0111 - 98ms/epoch - 8ms/step
# Epoch 105/300
# 13/13 - 0s - loss: 0.0124 - 100ms/epoch - 8ms/step
# Epoch 106/300
# 13/13 - 0s - loss: 0.0121 - 95ms/epoch - 7ms/step
# Epoch 107/300
# 13/13 - 0s - loss: 0.0120 - 102ms/epoch - 8ms/step
# Epoch 108/300
# 13/13 - 0s - loss: 0.0162 - 104ms/epoch - 8ms/step
# Epoch 109/300
# 13/13 - 0s - loss: 0.0139 - 102ms/epoch - 8ms/step
# Epoch 110/300
# 13/13 - 0s - loss: 0.0142 - 100ms/epoch - 8ms/step
# Epoch 111/300
# 13/13 - 0s - loss: 0.0137 - 97ms/epoch - 7ms/step
# Epoch 112/300
# 13/13 - 0s - loss: 0.0175 - 93ms/epoch - 7ms/step
# Epoch 113/300
# 13/13 - 0s - loss: 0.0149 - 106ms/epoch - 8ms/step
# Epoch 114/300
# 13/13 - 0s - loss: 0.0108 - 106ms/epoch - 8ms/step
# Epoch 115/300
# 13/13 - 0s - loss: 0.0098 - 110ms/epoch - 8ms/step
# Epoch 116/300
# 13/13 - 0s - loss: 0.0097 - 102ms/epoch - 8ms/step
# Epoch 117/300
# 13/13 - 0s - loss: 0.0098 - 113ms/epoch - 9ms/step
# Epoch 118/300
# 13/13 - 0s - loss: 0.0098 - 108ms/epoch - 8ms/step
# Epoch 119/300
# 13/13 - 0s - loss: 0.0123 - 111ms/epoch - 9ms/step
# Epoch 120/300
# 13/13 - 0s - loss: 0.0127 - 106ms/epoch - 8ms/step
# Epoch 121/300
# 13/13 - 0s - loss: 0.0136 - 99ms/epoch - 8ms/step
# Epoch 122/300
# 13/13 - 0s - loss: 0.0196 - 102ms/epoch - 8ms/step
# Epoch 123/300
# 13/13 - 0s - loss: 0.0170 - 98ms/epoch - 8ms/step
# Epoch 124/300
# 13/13 - 0s - loss: 0.0110 - 104ms/epoch - 8ms/step
# Epoch 125/300
# 13/13 - 0s - loss: 0.0107 - 105ms/epoch - 8ms/step
# Epoch 126/300
# 13/13 - 0s - loss: 0.0104 - 98ms/epoch - 8ms/step
# Epoch 127/300
# 13/13 - 0s - loss: 0.0121 - 101ms/epoch - 8ms/step
# Epoch 128/300
# 13/13 - 0s - loss: 0.0122 - 96ms/epoch - 7ms/step
# Epoch 129/300
# 13/13 - 0s - loss: 0.0112 - 100ms/epoch - 8ms/step
# Epoch 130/300
# 13/13 - 0s - loss: 0.0108 - 94ms/epoch - 7ms/step
# Epoch 131/300
# 13/13 - 0s - loss: 0.0124 - 101ms/epoch - 8ms/step
# Epoch 132/300
# 13/13 - 0s - loss: 0.0130 - 94ms/epoch - 7ms/step
# Epoch 133/300
# 13/13 - 0s - loss: 0.0132 - 91ms/epoch - 7ms/step
# Epoch 134/300
# 13/13 - 0s - loss: 0.0112 - 95ms/epoch - 7ms/step
# Epoch 135/300
# 13/13 - 0s - loss: 0.0105 - 102ms/epoch - 8ms/step
# Epoch 136/300
# 13/13 - 0s - loss: 0.0098 - 103ms/epoch - 8ms/step
# Epoch 137/300
# 13/13 - 0s - loss: 0.0102 - 100ms/epoch - 8ms/step
# Epoch 138/300
# 13/13 - 0s - loss: 0.0114 - 109ms/epoch - 8ms/step
# Epoch 139/300
# 13/13 - 0s - loss: 0.0097 - 99ms/epoch - 8ms/step
# Epoch 140/300
# 13/13 - 0s - loss: 0.0090 - 97ms/epoch - 7ms/step
# Epoch 141/300
# 13/13 - 0s - loss: 0.0090 - 103ms/epoch - 8ms/step
# Epoch 142/300
# 13/13 - 0s - loss: 0.0093 - 99ms/epoch - 8ms/step
# Epoch 143/300
# 13/13 - 0s - loss: 0.0113 - 88ms/epoch - 7ms/step
# Epoch 144/300
# 13/13 - 0s - loss: 0.0104 - 104ms/epoch - 8ms/step
# Epoch 145/300
# 13/13 - 0s - loss: 0.0131 - 102ms/epoch - 8ms/step
# Epoch 146/300
# 13/13 - 0s - loss: 0.0098 - 96ms/epoch - 7ms/step
# Epoch 147/300
# 13/13 - 0s - loss: 0.0109 - 99ms/epoch - 8ms/step
# Epoch 148/300
# 13/13 - 0s - loss: 0.0096 - 95ms/epoch - 7ms/step
# Epoch 149/300
# 13/13 - 0s - loss: 0.0114 - 96ms/epoch - 7ms/step
# Epoch 150/300
# 13/13 - 0s - loss: 0.0104 - 104ms/epoch - 8ms/step
# Epoch 151/300
# 13/13 - 0s - loss: 0.0108 - 101ms/epoch - 8ms/step
# Epoch 152/300
# 13/13 - 0s - loss: 0.0119 - 93ms/epoch - 7ms/step
# Epoch 153/300
# 13/13 - 0s - loss: 0.0115 - 90ms/epoch - 7ms/step
# Epoch 154/300
# 13/13 - 0s - loss: 0.0118 - 105ms/epoch - 8ms/step
# Epoch 155/300
# 13/13 - 0s - loss: 0.0102 - 98ms/epoch - 8ms/step
# Epoch 156/300
# 13/13 - 0s - loss: 0.0105 - 101ms/epoch - 8ms/step
# Epoch 157/300
# 13/13 - 0s - loss: 0.0118 - 101ms/epoch - 8ms/step
# Epoch 158/300
# 13/13 - 0s - loss: 0.0116 - 114ms/epoch - 9ms/step
# Epoch 159/300
# 13/13 - 0s - loss: 0.0172 - 120ms/epoch - 9ms/step
# Epoch 160/300
# 13/13 - 0s - loss: 0.0208 - 101ms/epoch - 8ms/step
# Epoch 161/300
# 13/13 - 0s - loss: 0.0270 - 109ms/epoch - 8ms/step
# Epoch 162/300
# 13/13 - 0s - loss: 0.0204 - 93ms/epoch - 7ms/step
# Epoch 163/300
# 13/13 - 0s - loss: 0.0159 - 94ms/epoch - 7ms/step
# Epoch 164/300
# 13/13 - 0s - loss: 0.0112 - 96ms/epoch - 7ms/step
# Epoch 165/300
# 13/13 - 0s - loss: 0.0106 - 101ms/epoch - 8ms/step
# Epoch 166/300
# 13/13 - 0s - loss: 0.0102 - 101ms/epoch - 8ms/step
# Epoch 167/300
# 13/13 - 0s - loss: 0.0102 - 92ms/epoch - 7ms/step
# Epoch 168/300
# 13/13 - 0s - loss: 0.0088 - 96ms/epoch - 7ms/step
# Epoch 169/300
# 13/13 - 0s - loss: 0.0102 - 100ms/epoch - 8ms/step
# Epoch 170/300
# 13/13 - 0s - loss: 0.0082 - 105ms/epoch - 8ms/step
# Epoch 171/300
# 13/13 - 0s - loss: 0.0079 - 102ms/epoch - 8ms/step
# Epoch 172/300
# 13/13 - 0s - loss: 0.0086 - 96ms/epoch - 7ms/step
# Epoch 173/300
# 13/13 - 0s - loss: 0.0112 - 101ms/epoch - 8ms/step
# Epoch 174/300
# 13/13 - 0s - loss: 0.0090 - 108ms/epoch - 8ms/step
# Epoch 175/300
# 13/13 - 0s - loss: 0.0105 - 99ms/epoch - 8ms/step
# Epoch 176/300
# 13/13 - 0s - loss: 0.0090 - 108ms/epoch - 8ms/step
# Epoch 177/300
# 13/13 - 0s - loss: 0.0106 - 100ms/epoch - 8ms/step
# Epoch 178/300
# 13/13 - 0s - loss: 0.0096 - 92ms/epoch - 7ms/step
# Epoch 179/300
# 13/13 - 0s - loss: 0.0095 - 98ms/epoch - 8ms/step
# Epoch 180/300
# 13/13 - 0s - loss: 0.0090 - 105ms/epoch - 8ms/step
# Epoch 181/300
# 13/13 - 0s - loss: 0.0100 - 94ms/epoch - 7ms/step
# Epoch 182/300
# 13/13 - 0s - loss: 0.0086 - 106ms/epoch - 8ms/step
# Epoch 183/300
# 13/13 - 0s - loss: 0.0083 - 96ms/epoch - 7ms/step
# Epoch 184/300
# 13/13 - 0s - loss: 0.0076 - 100ms/epoch - 8ms/step
# Epoch 185/300
# 13/13 - 0s - loss: 0.0102 - 91ms/epoch - 7ms/step
# Epoch 186/300
# 13/13 - 0s - loss: 0.0077 - 106ms/epoch - 8ms/step
# Epoch 187/300
# 13/13 - 0s - loss: 0.0083 - 102ms/epoch - 8ms/step
# Epoch 188/300
# 13/13 - 0s - loss: 0.0098 - 110ms/epoch - 8ms/step
# Epoch 189/300
# 13/13 - 0s - loss: 0.0080 - 95ms/epoch - 7ms/step
# Epoch 190/300
# 13/13 - 0s - loss: 0.0091 - 98ms/epoch - 8ms/step
# Epoch 191/300
# 13/13 - 0s - loss: 0.0085 - 99ms/epoch - 8ms/step
# Epoch 192/300
# 13/13 - 0s - loss: 0.0078 - 91ms/epoch - 7ms/step
# Epoch 193/300
# 13/13 - 0s - loss: 0.0086 - 97ms/epoch - 7ms/step
# Epoch 194/300
# 13/13 - 0s - loss: 0.0071 - 95ms/epoch - 7ms/step
# Epoch 195/300
# 13/13 - 0s - loss: 0.0069 - 108ms/epoch - 8ms/step
# Epoch 196/300
# 13/13 - 0s - loss: 0.0073 - 97ms/epoch - 7ms/step
# Epoch 197/300
# 13/13 - 0s - loss: 0.0071 - 100ms/epoch - 8ms/step
# Epoch 198/300
# 13/13 - 0s - loss: 0.0071 - 94ms/epoch - 7ms/step
# Epoch 199/300
# 13/13 - 0s - loss: 0.0064 - 100ms/epoch - 8ms/step
# Epoch 200/300
# 13/13 - 0s - loss: 0.0074 - 102ms/epoch - 8ms/step
# Epoch 201/300
# 13/13 - 0s - loss: 0.0081 - 103ms/epoch - 8ms/step
# Epoch 202/300
# 13/13 - 0s - loss: 0.0084 - 94ms/epoch - 7ms/step
# Epoch 203/300
# 13/13 - 0s - loss: 0.0080 - 97ms/epoch - 7ms/step
# Epoch 204/300
# 13/13 - 0s - loss: 0.0084 - 96ms/epoch - 7ms/step
# Epoch 205/300
# 13/13 - 0s - loss: 0.0078 - 100ms/epoch - 8ms/step
# Epoch 206/300
# 13/13 - 0s - loss: 0.0065 - 100ms/epoch - 8ms/step
# Epoch 207/300
# 13/13 - 0s - loss: 0.0074 - 98ms/epoch - 8ms/step
# Epoch 208/300
# 13/13 - 0s - loss: 0.0075 - 92ms/epoch - 7ms/step
# Epoch 209/300
# 13/13 - 0s - loss: 0.0074 - 98ms/epoch - 8ms/step
# Epoch 210/300
# 13/13 - 0s - loss: 0.0081 - 96ms/epoch - 7ms/step
# Epoch 211/300
# 13/13 - 0s - loss: 0.0088 - 98ms/epoch - 8ms/step
# Epoch 212/300
# 13/13 - 0s - loss: 0.0085 - 94ms/epoch - 7ms/step
# Epoch 213/300
# 13/13 - 0s - loss: 0.0079 - 99ms/epoch - 8ms/step
# Epoch 214/300
# 13/13 - 0s - loss: 0.0067 - 101ms/epoch - 8ms/step
# Epoch 215/300
# 13/13 - 0s - loss: 0.0062 - 97ms/epoch - 7ms/step
# Epoch 216/300
# 13/13 - 0s - loss: 0.0063 - 107ms/epoch - 8ms/step
# Epoch 217/300
# 13/13 - 0s - loss: 0.0072 - 92ms/epoch - 7ms/step
# Epoch 218/300
# 13/13 - 0s - loss: 0.0066 - 92ms/epoch - 7ms/step
# Epoch 219/300
# 13/13 - 0s - loss: 0.0076 - 107ms/epoch - 8ms/step
# Epoch 220/300
# 13/13 - 0s - loss: 0.0086 - 107ms/epoch - 8ms/step
# Epoch 221/300
# 13/13 - 0s - loss: 0.0074 - 104ms/epoch - 8ms/step
# Epoch 222/300
# 13/13 - 0s - loss: 0.0072 - 108ms/epoch - 8ms/step
# Epoch 223/300
# 13/13 - 0s - loss: 0.0070 - 109ms/epoch - 8ms/step
# Epoch 224/300
# 13/13 - 0s - loss: 0.0087 - 100ms/epoch - 8ms/step
# Epoch 225/300
# 13/13 - 0s - loss: 0.0098 - 108ms/epoch - 8ms/step
# Epoch 226/300
# 13/13 - 0s - loss: 0.0087 - 105ms/epoch - 8ms/step
# Epoch 227/300
# 13/13 - 0s - loss: 0.0069 - 93ms/epoch - 7ms/step
# Epoch 228/300
# 13/13 - 0s - loss: 0.0064 - 97ms/epoch - 7ms/step
# Epoch 229/300
# 13/13 - 0s - loss: 0.0069 - 103ms/epoch - 8ms/step
# Epoch 230/300
# 13/13 - 0s - loss: 0.0058 - 102ms/epoch - 8ms/step
# Epoch 231/300
# 13/13 - 0s - loss: 0.0071 - 95ms/epoch - 7ms/step
# Epoch 232/300
# 13/13 - 0s - loss: 0.0070 - 111ms/epoch - 9ms/step
# Epoch 233/300
# 13/13 - 0s - loss: 0.0060 - 108ms/epoch - 8ms/step
# Epoch 234/300
# 13/13 - 0s - loss: 0.0062 - 103ms/epoch - 8ms/step
# Epoch 235/300
# 13/13 - 0s - loss: 0.0053 - 107ms/epoch - 8ms/step
# Epoch 236/300
# 13/13 - 0s - loss: 0.0050 - 101ms/epoch - 8ms/step
# Epoch 237/300
# 13/13 - 0s - loss: 0.0060 - 105ms/epoch - 8ms/step
# Epoch 238/300
# 13/13 - 0s - loss: 0.0061 - 100ms/epoch - 8ms/step
# Epoch 239/300
# 13/13 - 0s - loss: 0.0062 - 97ms/epoch - 7ms/step
# Epoch 240/300
# 13/13 - 0s - loss: 0.0058 - 94ms/epoch - 7ms/step
# Epoch 241/300
# 13/13 - 0s - loss: 0.0060 - 98ms/epoch - 8ms/step
# Epoch 242/300
# 13/13 - 0s - loss: 0.0062 - 104ms/epoch - 8ms/step
# Epoch 243/300
# 13/13 - 0s - loss: 0.0055 - 95ms/epoch - 7ms/step
# Epoch 244/300
# 13/13 - 0s - loss: 0.0056 - 95ms/epoch - 7ms/step
# Epoch 245/300
# 13/13 - 0s - loss: 0.0066 - 101ms/epoch - 8ms/step
# Epoch 246/300
# 13/13 - 0s - loss: 0.0053 - 99ms/epoch - 8ms/step
# Epoch 247/300
# 13/13 - 0s - loss: 0.0058 - 93ms/epoch - 7ms/step
# Epoch 248/300
# 13/13 - 0s - loss: 0.0076 - 96ms/epoch - 7ms/step
# Epoch 249/300
# 13/13 - 0s - loss: 0.0074 - 91ms/epoch - 7ms/step
# Epoch 250/300
# 13/13 - 0s - loss: 0.0085 - 95ms/epoch - 7ms/step
# Epoch 251/300
# 13/13 - 0s - loss: 0.0070 - 93ms/epoch - 7ms/step
# Epoch 252/300
# 13/13 - 0s - loss: 0.0095 - 93ms/epoch - 7ms/step
# Epoch 253/300
# 13/13 - 0s - loss: 0.0117 - 91ms/epoch - 7ms/step
# Epoch 254/300
# 13/13 - 0s - loss: 0.0100 - 92ms/epoch - 7ms/step
# Epoch 255/300
# 13/13 - 0s - loss: 0.0216 - 102ms/epoch - 8ms/step
# Epoch 256/300
# 13/13 - 0s - loss: 0.0231 - 106ms/epoch - 8ms/step
# Epoch 257/300
# 13/13 - 0s - loss: 0.0189 - 97ms/epoch - 7ms/step
# Epoch 258/300
# 13/13 - 0s - loss: 0.0163 - 99ms/epoch - 8ms/step
# Epoch 259/300
# 13/13 - 0s - loss: 0.0153 - 100ms/epoch - 8ms/step
# Epoch 260/300
# 13/13 - 0s - loss: 0.0138 - 95ms/epoch - 7ms/step
# Epoch 261/300
# 13/13 - 0s - loss: 0.0123 - 92ms/epoch - 7ms/step
# Epoch 262/300
# 13/13 - 0s - loss: 0.0122 - 92ms/epoch - 7ms/step
# Epoch 263/300
# 13/13 - 0s - loss: 0.0103 - 96ms/epoch - 7ms/step
# Epoch 264/300
# 13/13 - 0s - loss: 0.0116 - 96ms/epoch - 7ms/step
# Epoch 265/300
# 13/13 - 0s - loss: 0.0128 - 94ms/epoch - 7ms/step
# Epoch 266/300
# 13/13 - 0s - loss: 0.0115 - 89ms/epoch - 7ms/step
# Epoch 267/300
# 13/13 - 0s - loss: 0.0098 - 93ms/epoch - 7ms/step
# Epoch 268/300
# 13/13 - 0s - loss: 0.0095 - 97ms/epoch - 7ms/step
# Epoch 269/300
# 13/13 - 0s - loss: 0.0112 - 97ms/epoch - 7ms/step
# Epoch 270/300
# 13/13 - 0s - loss: 0.0115 - 91ms/epoch - 7ms/step
# Epoch 271/300
# 13/13 - 0s - loss: 0.0103 - 91ms/epoch - 7ms/step
# Epoch 272/300
# 13/13 - 0s - loss: 0.0089 - 99ms/epoch - 8ms/step
# Epoch 273/300
# 13/13 - 0s - loss: 0.0098 - 93ms/epoch - 7ms/step
# Epoch 274/300
# 13/13 - 0s - loss: 0.0090 - 90ms/epoch - 7ms/step
# Epoch 275/300
# 13/13 - 0s - loss: 0.0088 - 104ms/epoch - 8ms/step
# Epoch 276/300
# 13/13 - 0s - loss: 0.0084 - 95ms/epoch - 7ms/step
# Epoch 277/300
# 13/13 - 0s - loss: 0.0094 - 95ms/epoch - 7ms/step
# Epoch 278/300
# 13/13 - 0s - loss: 0.0088 - 93ms/epoch - 7ms/step
# Epoch 279/300
# 13/13 - 0s - loss: 0.0092 - 96ms/epoch - 7ms/step
# Epoch 280/300
# 13/13 - 0s - loss: 0.0090 - 96ms/epoch - 7ms/step
# Epoch 281/300
# 13/13 - 0s - loss: 0.0091 - 99ms/epoch - 8ms/step
# Epoch 282/300
# 13/13 - 0s - loss: 0.0118 - 102ms/epoch - 8ms/step
# Epoch 283/300
# 13/13 - 0s - loss: 0.0132 - 104ms/epoch - 8ms/step
# Epoch 284/300
# 13/13 - 0s - loss: 0.0165 - 90ms/epoch - 7ms/step
# Epoch 285/300
# 13/13 - 0s - loss: 0.0154 - 92ms/epoch - 7ms/step
# Epoch 286/300
# 13/13 - 0s - loss: 0.0140 - 97ms/epoch - 7ms/step
# Epoch 287/300
# 13/13 - 0s - loss: 0.0110 - 97ms/epoch - 7ms/step
# Epoch 288/300
# 13/13 - 0s - loss: 0.0102 - 89ms/epoch - 7ms/step
# Epoch 289/300
# 13/13 - 0s - loss: 0.0094 - 94ms/epoch - 7ms/step
# Epoch 290/300
# 13/13 - 0s - loss: 0.0090 - 98ms/epoch - 8ms/step
# Epoch 291/300
# 13/13 - 0s - loss: 0.0098 - 97ms/epoch - 7ms/step
# Epoch 292/300
# 13/13 - 0s - loss: 0.0131 - 94ms/epoch - 7ms/step
# Epoch 293/300
# 13/13 - 0s - loss: 0.0106 - 96ms/epoch - 7ms/step
# Epoch 294/300
# 13/13 - 0s - loss: 0.0094 - 97ms/epoch - 7ms/step
# Epoch 295/300
# 13/13 - 0s - loss: 0.0098 - 100ms/epoch - 8ms/step
# Epoch 296/300
# 13/13 - 0s - loss: 0.0076 - 97ms/epoch - 7ms/step
# Epoch 297/300
# 13/13 - 0s - loss: 0.0082 - 97ms/epoch - 7ms/step
# Epoch 298/300
# 13/13 - 0s - loss: 0.0075 - 90ms/epoch - 7ms/step
# Epoch 299/300
# 13/13 - 0s - loss: 0.0093 - 95ms/epoch - 7ms/step
# Epoch 300/300
# 13/13 - 0s - loss: 0.0090 - 90ms/epoch - 7ms/step
# 15/15 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710202429.946927
# Tue Mar 12 00:13:49 2024
