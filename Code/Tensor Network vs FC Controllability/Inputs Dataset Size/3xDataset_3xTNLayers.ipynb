# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_55 (Dense)            (None, 1024)              3072
#
#  dense_56 (Dense)            (None, 1024)              1049600
#
#  dense_57 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_58 (Dense)            (None, 1024)              3072
#
#  tn_layer_33 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_34 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_35 (TNLayer)       (None, 1024)              5120
#
#  dense_59 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(60, 2) + np.array([3, 3]),
                    np.random.randn(60, 2) + np.array([-3, -3]),
                    np.random.randn(60, 2) + np.array([-3, 3]),
                    np.random.randn(60, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((120)), -np.ones((120))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710201546.6629367
# Mon Mar 11 23:59:06 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 8/8 - 2s - loss: 1.0050 - 2s/epoch - 273ms/step
# Epoch 2/300
# 8/8 - 0s - loss: 1.0021 - 50ms/epoch - 6ms/step
# Epoch 3/300
# 8/8 - 0s - loss: 0.9986 - 46ms/epoch - 6ms/step
# Epoch 4/300
# 8/8 - 0s - loss: 0.9881 - 47ms/epoch - 6ms/step
# Epoch 5/300
# 8/8 - 0s - loss: 0.9049 - 48ms/epoch - 6ms/step
# Epoch 6/300
# 8/8 - 0s - loss: 0.5030 - 49ms/epoch - 6ms/step
# Epoch 7/300
# 8/8 - 0s - loss: 0.1213 - 49ms/epoch - 6ms/step
# Epoch 8/300
# 8/8 - 0s - loss: 0.0770 - 49ms/epoch - 6ms/step
# Epoch 9/300
# 8/8 - 0s - loss: 0.0391 - 47ms/epoch - 6ms/step
# Epoch 10/300
# 8/8 - 0s - loss: 0.0293 - 42ms/epoch - 5ms/step
# Epoch 11/300
# 8/8 - 0s - loss: 0.0260 - 42ms/epoch - 5ms/step
# Epoch 12/300
# 8/8 - 0s - loss: 0.0201 - 42ms/epoch - 5ms/step
# Epoch 13/300
# 8/8 - 0s - loss: 0.0197 - 44ms/epoch - 6ms/step
# Epoch 14/300
# 8/8 - 0s - loss: 0.0205 - 42ms/epoch - 5ms/step
# Epoch 15/300
# 8/8 - 0s - loss: 0.0181 - 48ms/epoch - 6ms/step
# Epoch 16/300
# 8/8 - 0s - loss: 0.0170 - 42ms/epoch - 5ms/step
# Epoch 17/300
# 8/8 - 0s - loss: 0.0139 - 42ms/epoch - 5ms/step
# Epoch 18/300
# 8/8 - 0s - loss: 0.0133 - 43ms/epoch - 5ms/step
# Epoch 19/300
# 8/8 - 0s - loss: 0.0133 - 45ms/epoch - 6ms/step
# Epoch 20/300
# 8/8 - 0s - loss: 0.0120 - 43ms/epoch - 5ms/step
# Epoch 21/300
# 8/8 - 0s - loss: 0.0146 - 42ms/epoch - 5ms/step
# Epoch 22/300
# 8/8 - 0s - loss: 0.0123 - 43ms/epoch - 5ms/step
# Epoch 23/300
# 8/8 - 0s - loss: 0.0121 - 47ms/epoch - 6ms/step
# Epoch 24/300
# 8/8 - 0s - loss: 0.0098 - 46ms/epoch - 6ms/step
# Epoch 25/300
# 8/8 - 0s - loss: 0.0093 - 45ms/epoch - 6ms/step
# Epoch 26/300
# 8/8 - 0s - loss: 0.0100 - 44ms/epoch - 6ms/step
# Epoch 27/300
# 8/8 - 0s - loss: 0.0083 - 46ms/epoch - 6ms/step
# Epoch 28/300
# 8/8 - 0s - loss: 0.0106 - 47ms/epoch - 6ms/step
# Epoch 29/300
# 8/8 - 0s - loss: 0.0056 - 42ms/epoch - 5ms/step
# Epoch 30/300
# 8/8 - 0s - loss: 0.0119 - 45ms/epoch - 6ms/step
# Epoch 31/300
# 8/8 - 0s - loss: 0.0060 - 44ms/epoch - 5ms/step
# Epoch 32/300
# 8/8 - 0s - loss: 0.0070 - 44ms/epoch - 6ms/step
# Epoch 33/300
# 8/8 - 0s - loss: 0.0054 - 46ms/epoch - 6ms/step
# Epoch 34/300
# 8/8 - 0s - loss: 0.0033 - 50ms/epoch - 6ms/step
# Epoch 35/300
# 8/8 - 0s - loss: 0.0043 - 42ms/epoch - 5ms/step
# Epoch 36/300
# 8/8 - 0s - loss: 0.0029 - 42ms/epoch - 5ms/step
# Epoch 37/300
# 8/8 - 0s - loss: 0.0025 - 45ms/epoch - 6ms/step
# Epoch 38/300
# 8/8 - 0s - loss: 0.0023 - 44ms/epoch - 6ms/step
# Epoch 39/300
# 8/8 - 0s - loss: 0.0015 - 47ms/epoch - 6ms/step
# Epoch 40/300
# 8/8 - 0s - loss: 0.0017 - 44ms/epoch - 6ms/step
# Epoch 41/300
# 8/8 - 0s - loss: 7.6595e-04 - 42ms/epoch - 5ms/step
# Epoch 42/300
# 8/8 - 0s - loss: 8.7094e-04 - 36ms/epoch - 5ms/step
# Epoch 43/300
# 8/8 - 0s - loss: 3.6930e-04 - 40ms/epoch - 5ms/step
# Epoch 44/300
# 8/8 - 0s - loss: 2.5879e-04 - 41ms/epoch - 5ms/step
# Epoch 45/300
# 8/8 - 0s - loss: 2.1369e-04 - 42ms/epoch - 5ms/step
# Epoch 46/300
# 8/8 - 0s - loss: 2.2268e-04 - 41ms/epoch - 5ms/step
# Epoch 47/300
# 8/8 - 0s - loss: 1.6918e-04 - 42ms/epoch - 5ms/step
# Epoch 48/300
# 8/8 - 0s - loss: 1.4395e-04 - 42ms/epoch - 5ms/step
# Epoch 49/300
# 8/8 - 0s - loss: 1.1683e-04 - 43ms/epoch - 5ms/step
# Epoch 50/300
# 8/8 - 0s - loss: 2.5850e-04 - 43ms/epoch - 5ms/step
# Epoch 51/300
# 8/8 - 0s - loss: 2.4846e-04 - 45ms/epoch - 6ms/step
# Epoch 52/300
# 8/8 - 0s - loss: 1.6407e-04 - 43ms/epoch - 5ms/step
# Epoch 53/300
# 8/8 - 0s - loss: 1.2705e-04 - 43ms/epoch - 5ms/step
# Epoch 54/300
# 8/8 - 0s - loss: 1.7350e-04 - 43ms/epoch - 5ms/step
# Epoch 55/300
# 8/8 - 0s - loss: 5.9832e-05 - 43ms/epoch - 5ms/step
# Epoch 56/300
# 8/8 - 0s - loss: 6.8685e-04 - 42ms/epoch - 5ms/step
# Epoch 57/300
# 8/8 - 0s - loss: 4.3038e-05 - 45ms/epoch - 6ms/step
# Epoch 58/300
# 8/8 - 0s - loss: 3.7193e-05 - 45ms/epoch - 6ms/step
# Epoch 59/300
# 8/8 - 0s - loss: 5.7962e-05 - 46ms/epoch - 6ms/step
# Epoch 60/300
# 8/8 - 0s - loss: 3.3933e-05 - 47ms/epoch - 6ms/step
# Epoch 61/300
# 8/8 - 0s - loss: 2.6501e-05 - 41ms/epoch - 5ms/step
# Epoch 62/300
# 8/8 - 0s - loss: 2.6260e-05 - 43ms/epoch - 5ms/step
# Epoch 63/300
# 8/8 - 0s - loss: 4.6141e-05 - 43ms/epoch - 5ms/step
# Epoch 64/300
# 8/8 - 0s - loss: 3.3645e-05 - 41ms/epoch - 5ms/step
# Epoch 65/300
# 8/8 - 0s - loss: 7.4302e-05 - 41ms/epoch - 5ms/step
# Epoch 66/300
# 8/8 - 0s - loss: 6.0122e-05 - 43ms/epoch - 5ms/step
# Epoch 67/300
# 8/8 - 0s - loss: 1.9940e-04 - 44ms/epoch - 5ms/step
# Epoch 68/300
# 8/8 - 0s - loss: 1.1779e-04 - 41ms/epoch - 5ms/step
# Epoch 69/300
# 8/8 - 0s - loss: 4.3370e-05 - 43ms/epoch - 5ms/step
# Epoch 70/300
# 8/8 - 0s - loss: 4.3602e-05 - 44ms/epoch - 5ms/step
# Epoch 71/300
# 8/8 - 0s - loss: 2.2315e-05 - 45ms/epoch - 6ms/step
# Epoch 72/300
# 8/8 - 0s - loss: 1.4755e-05 - 46ms/epoch - 6ms/step
# Epoch 73/300
# 8/8 - 0s - loss: 1.8498e-05 - 45ms/epoch - 6ms/step
# Epoch 74/300
# 8/8 - 0s - loss: 1.3542e-05 - 41ms/epoch - 5ms/step
# Epoch 75/300
# 8/8 - 0s - loss: 1.0723e-05 - 42ms/epoch - 5ms/step
# Epoch 76/300
# 8/8 - 0s - loss: 1.4543e-05 - 44ms/epoch - 5ms/step
# Epoch 77/300
# 8/8 - 0s - loss: 1.8363e-05 - 43ms/epoch - 5ms/step
# Epoch 78/300
# 8/8 - 0s - loss: 1.5798e-05 - 44ms/epoch - 5ms/step
# Epoch 79/300
# 8/8 - 0s - loss: 8.8436e-06 - 47ms/epoch - 6ms/step
# Epoch 80/300
# 8/8 - 0s - loss: 9.6187e-06 - 44ms/epoch - 5ms/step
# Epoch 81/300
# 8/8 - 0s - loss: 8.1513e-06 - 43ms/epoch - 5ms/step
# Epoch 82/300
# 8/8 - 0s - loss: 7.5883e-06 - 42ms/epoch - 5ms/step
# Epoch 83/300
# 8/8 - 0s - loss: 9.5948e-06 - 41ms/epoch - 5ms/step
# Epoch 84/300
# 8/8 - 0s - loss: 8.8288e-06 - 44ms/epoch - 5ms/step
# Epoch 85/300
# 8/8 - 0s - loss: 8.3409e-06 - 47ms/epoch - 6ms/step
# Epoch 86/300
# 8/8 - 0s - loss: 9.2149e-06 - 47ms/epoch - 6ms/step
# Epoch 87/300
# 8/8 - 0s - loss: 5.7532e-06 - 44ms/epoch - 6ms/step
# Epoch 88/300
# 8/8 - 0s - loss: 5.5459e-06 - 46ms/epoch - 6ms/step
# Epoch 89/300
# 8/8 - 0s - loss: 6.1627e-06 - 45ms/epoch - 6ms/step
# Epoch 90/300
# 8/8 - 0s - loss: 6.2414e-06 - 45ms/epoch - 6ms/step
# Epoch 91/300
# 8/8 - 0s - loss: 9.6101e-06 - 43ms/epoch - 5ms/step
# Epoch 92/300
# 8/8 - 0s - loss: 1.2637e-05 - 47ms/epoch - 6ms/step
# Epoch 93/300
# 8/8 - 0s - loss: 7.9807e-06 - 52ms/epoch - 6ms/step
# Epoch 94/300
# 8/8 - 0s - loss: 6.5230e-06 - 44ms/epoch - 5ms/step
# Epoch 95/300
# 8/8 - 0s - loss: 5.4845e-06 - 45ms/epoch - 6ms/step
# Epoch 96/300
# 8/8 - 0s - loss: 4.0501e-06 - 48ms/epoch - 6ms/step
# Epoch 97/300
# 8/8 - 0s - loss: 4.5092e-06 - 42ms/epoch - 5ms/step
# Epoch 98/300
# 8/8 - 0s - loss: 5.7872e-06 - 46ms/epoch - 6ms/step
# Epoch 99/300
# 8/8 - 0s - loss: 5.2129e-06 - 46ms/epoch - 6ms/step
# Epoch 100/300
# 8/8 - 0s - loss: 1.3923e-05 - 49ms/epoch - 6ms/step
# Epoch 101/300
# 8/8 - 0s - loss: 1.7952e-05 - 44ms/epoch - 5ms/step
# Epoch 102/300
# 8/8 - 0s - loss: 8.2193e-06 - 44ms/epoch - 5ms/step
# Epoch 103/300
# 8/8 - 0s - loss: 7.5959e-06 - 46ms/epoch - 6ms/step
# Epoch 104/300
# 8/8 - 0s - loss: 1.0261e-05 - 43ms/epoch - 5ms/step
# Epoch 105/300
# 8/8 - 0s - loss: 1.0029e-05 - 49ms/epoch - 6ms/step
# Epoch 106/300
# 8/8 - 0s - loss: 9.7758e-06 - 45ms/epoch - 6ms/step
# Epoch 107/300
# 8/8 - 0s - loss: 3.5598e-06 - 47ms/epoch - 6ms/step
# Epoch 108/300
# 8/8 - 0s - loss: 3.3587e-06 - 47ms/epoch - 6ms/step
# Epoch 109/300
# 8/8 - 0s - loss: 3.6178e-06 - 45ms/epoch - 6ms/step
# Epoch 110/300
# 8/8 - 0s - loss: 2.0773e-06 - 47ms/epoch - 6ms/step
# Epoch 111/300
# 8/8 - 0s - loss: 1.9982e-06 - 46ms/epoch - 6ms/step
# Epoch 112/300
# 8/8 - 0s - loss: 2.0869e-06 - 42ms/epoch - 5ms/step
# Epoch 113/300
# 8/8 - 0s - loss: 1.9116e-06 - 44ms/epoch - 5ms/step
# Epoch 114/300
# 8/8 - 0s - loss: 1.7771e-06 - 46ms/epoch - 6ms/step
# Epoch 115/300
# 8/8 - 0s - loss: 2.8804e-06 - 45ms/epoch - 6ms/step
# Epoch 116/300
# 8/8 - 0s - loss: 4.1536e-06 - 48ms/epoch - 6ms/step
# Epoch 117/300
# 8/8 - 0s - loss: 2.9636e-06 - 43ms/epoch - 5ms/step
# Epoch 118/300
# 8/8 - 0s - loss: 2.0825e-06 - 46ms/epoch - 6ms/step
# Epoch 119/300
# 8/8 - 0s - loss: 1.9561e-06 - 46ms/epoch - 6ms/step
# Epoch 120/300
# 8/8 - 0s - loss: 3.3780e-06 - 46ms/epoch - 6ms/step
# Epoch 121/300
# 8/8 - 0s - loss: 3.0367e-06 - 47ms/epoch - 6ms/step
# Epoch 122/300
# 8/8 - 0s - loss: 4.3482e-06 - 43ms/epoch - 5ms/step
# Epoch 123/300
# 8/8 - 0s - loss: 1.2064e-05 - 43ms/epoch - 5ms/step
# Epoch 124/300
# 8/8 - 0s - loss: 1.0733e-05 - 41ms/epoch - 5ms/step
# Epoch 125/300
# 8/8 - 0s - loss: 1.2892e-05 - 43ms/epoch - 5ms/step
# Epoch 126/300
# 8/8 - 0s - loss: 1.9568e-05 - 44ms/epoch - 5ms/step
# Epoch 127/300
# 8/8 - 0s - loss: 1.3890e-05 - 43ms/epoch - 5ms/step
# Epoch 128/300
# 8/8 - 0s - loss: 8.9551e-05 - 41ms/epoch - 5ms/step
# Epoch 129/300
# 8/8 - 0s - loss: 7.2904e-05 - 40ms/epoch - 5ms/step
# Epoch 130/300
# 8/8 - 0s - loss: 4.3574e-05 - 42ms/epoch - 5ms/step
# Epoch 131/300
# 8/8 - 0s - loss: 2.9635e-05 - 39ms/epoch - 5ms/step
# Epoch 132/300
# 8/8 - 0s - loss: 8.1473e-05 - 42ms/epoch - 5ms/step
# Epoch 133/300
# 8/8 - 0s - loss: 1.7582e-04 - 41ms/epoch - 5ms/step
# Epoch 134/300
# 8/8 - 0s - loss: 3.8539e-04 - 44ms/epoch - 6ms/step
# Epoch 135/300
# 8/8 - 0s - loss: 5.9472e-04 - 45ms/epoch - 6ms/step
# Epoch 136/300
# 8/8 - 0s - loss: 3.8337e-04 - 43ms/epoch - 5ms/step
# Epoch 137/300
# 8/8 - 0s - loss: 2.9065e-04 - 44ms/epoch - 6ms/step
# Epoch 138/300
# 8/8 - 0s - loss: 1.7052e-04 - 42ms/epoch - 5ms/step
# Epoch 139/300
# 8/8 - 0s - loss: 7.6964e-05 - 42ms/epoch - 5ms/step
# Epoch 140/300
# 8/8 - 0s - loss: 3.8605e-05 - 44ms/epoch - 5ms/step
# Epoch 141/300
# 8/8 - 0s - loss: 2.4628e-05 - 43ms/epoch - 5ms/step
# Epoch 142/300
# 8/8 - 0s - loss: 1.1901e-05 - 44ms/epoch - 5ms/step
# Epoch 143/300
# 8/8 - 0s - loss: 9.3535e-06 - 44ms/epoch - 6ms/step
# Epoch 144/300
# 8/8 - 0s - loss: 1.2209e-05 - 41ms/epoch - 5ms/step
# Epoch 145/300
# 8/8 - 0s - loss: 6.7727e-06 - 44ms/epoch - 6ms/step
# Epoch 146/300
# 8/8 - 0s - loss: 5.5793e-06 - 44ms/epoch - 5ms/step
# Epoch 147/300
# 8/8 - 0s - loss: 5.8106e-06 - 39ms/epoch - 5ms/step
# Epoch 148/300
# 8/8 - 0s - loss: 4.5867e-06 - 45ms/epoch - 6ms/step
# Epoch 149/300
# 8/8 - 0s - loss: 1.0245e-05 - 46ms/epoch - 6ms/step
# Epoch 150/300
# 8/8 - 0s - loss: 6.4274e-06 - 44ms/epoch - 5ms/step
# Epoch 151/300
# 8/8 - 0s - loss: 6.9650e-06 - 43ms/epoch - 5ms/step
# Epoch 152/300
# 8/8 - 0s - loss: 8.2306e-06 - 41ms/epoch - 5ms/step
# Epoch 153/300
# 8/8 - 0s - loss: 5.9641e-06 - 44ms/epoch - 6ms/step
# Epoch 154/300
# 8/8 - 0s - loss: 6.1834e-06 - 45ms/epoch - 6ms/step
# Epoch 155/300
# 8/8 - 0s - loss: 9.9218e-06 - 44ms/epoch - 6ms/step
# Epoch 156/300
# 8/8 - 0s - loss: 2.2110e-05 - 42ms/epoch - 5ms/step
# Epoch 157/300
# 8/8 - 0s - loss: 2.0179e-05 - 42ms/epoch - 5ms/step
# Epoch 158/300
# 8/8 - 0s - loss: 1.6497e-05 - 45ms/epoch - 6ms/step
# Epoch 159/300
# 8/8 - 0s - loss: 1.9796e-05 - 46ms/epoch - 6ms/step
# Epoch 160/300
# 8/8 - 0s - loss: 9.2398e-06 - 45ms/epoch - 6ms/step
# Epoch 161/300
# 8/8 - 0s - loss: 4.4345e-06 - 44ms/epoch - 5ms/step
# Epoch 162/300
# 8/8 - 0s - loss: 1.6154e-06 - 43ms/epoch - 5ms/step
# Epoch 163/300
# 8/8 - 0s - loss: 1.4282e-06 - 42ms/epoch - 5ms/step
# Epoch 164/300
# 8/8 - 0s - loss: 1.8825e-06 - 46ms/epoch - 6ms/step
# Epoch 165/300
# 8/8 - 0s - loss: 1.4517e-06 - 46ms/epoch - 6ms/step
# Epoch 166/300
# 8/8 - 0s - loss: 1.2382e-06 - 43ms/epoch - 5ms/step
# Epoch 167/300
# 8/8 - 0s - loss: 7.8623e-07 - 44ms/epoch - 6ms/step
# Epoch 168/300
# 8/8 - 0s - loss: 8.6990e-07 - 40ms/epoch - 5ms/step
# Epoch 169/300
# 8/8 - 0s - loss: 8.7787e-07 - 43ms/epoch - 5ms/step
# Epoch 170/300
# 8/8 - 0s - loss: 1.6703e-06 - 47ms/epoch - 6ms/step
# Epoch 171/300
# 8/8 - 0s - loss: 1.6198e-06 - 44ms/epoch - 6ms/step
# Epoch 172/300
# 8/8 - 0s - loss: 8.8152e-07 - 51ms/epoch - 6ms/step
# Epoch 173/300
# 8/8 - 0s - loss: 1.1167e-06 - 48ms/epoch - 6ms/step
# Epoch 174/300
# 8/8 - 0s - loss: 1.3123e-06 - 48ms/epoch - 6ms/step
# Epoch 175/300
# 8/8 - 0s - loss: 1.0242e-06 - 46ms/epoch - 6ms/step
# Epoch 176/300
# 8/8 - 0s - loss: 7.2933e-07 - 50ms/epoch - 6ms/step
# Epoch 177/300
# 8/8 - 0s - loss: 5.5480e-07 - 48ms/epoch - 6ms/step
# Epoch 178/300
# 8/8 - 0s - loss: 6.3424e-07 - 51ms/epoch - 6ms/step
# Epoch 179/300
# 8/8 - 0s - loss: 7.2122e-07 - 44ms/epoch - 5ms/step
# Epoch 180/300
# 8/8 - 0s - loss: 5.7610e-07 - 45ms/epoch - 6ms/step
# Epoch 181/300
# 8/8 - 0s - loss: 6.5580e-07 - 45ms/epoch - 6ms/step
# Epoch 182/300
# 8/8 - 0s - loss: 6.4124e-07 - 46ms/epoch - 6ms/step
# Epoch 183/300
# 8/8 - 0s - loss: 8.2664e-07 - 46ms/epoch - 6ms/step
# Epoch 184/300
# 8/8 - 0s - loss: 1.1331e-06 - 47ms/epoch - 6ms/step
# Epoch 185/300
# 8/8 - 0s - loss: 6.5199e-07 - 45ms/epoch - 6ms/step
# Epoch 186/300
# 8/8 - 0s - loss: 7.3583e-07 - 45ms/epoch - 6ms/step
# Epoch 187/300
# 8/8 - 0s - loss: 5.4071e-07 - 44ms/epoch - 5ms/step
# Epoch 188/300
# 8/8 - 0s - loss: 6.1632e-07 - 45ms/epoch - 6ms/step
# Epoch 189/300
# 8/8 - 0s - loss: 9.5709e-07 - 43ms/epoch - 5ms/step
# Epoch 190/300
# 8/8 - 0s - loss: 3.9973e-06 - 48ms/epoch - 6ms/step
# Epoch 191/300
# 8/8 - 0s - loss: 2.6039e-06 - 49ms/epoch - 6ms/step
# Epoch 192/300
# 8/8 - 0s - loss: 1.0824e-06 - 49ms/epoch - 6ms/step
# Epoch 193/300
# 8/8 - 0s - loss: 7.9466e-07 - 49ms/epoch - 6ms/step
# Epoch 194/300
# 8/8 - 0s - loss: 8.8286e-07 - 47ms/epoch - 6ms/step
# Epoch 195/300
# 8/8 - 0s - loss: 1.2247e-06 - 47ms/epoch - 6ms/step
# Epoch 196/300
# 8/8 - 0s - loss: 1.9739e-06 - 46ms/epoch - 6ms/step
# Epoch 197/300
# 8/8 - 0s - loss: 1.9626e-06 - 48ms/epoch - 6ms/step
# Epoch 198/300
# 8/8 - 0s - loss: 1.0232e-06 - 49ms/epoch - 6ms/step
# Epoch 199/300
# 8/8 - 0s - loss: 1.1241e-06 - 47ms/epoch - 6ms/step
# Epoch 200/300
# 8/8 - 0s - loss: 1.6989e-06 - 43ms/epoch - 5ms/step
# Epoch 201/300
# 8/8 - 0s - loss: 2.3925e-06 - 44ms/epoch - 6ms/step
# Epoch 202/300
# 8/8 - 0s - loss: 1.1973e-06 - 49ms/epoch - 6ms/step
# Epoch 203/300
# 8/8 - 0s - loss: 5.8325e-07 - 47ms/epoch - 6ms/step
# Epoch 204/300
# 8/8 - 0s - loss: 3.6968e-07 - 49ms/epoch - 6ms/step
# Epoch 205/300
# 8/8 - 0s - loss: 4.7801e-07 - 46ms/epoch - 6ms/step
# Epoch 206/300
# 8/8 - 0s - loss: 5.9345e-07 - 43ms/epoch - 5ms/step
# Epoch 207/300
# 8/8 - 0s - loss: 1.1985e-06 - 44ms/epoch - 6ms/step
# Epoch 208/300
# 8/8 - 0s - loss: 1.0144e-06 - 45ms/epoch - 6ms/step
# Epoch 209/300
# 8/8 - 0s - loss: 6.9536e-07 - 42ms/epoch - 5ms/step
# Epoch 210/300
# 8/8 - 0s - loss: 9.1899e-07 - 42ms/epoch - 5ms/step
# Epoch 211/300
# 8/8 - 0s - loss: 8.3389e-07 - 42ms/epoch - 5ms/step
# Epoch 212/300
# 8/8 - 0s - loss: 1.0061e-06 - 44ms/epoch - 5ms/step
# Epoch 213/300
# 8/8 - 0s - loss: 1.2558e-06 - 40ms/epoch - 5ms/step
# Epoch 214/300
# 8/8 - 0s - loss: 1.1654e-06 - 41ms/epoch - 5ms/step
# Epoch 215/300
# 8/8 - 0s - loss: 3.4453e-07 - 41ms/epoch - 5ms/step
# Epoch 216/300
# 8/8 - 0s - loss: 5.9618e-07 - 43ms/epoch - 5ms/step
# Epoch 217/300
# 8/8 - 0s - loss: 1.1566e-06 - 46ms/epoch - 6ms/step
# Epoch 218/300
# 8/8 - 0s - loss: 2.3474e-06 - 45ms/epoch - 6ms/step
# Epoch 219/300
# 8/8 - 0s - loss: 4.1192e-06 - 43ms/epoch - 5ms/step
# Epoch 220/300
# 8/8 - 0s - loss: 3.3447e-06 - 42ms/epoch - 5ms/step
# Epoch 221/300
# 8/8 - 0s - loss: 2.6308e-06 - 42ms/epoch - 5ms/step
# Epoch 222/300
# 8/8 - 0s - loss: 3.1198e-06 - 42ms/epoch - 5ms/step
# Epoch 223/300
# 8/8 - 0s - loss: 5.1051e-07 - 42ms/epoch - 5ms/step
# Epoch 224/300
# 8/8 - 0s - loss: 4.9874e-07 - 42ms/epoch - 5ms/step
# Epoch 225/300
# 8/8 - 0s - loss: 8.3192e-07 - 41ms/epoch - 5ms/step
# Epoch 226/300
# 8/8 - 0s - loss: 7.9399e-07 - 41ms/epoch - 5ms/step
# Epoch 227/300
# 8/8 - 0s - loss: 1.8565e-06 - 41ms/epoch - 5ms/step
# Epoch 228/300
# 8/8 - 0s - loss: 1.1522e-06 - 44ms/epoch - 5ms/step
# Epoch 229/300
# 8/8 - 0s - loss: 1.7615e-06 - 41ms/epoch - 5ms/step
# Epoch 230/300
# 8/8 - 0s - loss: 2.4878e-06 - 43ms/epoch - 5ms/step
# Epoch 231/300
# 8/8 - 0s - loss: 9.6098e-07 - 38ms/epoch - 5ms/step
# Epoch 232/300
# 8/8 - 0s - loss: 2.8108e-06 - 39ms/epoch - 5ms/step
# Epoch 233/300
# 8/8 - 0s - loss: 1.8729e-06 - 40ms/epoch - 5ms/step
# Epoch 234/300
# 8/8 - 0s - loss: 1.2310e-06 - 38ms/epoch - 5ms/step
# Epoch 235/300
# 8/8 - 0s - loss: 9.1325e-07 - 41ms/epoch - 5ms/step
# Epoch 236/300
# 8/8 - 0s - loss: 6.3396e-07 - 44ms/epoch - 5ms/step
# Epoch 237/300
# 8/8 - 0s - loss: 9.6299e-07 - 43ms/epoch - 5ms/step
# Epoch 238/300
# 8/8 - 0s - loss: 1.3049e-06 - 42ms/epoch - 5ms/step
# Epoch 239/300
# 8/8 - 0s - loss: 2.4520e-06 - 41ms/epoch - 5ms/step
# Epoch 240/300
# 8/8 - 0s - loss: 3.0025e-06 - 41ms/epoch - 5ms/step
# Epoch 241/300
# 8/8 - 0s - loss: 1.2054e-05 - 44ms/epoch - 5ms/step
# Epoch 242/300
# 8/8 - 0s - loss: 1.0691e-05 - 47ms/epoch - 6ms/step
# Epoch 243/300
# 8/8 - 0s - loss: 2.7357e-06 - 42ms/epoch - 5ms/step
# Epoch 244/300
# 8/8 - 0s - loss: 3.1357e-06 - 44ms/epoch - 6ms/step
# Epoch 245/300
# 8/8 - 0s - loss: 6.7595e-06 - 45ms/epoch - 6ms/step
# Epoch 246/300
# 8/8 - 0s - loss: 7.6948e-06 - 46ms/epoch - 6ms/step
# Epoch 247/300
# 8/8 - 0s - loss: 7.4134e-06 - 46ms/epoch - 6ms/step
# Epoch 248/300
# 8/8 - 0s - loss: 3.7912e-05 - 46ms/epoch - 6ms/step
# Epoch 249/300
# 8/8 - 0s - loss: 3.5523e-05 - 43ms/epoch - 5ms/step
# Epoch 250/300
# 8/8 - 0s - loss: 1.2937e-05 - 42ms/epoch - 5ms/step
# Epoch 251/300
# 8/8 - 0s - loss: 6.2814e-05 - 41ms/epoch - 5ms/step
# Epoch 252/300
# 8/8 - 0s - loss: 2.6770e-04 - 45ms/epoch - 6ms/step
# Epoch 253/300
# 8/8 - 0s - loss: 3.4039e-04 - 41ms/epoch - 5ms/step
# Epoch 254/300
# 8/8 - 0s - loss: 1.9313e-04 - 41ms/epoch - 5ms/step
# Epoch 255/300
# 8/8 - 0s - loss: 2.2996e-04 - 41ms/epoch - 5ms/step
# Epoch 256/300
# 8/8 - 0s - loss: 3.2042e-04 - 38ms/epoch - 5ms/step
# Epoch 257/300
# 8/8 - 0s - loss: 3.3170e-04 - 40ms/epoch - 5ms/step
# Epoch 258/300
# 8/8 - 0s - loss: 4.2529e-04 - 44ms/epoch - 5ms/step
# Epoch 259/300
# 8/8 - 0s - loss: 3.9909e-04 - 41ms/epoch - 5ms/step
# Epoch 260/300
# 8/8 - 0s - loss: 2.8493e-04 - 43ms/epoch - 5ms/step
# Epoch 261/300
# 8/8 - 0s - loss: 2.1922e-04 - 43ms/epoch - 5ms/step
# Epoch 262/300
# 8/8 - 0s - loss: 1.3784e-04 - 40ms/epoch - 5ms/step
# Epoch 263/300
# 8/8 - 0s - loss: 2.9261e-04 - 44ms/epoch - 6ms/step
# Epoch 264/300
# 8/8 - 0s - loss: 0.0057 - 40ms/epoch - 5ms/step
# Epoch 265/300
# 8/8 - 0s - loss: 0.0191 - 39ms/epoch - 5ms/step
# Epoch 266/300
# 8/8 - 0s - loss: 0.0248 - 39ms/epoch - 5ms/step
# Epoch 267/300
# 8/8 - 0s - loss: 0.0271 - 42ms/epoch - 5ms/step
# Epoch 268/300
# 8/8 - 0s - loss: 0.0211 - 42ms/epoch - 5ms/step
# Epoch 269/300
# 8/8 - 0s - loss: 0.0183 - 44ms/epoch - 5ms/step
# Epoch 270/300
# 8/8 - 0s - loss: 0.0150 - 42ms/epoch - 5ms/step
# Epoch 271/300
# 8/8 - 0s - loss: 0.0086 - 46ms/epoch - 6ms/step
# Epoch 272/300
# 8/8 - 0s - loss: 0.0054 - 42ms/epoch - 5ms/step
# Epoch 273/300
# 8/8 - 0s - loss: 0.0202 - 43ms/epoch - 5ms/step
# Epoch 274/300
# 8/8 - 0s - loss: 0.0257 - 42ms/epoch - 5ms/step
# Epoch 275/300
# 8/8 - 0s - loss: 0.0123 - 44ms/epoch - 6ms/step
# Epoch 276/300
# 8/8 - 0s - loss: 0.0144 - 43ms/epoch - 5ms/step
# Epoch 277/300
# 8/8 - 0s - loss: 0.0162 - 48ms/epoch - 6ms/step
# Epoch 278/300
# 8/8 - 0s - loss: 0.0048 - 47ms/epoch - 6ms/step
# Epoch 279/300
# 8/8 - 0s - loss: 0.0034 - 42ms/epoch - 5ms/step
# Epoch 280/300
# 8/8 - 0s - loss: 0.0013 - 46ms/epoch - 6ms/step
# Epoch 281/300
# 8/8 - 0s - loss: 7.4715e-04 - 44ms/epoch - 5ms/step
# Epoch 282/300
# 8/8 - 0s - loss: 4.7122e-04 - 48ms/epoch - 6ms/step
# Epoch 283/300
# 8/8 - 0s - loss: 6.5952e-05 - 44ms/epoch - 5ms/step
# Epoch 284/300
# 8/8 - 0s - loss: 3.7070e-05 - 47ms/epoch - 6ms/step
# Epoch 285/300
# 8/8 - 0s - loss: 3.7084e-05 - 44ms/epoch - 6ms/step
# Epoch 286/300
# 8/8 - 0s - loss: 2.2994e-05 - 40ms/epoch - 5ms/step
# Epoch 287/300
# 8/8 - 0s - loss: 5.1150e-05 - 44ms/epoch - 5ms/step
# Epoch 288/300
# 8/8 - 0s - loss: 5.2153e-05 - 41ms/epoch - 5ms/step
# Epoch 289/300
# 8/8 - 0s - loss: 2.5754e-05 - 44ms/epoch - 5ms/step
# Epoch 290/300
# 8/8 - 0s - loss: 1.9872e-05 - 43ms/epoch - 5ms/step
# Epoch 291/300
# 8/8 - 0s - loss: 1.3627e-05 - 46ms/epoch - 6ms/step
# Epoch 292/300
# 8/8 - 0s - loss: 9.8157e-06 - 46ms/epoch - 6ms/step
# Epoch 293/300
# 8/8 - 0s - loss: 9.7782e-06 - 44ms/epoch - 5ms/step
# Epoch 294/300
# 8/8 - 0s - loss: 8.9018e-06 - 44ms/epoch - 6ms/step
# Epoch 295/300
# 8/8 - 0s - loss: 8.4406e-06 - 45ms/epoch - 6ms/step
# Epoch 296/300
# 8/8 - 0s - loss: 7.1806e-06 - 46ms/epoch - 6ms/step
# Epoch 297/300
# 8/8 - 0s - loss: 7.3908e-06 - 47ms/epoch - 6ms/step
# Epoch 298/300
# 8/8 - 0s - loss: 6.6786e-06 - 47ms/epoch - 6ms/step
# Epoch 299/300
# 8/8 - 0s - loss: 4.7293e-06 - 49ms/epoch - 6ms/step
# Epoch 300/300
# 8/8 - 0s - loss: 4.7748e-06 - 46ms/epoch - 6ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 16/16 [==============================] - 1s 4ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710201563.6897035
# Mon Mar 11 23:59:23 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710201563.7010784
# Mon Mar 11 23:59:23 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 8/8 - 1s - loss: 0.3134 - 714ms/epoch - 89ms/step
# Epoch 2/300
# 8/8 - 0s - loss: 0.1363 - 62ms/epoch - 8ms/step
# Epoch 3/300
# 8/8 - 0s - loss: 0.1235 - 63ms/epoch - 8ms/step
# Epoch 4/300
# 8/8 - 0s - loss: 0.1180 - 64ms/epoch - 8ms/step
# Epoch 5/300
# 8/8 - 0s - loss: 0.1126 - 58ms/epoch - 7ms/step
# Epoch 6/300
# 8/8 - 0s - loss: 0.0981 - 59ms/epoch - 7ms/step
# Epoch 7/300
# 8/8 - 0s - loss: 0.0791 - 60ms/epoch - 7ms/step
# Epoch 8/300
# 8/8 - 0s - loss: 0.0808 - 63ms/epoch - 8ms/step
# Epoch 9/300
# 8/8 - 0s - loss: 0.0779 - 64ms/epoch - 8ms/step
# Epoch 10/300
# 8/8 - 0s - loss: 0.0647 - 68ms/epoch - 9ms/step
# Epoch 11/300
# 8/8 - 0s - loss: 0.0651 - 67ms/epoch - 8ms/step
# Epoch 12/300
# 8/8 - 0s - loss: 0.0647 - 66ms/epoch - 8ms/step
# Epoch 13/300
# 8/8 - 0s - loss: 0.0617 - 63ms/epoch - 8ms/step
# Epoch 14/300
# 8/8 - 0s - loss: 0.0682 - 61ms/epoch - 8ms/step
# Epoch 15/300
# 8/8 - 0s - loss: 0.0655 - 62ms/epoch - 8ms/step
# Epoch 16/300
# 8/8 - 0s - loss: 0.0661 - 63ms/epoch - 8ms/step
# Epoch 17/300
# 8/8 - 0s - loss: 0.0559 - 55ms/epoch - 7ms/step
# Epoch 18/300
# 8/8 - 0s - loss: 0.0469 - 61ms/epoch - 8ms/step
# Epoch 19/300
# 8/8 - 0s - loss: 0.0462 - 57ms/epoch - 7ms/step
# Epoch 20/300
# 8/8 - 0s - loss: 0.0511 - 61ms/epoch - 8ms/step
# Epoch 21/300
# 8/8 - 0s - loss: 0.0520 - 58ms/epoch - 7ms/step
# Epoch 22/300
# 8/8 - 0s - loss: 0.0602 - 60ms/epoch - 7ms/step
# Epoch 23/300
# 8/8 - 0s - loss: 0.0588 - 63ms/epoch - 8ms/step
# Epoch 24/300
# 8/8 - 0s - loss: 0.0563 - 55ms/epoch - 7ms/step
# Epoch 25/300
# 8/8 - 0s - loss: 0.0380 - 59ms/epoch - 7ms/step
# Epoch 26/300
# 8/8 - 0s - loss: 0.0335 - 58ms/epoch - 7ms/step
# Epoch 27/300
# 8/8 - 0s - loss: 0.0340 - 65ms/epoch - 8ms/step
# Epoch 28/300
# 8/8 - 0s - loss: 0.0267 - 58ms/epoch - 7ms/step
# Epoch 29/300
# 8/8 - 0s - loss: 0.0290 - 58ms/epoch - 7ms/step
# Epoch 30/300
# 8/8 - 0s - loss: 0.0364 - 59ms/epoch - 7ms/step
# Epoch 31/300
# 8/8 - 0s - loss: 0.0400 - 62ms/epoch - 8ms/step
# Epoch 32/300
# 8/8 - 0s - loss: 0.0417 - 57ms/epoch - 7ms/step
# Epoch 33/300
# 8/8 - 0s - loss: 0.0239 - 55ms/epoch - 7ms/step
# Epoch 34/300
# 8/8 - 0s - loss: 0.0190 - 59ms/epoch - 7ms/step
# Epoch 35/300
# 8/8 - 0s - loss: 0.0207 - 58ms/epoch - 7ms/step
# Epoch 36/300
# 8/8 - 0s - loss: 0.0178 - 57ms/epoch - 7ms/step
# Epoch 37/300
# 8/8 - 0s - loss: 0.0138 - 57ms/epoch - 7ms/step
# Epoch 38/300
# 8/8 - 0s - loss: 0.0156 - 61ms/epoch - 8ms/step
# Epoch 39/300
# 8/8 - 0s - loss: 0.0134 - 60ms/epoch - 7ms/step
# Epoch 40/300
# 8/8 - 0s - loss: 0.0120 - 60ms/epoch - 7ms/step
# Epoch 41/300
# 8/8 - 0s - loss: 0.0109 - 54ms/epoch - 7ms/step
# Epoch 42/300
# 8/8 - 0s - loss: 0.0111 - 55ms/epoch - 7ms/step
# Epoch 43/300
# 8/8 - 0s - loss: 0.0089 - 57ms/epoch - 7ms/step
# Epoch 44/300
# 8/8 - 0s - loss: 0.0082 - 59ms/epoch - 7ms/step
# Epoch 45/300
# 8/8 - 0s - loss: 0.0081 - 68ms/epoch - 9ms/step
# Epoch 46/300
# 8/8 - 0s - loss: 0.0081 - 58ms/epoch - 7ms/step
# Epoch 47/300
# 8/8 - 0s - loss: 0.0087 - 59ms/epoch - 7ms/step
# Epoch 48/300
# 8/8 - 0s - loss: 0.0087 - 60ms/epoch - 8ms/step
# Epoch 49/300
# 8/8 - 0s - loss: 0.0098 - 57ms/epoch - 7ms/step
# Epoch 50/300
# 8/8 - 0s - loss: 0.0104 - 57ms/epoch - 7ms/step
# Epoch 51/300
# 8/8 - 0s - loss: 0.0103 - 58ms/epoch - 7ms/step
# Epoch 52/300
# 8/8 - 0s - loss: 0.0123 - 58ms/epoch - 7ms/step
# Epoch 53/300
# 8/8 - 0s - loss: 0.0178 - 66ms/epoch - 8ms/step
# Epoch 54/300
# 8/8 - 0s - loss: 0.0111 - 58ms/epoch - 7ms/step
# Epoch 55/300
# 8/8 - 0s - loss: 0.0115 - 65ms/epoch - 8ms/step
# Epoch 56/300
# 8/8 - 0s - loss: 0.0087 - 64ms/epoch - 8ms/step
# Epoch 57/300
# 8/8 - 0s - loss: 0.0097 - 53ms/epoch - 7ms/step
# Epoch 58/300
# 8/8 - 0s - loss: 0.0090 - 58ms/epoch - 7ms/step
# Epoch 59/300
# 8/8 - 0s - loss: 0.0093 - 63ms/epoch - 8ms/step
# Epoch 60/300
# 8/8 - 0s - loss: 0.0060 - 63ms/epoch - 8ms/step
# Epoch 61/300
# 8/8 - 0s - loss: 0.0062 - 58ms/epoch - 7ms/step
# Epoch 62/300
# 8/8 - 0s - loss: 0.0062 - 56ms/epoch - 7ms/step
# Epoch 63/300
# 8/8 - 0s - loss: 0.0058 - 56ms/epoch - 7ms/step
# Epoch 64/300
# 8/8 - 0s - loss: 0.0062 - 62ms/epoch - 8ms/step
# Epoch 65/300
# 8/8 - 0s - loss: 0.0054 - 55ms/epoch - 7ms/step
# Epoch 66/300
# 8/8 - 0s - loss: 0.0043 - 63ms/epoch - 8ms/step
# Epoch 67/300
# 8/8 - 0s - loss: 0.0038 - 63ms/epoch - 8ms/step
# Epoch 68/300
# 8/8 - 0s - loss: 0.0036 - 65ms/epoch - 8ms/step
# Epoch 69/300
# 8/8 - 0s - loss: 0.0033 - 62ms/epoch - 8ms/step
# Epoch 70/300
# 8/8 - 0s - loss: 0.0037 - 63ms/epoch - 8ms/step
# Epoch 71/300
# 8/8 - 0s - loss: 0.0036 - 62ms/epoch - 8ms/step
# Epoch 72/300
# 8/8 - 0s - loss: 0.0047 - 63ms/epoch - 8ms/step
# Epoch 73/300
# 8/8 - 0s - loss: 0.0059 - 60ms/epoch - 7ms/step
# Epoch 74/300
# 8/8 - 0s - loss: 0.0058 - 58ms/epoch - 7ms/step
# Epoch 75/300
# 8/8 - 0s - loss: 0.0048 - 61ms/epoch - 8ms/step
# Epoch 76/300
# 8/8 - 0s - loss: 0.0049 - 62ms/epoch - 8ms/step
# Epoch 77/300
# 8/8 - 0s - loss: 0.0052 - 68ms/epoch - 9ms/step
# Epoch 78/300
# 8/8 - 0s - loss: 0.0039 - 63ms/epoch - 8ms/step
# Epoch 79/300
# 8/8 - 0s - loss: 0.0058 - 66ms/epoch - 8ms/step
# Epoch 80/300
# 8/8 - 0s - loss: 0.0058 - 59ms/epoch - 7ms/step
# Epoch 81/300
# 8/8 - 0s - loss: 0.0047 - 62ms/epoch - 8ms/step
# Epoch 82/300
# 8/8 - 0s - loss: 0.0050 - 61ms/epoch - 8ms/step
# Epoch 83/300
# 8/8 - 0s - loss: 0.0094 - 59ms/epoch - 7ms/step
# Epoch 84/300
# 8/8 - 0s - loss: 0.0129 - 71ms/epoch - 9ms/step
# Epoch 85/300
# 8/8 - 0s - loss: 0.0092 - 60ms/epoch - 7ms/step
# Epoch 86/300
# 8/8 - 0s - loss: 0.0060 - 58ms/epoch - 7ms/step
# Epoch 87/300
# 8/8 - 0s - loss: 0.0040 - 61ms/epoch - 8ms/step
# Epoch 88/300
# 8/8 - 0s - loss: 0.0037 - 66ms/epoch - 8ms/step
# Epoch 89/300
# 8/8 - 0s - loss: 0.0035 - 62ms/epoch - 8ms/step
# Epoch 90/300
# 8/8 - 0s - loss: 0.0024 - 66ms/epoch - 8ms/step
# Epoch 91/300
# 8/8 - 0s - loss: 0.0021 - 61ms/epoch - 8ms/step
# Epoch 92/300
# 8/8 - 0s - loss: 0.0017 - 59ms/epoch - 7ms/step
# Epoch 93/300
# 8/8 - 0s - loss: 0.0016 - 63ms/epoch - 8ms/step
# Epoch 94/300
# 8/8 - 0s - loss: 0.0018 - 61ms/epoch - 8ms/step
# Epoch 95/300
# 8/8 - 0s - loss: 0.0023 - 54ms/epoch - 7ms/step
# Epoch 96/300
# 8/8 - 0s - loss: 0.0015 - 57ms/epoch - 7ms/step
# Epoch 97/300
# 8/8 - 0s - loss: 0.0019 - 59ms/epoch - 7ms/step
# Epoch 98/300
# 8/8 - 0s - loss: 0.0017 - 59ms/epoch - 7ms/step
# Epoch 99/300
# 8/8 - 0s - loss: 0.0015 - 56ms/epoch - 7ms/step
# Epoch 100/300
# 8/8 - 0s - loss: 0.0019 - 62ms/epoch - 8ms/step
# Epoch 101/300
# 8/8 - 0s - loss: 0.0016 - 58ms/epoch - 7ms/step
# Epoch 102/300
# 8/8 - 0s - loss: 0.0016 - 59ms/epoch - 7ms/step
# Epoch 103/300
# 8/8 - 0s - loss: 0.0016 - 55ms/epoch - 7ms/step
# Epoch 104/300
# 8/8 - 0s - loss: 0.0020 - 62ms/epoch - 8ms/step
# Epoch 105/300
# 8/8 - 0s - loss: 0.0019 - 60ms/epoch - 8ms/step
# Epoch 106/300
# 8/8 - 0s - loss: 0.0017 - 61ms/epoch - 8ms/step
# Epoch 107/300
# 8/8 - 0s - loss: 0.0020 - 65ms/epoch - 8ms/step
# Epoch 108/300
# 8/8 - 0s - loss: 8.8006e-04 - 60ms/epoch - 7ms/step
# Epoch 109/300
# 8/8 - 0s - loss: 0.0018 - 55ms/epoch - 7ms/step
# Epoch 110/300
# 8/8 - 0s - loss: 0.0035 - 58ms/epoch - 7ms/step
# Epoch 111/300
# 8/8 - 0s - loss: 0.0036 - 60ms/epoch - 8ms/step
# Epoch 112/300
# 8/8 - 0s - loss: 0.0045 - 56ms/epoch - 7ms/step
# Epoch 113/300
# 8/8 - 0s - loss: 0.0049 - 61ms/epoch - 8ms/step
# Epoch 114/300
# 8/8 - 0s - loss: 0.0052 - 58ms/epoch - 7ms/step
# Epoch 115/300
# 8/8 - 0s - loss: 0.0055 - 54ms/epoch - 7ms/step
# Epoch 116/300
# 8/8 - 0s - loss: 0.0033 - 55ms/epoch - 7ms/step
# Epoch 117/300
# 8/8 - 0s - loss: 0.0044 - 58ms/epoch - 7ms/step
# Epoch 118/300
# 8/8 - 0s - loss: 0.0038 - 56ms/epoch - 7ms/step
# Epoch 119/300
# 8/8 - 0s - loss: 0.0022 - 59ms/epoch - 7ms/step
# Epoch 120/300
# 8/8 - 0s - loss: 0.0016 - 58ms/epoch - 7ms/step
# Epoch 121/300
# 8/8 - 0s - loss: 0.0012 - 57ms/epoch - 7ms/step
# Epoch 122/300
# 8/8 - 0s - loss: 0.0013 - 55ms/epoch - 7ms/step
# Epoch 123/300
# 8/8 - 0s - loss: 0.0018 - 57ms/epoch - 7ms/step
# Epoch 124/300
# 8/8 - 0s - loss: 0.0019 - 59ms/epoch - 7ms/step
# Epoch 125/300
# 8/8 - 0s - loss: 0.0029 - 58ms/epoch - 7ms/step
# Epoch 126/300
# 8/8 - 0s - loss: 0.0025 - 57ms/epoch - 7ms/step
# Epoch 127/300
# 8/8 - 0s - loss: 0.0027 - 55ms/epoch - 7ms/step
# Epoch 128/300
# 8/8 - 0s - loss: 0.0018 - 54ms/epoch - 7ms/step
# Epoch 129/300
# 8/8 - 0s - loss: 0.0012 - 58ms/epoch - 7ms/step
# Epoch 130/300
# 8/8 - 0s - loss: 0.0013 - 56ms/epoch - 7ms/step
# Epoch 131/300
# 8/8 - 0s - loss: 0.0010 - 57ms/epoch - 7ms/step
# Epoch 132/300
# 8/8 - 0s - loss: 0.0024 - 55ms/epoch - 7ms/step
# Epoch 133/300
# 8/8 - 0s - loss: 0.0026 - 53ms/epoch - 7ms/step
# Epoch 134/300
# 8/8 - 0s - loss: 0.0031 - 56ms/epoch - 7ms/step
# Epoch 135/300
# 8/8 - 0s - loss: 0.0014 - 61ms/epoch - 8ms/step
# Epoch 136/300
# 8/8 - 0s - loss: 0.0014 - 63ms/epoch - 8ms/step
# Epoch 137/300
# 8/8 - 0s - loss: 0.0014 - 58ms/epoch - 7ms/step
# Epoch 138/300
# 8/8 - 0s - loss: 0.0014 - 68ms/epoch - 9ms/step
# Epoch 139/300
# 8/8 - 0s - loss: 0.0012 - 62ms/epoch - 8ms/step
# Epoch 140/300
# 8/8 - 0s - loss: 0.0011 - 58ms/epoch - 7ms/step
# Epoch 141/300
# 8/8 - 0s - loss: 8.8087e-04 - 57ms/epoch - 7ms/step
# Epoch 142/300
# 8/8 - 0s - loss: 8.5322e-04 - 59ms/epoch - 7ms/step
# Epoch 143/300
# 8/8 - 0s - loss: 0.0011 - 63ms/epoch - 8ms/step
# Epoch 144/300
# 8/8 - 0s - loss: 0.0015 - 58ms/epoch - 7ms/step
# Epoch 145/300
# 8/8 - 0s - loss: 0.0038 - 62ms/epoch - 8ms/step
# Epoch 146/300
# 8/8 - 0s - loss: 0.0040 - 59ms/epoch - 7ms/step
# Epoch 147/300
# 8/8 - 0s - loss: 0.0027 - 61ms/epoch - 8ms/step
# Epoch 148/300
# 8/8 - 0s - loss: 0.0014 - 59ms/epoch - 7ms/step
# Epoch 149/300
# 8/8 - 0s - loss: 0.0018 - 63ms/epoch - 8ms/step
# Epoch 150/300
# 8/8 - 0s - loss: 9.3223e-04 - 54ms/epoch - 7ms/step
# Epoch 151/300
# 8/8 - 0s - loss: 7.6260e-04 - 60ms/epoch - 7ms/step
# Epoch 152/300
# 8/8 - 0s - loss: 3.3238e-04 - 62ms/epoch - 8ms/step
# Epoch 153/300
# 8/8 - 0s - loss: 2.6249e-04 - 64ms/epoch - 8ms/step
# Epoch 154/300
# 8/8 - 0s - loss: 3.1631e-04 - 62ms/epoch - 8ms/step
# Epoch 155/300
# 8/8 - 0s - loss: 5.6837e-04 - 57ms/epoch - 7ms/step
# Epoch 156/300
# 8/8 - 0s - loss: 4.2657e-04 - 62ms/epoch - 8ms/step
# Epoch 157/300
# 8/8 - 0s - loss: 3.5362e-04 - 64ms/epoch - 8ms/step
# Epoch 158/300
# 8/8 - 0s - loss: 2.9499e-04 - 56ms/epoch - 7ms/step
# Epoch 159/300
# 8/8 - 0s - loss: 4.0005e-04 - 62ms/epoch - 8ms/step
# Epoch 160/300
# 8/8 - 0s - loss: 3.4905e-04 - 56ms/epoch - 7ms/step
# Epoch 161/300
# 8/8 - 0s - loss: 8.8883e-04 - 65ms/epoch - 8ms/step
# Epoch 162/300
# 8/8 - 0s - loss: 4.9928e-04 - 58ms/epoch - 7ms/step
# Epoch 163/300
# 8/8 - 0s - loss: 4.2060e-04 - 58ms/epoch - 7ms/step
# Epoch 164/300
# 8/8 - 0s - loss: 4.1039e-04 - 61ms/epoch - 8ms/step
# Epoch 165/300
# 8/8 - 0s - loss: 7.2077e-04 - 60ms/epoch - 7ms/step
# Epoch 166/300
# 8/8 - 0s - loss: 0.0013 - 56ms/epoch - 7ms/step
# Epoch 167/300
# 8/8 - 0s - loss: 7.1797e-04 - 58ms/epoch - 7ms/step
# Epoch 168/300
# 8/8 - 0s - loss: 8.5144e-04 - 57ms/epoch - 7ms/step
# Epoch 169/300
# 8/8 - 0s - loss: 9.0761e-04 - 61ms/epoch - 8ms/step
# Epoch 170/300
# 8/8 - 0s - loss: 5.8290e-04 - 63ms/epoch - 8ms/step
# Epoch 171/300
# 8/8 - 0s - loss: 9.0732e-04 - 60ms/epoch - 7ms/step
# Epoch 172/300
# 8/8 - 0s - loss: 0.0015 - 55ms/epoch - 7ms/step
# Epoch 173/300
# 8/8 - 0s - loss: 0.0018 - 59ms/epoch - 7ms/step
# Epoch 174/300
# 8/8 - 0s - loss: 0.0019 - 58ms/epoch - 7ms/step
# Epoch 175/300
# 8/8 - 0s - loss: 0.0015 - 60ms/epoch - 7ms/step
# Epoch 176/300
# 8/8 - 0s - loss: 0.0024 - 57ms/epoch - 7ms/step
# Epoch 177/300
# 8/8 - 0s - loss: 0.0029 - 62ms/epoch - 8ms/step
# Epoch 178/300
# 8/8 - 0s - loss: 0.0039 - 58ms/epoch - 7ms/step
# Epoch 179/300
# 8/8 - 0s - loss: 0.0035 - 59ms/epoch - 7ms/step
# Epoch 180/300
# 8/8 - 0s - loss: 0.0032 - 63ms/epoch - 8ms/step
# Epoch 181/300
# 8/8 - 0s - loss: 0.0032 - 59ms/epoch - 7ms/step
# Epoch 182/300
# 8/8 - 0s - loss: 0.0031 - 55ms/epoch - 7ms/step
# Epoch 183/300
# 8/8 - 0s - loss: 0.0026 - 60ms/epoch - 8ms/step
# Epoch 184/300
# 8/8 - 0s - loss: 0.0044 - 54ms/epoch - 7ms/step
# Epoch 185/300
# 8/8 - 0s - loss: 0.0060 - 59ms/epoch - 7ms/step
# Epoch 186/300
# 8/8 - 0s - loss: 0.0072 - 61ms/epoch - 8ms/step
# Epoch 187/300
# 8/8 - 0s - loss: 0.0030 - 66ms/epoch - 8ms/step
# Epoch 188/300
# 8/8 - 0s - loss: 0.0021 - 57ms/epoch - 7ms/step
# Epoch 189/300
# 8/8 - 0s - loss: 0.0012 - 65ms/epoch - 8ms/step
# Epoch 190/300
# 8/8 - 0s - loss: 3.8822e-04 - 61ms/epoch - 8ms/step
# Epoch 191/300
# 8/8 - 0s - loss: 4.2268e-04 - 59ms/epoch - 7ms/step
# Epoch 192/300
# 8/8 - 0s - loss: 3.3116e-04 - 58ms/epoch - 7ms/step
# Epoch 193/300
# 8/8 - 0s - loss: 4.7418e-04 - 59ms/epoch - 7ms/step
# Epoch 194/300
# 8/8 - 0s - loss: 3.1055e-04 - 57ms/epoch - 7ms/step
# Epoch 195/300
# 8/8 - 0s - loss: 2.4056e-04 - 53ms/epoch - 7ms/step
# Epoch 196/300
# 8/8 - 0s - loss: 2.9393e-04 - 57ms/epoch - 7ms/step
# Epoch 197/300
# 8/8 - 0s - loss: 2.6151e-04 - 57ms/epoch - 7ms/step
# Epoch 198/300
# 8/8 - 0s - loss: 1.6825e-04 - 65ms/epoch - 8ms/step
# Epoch 199/300
# 8/8 - 0s - loss: 1.7944e-04 - 66ms/epoch - 8ms/step
# Epoch 200/300
# 8/8 - 0s - loss: 1.5195e-04 - 65ms/epoch - 8ms/step
# Epoch 201/300
# 8/8 - 0s - loss: 2.7216e-04 - 56ms/epoch - 7ms/step
# Epoch 202/300
# 8/8 - 0s - loss: 3.7011e-04 - 56ms/epoch - 7ms/step
# Epoch 203/300
# 8/8 - 0s - loss: 4.1259e-04 - 65ms/epoch - 8ms/step
# Epoch 204/300
# 8/8 - 0s - loss: 3.2259e-04 - 60ms/epoch - 7ms/step
# Epoch 205/300
# 8/8 - 0s - loss: 2.4988e-04 - 58ms/epoch - 7ms/step
# Epoch 206/300
# 8/8 - 0s - loss: 1.9771e-04 - 56ms/epoch - 7ms/step
# Epoch 207/300
# 8/8 - 0s - loss: 4.1108e-04 - 57ms/epoch - 7ms/step
# Epoch 208/300
# 8/8 - 0s - loss: 5.2188e-04 - 58ms/epoch - 7ms/step
# Epoch 209/300
# 8/8 - 0s - loss: 5.9280e-04 - 57ms/epoch - 7ms/step
# Epoch 210/300
# 8/8 - 0s - loss: 0.0012 - 54ms/epoch - 7ms/step
# Epoch 211/300
# 8/8 - 0s - loss: 0.0016 - 63ms/epoch - 8ms/step
# Epoch 212/300
# 8/8 - 0s - loss: 7.9694e-04 - 62ms/epoch - 8ms/step
# Epoch 213/300
# 8/8 - 0s - loss: 0.0013 - 54ms/epoch - 7ms/step
# Epoch 214/300
# 8/8 - 0s - loss: 0.0010 - 66ms/epoch - 8ms/step
# Epoch 215/300
# 8/8 - 0s - loss: 8.4463e-04 - 62ms/epoch - 8ms/step
# Epoch 216/300
# 8/8 - 0s - loss: 0.0014 - 61ms/epoch - 8ms/step
# Epoch 217/300
# 8/8 - 0s - loss: 0.0012 - 61ms/epoch - 8ms/step
# Epoch 218/300
# 8/8 - 0s - loss: 0.0013 - 59ms/epoch - 7ms/step
# Epoch 219/300
# 8/8 - 0s - loss: 0.0014 - 55ms/epoch - 7ms/step
# Epoch 220/300
# 8/8 - 0s - loss: 8.1408e-04 - 66ms/epoch - 8ms/step
# Epoch 221/300
# 8/8 - 0s - loss: 3.8217e-04 - 70ms/epoch - 9ms/step
# Epoch 222/300
# 8/8 - 0s - loss: 4.3405e-04 - 67ms/epoch - 8ms/step
# Epoch 223/300
# 8/8 - 0s - loss: 5.8066e-04 - 69ms/epoch - 9ms/step
# Epoch 224/300
# 8/8 - 0s - loss: 6.7866e-04 - 58ms/epoch - 7ms/step
# Epoch 225/300
# 8/8 - 0s - loss: 6.7571e-04 - 56ms/epoch - 7ms/step
# Epoch 226/300
# 8/8 - 0s - loss: 4.9848e-04 - 59ms/epoch - 7ms/step
# Epoch 227/300
# 8/8 - 0s - loss: 4.8746e-04 - 57ms/epoch - 7ms/step
# Epoch 228/300
# 8/8 - 0s - loss: 3.7378e-04 - 61ms/epoch - 8ms/step
# Epoch 229/300
# 8/8 - 0s - loss: 4.6204e-04 - 56ms/epoch - 7ms/step
# Epoch 230/300
# 8/8 - 0s - loss: 1.8720e-04 - 56ms/epoch - 7ms/step
# Epoch 231/300
# 8/8 - 0s - loss: 2.6717e-04 - 56ms/epoch - 7ms/step
# Epoch 232/300
# 8/8 - 0s - loss: 2.0293e-04 - 59ms/epoch - 7ms/step
# Epoch 233/300
# 8/8 - 0s - loss: 2.1115e-04 - 58ms/epoch - 7ms/step
# Epoch 234/300
# 8/8 - 0s - loss: 1.8212e-04 - 56ms/epoch - 7ms/step
# Epoch 235/300
# 8/8 - 0s - loss: 1.6372e-04 - 55ms/epoch - 7ms/step
# Epoch 236/300
# 8/8 - 0s - loss: 1.5463e-04 - 58ms/epoch - 7ms/step
# Epoch 237/300
# 8/8 - 0s - loss: 3.4631e-04 - 57ms/epoch - 7ms/step
# Epoch 238/300
# 8/8 - 0s - loss: 3.9036e-04 - 64ms/epoch - 8ms/step
# Epoch 239/300
# 8/8 - 0s - loss: 4.7636e-04 - 59ms/epoch - 7ms/step
# Epoch 240/300
# 8/8 - 0s - loss: 6.8311e-04 - 56ms/epoch - 7ms/step
# Epoch 241/300
# 8/8 - 0s - loss: 2.3748e-04 - 58ms/epoch - 7ms/step
# Epoch 242/300
# 8/8 - 0s - loss: 2.1918e-04 - 58ms/epoch - 7ms/step
# Epoch 243/300
# 8/8 - 0s - loss: 3.2597e-04 - 59ms/epoch - 7ms/step
# Epoch 244/300
# 8/8 - 0s - loss: 2.6536e-04 - 56ms/epoch - 7ms/step
# Epoch 245/300
# 8/8 - 0s - loss: 2.7040e-04 - 58ms/epoch - 7ms/step
# Epoch 246/300
# 8/8 - 0s - loss: 3.5770e-04 - 58ms/epoch - 7ms/step
# Epoch 247/300
# 8/8 - 0s - loss: 0.0012 - 56ms/epoch - 7ms/step
# Epoch 248/300
# 8/8 - 0s - loss: 0.0021 - 61ms/epoch - 8ms/step
# Epoch 249/300
# 8/8 - 0s - loss: 0.0030 - 60ms/epoch - 7ms/step
# Epoch 250/300
# 8/8 - 0s - loss: 0.0027 - 60ms/epoch - 8ms/step
# Epoch 251/300
# 8/8 - 0s - loss: 0.0019 - 57ms/epoch - 7ms/step
# Epoch 252/300
# 8/8 - 0s - loss: 0.0020 - 58ms/epoch - 7ms/step
# Epoch 253/300
# 8/8 - 0s - loss: 0.0014 - 65ms/epoch - 8ms/step
# Epoch 254/300
# 8/8 - 0s - loss: 7.8590e-04 - 63ms/epoch - 8ms/step
# Epoch 255/300
# 8/8 - 0s - loss: 0.0016 - 60ms/epoch - 8ms/step
# Epoch 256/300
# 8/8 - 0s - loss: 0.0026 - 62ms/epoch - 8ms/step
# Epoch 257/300
# 8/8 - 0s - loss: 0.0033 - 60ms/epoch - 8ms/step
# Epoch 258/300
# 8/8 - 0s - loss: 0.0025 - 60ms/epoch - 7ms/step
# Epoch 259/300
# 8/8 - 0s - loss: 0.0028 - 65ms/epoch - 8ms/step
# Epoch 260/300
# 8/8 - 0s - loss: 0.0012 - 63ms/epoch - 8ms/step
# Epoch 261/300
# 8/8 - 0s - loss: 7.8949e-04 - 68ms/epoch - 8ms/step
# Epoch 262/300
# 8/8 - 0s - loss: 8.0263e-04 - 63ms/epoch - 8ms/step
# Epoch 263/300
# 8/8 - 0s - loss: 7.1936e-04 - 64ms/epoch - 8ms/step
# Epoch 264/300
# 8/8 - 0s - loss: 4.3555e-04 - 66ms/epoch - 8ms/step
# Epoch 265/300
# 8/8 - 0s - loss: 3.0122e-04 - 60ms/epoch - 8ms/step
# Epoch 266/300
# 8/8 - 0s - loss: 3.4758e-04 - 66ms/epoch - 8ms/step
# Epoch 267/300
# 8/8 - 0s - loss: 2.7923e-04 - 64ms/epoch - 8ms/step
# Epoch 268/300
# 8/8 - 0s - loss: 2.2874e-04 - 64ms/epoch - 8ms/step
# Epoch 269/300
# 8/8 - 0s - loss: 2.5330e-04 - 67ms/epoch - 8ms/step
# Epoch 270/300
# 8/8 - 0s - loss: 2.4635e-04 - 59ms/epoch - 7ms/step
# Epoch 271/300
# 8/8 - 0s - loss: 4.6549e-04 - 71ms/epoch - 9ms/step
# Epoch 272/300
# 8/8 - 0s - loss: 6.0443e-04 - 63ms/epoch - 8ms/step
# Epoch 273/300
# 8/8 - 0s - loss: 6.9283e-04 - 70ms/epoch - 9ms/step
# Epoch 274/300
# 8/8 - 0s - loss: 3.1506e-04 - 56ms/epoch - 7ms/step
# Epoch 275/300
# 8/8 - 0s - loss: 3.4771e-04 - 64ms/epoch - 8ms/step
# Epoch 276/300
# 8/8 - 0s - loss: 5.3912e-04 - 64ms/epoch - 8ms/step
# Epoch 277/300
# 8/8 - 0s - loss: 3.8732e-04 - 67ms/epoch - 8ms/step
# Epoch 278/300
# 8/8 - 0s - loss: 5.3130e-04 - 61ms/epoch - 8ms/step
# Epoch 279/300
# 8/8 - 0s - loss: 1.9336e-04 - 61ms/epoch - 8ms/step
# Epoch 280/300
# 8/8 - 0s - loss: 1.7299e-04 - 64ms/epoch - 8ms/step
# Epoch 281/300
# 8/8 - 0s - loss: 1.0355e-04 - 63ms/epoch - 8ms/step
# Epoch 282/300
# 8/8 - 0s - loss: 1.7376e-04 - 61ms/epoch - 8ms/step
# Epoch 283/300
# 8/8 - 0s - loss: 2.8477e-04 - 59ms/epoch - 7ms/step
# Epoch 284/300
# 8/8 - 0s - loss: 1.8387e-04 - 60ms/epoch - 8ms/step
# Epoch 285/300
# 8/8 - 0s - loss: 8.5992e-05 - 56ms/epoch - 7ms/step
# Epoch 286/300
# 8/8 - 0s - loss: 1.0875e-04 - 56ms/epoch - 7ms/step
# Epoch 287/300
# 8/8 - 0s - loss: 1.0826e-04 - 57ms/epoch - 7ms/step
# Epoch 288/300
# 8/8 - 0s - loss: 8.9759e-05 - 62ms/epoch - 8ms/step
# Epoch 289/300
# 8/8 - 0s - loss: 8.4106e-05 - 55ms/epoch - 7ms/step
# Epoch 290/300
# 8/8 - 0s - loss: 7.0229e-05 - 57ms/epoch - 7ms/step
# Epoch 291/300
# 8/8 - 0s - loss: 5.2806e-05 - 54ms/epoch - 7ms/step
# Epoch 292/300
# 8/8 - 0s - loss: 4.3378e-05 - 58ms/epoch - 7ms/step
# Epoch 293/300
# 8/8 - 0s - loss: 5.6053e-05 - 64ms/epoch - 8ms/step
# Epoch 294/300
# 8/8 - 0s - loss: 3.3228e-05 - 59ms/epoch - 7ms/step
# Epoch 295/300
# 8/8 - 0s - loss: 3.2518e-05 - 60ms/epoch - 7ms/step
# Epoch 296/300
# 8/8 - 0s - loss: 2.4098e-05 - 58ms/epoch - 7ms/step
# Epoch 297/300
# 8/8 - 0s - loss: 2.2625e-05 - 65ms/epoch - 8ms/step
# Epoch 298/300
# 8/8 - 0s - loss: 1.5257e-05 - 57ms/epoch - 7ms/step
# Epoch 299/300
# 8/8 - 0s - loss: 1.6690e-05 - 60ms/epoch - 7ms/step
# Epoch 300/300
# 8/8 - 0s - loss: 1.7248e-05 - 60ms/epoch - 7ms/step
# 16/16 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710201583.563374
# Mon Mar 11 23:59:43 2024
