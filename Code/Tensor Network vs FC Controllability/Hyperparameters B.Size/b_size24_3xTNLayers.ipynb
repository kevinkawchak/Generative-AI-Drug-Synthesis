# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 1024)              3072
#
#  dense_16 (Dense)            (None, 1024)              1049600
#
#  dense_17 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 1024)              3072
#
#  tn_layer_9 (TNLayer)        (None, 1024)              5120
#
#  tn_layer_10 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_11 (TNLayer)       (None, 1024)              5120
#
#  dense_19 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(20, 2) + np.array([3, 3]),
                    np.random.randn(20, 2) + np.array([-3, -3]),
                    np.random.randn(20, 2) + np.array([-3, 3]),
                    np.random.randn(20, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((40)), -np.ones((40))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710203565.596225
# Tue Mar 12 00:32:45 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2, batch_size=24)
# Out:
# Epoch 1/300
# 4/4 - 2s - loss: 1.0015 - 2s/epoch - 505ms/step
# Epoch 2/300
# 4/4 - 0s - loss: 1.0015 - 19ms/epoch - 5ms/step
# Epoch 3/300
# 4/4 - 0s - loss: 1.0016 - 20ms/epoch - 5ms/step
# Epoch 4/300
# 4/4 - 0s - loss: 1.0001 - 20ms/epoch - 5ms/step
# Epoch 5/300
# 4/4 - 0s - loss: 1.0002 - 21ms/epoch - 5ms/step
# Epoch 6/300
# 4/4 - 0s - loss: 0.9991 - 20ms/epoch - 5ms/step
# Epoch 7/300
# 4/4 - 0s - loss: 0.9977 - 22ms/epoch - 5ms/step
# Epoch 8/300
# 4/4 - 0s - loss: 0.9929 - 25ms/epoch - 6ms/step
# Epoch 9/300
# 4/4 - 0s - loss: 0.9776 - 22ms/epoch - 5ms/step
# Epoch 10/300
# 4/4 - 0s - loss: 0.9345 - 20ms/epoch - 5ms/step
# Epoch 11/300
# 4/4 - 0s - loss: 0.8243 - 20ms/epoch - 5ms/step
# Epoch 12/300
# 4/4 - 0s - loss: 0.5413 - 20ms/epoch - 5ms/step
# Epoch 13/300
# 4/4 - 0s - loss: 0.1143 - 19ms/epoch - 5ms/step
# Epoch 14/300
# 4/4 - 0s - loss: 0.1650 - 20ms/epoch - 5ms/step
# Epoch 15/300
# 4/4 - 0s - loss: 0.0332 - 22ms/epoch - 5ms/step
# Epoch 16/300
# 4/4 - 0s - loss: 0.0503 - 20ms/epoch - 5ms/step
# Epoch 17/300
# 4/4 - 0s - loss: 0.0395 - 23ms/epoch - 6ms/step
# Epoch 18/300
# 4/4 - 0s - loss: 0.0189 - 22ms/epoch - 6ms/step
# Epoch 19/300
# 4/4 - 0s - loss: 0.0225 - 22ms/epoch - 5ms/step
# Epoch 20/300
# 4/4 - 0s - loss: 0.0156 - 21ms/epoch - 5ms/step
# Epoch 21/300
# 4/4 - 0s - loss: 0.0129 - 23ms/epoch - 6ms/step
# Epoch 22/300
# 4/4 - 0s - loss: 0.0131 - 20ms/epoch - 5ms/step
# Epoch 23/300
# 4/4 - 0s - loss: 0.0104 - 22ms/epoch - 6ms/step
# Epoch 24/300
# 4/4 - 0s - loss: 0.0095 - 21ms/epoch - 5ms/step
# Epoch 25/300
# 4/4 - 0s - loss: 0.0090 - 20ms/epoch - 5ms/step
# Epoch 26/300
# 4/4 - 0s - loss: 0.0083 - 19ms/epoch - 5ms/step
# Epoch 27/300
# 4/4 - 0s - loss: 0.0080 - 20ms/epoch - 5ms/step
# Epoch 28/300
# 4/4 - 0s - loss: 0.0075 - 21ms/epoch - 5ms/step
# Epoch 29/300
# 4/4 - 0s - loss: 0.0070 - 21ms/epoch - 5ms/step
# Epoch 30/300
# 4/4 - 0s - loss: 0.0067 - 20ms/epoch - 5ms/step
# Epoch 31/300
# 4/4 - 0s - loss: 0.0063 - 20ms/epoch - 5ms/step
# Epoch 32/300
# 4/4 - 0s - loss: 0.0061 - 20ms/epoch - 5ms/step
# Epoch 33/300
# 4/4 - 0s - loss: 0.0058 - 20ms/epoch - 5ms/step
# Epoch 34/300
# 4/4 - 0s - loss: 0.0055 - 19ms/epoch - 5ms/step
# Epoch 35/300
# 4/4 - 0s - loss: 0.0054 - 19ms/epoch - 5ms/step
# Epoch 36/300
# 4/4 - 0s - loss: 0.0053 - 21ms/epoch - 5ms/step
# Epoch 37/300
# 4/4 - 0s - loss: 0.0049 - 20ms/epoch - 5ms/step
# Epoch 38/300
# 4/4 - 0s - loss: 0.0047 - 21ms/epoch - 5ms/step
# Epoch 39/300
# 4/4 - 0s - loss: 0.0045 - 20ms/epoch - 5ms/step
# Epoch 40/300
# 4/4 - 0s - loss: 0.0043 - 22ms/epoch - 5ms/step
# Epoch 41/300
# 4/4 - 0s - loss: 0.0041 - 19ms/epoch - 5ms/step
# Epoch 42/300
# 4/4 - 0s - loss: 0.0040 - 21ms/epoch - 5ms/step
# Epoch 43/300
# 4/4 - 0s - loss: 0.0039 - 20ms/epoch - 5ms/step
# Epoch 44/300
# 4/4 - 0s - loss: 0.0037 - 20ms/epoch - 5ms/step
# Epoch 45/300
# 4/4 - 0s - loss: 0.0035 - 20ms/epoch - 5ms/step
# Epoch 46/300
# 4/4 - 0s - loss: 0.0033 - 19ms/epoch - 5ms/step
# Epoch 47/300
# 4/4 - 0s - loss: 0.0032 - 20ms/epoch - 5ms/step
# Epoch 48/300
# 4/4 - 0s - loss: 0.0031 - 20ms/epoch - 5ms/step
# Epoch 49/300
# 4/4 - 0s - loss: 0.0030 - 20ms/epoch - 5ms/step
# Epoch 50/300
# 4/4 - 0s - loss: 0.0029 - 20ms/epoch - 5ms/step
# Epoch 51/300
# 4/4 - 0s - loss: 0.0028 - 21ms/epoch - 5ms/step
# Epoch 52/300
# 4/4 - 0s - loss: 0.0026 - 20ms/epoch - 5ms/step
# Epoch 53/300
# 4/4 - 0s - loss: 0.0026 - 19ms/epoch - 5ms/step
# Epoch 54/300
# 4/4 - 0s - loss: 0.0026 - 19ms/epoch - 5ms/step
# Epoch 55/300
# 4/4 - 0s - loss: 0.0024 - 20ms/epoch - 5ms/step
# Epoch 56/300
# 4/4 - 0s - loss: 0.0025 - 21ms/epoch - 5ms/step
# Epoch 57/300
# 4/4 - 0s - loss: 0.0023 - 20ms/epoch - 5ms/step
# Epoch 58/300
# 4/4 - 0s - loss: 0.0022 - 19ms/epoch - 5ms/step
# Epoch 59/300
# 4/4 - 0s - loss: 0.0021 - 21ms/epoch - 5ms/step
# Epoch 60/300
# 4/4 - 0s - loss: 0.0020 - 20ms/epoch - 5ms/step
# Epoch 61/300
# 4/4 - 0s - loss: 0.0019 - 21ms/epoch - 5ms/step
# Epoch 62/300
# 4/4 - 0s - loss: 0.0019 - 20ms/epoch - 5ms/step
# Epoch 63/300
# 4/4 - 0s - loss: 0.0018 - 21ms/epoch - 5ms/step
# Epoch 64/300
# 4/4 - 0s - loss: 0.0017 - 21ms/epoch - 5ms/step
# Epoch 65/300
# 4/4 - 0s - loss: 0.0016 - 22ms/epoch - 5ms/step
# Epoch 66/300
# 4/4 - 0s - loss: 0.0016 - 19ms/epoch - 5ms/step
# Epoch 67/300
# 4/4 - 0s - loss: 0.0015 - 19ms/epoch - 5ms/step
# Epoch 68/300
# 4/4 - 0s - loss: 0.0016 - 21ms/epoch - 5ms/step
# Epoch 69/300
# 4/4 - 0s - loss: 0.0014 - 20ms/epoch - 5ms/step
# Epoch 70/300
# 4/4 - 0s - loss: 0.0014 - 20ms/epoch - 5ms/step
# Epoch 71/300
# 4/4 - 0s - loss: 0.0012 - 20ms/epoch - 5ms/step
# Epoch 72/300
# 4/4 - 0s - loss: 0.0013 - 20ms/epoch - 5ms/step
# Epoch 73/300
# 4/4 - 0s - loss: 0.0011 - 21ms/epoch - 5ms/step
# Epoch 74/300
# 4/4 - 0s - loss: 0.0011 - 21ms/epoch - 5ms/step
# Epoch 75/300
# 4/4 - 0s - loss: 0.0010 - 21ms/epoch - 5ms/step
# Epoch 76/300
# 4/4 - 0s - loss: 0.0010 - 21ms/epoch - 5ms/step
# Epoch 77/300
# 4/4 - 0s - loss: 9.3515e-04 - 19ms/epoch - 5ms/step
# Epoch 78/300
# 4/4 - 0s - loss: 8.8159e-04 - 20ms/epoch - 5ms/step
# Epoch 79/300
# 4/4 - 0s - loss: 8.4273e-04 - 19ms/epoch - 5ms/step
# Epoch 80/300
# 4/4 - 0s - loss: 7.9113e-04 - 20ms/epoch - 5ms/step
# Epoch 81/300
# 4/4 - 0s - loss: 7.6416e-04 - 21ms/epoch - 5ms/step
# Epoch 82/300
# 4/4 - 0s - loss: 7.1885e-04 - 22ms/epoch - 5ms/step
# Epoch 83/300
# 4/4 - 0s - loss: 7.1955e-04 - 23ms/epoch - 6ms/step
# Epoch 84/300
# 4/4 - 0s - loss: 6.3505e-04 - 24ms/epoch - 6ms/step
# Epoch 85/300
# 4/4 - 0s - loss: 6.3379e-04 - 20ms/epoch - 5ms/step
# Epoch 86/300
# 4/4 - 0s - loss: 5.8185e-04 - 21ms/epoch - 5ms/step
# Epoch 87/300
# 4/4 - 0s - loss: 5.4482e-04 - 21ms/epoch - 5ms/step
# Epoch 88/300
# 4/4 - 0s - loss: 5.1706e-04 - 19ms/epoch - 5ms/step
# Epoch 89/300
# 4/4 - 0s - loss: 5.3030e-04 - 20ms/epoch - 5ms/step
# Epoch 90/300
# 4/4 - 0s - loss: 4.6954e-04 - 21ms/epoch - 5ms/step
# Epoch 91/300
# 4/4 - 0s - loss: 4.3993e-04 - 20ms/epoch - 5ms/step
# Epoch 92/300
# 4/4 - 0s - loss: 3.9395e-04 - 20ms/epoch - 5ms/step
# Epoch 93/300
# 4/4 - 0s - loss: 3.6965e-04 - 21ms/epoch - 5ms/step
# Epoch 94/300
# 4/4 - 0s - loss: 3.3760e-04 - 21ms/epoch - 5ms/step
# Epoch 95/300
# 4/4 - 0s - loss: 3.5075e-04 - 21ms/epoch - 5ms/step
# Epoch 96/300
# 4/4 - 0s - loss: 2.8356e-04 - 20ms/epoch - 5ms/step
# Epoch 97/300
# 4/4 - 0s - loss: 3.0723e-04 - 21ms/epoch - 5ms/step
# Epoch 98/300
# 4/4 - 0s - loss: 2.5568e-04 - 20ms/epoch - 5ms/step
# Epoch 99/300
# 4/4 - 0s - loss: 2.4554e-04 - 22ms/epoch - 5ms/step
# Epoch 100/300
# 4/4 - 0s - loss: 2.1670e-04 - 20ms/epoch - 5ms/step
# Epoch 101/300
# 4/4 - 0s - loss: 1.9960e-04 - 21ms/epoch - 5ms/step
# Epoch 102/300
# 4/4 - 0s - loss: 1.9069e-04 - 19ms/epoch - 5ms/step
# Epoch 103/300
# 4/4 - 0s - loss: 1.7293e-04 - 19ms/epoch - 5ms/step
# Epoch 104/300
# 4/4 - 0s - loss: 1.6630e-04 - 21ms/epoch - 5ms/step
# Epoch 105/300
# 4/4 - 0s - loss: 1.3791e-04 - 20ms/epoch - 5ms/step
# Epoch 106/300
# 4/4 - 0s - loss: 1.3548e-04 - 22ms/epoch - 5ms/step
# Epoch 107/300
# 4/4 - 0s - loss: 1.2470e-04 - 21ms/epoch - 5ms/step
# Epoch 108/300
# 4/4 - 0s - loss: 1.1705e-04 - 21ms/epoch - 5ms/step
# Epoch 109/300
# 4/4 - 0s - loss: 1.0293e-04 - 21ms/epoch - 5ms/step
# Epoch 110/300
# 4/4 - 0s - loss: 8.3455e-05 - 19ms/epoch - 5ms/step
# Epoch 111/300
# 4/4 - 0s - loss: 8.8826e-05 - 19ms/epoch - 5ms/step
# Epoch 112/300
# 4/4 - 0s - loss: 7.4981e-05 - 22ms/epoch - 5ms/step
# Epoch 113/300
# 4/4 - 0s - loss: 6.3537e-05 - 20ms/epoch - 5ms/step
# Epoch 114/300
# 4/4 - 0s - loss: 5.5702e-05 - 21ms/epoch - 5ms/step
# Epoch 115/300
# 4/4 - 0s - loss: 5.4901e-05 - 21ms/epoch - 5ms/step
# Epoch 116/300
# 4/4 - 0s - loss: 5.0733e-05 - 21ms/epoch - 5ms/step
# Epoch 117/300
# 4/4 - 0s - loss: 4.3667e-05 - 20ms/epoch - 5ms/step
# Epoch 118/300
# 4/4 - 0s - loss: 3.6462e-05 - 21ms/epoch - 5ms/step
# Epoch 119/300
# 4/4 - 0s - loss: 4.8016e-05 - 20ms/epoch - 5ms/step
# Epoch 120/300
# 4/4 - 0s - loss: 2.5101e-05 - 23ms/epoch - 6ms/step
# Epoch 121/300
# 4/4 - 0s - loss: 3.5187e-05 - 21ms/epoch - 5ms/step
# Epoch 122/300
# 4/4 - 0s - loss: 2.7612e-05 - 20ms/epoch - 5ms/step
# Epoch 123/300
# 4/4 - 0s - loss: 1.8289e-05 - 20ms/epoch - 5ms/step
# Epoch 124/300
# 4/4 - 0s - loss: 1.6922e-05 - 21ms/epoch - 5ms/step
# Epoch 125/300
# 4/4 - 0s - loss: 1.9995e-05 - 20ms/epoch - 5ms/step
# Epoch 126/300
# 4/4 - 0s - loss: 1.4761e-05 - 20ms/epoch - 5ms/step
# Epoch 127/300
# 4/4 - 0s - loss: 1.2133e-05 - 22ms/epoch - 5ms/step
# Epoch 128/300
# 4/4 - 0s - loss: 1.0514e-05 - 19ms/epoch - 5ms/step
# Epoch 129/300
# 4/4 - 0s - loss: 9.9378e-06 - 20ms/epoch - 5ms/step
# Epoch 130/300
# 4/4 - 0s - loss: 9.8584e-06 - 21ms/epoch - 5ms/step
# Epoch 131/300
# 4/4 - 0s - loss: 7.4648e-06 - 21ms/epoch - 5ms/step
# Epoch 132/300
# 4/4 - 0s - loss: 7.6676e-06 - 22ms/epoch - 5ms/step
# Epoch 133/300
# 4/4 - 0s - loss: 6.0838e-06 - 20ms/epoch - 5ms/step
# Epoch 134/300
# 4/4 - 0s - loss: 5.8905e-06 - 19ms/epoch - 5ms/step
# Epoch 135/300
# 4/4 - 0s - loss: 4.8429e-06 - 20ms/epoch - 5ms/step
# Epoch 136/300
# 4/4 - 0s - loss: 4.1179e-06 - 22ms/epoch - 5ms/step
# Epoch 137/300
# 4/4 - 0s - loss: 4.7923e-06 - 21ms/epoch - 5ms/step
# Epoch 138/300
# 4/4 - 0s - loss: 2.7936e-06 - 22ms/epoch - 5ms/step
# Epoch 139/300
# 4/4 - 0s - loss: 2.5816e-06 - 21ms/epoch - 5ms/step
# Epoch 140/300
# 4/4 - 0s - loss: 2.2432e-06 - 20ms/epoch - 5ms/step
# Epoch 141/300
# 4/4 - 0s - loss: 2.1175e-06 - 24ms/epoch - 6ms/step
# Epoch 142/300
# 4/4 - 0s - loss: 1.9503e-06 - 22ms/epoch - 5ms/step
# Epoch 143/300
# 4/4 - 0s - loss: 1.8317e-06 - 22ms/epoch - 6ms/step
# Epoch 144/300
# 4/4 - 0s - loss: 1.7809e-06 - 23ms/epoch - 6ms/step
# Epoch 145/300
# 4/4 - 0s - loss: 1.5353e-06 - 24ms/epoch - 6ms/step
# Epoch 146/300
# 4/4 - 0s - loss: 1.5958e-06 - 20ms/epoch - 5ms/step
# Epoch 147/300
# 4/4 - 0s - loss: 1.6734e-06 - 19ms/epoch - 5ms/step
# Epoch 148/300
# 4/4 - 0s - loss: 1.3841e-06 - 22ms/epoch - 6ms/step
# Epoch 149/300
# 4/4 - 0s - loss: 1.3674e-06 - 26ms/epoch - 7ms/step
# Epoch 150/300
# 4/4 - 0s - loss: 1.1938e-06 - 21ms/epoch - 5ms/step
# Epoch 151/300
# 4/4 - 0s - loss: 1.3073e-06 - 21ms/epoch - 5ms/step
# Epoch 152/300
# 4/4 - 0s - loss: 1.1887e-06 - 20ms/epoch - 5ms/step
# Epoch 153/300
# 4/4 - 0s - loss: 1.2316e-06 - 23ms/epoch - 6ms/step
# Epoch 154/300
# 4/4 - 0s - loss: 1.0790e-06 - 21ms/epoch - 5ms/step
# Epoch 155/300
# 4/4 - 0s - loss: 1.0440e-06 - 21ms/epoch - 5ms/step
# Epoch 156/300
# 4/4 - 0s - loss: 1.0557e-06 - 23ms/epoch - 6ms/step
# Epoch 157/300
# 4/4 - 0s - loss: 1.0955e-06 - 21ms/epoch - 5ms/step
# Epoch 158/300
# 4/4 - 0s - loss: 1.0674e-06 - 21ms/epoch - 5ms/step
# Epoch 159/300
# 4/4 - 0s - loss: 1.0964e-06 - 20ms/epoch - 5ms/step
# Epoch 160/300
# 4/4 - 0s - loss: 1.1976e-06 - 21ms/epoch - 5ms/step
# Epoch 161/300
# 4/4 - 0s - loss: 1.2578e-06 - 21ms/epoch - 5ms/step
# Epoch 162/300
# 4/4 - 0s - loss: 1.0462e-06 - 22ms/epoch - 6ms/step
# Epoch 163/300
# 4/4 - 0s - loss: 9.5968e-07 - 20ms/epoch - 5ms/step
# Epoch 164/300
# 4/4 - 0s - loss: 1.2085e-06 - 21ms/epoch - 5ms/step
# Epoch 165/300
# 4/4 - 0s - loss: 8.7226e-07 - 19ms/epoch - 5ms/step
# Epoch 166/300
# 4/4 - 0s - loss: 1.1553e-06 - 19ms/epoch - 5ms/step
# Epoch 167/300
# 4/4 - 0s - loss: 9.5901e-07 - 21ms/epoch - 5ms/step
# Epoch 168/300
# 4/4 - 0s - loss: 9.6192e-07 - 22ms/epoch - 6ms/step
# Epoch 169/300
# 4/4 - 0s - loss: 8.6856e-07 - 23ms/epoch - 6ms/step
# Epoch 170/300
# 4/4 - 0s - loss: 8.3585e-07 - 20ms/epoch - 5ms/step
# Epoch 171/300
# 4/4 - 0s - loss: 8.0185e-07 - 26ms/epoch - 6ms/step
# Epoch 172/300
# 4/4 - 0s - loss: 8.0029e-07 - 20ms/epoch - 5ms/step
# Epoch 173/300
# 4/4 - 0s - loss: 8.6694e-07 - 22ms/epoch - 5ms/step
# Epoch 174/300
# 4/4 - 0s - loss: 8.4180e-07 - 20ms/epoch - 5ms/step
# Epoch 175/300
# 4/4 - 0s - loss: 8.3355e-07 - 21ms/epoch - 5ms/step
# Epoch 176/300
# 4/4 - 0s - loss: 8.9541e-07 - 19ms/epoch - 5ms/step
# Epoch 177/300
# 4/4 - 0s - loss: 9.9914e-07 - 20ms/epoch - 5ms/step
# Epoch 178/300
# 4/4 - 0s - loss: 1.0082e-06 - 20ms/epoch - 5ms/step
# Epoch 179/300
# 4/4 - 0s - loss: 8.8311e-07 - 23ms/epoch - 6ms/step
# Epoch 180/300
# 4/4 - 0s - loss: 8.1343e-07 - 23ms/epoch - 6ms/step
# Epoch 181/300
# 4/4 - 0s - loss: 9.9522e-07 - 24ms/epoch - 6ms/step
# Epoch 182/300
# 4/4 - 0s - loss: 1.0888e-06 - 23ms/epoch - 6ms/step
# Epoch 183/300
# 4/4 - 0s - loss: 1.1212e-06 - 22ms/epoch - 6ms/step
# Epoch 184/300
# 4/4 - 0s - loss: 7.3416e-07 - 22ms/epoch - 5ms/step
# Epoch 185/300
# 4/4 - 0s - loss: 8.3682e-07 - 21ms/epoch - 5ms/step
# Epoch 186/300
# 4/4 - 0s - loss: 8.5813e-07 - 21ms/epoch - 5ms/step
# Epoch 187/300
# 4/4 - 0s - loss: 6.6379e-07 - 20ms/epoch - 5ms/step
# Epoch 188/300
# 4/4 - 0s - loss: 7.6695e-07 - 21ms/epoch - 5ms/step
# Epoch 189/300
# 4/4 - 0s - loss: 9.0087e-07 - 21ms/epoch - 5ms/step
# Epoch 190/300
# 4/4 - 0s - loss: 7.3258e-07 - 21ms/epoch - 5ms/step
# Epoch 191/300
# 4/4 - 0s - loss: 7.7198e-07 - 21ms/epoch - 5ms/step
# Epoch 192/300
# 4/4 - 0s - loss: 8.9887e-07 - 23ms/epoch - 6ms/step
# Epoch 193/300
# 4/4 - 0s - loss: 9.3234e-07 - 21ms/epoch - 5ms/step
# Epoch 194/300
# 4/4 - 0s - loss: 8.9539e-07 - 22ms/epoch - 5ms/step
# Epoch 195/300
# 4/4 - 0s - loss: 7.4069e-07 - 22ms/epoch - 6ms/step
# Epoch 196/300
# 4/4 - 0s - loss: 8.1563e-07 - 24ms/epoch - 6ms/step
# Epoch 197/300
# 4/4 - 0s - loss: 1.0316e-06 - 21ms/epoch - 5ms/step
# Epoch 198/300
# 4/4 - 0s - loss: 8.9787e-07 - 22ms/epoch - 5ms/step
# Epoch 199/300
# 4/4 - 0s - loss: 1.1901e-06 - 24ms/epoch - 6ms/step
# Epoch 200/300
# 4/4 - 0s - loss: 7.6574e-07 - 20ms/epoch - 5ms/step
# Epoch 201/300
# 4/4 - 0s - loss: 6.8976e-07 - 25ms/epoch - 6ms/step
# Epoch 202/300
# 4/4 - 0s - loss: 6.7312e-07 - 21ms/epoch - 5ms/step
# Epoch 203/300
# 4/4 - 0s - loss: 7.4808e-07 - 25ms/epoch - 6ms/step
# Epoch 204/300
# 4/4 - 0s - loss: 5.9989e-07 - 23ms/epoch - 6ms/step
# Epoch 205/300
# 4/4 - 0s - loss: 6.2369e-07 - 22ms/epoch - 5ms/step
# Epoch 206/300
# 4/4 - 0s - loss: 5.8998e-07 - 21ms/epoch - 5ms/step
# Epoch 207/300
# 4/4 - 0s - loss: 8.5013e-07 - 24ms/epoch - 6ms/step
# Epoch 208/300
# 4/4 - 0s - loss: 8.4910e-07 - 21ms/epoch - 5ms/step
# Epoch 209/300
# 4/4 - 0s - loss: 7.4204e-07 - 22ms/epoch - 5ms/step
# Epoch 210/300
# 4/4 - 0s - loss: 6.8349e-07 - 22ms/epoch - 5ms/step
# Epoch 211/300
# 4/4 - 0s - loss: 8.1512e-07 - 18ms/epoch - 5ms/step
# Epoch 212/300
# 4/4 - 0s - loss: 9.8285e-07 - 20ms/epoch - 5ms/step
# Epoch 213/300
# 4/4 - 0s - loss: 7.3538e-07 - 21ms/epoch - 5ms/step
# Epoch 214/300
# 4/4 - 0s - loss: 9.6060e-07 - 19ms/epoch - 5ms/step
# Epoch 215/300
# 4/4 - 0s - loss: 7.1791e-07 - 21ms/epoch - 5ms/step
# Epoch 216/300
# 4/4 - 0s - loss: 6.1737e-07 - 20ms/epoch - 5ms/step
# Epoch 217/300
# 4/4 - 0s - loss: 6.3523e-07 - 22ms/epoch - 6ms/step
# Epoch 218/300
# 4/4 - 0s - loss: 6.0925e-07 - 21ms/epoch - 5ms/step
# Epoch 219/300
# 4/4 - 0s - loss: 7.7933e-07 - 19ms/epoch - 5ms/step
# Epoch 220/300
# 4/4 - 0s - loss: 6.1124e-07 - 21ms/epoch - 5ms/step
# Epoch 221/300
# 4/4 - 0s - loss: 5.7974e-07 - 20ms/epoch - 5ms/step
# Epoch 222/300
# 4/4 - 0s - loss: 6.6282e-07 - 20ms/epoch - 5ms/step
# Epoch 223/300
# 4/4 - 0s - loss: 6.3738e-07 - 20ms/epoch - 5ms/step
# Epoch 224/300
# 4/4 - 0s - loss: 7.4188e-07 - 19ms/epoch - 5ms/step
# Epoch 225/300
# 4/4 - 0s - loss: 8.5189e-07 - 20ms/epoch - 5ms/step
# Epoch 226/300
# 4/4 - 0s - loss: 6.4640e-07 - 19ms/epoch - 5ms/step
# Epoch 227/300
# 4/4 - 0s - loss: 5.9160e-07 - 20ms/epoch - 5ms/step
# Epoch 228/300
# 4/4 - 0s - loss: 4.9366e-07 - 19ms/epoch - 5ms/step
# Epoch 229/300
# 4/4 - 0s - loss: 4.9956e-07 - 21ms/epoch - 5ms/step
# Epoch 230/300
# 4/4 - 0s - loss: 4.6772e-07 - 22ms/epoch - 5ms/step
# Epoch 231/300
# 4/4 - 0s - loss: 4.6739e-07 - 20ms/epoch - 5ms/step
# Epoch 232/300
# 4/4 - 0s - loss: 4.9088e-07 - 22ms/epoch - 5ms/step
# Epoch 233/300
# 4/4 - 0s - loss: 4.1662e-07 - 21ms/epoch - 5ms/step
# Epoch 234/300
# 4/4 - 0s - loss: 4.7807e-07 - 20ms/epoch - 5ms/step
# Epoch 235/300
# 4/4 - 0s - loss: 4.5840e-07 - 20ms/epoch - 5ms/step
# Epoch 236/300
# 4/4 - 0s - loss: 4.8169e-07 - 19ms/epoch - 5ms/step
# Epoch 237/300
# 4/4 - 0s - loss: 5.8914e-07 - 20ms/epoch - 5ms/step
# Epoch 238/300
# 4/4 - 0s - loss: 5.7919e-07 - 20ms/epoch - 5ms/step
# Epoch 239/300
# 4/4 - 0s - loss: 4.8332e-07 - 19ms/epoch - 5ms/step
# Epoch 240/300
# 4/4 - 0s - loss: 5.9101e-07 - 19ms/epoch - 5ms/step
# Epoch 241/300
# 4/4 - 0s - loss: 6.0452e-07 - 19ms/epoch - 5ms/step
# Epoch 242/300
# 4/4 - 0s - loss: 4.5169e-07 - 20ms/epoch - 5ms/step
# Epoch 243/300
# 4/4 - 0s - loss: 4.0640e-07 - 19ms/epoch - 5ms/step
# Epoch 244/300
# 4/4 - 0s - loss: 3.7185e-07 - 20ms/epoch - 5ms/step
# Epoch 245/300
# 4/4 - 0s - loss: 4.7094e-07 - 21ms/epoch - 5ms/step
# Epoch 246/300
# 4/4 - 0s - loss: 4.4085e-07 - 22ms/epoch - 6ms/step
# Epoch 247/300
# 4/4 - 0s - loss: 4.4243e-07 - 19ms/epoch - 5ms/step
# Epoch 248/300
# 4/4 - 0s - loss: 4.1231e-07 - 22ms/epoch - 5ms/step
# Epoch 249/300
# 4/4 - 0s - loss: 3.8221e-07 - 20ms/epoch - 5ms/step
# Epoch 250/300
# 4/4 - 0s - loss: 3.5327e-07 - 19ms/epoch - 5ms/step
# Epoch 251/300
# 4/4 - 0s - loss: 3.9061e-07 - 20ms/epoch - 5ms/step
# Epoch 252/300
# 4/4 - 0s - loss: 3.6525e-07 - 20ms/epoch - 5ms/step
# Epoch 253/300
# 4/4 - 0s - loss: 3.5566e-07 - 22ms/epoch - 5ms/step
# Epoch 254/300
# 4/4 - 0s - loss: 4.3622e-07 - 21ms/epoch - 5ms/step
# Epoch 255/300
# 4/4 - 0s - loss: 4.0337e-07 - 20ms/epoch - 5ms/step
# Epoch 256/300
# 4/4 - 0s - loss: 4.0623e-07 - 19ms/epoch - 5ms/step
# Epoch 257/300
# 4/4 - 0s - loss: 4.0086e-07 - 19ms/epoch - 5ms/step
# Epoch 258/300
# 4/4 - 0s - loss: 5.0323e-07 - 20ms/epoch - 5ms/step
# Epoch 259/300
# 4/4 - 0s - loss: 5.7251e-07 - 21ms/epoch - 5ms/step
# Epoch 260/300
# 4/4 - 0s - loss: 3.9891e-07 - 19ms/epoch - 5ms/step
# Epoch 261/300
# 4/4 - 0s - loss: 4.1919e-07 - 20ms/epoch - 5ms/step
# Epoch 262/300
# 4/4 - 0s - loss: 4.7040e-07 - 18ms/epoch - 5ms/step
# Epoch 263/300
# 4/4 - 0s - loss: 4.3548e-07 - 21ms/epoch - 5ms/step
# Epoch 264/300
# 4/4 - 0s - loss: 4.1206e-07 - 20ms/epoch - 5ms/step
# Epoch 265/300
# 4/4 - 0s - loss: 4.6212e-07 - 20ms/epoch - 5ms/step
# Epoch 266/300
# 4/4 - 0s - loss: 3.7586e-07 - 21ms/epoch - 5ms/step
# Epoch 267/300
# 4/4 - 0s - loss: 3.8866e-07 - 19ms/epoch - 5ms/step
# Epoch 268/300
# 4/4 - 0s - loss: 3.8345e-07 - 19ms/epoch - 5ms/step
# Epoch 269/300
# 4/4 - 0s - loss: 3.9896e-07 - 19ms/epoch - 5ms/step
# Epoch 270/300
# 4/4 - 0s - loss: 3.5074e-07 - 19ms/epoch - 5ms/step
# Epoch 271/300
# 4/4 - 0s - loss: 3.2775e-07 - 20ms/epoch - 5ms/step
# Epoch 272/300
# 4/4 - 0s - loss: 3.1611e-07 - 20ms/epoch - 5ms/step
# Epoch 273/300
# 4/4 - 0s - loss: 3.3120e-07 - 19ms/epoch - 5ms/step
# Epoch 274/300
# 4/4 - 0s - loss: 3.1759e-07 - 19ms/epoch - 5ms/step
# Epoch 275/300
# 4/4 - 0s - loss: 2.9972e-07 - 18ms/epoch - 5ms/step
# Epoch 276/300
# 4/4 - 0s - loss: 3.5676e-07 - 19ms/epoch - 5ms/step
# Epoch 277/300
# 4/4 - 0s - loss: 3.4075e-07 - 19ms/epoch - 5ms/step
# Epoch 278/300
# 4/4 - 0s - loss: 2.8106e-07 - 19ms/epoch - 5ms/step
# Epoch 279/300
# 4/4 - 0s - loss: 3.3063e-07 - 19ms/epoch - 5ms/step
# Epoch 280/300
# 4/4 - 0s - loss: 4.3117e-07 - 19ms/epoch - 5ms/step
# Epoch 281/300
# 4/4 - 0s - loss: 5.3413e-07 - 22ms/epoch - 6ms/step
# Epoch 282/300
# 4/4 - 0s - loss: 4.1232e-07 - 19ms/epoch - 5ms/step
# Epoch 283/300
# 4/4 - 0s - loss: 3.9912e-07 - 20ms/epoch - 5ms/step
# Epoch 284/300
# 4/4 - 0s - loss: 3.3182e-07 - 19ms/epoch - 5ms/step
# Epoch 285/300
# 4/4 - 0s - loss: 4.6909e-07 - 20ms/epoch - 5ms/step
# Epoch 286/300
# 4/4 - 0s - loss: 3.9753e-07 - 19ms/epoch - 5ms/step
# Epoch 287/300
# 4/4 - 0s - loss: 4.0189e-07 - 20ms/epoch - 5ms/step
# Epoch 288/300
# 4/4 - 0s - loss: 5.6360e-07 - 20ms/epoch - 5ms/step
# Epoch 289/300
# 4/4 - 0s - loss: 4.3074e-07 - 20ms/epoch - 5ms/step
# Epoch 290/300
# 4/4 - 0s - loss: 2.9029e-07 - 19ms/epoch - 5ms/step
# Epoch 291/300
# 4/4 - 0s - loss: 3.7870e-07 - 21ms/epoch - 5ms/step
# Epoch 292/300
# 4/4 - 0s - loss: 2.9291e-07 - 20ms/epoch - 5ms/step
# Epoch 293/300
# 4/4 - 0s - loss: 2.7021e-07 - 19ms/epoch - 5ms/step
# Epoch 294/300
# 4/4 - 0s - loss: 2.5982e-07 - 19ms/epoch - 5ms/step
# Epoch 295/300
# 4/4 - 0s - loss: 3.5193e-07 - 20ms/epoch - 5ms/step
# Epoch 296/300
# 4/4 - 0s - loss: 2.9704e-07 - 19ms/epoch - 5ms/step
# Epoch 297/300
# 4/4 - 0s - loss: 2.7215e-07 - 19ms/epoch - 5ms/step
# Epoch 298/300
# 4/4 - 0s - loss: 2.7249e-07 - 19ms/epoch - 5ms/step
# Epoch 299/300
# 4/4 - 0s - loss: 3.9674e-07 - 18ms/epoch - 4ms/step
# Epoch 300/300
# 4/4 - 0s - loss: 2.6929e-07 - 19ms/epoch - 5ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 14/14 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710203575.2774904
# Tue Mar 12 00:32:55 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710203575.2867231
# Tue Mar 12 00:32:55 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2, batch_size=24)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 4/4 - 1s - loss: 0.5430 - 635ms/epoch - 159ms/step
# Epoch 2/300
# 4/4 - 0s - loss: 0.1689 - 36ms/epoch - 9ms/step
# Epoch 3/300
# 4/4 - 0s - loss: 0.1648 - 27ms/epoch - 7ms/step
# Epoch 4/300
# 4/4 - 0s - loss: 0.0801 - 28ms/epoch - 7ms/step
# Epoch 5/300
# 4/4 - 0s - loss: 0.1277 - 34ms/epoch - 8ms/step
# Epoch 6/300
# 4/4 - 0s - loss: 0.0697 - 29ms/epoch - 7ms/step
# Epoch 7/300
# 4/4 - 0s - loss: 0.0884 - 31ms/epoch - 8ms/step
# Epoch 8/300
# 4/4 - 0s - loss: 0.0777 - 33ms/epoch - 8ms/step
# Epoch 9/300
# 4/4 - 0s - loss: 0.0575 - 35ms/epoch - 9ms/step
# Epoch 10/300
# 4/4 - 0s - loss: 0.0629 - 30ms/epoch - 8ms/step
# Epoch 11/300
# 4/4 - 0s - loss: 0.0575 - 32ms/epoch - 8ms/step
# Epoch 12/300
# 4/4 - 0s - loss: 0.0605 - 33ms/epoch - 8ms/step
# Epoch 13/300
# 4/4 - 0s - loss: 0.0505 - 31ms/epoch - 8ms/step
# Epoch 14/300
# 4/4 - 0s - loss: 0.0459 - 32ms/epoch - 8ms/step
# Epoch 15/300
# 4/4 - 0s - loss: 0.0579 - 32ms/epoch - 8ms/step
# Epoch 16/300
# 4/4 - 0s - loss: 0.0644 - 37ms/epoch - 9ms/step
# Epoch 17/300
# 4/4 - 0s - loss: 0.0519 - 36ms/epoch - 9ms/step
# Epoch 18/300
# 4/4 - 0s - loss: 0.0545 - 33ms/epoch - 8ms/step
# Epoch 19/300
# 4/4 - 0s - loss: 0.0458 - 40ms/epoch - 10ms/step
# Epoch 20/300
# 4/4 - 0s - loss: 0.0627 - 30ms/epoch - 7ms/step
# Epoch 21/300
# 4/4 - 0s - loss: 0.0559 - 27ms/epoch - 7ms/step
# Epoch 22/300
# 4/4 - 0s - loss: 0.0476 - 31ms/epoch - 8ms/step
# Epoch 23/300
# 4/4 - 0s - loss: 0.0684 - 34ms/epoch - 8ms/step
# Epoch 24/300
# 4/4 - 0s - loss: 0.0501 - 34ms/epoch - 9ms/step
# Epoch 25/300
# 4/4 - 0s - loss: 0.0441 - 31ms/epoch - 8ms/step
# Epoch 26/300
# 4/4 - 0s - loss: 0.0472 - 33ms/epoch - 8ms/step
# Epoch 27/300
# 4/4 - 0s - loss: 0.0464 - 35ms/epoch - 9ms/step
# Epoch 28/300
# 4/4 - 0s - loss: 0.0614 - 33ms/epoch - 8ms/step
# Epoch 29/300
# 4/4 - 0s - loss: 0.0501 - 31ms/epoch - 8ms/step
# Epoch 30/300
# 4/4 - 0s - loss: 0.0630 - 30ms/epoch - 7ms/step
# Epoch 31/300
# 4/4 - 0s - loss: 0.0576 - 33ms/epoch - 8ms/step
# Epoch 32/300
# 4/4 - 0s - loss: 0.0420 - 35ms/epoch - 9ms/step
# Epoch 33/300
# 4/4 - 0s - loss: 0.0414 - 30ms/epoch - 8ms/step
# Epoch 34/300
# 4/4 - 0s - loss: 0.0368 - 28ms/epoch - 7ms/step
# Epoch 35/300
# 4/4 - 0s - loss: 0.0445 - 28ms/epoch - 7ms/step
# Epoch 36/300
# 4/4 - 0s - loss: 0.0320 - 28ms/epoch - 7ms/step
# Epoch 37/300
# 4/4 - 0s - loss: 0.0313 - 28ms/epoch - 7ms/step
# Epoch 38/300
# 4/4 - 0s - loss: 0.0388 - 34ms/epoch - 9ms/step
# Epoch 39/300
# 4/4 - 0s - loss: 0.0352 - 30ms/epoch - 7ms/step
# Epoch 40/300
# 4/4 - 0s - loss: 0.0339 - 32ms/epoch - 8ms/step
# Epoch 41/300
# 4/4 - 0s - loss: 0.0239 - 31ms/epoch - 8ms/step
# Epoch 42/300
# 4/4 - 0s - loss: 0.0277 - 28ms/epoch - 7ms/step
# Epoch 43/300
# 4/4 - 0s - loss: 0.0224 - 27ms/epoch - 7ms/step
# Epoch 44/300
# 4/4 - 0s - loss: 0.0256 - 26ms/epoch - 7ms/step
# Epoch 45/300
# 4/4 - 0s - loss: 0.0220 - 31ms/epoch - 8ms/step
# Epoch 46/300
# 4/4 - 0s - loss: 0.0238 - 28ms/epoch - 7ms/step
# Epoch 47/300
# 4/4 - 0s - loss: 0.0270 - 33ms/epoch - 8ms/step
# Epoch 48/300
# 4/4 - 0s - loss: 0.0202 - 30ms/epoch - 7ms/step
# Epoch 49/300
# 4/4 - 0s - loss: 0.0202 - 29ms/epoch - 7ms/step
# Epoch 50/300
# 4/4 - 0s - loss: 0.0212 - 26ms/epoch - 7ms/step
# Epoch 51/300
# 4/4 - 0s - loss: 0.0191 - 28ms/epoch - 7ms/step
# Epoch 52/300
# 4/4 - 0s - loss: 0.0164 - 27ms/epoch - 7ms/step
# Epoch 53/300
# 4/4 - 0s - loss: 0.0201 - 27ms/epoch - 7ms/step
# Epoch 54/300
# 4/4 - 0s - loss: 0.0224 - 29ms/epoch - 7ms/step
# Epoch 55/300
# 4/4 - 0s - loss: 0.0191 - 28ms/epoch - 7ms/step
# Epoch 56/300
# 4/4 - 0s - loss: 0.0356 - 29ms/epoch - 7ms/step
# Epoch 57/300
# 4/4 - 0s - loss: 0.0566 - 29ms/epoch - 7ms/step
# Epoch 58/300
# 4/4 - 0s - loss: 0.0415 - 31ms/epoch - 8ms/step
# Epoch 59/300
# 4/4 - 0s - loss: 0.0431 - 29ms/epoch - 7ms/step
# Epoch 60/300
# 4/4 - 0s - loss: 0.0343 - 28ms/epoch - 7ms/step
# Epoch 61/300
# 4/4 - 0s - loss: 0.0224 - 29ms/epoch - 7ms/step
# Epoch 62/300
# 4/4 - 0s - loss: 0.0193 - 28ms/epoch - 7ms/step
# Epoch 63/300
# 4/4 - 0s - loss: 0.0163 - 31ms/epoch - 8ms/step
# Epoch 64/300
# 4/4 - 0s - loss: 0.0183 - 25ms/epoch - 6ms/step
# Epoch 65/300
# 4/4 - 0s - loss: 0.0141 - 32ms/epoch - 8ms/step
# Epoch 66/300
# 4/4 - 0s - loss: 0.0110 - 34ms/epoch - 9ms/step
# Epoch 67/300
# 4/4 - 0s - loss: 0.0131 - 26ms/epoch - 7ms/step
# Epoch 68/300
# 4/4 - 0s - loss: 0.0093 - 30ms/epoch - 7ms/step
# Epoch 69/300
# 4/4 - 0s - loss: 0.0098 - 31ms/epoch - 8ms/step
# Epoch 70/300
# 4/4 - 0s - loss: 0.0082 - 26ms/epoch - 7ms/step
# Epoch 71/300
# 4/4 - 0s - loss: 0.0065 - 26ms/epoch - 6ms/step
# Epoch 72/300
# 4/4 - 0s - loss: 0.0072 - 27ms/epoch - 7ms/step
# Epoch 73/300
# 4/4 - 0s - loss: 0.0071 - 29ms/epoch - 7ms/step
# Epoch 74/300
# 4/4 - 0s - loss: 0.0058 - 28ms/epoch - 7ms/step
# Epoch 75/300
# 4/4 - 0s - loss: 0.0057 - 26ms/epoch - 7ms/step
# Epoch 76/300
# 4/4 - 0s - loss: 0.0081 - 28ms/epoch - 7ms/step
# Epoch 77/300
# 4/4 - 0s - loss: 0.0118 - 33ms/epoch - 8ms/step
# Epoch 78/300
# 4/4 - 0s - loss: 0.0091 - 32ms/epoch - 8ms/step
# Epoch 79/300
# 4/4 - 0s - loss: 0.0082 - 27ms/epoch - 7ms/step
# Epoch 80/300
# 4/4 - 0s - loss: 0.0074 - 29ms/epoch - 7ms/step
# Epoch 81/300
# 4/4 - 0s - loss: 0.0057 - 27ms/epoch - 7ms/step
# Epoch 82/300
# 4/4 - 0s - loss: 0.0044 - 32ms/epoch - 8ms/step
# Epoch 83/300
# 4/4 - 0s - loss: 0.0067 - 31ms/epoch - 8ms/step
# Epoch 84/300
# 4/4 - 0s - loss: 0.0056 - 31ms/epoch - 8ms/step
# Epoch 85/300
# 4/4 - 0s - loss: 0.0040 - 31ms/epoch - 8ms/step
# Epoch 86/300
# 4/4 - 0s - loss: 0.0056 - 29ms/epoch - 7ms/step
# Epoch 87/300
# 4/4 - 0s - loss: 0.0063 - 29ms/epoch - 7ms/step
# Epoch 88/300
# 4/4 - 0s - loss: 0.0041 - 33ms/epoch - 8ms/step
# Epoch 89/300
# 4/4 - 0s - loss: 0.0034 - 32ms/epoch - 8ms/step
# Epoch 90/300
# 4/4 - 0s - loss: 0.0055 - 31ms/epoch - 8ms/step
# Epoch 91/300
# 4/4 - 0s - loss: 0.0052 - 30ms/epoch - 7ms/step
# Epoch 92/300
# 4/4 - 0s - loss: 0.0040 - 29ms/epoch - 7ms/step
# Epoch 93/300
# 4/4 - 0s - loss: 0.0047 - 31ms/epoch - 8ms/step
# Epoch 94/300
# 4/4 - 0s - loss: 0.0035 - 28ms/epoch - 7ms/step
# Epoch 95/300
# 4/4 - 0s - loss: 0.0041 - 33ms/epoch - 8ms/step
# Epoch 96/300
# 4/4 - 0s - loss: 0.0050 - 30ms/epoch - 8ms/step
# Epoch 97/300
# 4/4 - 0s - loss: 0.0051 - 29ms/epoch - 7ms/step
# Epoch 98/300
# 4/4 - 0s - loss: 0.0064 - 30ms/epoch - 7ms/step
# Epoch 99/300
# 4/4 - 0s - loss: 0.0048 - 31ms/epoch - 8ms/step
# Epoch 100/300
# 4/4 - 0s - loss: 0.0049 - 30ms/epoch - 8ms/step
# Epoch 101/300
# 4/4 - 0s - loss: 0.0029 - 31ms/epoch - 8ms/step
# Epoch 102/300
# 4/4 - 0s - loss: 0.0048 - 28ms/epoch - 7ms/step
# Epoch 103/300
# 4/4 - 0s - loss: 0.0025 - 31ms/epoch - 8ms/step
# Epoch 104/300
# 4/4 - 0s - loss: 0.0022 - 33ms/epoch - 8ms/step
# Epoch 105/300
# 4/4 - 0s - loss: 0.0012 - 28ms/epoch - 7ms/step
# Epoch 106/300
# 4/4 - 0s - loss: 8.6333e-04 - 32ms/epoch - 8ms/step
# Epoch 107/300
# 4/4 - 0s - loss: 7.9731e-04 - 34ms/epoch - 9ms/step
# Epoch 108/300
# 4/4 - 0s - loss: 7.8295e-04 - 31ms/epoch - 8ms/step
# Epoch 109/300
# 4/4 - 0s - loss: 4.6936e-04 - 28ms/epoch - 7ms/step
# Epoch 110/300
# 4/4 - 0s - loss: 4.9886e-04 - 27ms/epoch - 7ms/step
# Epoch 111/300
# 4/4 - 0s - loss: 5.8655e-04 - 27ms/epoch - 7ms/step
# Epoch 112/300
# 4/4 - 0s - loss: 7.8565e-04 - 30ms/epoch - 7ms/step
# Epoch 113/300
# 4/4 - 0s - loss: 5.9775e-04 - 29ms/epoch - 7ms/step
# Epoch 114/300
# 4/4 - 0s - loss: 6.3191e-04 - 31ms/epoch - 8ms/step
# Epoch 115/300
# 4/4 - 0s - loss: 5.0175e-04 - 28ms/epoch - 7ms/step
# Epoch 116/300
# 4/4 - 0s - loss: 0.0019 - 31ms/epoch - 8ms/step
# Epoch 117/300
# 4/4 - 0s - loss: 0.0023 - 30ms/epoch - 8ms/step
# Epoch 118/300
# 4/4 - 0s - loss: 0.0030 - 29ms/epoch - 7ms/step
# Epoch 119/300
# 4/4 - 0s - loss: 0.0054 - 29ms/epoch - 7ms/step
# Epoch 120/300
# 4/4 - 0s - loss: 0.0040 - 30ms/epoch - 7ms/step
# Epoch 121/300
# 4/4 - 0s - loss: 0.0025 - 33ms/epoch - 8ms/step
# Epoch 122/300
# 4/4 - 0s - loss: 0.0026 - 27ms/epoch - 7ms/step
# Epoch 123/300
# 4/4 - 0s - loss: 0.0025 - 25ms/epoch - 6ms/step
# Epoch 124/300
# 4/4 - 0s - loss: 0.0014 - 30ms/epoch - 7ms/step
# Epoch 125/300
# 4/4 - 0s - loss: 0.0019 - 28ms/epoch - 7ms/step
# Epoch 126/300
# 4/4 - 0s - loss: 0.0014 - 30ms/epoch - 8ms/step
# Epoch 127/300
# 4/4 - 0s - loss: 0.0011 - 31ms/epoch - 8ms/step
# Epoch 128/300
# 4/4 - 0s - loss: 4.1411e-04 - 30ms/epoch - 8ms/step
# Epoch 129/300
# 4/4 - 0s - loss: 4.5374e-04 - 29ms/epoch - 7ms/step
# Epoch 130/300
# 4/4 - 0s - loss: 2.2145e-04 - 29ms/epoch - 7ms/step
# Epoch 131/300
# 4/4 - 0s - loss: 1.6921e-04 - 27ms/epoch - 7ms/step
# Epoch 132/300
# 4/4 - 0s - loss: 1.7917e-04 - 28ms/epoch - 7ms/step
# Epoch 133/300
# 4/4 - 0s - loss: 2.1724e-04 - 30ms/epoch - 8ms/step
# Epoch 134/300
# 4/4 - 0s - loss: 1.1563e-04 - 30ms/epoch - 8ms/step
# Epoch 135/300
# 4/4 - 0s - loss: 1.4680e-04 - 34ms/epoch - 9ms/step
# Epoch 136/300
# 4/4 - 0s - loss: 1.3380e-04 - 31ms/epoch - 8ms/step
# Epoch 137/300
# 4/4 - 0s - loss: 1.3937e-04 - 30ms/epoch - 8ms/step
# Epoch 138/300
# 4/4 - 0s - loss: 2.3100e-04 - 32ms/epoch - 8ms/step
# Epoch 139/300
# 4/4 - 0s - loss: 1.7702e-04 - 30ms/epoch - 8ms/step
# Epoch 140/300
# 4/4 - 0s - loss: 1.4284e-04 - 27ms/epoch - 7ms/step
# Epoch 141/300
# 4/4 - 0s - loss: 3.0282e-04 - 30ms/epoch - 8ms/step
# Epoch 142/300
# 4/4 - 0s - loss: 4.3171e-04 - 37ms/epoch - 9ms/step
# Epoch 143/300
# 4/4 - 0s - loss: 7.0389e-04 - 32ms/epoch - 8ms/step
# Epoch 144/300
# 4/4 - 0s - loss: 4.7197e-04 - 28ms/epoch - 7ms/step
# Epoch 145/300
# 4/4 - 0s - loss: 6.7986e-04 - 30ms/epoch - 7ms/step
# Epoch 146/300
# 4/4 - 0s - loss: 3.6998e-04 - 27ms/epoch - 7ms/step
# Epoch 147/300
# 4/4 - 0s - loss: 4.1103e-04 - 25ms/epoch - 6ms/step
# Epoch 148/300
# 4/4 - 0s - loss: 5.3796e-04 - 27ms/epoch - 7ms/step
# Epoch 149/300
# 4/4 - 0s - loss: 4.5373e-04 - 27ms/epoch - 7ms/step
# Epoch 150/300
# 4/4 - 0s - loss: 3.0214e-04 - 26ms/epoch - 7ms/step
# Epoch 151/300
# 4/4 - 0s - loss: 4.2258e-04 - 28ms/epoch - 7ms/step
# Epoch 152/300
# 4/4 - 0s - loss: 5.9243e-04 - 33ms/epoch - 8ms/step
# Epoch 153/300
# 4/4 - 0s - loss: 2.0031e-04 - 29ms/epoch - 7ms/step
# Epoch 154/300
# 4/4 - 0s - loss: 2.8146e-04 - 26ms/epoch - 6ms/step
# Epoch 155/300
# 4/4 - 0s - loss: 2.8929e-04 - 32ms/epoch - 8ms/step
# Epoch 156/300
# 4/4 - 0s - loss: 3.1412e-04 - 33ms/epoch - 8ms/step
# Epoch 157/300
# 4/4 - 0s - loss: 2.2226e-04 - 30ms/epoch - 7ms/step
# Epoch 158/300
# 4/4 - 0s - loss: 3.0034e-04 - 29ms/epoch - 7ms/step
# Epoch 159/300
# 4/4 - 0s - loss: 1.9337e-04 - 35ms/epoch - 9ms/step
# Epoch 160/300
# 4/4 - 0s - loss: 2.0250e-04 - 32ms/epoch - 8ms/step
# Epoch 161/300
# 4/4 - 0s - loss: 2.1790e-04 - 28ms/epoch - 7ms/step
# Epoch 162/300
# 4/4 - 0s - loss: 2.4113e-04 - 30ms/epoch - 8ms/step
# Epoch 163/300
# 4/4 - 0s - loss: 2.1441e-04 - 28ms/epoch - 7ms/step
# Epoch 164/300
# 4/4 - 0s - loss: 7.9682e-04 - 29ms/epoch - 7ms/step
# Epoch 165/300
# 4/4 - 0s - loss: 0.0012 - 29ms/epoch - 7ms/step
# Epoch 166/300
# 4/4 - 0s - loss: 0.0012 - 28ms/epoch - 7ms/step
# Epoch 167/300
# 4/4 - 0s - loss: 6.8430e-04 - 30ms/epoch - 7ms/step
# Epoch 168/300
# 4/4 - 0s - loss: 7.6051e-04 - 29ms/epoch - 7ms/step
# Epoch 169/300
# 4/4 - 0s - loss: 0.0021 - 33ms/epoch - 8ms/step
# Epoch 170/300
# 4/4 - 0s - loss: 0.0023 - 35ms/epoch - 9ms/step
# Epoch 171/300
# 4/4 - 0s - loss: 0.0014 - 30ms/epoch - 7ms/step
# Epoch 172/300
# 4/4 - 0s - loss: 4.8216e-04 - 32ms/epoch - 8ms/step
# Epoch 173/300
# 4/4 - 0s - loss: 5.4072e-04 - 28ms/epoch - 7ms/step
# Epoch 174/300
# 4/4 - 0s - loss: 4.6084e-04 - 28ms/epoch - 7ms/step
# Epoch 175/300
# 4/4 - 0s - loss: 3.6593e-04 - 29ms/epoch - 7ms/step
# Epoch 176/300
# 4/4 - 0s - loss: 5.1370e-04 - 31ms/epoch - 8ms/step
# Epoch 177/300
# 4/4 - 0s - loss: 3.6530e-04 - 29ms/epoch - 7ms/step
# Epoch 178/300
# 4/4 - 0s - loss: 4.2069e-04 - 33ms/epoch - 8ms/step
# Epoch 179/300
# 4/4 - 0s - loss: 6.3717e-04 - 31ms/epoch - 8ms/step
# Epoch 180/300
# 4/4 - 0s - loss: 4.1206e-04 - 29ms/epoch - 7ms/step
# Epoch 181/300
# 4/4 - 0s - loss: 2.5474e-04 - 30ms/epoch - 8ms/step
# Epoch 182/300
# 4/4 - 0s - loss: 1.4398e-04 - 34ms/epoch - 8ms/step
# Epoch 183/300
# 4/4 - 0s - loss: 1.0418e-04 - 30ms/epoch - 7ms/step
# Epoch 184/300
# 4/4 - 0s - loss: 9.6066e-05 - 27ms/epoch - 7ms/step
# Epoch 185/300
# 4/4 - 0s - loss: 9.8157e-05 - 28ms/epoch - 7ms/step
# Epoch 186/300
# 4/4 - 0s - loss: 1.3715e-04 - 26ms/epoch - 7ms/step
# Epoch 187/300
# 4/4 - 0s - loss: 7.3943e-05 - 28ms/epoch - 7ms/step
# Epoch 188/300
# 4/4 - 0s - loss: 4.5410e-05 - 26ms/epoch - 6ms/step
# Epoch 189/300
# 4/4 - 0s - loss: 4.4325e-05 - 28ms/epoch - 7ms/step
# Epoch 190/300
# 4/4 - 0s - loss: 4.5910e-05 - 27ms/epoch - 7ms/step
# Epoch 191/300
# 4/4 - 0s - loss: 4.8294e-05 - 33ms/epoch - 8ms/step
# Epoch 192/300
# 4/4 - 0s - loss: 5.3961e-05 - 29ms/epoch - 7ms/step
# Epoch 193/300
# 4/4 - 0s - loss: 5.6969e-05 - 32ms/epoch - 8ms/step
# Epoch 194/300
# 4/4 - 0s - loss: 1.2355e-04 - 30ms/epoch - 8ms/step
# Epoch 195/300
# 4/4 - 0s - loss: 2.0406e-04 - 28ms/epoch - 7ms/step
# Epoch 196/300
# 4/4 - 0s - loss: 1.7738e-04 - 33ms/epoch - 8ms/step
# Epoch 197/300
# 4/4 - 0s - loss: 1.2506e-04 - 29ms/epoch - 7ms/step
# Epoch 198/300
# 4/4 - 0s - loss: 1.5374e-04 - 30ms/epoch - 8ms/step
# Epoch 199/300
# 4/4 - 0s - loss: 1.9098e-04 - 34ms/epoch - 9ms/step
# Epoch 200/300
# 4/4 - 0s - loss: 1.0374e-04 - 31ms/epoch - 8ms/step
# Epoch 201/300
# 4/4 - 0s - loss: 7.6814e-05 - 31ms/epoch - 8ms/step
# Epoch 202/300
# 4/4 - 0s - loss: 9.1159e-05 - 29ms/epoch - 7ms/step
# Epoch 203/300
# 4/4 - 0s - loss: 8.2208e-05 - 28ms/epoch - 7ms/step
# Epoch 204/300
# 4/4 - 0s - loss: 9.2208e-05 - 31ms/epoch - 8ms/step
# Epoch 205/300
# 4/4 - 0s - loss: 1.1835e-04 - 31ms/epoch - 8ms/step
# Epoch 206/300
# 4/4 - 0s - loss: 1.4805e-04 - 27ms/epoch - 7ms/step
# Epoch 207/300
# 4/4 - 0s - loss: 1.8289e-04 - 26ms/epoch - 7ms/step
# Epoch 208/300
# 4/4 - 0s - loss: 3.2848e-04 - 29ms/epoch - 7ms/step
# Epoch 209/300
# 4/4 - 0s - loss: 1.9770e-04 - 34ms/epoch - 9ms/step
# Epoch 210/300
# 4/4 - 0s - loss: 5.7243e-04 - 28ms/epoch - 7ms/step
# Epoch 211/300
# 4/4 - 0s - loss: 4.2927e-04 - 33ms/epoch - 8ms/step
# Epoch 212/300
# 4/4 - 0s - loss: 4.2968e-04 - 28ms/epoch - 7ms/step
# Epoch 213/300
# 4/4 - 0s - loss: 3.0033e-04 - 26ms/epoch - 6ms/step
# Epoch 214/300
# 4/4 - 0s - loss: 3.6360e-04 - 30ms/epoch - 7ms/step
# Epoch 215/300
# 4/4 - 0s - loss: 9.1232e-04 - 31ms/epoch - 8ms/step
# Epoch 216/300
# 4/4 - 0s - loss: 5.7814e-04 - 30ms/epoch - 7ms/step
# Epoch 217/300
# 4/4 - 0s - loss: 6.6498e-04 - 30ms/epoch - 8ms/step
# Epoch 218/300
# 4/4 - 0s - loss: 4.2660e-04 - 26ms/epoch - 7ms/step
# Epoch 219/300
# 4/4 - 0s - loss: 9.5923e-04 - 30ms/epoch - 7ms/step
# Epoch 220/300
# 4/4 - 0s - loss: 8.8599e-04 - 27ms/epoch - 7ms/step
# Epoch 221/300
# 4/4 - 0s - loss: 0.0014 - 29ms/epoch - 7ms/step
# Epoch 222/300
# 4/4 - 0s - loss: 0.0011 - 29ms/epoch - 7ms/step
# Epoch 223/300
# 4/4 - 0s - loss: 5.0305e-04 - 29ms/epoch - 7ms/step
# Epoch 224/300
# 4/4 - 0s - loss: 0.0013 - 31ms/epoch - 8ms/step
# Epoch 225/300
# 4/4 - 0s - loss: 0.0011 - 27ms/epoch - 7ms/step
# Epoch 226/300
# 4/4 - 0s - loss: 0.0021 - 26ms/epoch - 7ms/step
# Epoch 227/300
# 4/4 - 0s - loss: 0.0024 - 29ms/epoch - 7ms/step
# Epoch 228/300
# 4/4 - 0s - loss: 0.0065 - 27ms/epoch - 7ms/step
# Epoch 229/300
# 4/4 - 0s - loss: 0.0086 - 32ms/epoch - 8ms/step
# Epoch 230/300
# 4/4 - 0s - loss: 0.0062 - 26ms/epoch - 7ms/step
# Epoch 231/300
# 4/4 - 0s - loss: 0.0117 - 26ms/epoch - 7ms/step
# Epoch 232/300
# 4/4 - 0s - loss: 0.0143 - 31ms/epoch - 8ms/step
# Epoch 233/300
# 4/4 - 0s - loss: 0.0078 - 30ms/epoch - 8ms/step
# Epoch 234/300
# 4/4 - 0s - loss: 0.0116 - 26ms/epoch - 6ms/step
# Epoch 235/300
# 4/4 - 0s - loss: 0.0113 - 30ms/epoch - 7ms/step
# Epoch 236/300
# 4/4 - 0s - loss: 0.0140 - 36ms/epoch - 9ms/step
# Epoch 237/300
# 4/4 - 0s - loss: 0.0167 - 27ms/epoch - 7ms/step
# Epoch 238/300
# 4/4 - 0s - loss: 0.0328 - 30ms/epoch - 7ms/step
# Epoch 239/300
# 4/4 - 0s - loss: 0.0246 - 26ms/epoch - 7ms/step
# Epoch 240/300
# 4/4 - 0s - loss: 0.0187 - 33ms/epoch - 8ms/step
# Epoch 241/300
# 4/4 - 0s - loss: 0.0084 - 30ms/epoch - 8ms/step
# Epoch 242/300
# 4/4 - 0s - loss: 0.0117 - 29ms/epoch - 7ms/step
# Epoch 243/300
# 4/4 - 0s - loss: 0.0100 - 31ms/epoch - 8ms/step
# Epoch 244/300
# 4/4 - 0s - loss: 0.0062 - 31ms/epoch - 8ms/step
# Epoch 245/300
# 4/4 - 0s - loss: 0.0059 - 29ms/epoch - 7ms/step
# Epoch 246/300
# 4/4 - 0s - loss: 0.0023 - 32ms/epoch - 8ms/step
# Epoch 247/300
# 4/4 - 0s - loss: 0.0014 - 34ms/epoch - 8ms/step
# Epoch 248/300
# 4/4 - 0s - loss: 0.0010 - 31ms/epoch - 8ms/step
# Epoch 249/300
# 4/4 - 0s - loss: 0.0015 - 25ms/epoch - 6ms/step
# Epoch 250/300
# 4/4 - 0s - loss: 0.0014 - 25ms/epoch - 6ms/step
# Epoch 251/300
# 4/4 - 0s - loss: 0.0016 - 27ms/epoch - 7ms/step
# Epoch 252/300
# 4/4 - 0s - loss: 9.5280e-04 - 29ms/epoch - 7ms/step
# Epoch 253/300
# 4/4 - 0s - loss: 7.7532e-04 - 28ms/epoch - 7ms/step
# Epoch 254/300
# 4/4 - 0s - loss: 6.4352e-04 - 30ms/epoch - 8ms/step
# Epoch 255/300
# 4/4 - 0s - loss: 5.0370e-04 - 29ms/epoch - 7ms/step
# Epoch 256/300
# 4/4 - 0s - loss: 4.3259e-04 - 30ms/epoch - 7ms/step
# Epoch 257/300
# 4/4 - 0s - loss: 6.1216e-04 - 27ms/epoch - 7ms/step
# Epoch 258/300
# 4/4 - 0s - loss: 4.4686e-04 - 30ms/epoch - 8ms/step
# Epoch 259/300
# 4/4 - 0s - loss: 7.9687e-04 - 27ms/epoch - 7ms/step
# Epoch 260/300
# 4/4 - 0s - loss: 6.0379e-04 - 25ms/epoch - 6ms/step
# Epoch 261/300
# 4/4 - 0s - loss: 5.1464e-04 - 27ms/epoch - 7ms/step
# Epoch 262/300
# 4/4 - 0s - loss: 2.8531e-04 - 30ms/epoch - 8ms/step
# Epoch 263/300
# 4/4 - 0s - loss: 2.4126e-04 - 30ms/epoch - 7ms/step
# Epoch 264/300
# 4/4 - 0s - loss: 3.0727e-04 - 31ms/epoch - 8ms/step
# Epoch 265/300
# 4/4 - 0s - loss: 2.8085e-04 - 32ms/epoch - 8ms/step
# Epoch 266/300
# 4/4 - 0s - loss: 1.5130e-04 - 34ms/epoch - 8ms/step
# Epoch 267/300
# 4/4 - 0s - loss: 2.0949e-04 - 26ms/epoch - 7ms/step
# Epoch 268/300
# 4/4 - 0s - loss: 1.6935e-04 - 30ms/epoch - 7ms/step
# Epoch 269/300
# 4/4 - 0s - loss: 2.1519e-04 - 29ms/epoch - 7ms/step
# Epoch 270/300
# 4/4 - 0s - loss: 3.0443e-04 - 29ms/epoch - 7ms/step
# Epoch 271/300
# 4/4 - 0s - loss: 3.8425e-04 - 27ms/epoch - 7ms/step
# Epoch 272/300
# 4/4 - 0s - loss: 5.5993e-04 - 29ms/epoch - 7ms/step
# Epoch 273/300
# 4/4 - 0s - loss: 5.2034e-04 - 28ms/epoch - 7ms/step
# Epoch 274/300
# 4/4 - 0s - loss: 2.7459e-04 - 31ms/epoch - 8ms/step
# Epoch 275/300
# 4/4 - 0s - loss: 2.7617e-04 - 28ms/epoch - 7ms/step
# Epoch 276/300
# 4/4 - 0s - loss: 2.2311e-04 - 28ms/epoch - 7ms/step
# Epoch 277/300
# 4/4 - 0s - loss: 1.2979e-04 - 29ms/epoch - 7ms/step
# Epoch 278/300
# 4/4 - 0s - loss: 1.3317e-04 - 31ms/epoch - 8ms/step
# Epoch 279/300
# 4/4 - 0s - loss: 1.5797e-04 - 28ms/epoch - 7ms/step
# Epoch 280/300
# 4/4 - 0s - loss: 1.4287e-04 - 27ms/epoch - 7ms/step
# Epoch 281/300
# 4/4 - 0s - loss: 1.6894e-04 - 31ms/epoch - 8ms/step
# Epoch 282/300
# 4/4 - 0s - loss: 1.9863e-04 - 36ms/epoch - 9ms/step
# Epoch 283/300
# 4/4 - 0s - loss: 1.5957e-04 - 28ms/epoch - 7ms/step
# Epoch 284/300
# 4/4 - 0s - loss: 1.4929e-04 - 30ms/epoch - 8ms/step
# Epoch 285/300
# 4/4 - 0s - loss: 1.1099e-04 - 28ms/epoch - 7ms/step
# Epoch 286/300
# 4/4 - 0s - loss: 1.7682e-04 - 31ms/epoch - 8ms/step
# Epoch 287/300
# 4/4 - 0s - loss: 1.2738e-04 - 30ms/epoch - 7ms/step
# Epoch 288/300
# 4/4 - 0s - loss: 1.1147e-04 - 28ms/epoch - 7ms/step
# Epoch 289/300
# 4/4 - 0s - loss: 1.1862e-04 - 32ms/epoch - 8ms/step
# Epoch 290/300
# 4/4 - 0s - loss: 1.5457e-04 - 33ms/epoch - 8ms/step
# Epoch 291/300
# 4/4 - 0s - loss: 7.4007e-05 - 31ms/epoch - 8ms/step
# Epoch 292/300
# 4/4 - 0s - loss: 8.0812e-05 - 32ms/epoch - 8ms/step
# Epoch 293/300
# 4/4 - 0s - loss: 8.2003e-05 - 29ms/epoch - 7ms/step
# Epoch 294/300
# 4/4 - 0s - loss: 9.0779e-05 - 32ms/epoch - 8ms/step
# Epoch 295/300
# 4/4 - 0s - loss: 1.0683e-04 - 31ms/epoch - 8ms/step
# Epoch 296/300
# 4/4 - 0s - loss: 8.5040e-05 - 31ms/epoch - 8ms/step
# Epoch 297/300
# 4/4 - 0s - loss: 7.9208e-05 - 30ms/epoch - 7ms/step
# Epoch 298/300
# 4/4 - 0s - loss: 5.3127e-05 - 28ms/epoch - 7ms/step
# Epoch 299/300
# 4/4 - 0s - loss: 6.6388e-05 - 30ms/epoch - 8ms/step
# Epoch 300/300
# 4/4 - 0s - loss: 8.5085e-05 - 28ms/epoch - 7ms/step
# 14/14 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710203585.9343712
# Tue Mar 12 00:33:05 2024
