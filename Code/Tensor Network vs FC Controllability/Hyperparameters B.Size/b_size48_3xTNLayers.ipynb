# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_50 (Dense)            (None, 1024)              3072
#
#  dense_51 (Dense)            (None, 1024)              1049600
#
#  dense_52 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_53 (Dense)            (None, 1024)              3072
#
#  tn_layer_30 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_31 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_32 (TNLayer)       (None, 1024)              5120
#
#  dense_54 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(20, 2) + np.array([3, 3]),
                    np.random.randn(20, 2) + np.array([-3, -3]),
                    np.random.randn(20, 2) + np.array([-3, 3]),
                    np.random.randn(20, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((40)), -np.ones((40))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710204066.513918
# Tue Mar 12 00:41:06 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2, batch_size=48)
# Out:
# Epoch 1/300
# 2/2 - 2s - loss: 1.0005 - 2s/epoch - 1s/step
# Epoch 2/300
# 2/2 - 0s - loss: 1.0005 - 17ms/epoch - 8ms/step
# Epoch 3/300
# 2/2 - 0s - loss: 1.0017 - 16ms/epoch - 8ms/step
# Epoch 4/300
# 2/2 - 0s - loss: 0.9999 - 15ms/epoch - 8ms/step
# Epoch 5/300
# 2/2 - 0s - loss: 0.9999 - 15ms/epoch - 8ms/step
# Epoch 6/300
# 2/2 - 0s - loss: 0.9999 - 16ms/epoch - 8ms/step
# Epoch 7/300
# 2/2 - 0s - loss: 0.9998 - 16ms/epoch - 8ms/step
# Epoch 8/300
# 2/2 - 0s - loss: 0.9995 - 15ms/epoch - 7ms/step
# Epoch 9/300
# 2/2 - 0s - loss: 0.9985 - 17ms/epoch - 9ms/step
# Epoch 10/300
# 2/2 - 0s - loss: 0.9974 - 15ms/epoch - 7ms/step
# Epoch 11/300
# 2/2 - 0s - loss: 0.9953 - 18ms/epoch - 9ms/step
# Epoch 12/300
# 2/2 - 0s - loss: 0.9918 - 15ms/epoch - 8ms/step
# Epoch 13/300
# 2/2 - 0s - loss: 0.9860 - 16ms/epoch - 8ms/step
# Epoch 14/300
# 2/2 - 0s - loss: 0.9765 - 17ms/epoch - 8ms/step
# Epoch 15/300
# 2/2 - 0s - loss: 0.9596 - 15ms/epoch - 8ms/step
# Epoch 16/300
# 2/2 - 0s - loss: 0.9322 - 16ms/epoch - 8ms/step
# Epoch 17/300
# 2/2 - 0s - loss: 0.8884 - 15ms/epoch - 8ms/step
# Epoch 18/300
# 2/2 - 0s - loss: 0.8199 - 16ms/epoch - 8ms/step
# Epoch 19/300
# 2/2 - 0s - loss: 0.7133 - 15ms/epoch - 7ms/step
# Epoch 20/300
# 2/2 - 0s - loss: 0.5596 - 15ms/epoch - 7ms/step
# Epoch 21/300
# 2/2 - 0s - loss: 0.3603 - 16ms/epoch - 8ms/step
# Epoch 22/300
# 2/2 - 0s - loss: 0.1432 - 16ms/epoch - 8ms/step
# Epoch 23/300
# 2/2 - 0s - loss: 0.0456 - 17ms/epoch - 8ms/step
# Epoch 24/300
# 2/2 - 0s - loss: 0.1496 - 16ms/epoch - 8ms/step
# Epoch 25/300
# 2/2 - 0s - loss: 0.1246 - 17ms/epoch - 8ms/step
# Epoch 26/300
# 2/2 - 0s - loss: 0.0375 - 18ms/epoch - 9ms/step
# Epoch 27/300
# 2/2 - 0s - loss: 0.0223 - 17ms/epoch - 8ms/step
# Epoch 28/300
# 2/2 - 0s - loss: 0.0399 - 18ms/epoch - 9ms/step
# Epoch 29/300
# 2/2 - 0s - loss: 0.0508 - 16ms/epoch - 8ms/step
# Epoch 30/300
# 2/2 - 0s - loss: 0.0471 - 16ms/epoch - 8ms/step
# Epoch 31/300
# 2/2 - 0s - loss: 0.0343 - 16ms/epoch - 8ms/step
# Epoch 32/300
# 2/2 - 0s - loss: 0.0196 - 19ms/epoch - 9ms/step
# Epoch 33/300
# 2/2 - 0s - loss: 0.0118 - 17ms/epoch - 9ms/step
# Epoch 34/300
# 2/2 - 0s - loss: 0.0126 - 16ms/epoch - 8ms/step
# Epoch 35/300
# 2/2 - 0s - loss: 0.0165 - 15ms/epoch - 8ms/step
# Epoch 36/300
# 2/2 - 0s - loss: 0.0173 - 17ms/epoch - 8ms/step
# Epoch 37/300
# 2/2 - 0s - loss: 0.0140 - 15ms/epoch - 7ms/step
# Epoch 38/300
# 2/2 - 0s - loss: 0.0096 - 16ms/epoch - 8ms/step
# Epoch 39/300
# 2/2 - 0s - loss: 0.0079 - 16ms/epoch - 8ms/step
# Epoch 40/300
# 2/2 - 0s - loss: 0.0084 - 15ms/epoch - 8ms/step
# Epoch 41/300
# 2/2 - 0s - loss: 0.0094 - 16ms/epoch - 8ms/step
# Epoch 42/300
# 2/2 - 0s - loss: 0.0095 - 15ms/epoch - 8ms/step
# Epoch 43/300
# 2/2 - 0s - loss: 0.0085 - 16ms/epoch - 8ms/step
# Epoch 44/300
# 2/2 - 0s - loss: 0.0074 - 17ms/epoch - 8ms/step
# Epoch 45/300
# 2/2 - 0s - loss: 0.0066 - 15ms/epoch - 7ms/step
# Epoch 46/300
# 2/2 - 0s - loss: 0.0063 - 14ms/epoch - 7ms/step
# Epoch 47/300
# 2/2 - 0s - loss: 0.0065 - 16ms/epoch - 8ms/step
# Epoch 48/300
# 2/2 - 0s - loss: 0.0064 - 14ms/epoch - 7ms/step
# Epoch 49/300
# 2/2 - 0s - loss: 0.0061 - 14ms/epoch - 7ms/step
# Epoch 50/300
# 2/2 - 0s - loss: 0.0057 - 16ms/epoch - 8ms/step
# Epoch 51/300
# 2/2 - 0s - loss: 0.0055 - 16ms/epoch - 8ms/step
# Epoch 52/300
# 2/2 - 0s - loss: 0.0054 - 17ms/epoch - 8ms/step
# Epoch 53/300
# 2/2 - 0s - loss: 0.0053 - 16ms/epoch - 8ms/step
# Epoch 54/300
# 2/2 - 0s - loss: 0.0052 - 16ms/epoch - 8ms/step
# Epoch 55/300
# 2/2 - 0s - loss: 0.0051 - 16ms/epoch - 8ms/step
# Epoch 56/300
# 2/2 - 0s - loss: 0.0049 - 16ms/epoch - 8ms/step
# Epoch 57/300
# 2/2 - 0s - loss: 0.0048 - 14ms/epoch - 7ms/step
# Epoch 58/300
# 2/2 - 0s - loss: 0.0047 - 16ms/epoch - 8ms/step
# Epoch 59/300
# 2/2 - 0s - loss: 0.0046 - 16ms/epoch - 8ms/step
# Epoch 60/300
# 2/2 - 0s - loss: 0.0045 - 15ms/epoch - 8ms/step
# Epoch 61/300
# 2/2 - 0s - loss: 0.0044 - 14ms/epoch - 7ms/step
# Epoch 62/300
# 2/2 - 0s - loss: 0.0043 - 17ms/epoch - 8ms/step
# Epoch 63/300
# 2/2 - 0s - loss: 0.0042 - 17ms/epoch - 9ms/step
# Epoch 64/300
# 2/2 - 0s - loss: 0.0042 - 15ms/epoch - 8ms/step
# Epoch 65/300
# 2/2 - 0s - loss: 0.0041 - 16ms/epoch - 8ms/step
# Epoch 66/300
# 2/2 - 0s - loss: 0.0040 - 17ms/epoch - 8ms/step
# Epoch 67/300
# 2/2 - 0s - loss: 0.0039 - 18ms/epoch - 9ms/step
# Epoch 68/300
# 2/2 - 0s - loss: 0.0039 - 17ms/epoch - 8ms/step
# Epoch 69/300
# 2/2 - 0s - loss: 0.0038 - 16ms/epoch - 8ms/step
# Epoch 70/300
# 2/2 - 0s - loss: 0.0037 - 17ms/epoch - 8ms/step
# Epoch 71/300
# 2/2 - 0s - loss: 0.0036 - 15ms/epoch - 7ms/step
# Epoch 72/300
# 2/2 - 0s - loss: 0.0036 - 16ms/epoch - 8ms/step
# Epoch 73/300
# 2/2 - 0s - loss: 0.0035 - 15ms/epoch - 8ms/step
# Epoch 74/300
# 2/2 - 0s - loss: 0.0035 - 19ms/epoch - 9ms/step
# Epoch 75/300
# 2/2 - 0s - loss: 0.0034 - 15ms/epoch - 7ms/step
# Epoch 76/300
# 2/2 - 0s - loss: 0.0033 - 14ms/epoch - 7ms/step
# Epoch 77/300
# 2/2 - 0s - loss: 0.0033 - 16ms/epoch - 8ms/step
# Epoch 78/300
# 2/2 - 0s - loss: 0.0032 - 17ms/epoch - 8ms/step
# Epoch 79/300
# 2/2 - 0s - loss: 0.0032 - 16ms/epoch - 8ms/step
# Epoch 80/300
# 2/2 - 0s - loss: 0.0031 - 16ms/epoch - 8ms/step
# Epoch 81/300
# 2/2 - 0s - loss: 0.0030 - 16ms/epoch - 8ms/step
# Epoch 82/300
# 2/2 - 0s - loss: 0.0030 - 16ms/epoch - 8ms/step
# Epoch 83/300
# 2/2 - 0s - loss: 0.0030 - 16ms/epoch - 8ms/step
# Epoch 84/300
# 2/2 - 0s - loss: 0.0029 - 16ms/epoch - 8ms/step
# Epoch 85/300
# 2/2 - 0s - loss: 0.0029 - 15ms/epoch - 8ms/step
# Epoch 86/300
# 2/2 - 0s - loss: 0.0028 - 16ms/epoch - 8ms/step
# Epoch 87/300
# 2/2 - 0s - loss: 0.0028 - 15ms/epoch - 7ms/step
# Epoch 88/300
# 2/2 - 0s - loss: 0.0027 - 14ms/epoch - 7ms/step
# Epoch 89/300
# 2/2 - 0s - loss: 0.0027 - 15ms/epoch - 7ms/step
# Epoch 90/300
# 2/2 - 0s - loss: 0.0026 - 15ms/epoch - 8ms/step
# Epoch 91/300
# 2/2 - 0s - loss: 0.0026 - 14ms/epoch - 7ms/step
# Epoch 92/300
# 2/2 - 0s - loss: 0.0025 - 14ms/epoch - 7ms/step
# Epoch 93/300
# 2/2 - 0s - loss: 0.0025 - 14ms/epoch - 7ms/step
# Epoch 94/300
# 2/2 - 0s - loss: 0.0025 - 14ms/epoch - 7ms/step
# Epoch 95/300
# 2/2 - 0s - loss: 0.0024 - 14ms/epoch - 7ms/step
# Epoch 96/300
# 2/2 - 0s - loss: 0.0024 - 13ms/epoch - 7ms/step
# Epoch 97/300
# 2/2 - 0s - loss: 0.0023 - 14ms/epoch - 7ms/step
# Epoch 98/300
# 2/2 - 0s - loss: 0.0023 - 14ms/epoch - 7ms/step
# Epoch 99/300
# 2/2 - 0s - loss: 0.0023 - 14ms/epoch - 7ms/step
# Epoch 100/300
# 2/2 - 0s - loss: 0.0022 - 15ms/epoch - 7ms/step
# Epoch 101/300
# 2/2 - 0s - loss: 0.0022 - 14ms/epoch - 7ms/step
# Epoch 102/300
# 2/2 - 0s - loss: 0.0021 - 16ms/epoch - 8ms/step
# Epoch 103/300
# 2/2 - 0s - loss: 0.0021 - 16ms/epoch - 8ms/step
# Epoch 104/300
# 2/2 - 0s - loss: 0.0021 - 14ms/epoch - 7ms/step
# Epoch 105/300
# 2/2 - 0s - loss: 0.0020 - 16ms/epoch - 8ms/step
# Epoch 106/300
# 2/2 - 0s - loss: 0.0020 - 15ms/epoch - 7ms/step
# Epoch 107/300
# 2/2 - 0s - loss: 0.0020 - 15ms/epoch - 7ms/step
# Epoch 108/300
# 2/2 - 0s - loss: 0.0020 - 15ms/epoch - 7ms/step
# Epoch 109/300
# 2/2 - 0s - loss: 0.0019 - 16ms/epoch - 8ms/step
# Epoch 110/300
# 2/2 - 0s - loss: 0.0019 - 15ms/epoch - 7ms/step
# Epoch 111/300
# 2/2 - 0s - loss: 0.0018 - 14ms/epoch - 7ms/step
# Epoch 112/300
# 2/2 - 0s - loss: 0.0018 - 15ms/epoch - 7ms/step
# Epoch 113/300
# 2/2 - 0s - loss: 0.0018 - 16ms/epoch - 8ms/step
# Epoch 114/300
# 2/2 - 0s - loss: 0.0018 - 14ms/epoch - 7ms/step
# Epoch 115/300
# 2/2 - 0s - loss: 0.0017 - 15ms/epoch - 7ms/step
# Epoch 116/300
# 2/2 - 0s - loss: 0.0017 - 14ms/epoch - 7ms/step
# Epoch 117/300
# 2/2 - 0s - loss: 0.0017 - 14ms/epoch - 7ms/step
# Epoch 118/300
# 2/2 - 0s - loss: 0.0017 - 14ms/epoch - 7ms/step
# Epoch 119/300
# 2/2 - 0s - loss: 0.0016 - 14ms/epoch - 7ms/step
# Epoch 120/300
# 2/2 - 0s - loss: 0.0016 - 15ms/epoch - 7ms/step
# Epoch 121/300
# 2/2 - 0s - loss: 0.0016 - 13ms/epoch - 7ms/step
# Epoch 122/300
# 2/2 - 0s - loss: 0.0015 - 13ms/epoch - 7ms/step
# Epoch 123/300
# 2/2 - 0s - loss: 0.0015 - 14ms/epoch - 7ms/step
# Epoch 124/300
# 2/2 - 0s - loss: 0.0015 - 15ms/epoch - 7ms/step
# Epoch 125/300
# 2/2 - 0s - loss: 0.0015 - 15ms/epoch - 7ms/step
# Epoch 126/300
# 2/2 - 0s - loss: 0.0014 - 15ms/epoch - 8ms/step
# Epoch 127/300
# 2/2 - 0s - loss: 0.0014 - 14ms/epoch - 7ms/step
# Epoch 128/300
# 2/2 - 0s - loss: 0.0014 - 14ms/epoch - 7ms/step
# Epoch 129/300
# 2/2 - 0s - loss: 0.0014 - 13ms/epoch - 7ms/step
# Epoch 130/300
# 2/2 - 0s - loss: 0.0013 - 14ms/epoch - 7ms/step
# Epoch 131/300
# 2/2 - 0s - loss: 0.0013 - 14ms/epoch - 7ms/step
# Epoch 132/300
# 2/2 - 0s - loss: 0.0013 - 14ms/epoch - 7ms/step
# Epoch 133/300
# 2/2 - 0s - loss: 0.0013 - 13ms/epoch - 7ms/step
# Epoch 134/300
# 2/2 - 0s - loss: 0.0012 - 14ms/epoch - 7ms/step
# Epoch 135/300
# 2/2 - 0s - loss: 0.0012 - 16ms/epoch - 8ms/step
# Epoch 136/300
# 2/2 - 0s - loss: 0.0012 - 15ms/epoch - 8ms/step
# Epoch 137/300
# 2/2 - 0s - loss: 0.0012 - 15ms/epoch - 7ms/step
# Epoch 138/300
# 2/2 - 0s - loss: 0.0012 - 13ms/epoch - 7ms/step
# Epoch 139/300
# 2/2 - 0s - loss: 0.0011 - 14ms/epoch - 7ms/step
# Epoch 140/300
# 2/2 - 0s - loss: 0.0011 - 15ms/epoch - 8ms/step
# Epoch 141/300
# 2/2 - 0s - loss: 0.0011 - 14ms/epoch - 7ms/step
# Epoch 142/300
# 2/2 - 0s - loss: 0.0011 - 13ms/epoch - 6ms/step
# Epoch 143/300
# 2/2 - 0s - loss: 0.0011 - 14ms/epoch - 7ms/step
# Epoch 144/300
# 2/2 - 0s - loss: 0.0010 - 16ms/epoch - 8ms/step
# Epoch 145/300
# 2/2 - 0s - loss: 0.0010 - 15ms/epoch - 8ms/step
# Epoch 146/300
# 2/2 - 0s - loss: 0.0010 - 14ms/epoch - 7ms/step
# Epoch 147/300
# 2/2 - 0s - loss: 9.7254e-04 - 14ms/epoch - 7ms/step
# Epoch 148/300
# 2/2 - 0s - loss: 9.7319e-04 - 15ms/epoch - 7ms/step
# Epoch 149/300
# 2/2 - 0s - loss: 9.6375e-04 - 15ms/epoch - 8ms/step
# Epoch 150/300
# 2/2 - 0s - loss: 9.3346e-04 - 15ms/epoch - 8ms/step
# Epoch 151/300
# 2/2 - 0s - loss: 9.1083e-04 - 14ms/epoch - 7ms/step
# Epoch 152/300
# 2/2 - 0s - loss: 8.8757e-04 - 14ms/epoch - 7ms/step
# Epoch 153/300
# 2/2 - 0s - loss: 8.8255e-04 - 15ms/epoch - 8ms/step
# Epoch 154/300
# 2/2 - 0s - loss: 8.7024e-04 - 15ms/epoch - 7ms/step
# Epoch 155/300
# 2/2 - 0s - loss: 8.5221e-04 - 15ms/epoch - 7ms/step
# Epoch 156/300
# 2/2 - 0s - loss: 8.1904e-04 - 16ms/epoch - 8ms/step
# Epoch 157/300
# 2/2 - 0s - loss: 8.1927e-04 - 15ms/epoch - 7ms/step
# Epoch 158/300
# 2/2 - 0s - loss: 7.9096e-04 - 15ms/epoch - 8ms/step
# Epoch 159/300
# 2/2 - 0s - loss: 7.8091e-04 - 14ms/epoch - 7ms/step
# Epoch 160/300
# 2/2 - 0s - loss: 7.5916e-04 - 14ms/epoch - 7ms/step
# Epoch 161/300
# 2/2 - 0s - loss: 7.4151e-04 - 15ms/epoch - 7ms/step
# Epoch 162/300
# 2/2 - 0s - loss: 7.2508e-04 - 15ms/epoch - 7ms/step
# Epoch 163/300
# 2/2 - 0s - loss: 7.2685e-04 - 16ms/epoch - 8ms/step
# Epoch 164/300
# 2/2 - 0s - loss: 6.9718e-04 - 16ms/epoch - 8ms/step
# Epoch 165/300
# 2/2 - 0s - loss: 6.8518e-04 - 14ms/epoch - 7ms/step
# Epoch 166/300
# 2/2 - 0s - loss: 6.6510e-04 - 15ms/epoch - 8ms/step
# Epoch 167/300
# 2/2 - 0s - loss: 6.4798e-04 - 16ms/epoch - 8ms/step
# Epoch 168/300
# 2/2 - 0s - loss: 6.3446e-04 - 14ms/epoch - 7ms/step
# Epoch 169/300
# 2/2 - 0s - loss: 6.2546e-04 - 15ms/epoch - 7ms/step
# Epoch 170/300
# 2/2 - 0s - loss: 6.1036e-04 - 16ms/epoch - 8ms/step
# Epoch 171/300
# 2/2 - 0s - loss: 5.9364e-04 - 14ms/epoch - 7ms/step
# Epoch 172/300
# 2/2 - 0s - loss: 5.8319e-04 - 16ms/epoch - 8ms/step
# Epoch 173/300
# 2/2 - 0s - loss: 5.6863e-04 - 15ms/epoch - 7ms/step
# Epoch 174/300
# 2/2 - 0s - loss: 5.5521e-04 - 15ms/epoch - 7ms/step
# Epoch 175/300
# 2/2 - 0s - loss: 5.4659e-04 - 14ms/epoch - 7ms/step
# Epoch 176/300
# 2/2 - 0s - loss: 5.3991e-04 - 15ms/epoch - 8ms/step
# Epoch 177/300
# 2/2 - 0s - loss: 5.3252e-04 - 15ms/epoch - 7ms/step
# Epoch 178/300
# 2/2 - 0s - loss: 5.0833e-04 - 15ms/epoch - 7ms/step
# Epoch 179/300
# 2/2 - 0s - loss: 4.9469e-04 - 14ms/epoch - 7ms/step
# Epoch 180/300
# 2/2 - 0s - loss: 4.8379e-04 - 15ms/epoch - 8ms/step
# Epoch 181/300
# 2/2 - 0s - loss: 4.7309e-04 - 15ms/epoch - 7ms/step
# Epoch 182/300
# 2/2 - 0s - loss: 4.5934e-04 - 16ms/epoch - 8ms/step
# Epoch 183/300
# 2/2 - 0s - loss: 4.5054e-04 - 15ms/epoch - 7ms/step
# Epoch 184/300
# 2/2 - 0s - loss: 4.3866e-04 - 16ms/epoch - 8ms/step
# Epoch 185/300
# 2/2 - 0s - loss: 4.2713e-04 - 16ms/epoch - 8ms/step
# Epoch 186/300
# 2/2 - 0s - loss: 4.1656e-04 - 15ms/epoch - 8ms/step
# Epoch 187/300
# 2/2 - 0s - loss: 4.0673e-04 - 15ms/epoch - 7ms/step
# Epoch 188/300
# 2/2 - 0s - loss: 3.9442e-04 - 15ms/epoch - 7ms/step
# Epoch 189/300
# 2/2 - 0s - loss: 3.8447e-04 - 15ms/epoch - 7ms/step
# Epoch 190/300
# 2/2 - 0s - loss: 3.7869e-04 - 14ms/epoch - 7ms/step
# Epoch 191/300
# 2/2 - 0s - loss: 3.6629e-04 - 15ms/epoch - 8ms/step
# Epoch 192/300
# 2/2 - 0s - loss: 3.5414e-04 - 16ms/epoch - 8ms/step
# Epoch 193/300
# 2/2 - 0s - loss: 3.4521e-04 - 13ms/epoch - 7ms/step
# Epoch 194/300
# 2/2 - 0s - loss: 3.3839e-04 - 14ms/epoch - 7ms/step
# Epoch 195/300
# 2/2 - 0s - loss: 3.2872e-04 - 14ms/epoch - 7ms/step
# Epoch 196/300
# 2/2 - 0s - loss: 3.1713e-04 - 14ms/epoch - 7ms/step
# Epoch 197/300
# 2/2 - 0s - loss: 3.1435e-04 - 14ms/epoch - 7ms/step
# Epoch 198/300
# 2/2 - 0s - loss: 3.0255e-04 - 15ms/epoch - 8ms/step
# Epoch 199/300
# 2/2 - 0s - loss: 2.9507e-04 - 15ms/epoch - 7ms/step
# Epoch 200/300
# 2/2 - 0s - loss: 2.9163e-04 - 14ms/epoch - 7ms/step
# Epoch 201/300
# 2/2 - 0s - loss: 2.7829e-04 - 15ms/epoch - 7ms/step
# Epoch 202/300
# 2/2 - 0s - loss: 2.6756e-04 - 15ms/epoch - 7ms/step
# Epoch 203/300
# 2/2 - 0s - loss: 2.6995e-04 - 15ms/epoch - 8ms/step
# Epoch 204/300
# 2/2 - 0s - loss: 2.5621e-04 - 14ms/epoch - 7ms/step
# Epoch 205/300
# 2/2 - 0s - loss: 2.5119e-04 - 15ms/epoch - 7ms/step
# Epoch 206/300
# 2/2 - 0s - loss: 2.4756e-04 - 13ms/epoch - 7ms/step
# Epoch 207/300
# 2/2 - 0s - loss: 2.3231e-04 - 14ms/epoch - 7ms/step
# Epoch 208/300
# 2/2 - 0s - loss: 2.2607e-04 - 15ms/epoch - 8ms/step
# Epoch 209/300
# 2/2 - 0s - loss: 2.2122e-04 - 15ms/epoch - 7ms/step
# Epoch 210/300
# 2/2 - 0s - loss: 2.1187e-04 - 15ms/epoch - 7ms/step
# Epoch 211/300
# 2/2 - 0s - loss: 2.0501e-04 - 14ms/epoch - 7ms/step
# Epoch 212/300
# 2/2 - 0s - loss: 2.0489e-04 - 15ms/epoch - 7ms/step
# Epoch 213/300
# 2/2 - 0s - loss: 1.9454e-04 - 16ms/epoch - 8ms/step
# Epoch 214/300
# 2/2 - 0s - loss: 1.8684e-04 - 15ms/epoch - 7ms/step
# Epoch 215/300
# 2/2 - 0s - loss: 1.8170e-04 - 15ms/epoch - 7ms/step
# Epoch 216/300
# 2/2 - 0s - loss: 1.7331e-04 - 15ms/epoch - 7ms/step
# Epoch 217/300
# 2/2 - 0s - loss: 1.6890e-04 - 15ms/epoch - 8ms/step
# Epoch 218/300
# 2/2 - 0s - loss: 1.6338e-04 - 14ms/epoch - 7ms/step
# Epoch 219/300
# 2/2 - 0s - loss: 1.6246e-04 - 14ms/epoch - 7ms/step
# Epoch 220/300
# 2/2 - 0s - loss: 1.5312e-04 - 14ms/epoch - 7ms/step
# Epoch 221/300
# 2/2 - 0s - loss: 1.4605e-04 - 14ms/epoch - 7ms/step
# Epoch 222/300
# 2/2 - 0s - loss: 1.4279e-04 - 15ms/epoch - 7ms/step
# Epoch 223/300
# 2/2 - 0s - loss: 1.3701e-04 - 14ms/epoch - 7ms/step
# Epoch 224/300
# 2/2 - 0s - loss: 1.3390e-04 - 15ms/epoch - 7ms/step
# Epoch 225/300
# 2/2 - 0s - loss: 1.2987e-04 - 16ms/epoch - 8ms/step
# Epoch 226/300
# 2/2 - 0s - loss: 1.2121e-04 - 14ms/epoch - 7ms/step
# Epoch 227/300
# 2/2 - 0s - loss: 1.1975e-04 - 15ms/epoch - 8ms/step
# Epoch 228/300
# 2/2 - 0s - loss: 1.1773e-04 - 15ms/epoch - 8ms/step
# Epoch 229/300
# 2/2 - 0s - loss: 1.1071e-04 - 15ms/epoch - 8ms/step
# Epoch 230/300
# 2/2 - 0s - loss: 1.0874e-04 - 15ms/epoch - 7ms/step
# Epoch 231/300
# 2/2 - 0s - loss: 1.0370e-04 - 13ms/epoch - 7ms/step
# Epoch 232/300
# 2/2 - 0s - loss: 9.5843e-05 - 14ms/epoch - 7ms/step
# Epoch 233/300
# 2/2 - 0s - loss: 9.3199e-05 - 16ms/epoch - 8ms/step
# Epoch 234/300
# 2/2 - 0s - loss: 8.8777e-05 - 15ms/epoch - 7ms/step
# Epoch 235/300
# 2/2 - 0s - loss: 8.6563e-05 - 15ms/epoch - 7ms/step
# Epoch 236/300
# 2/2 - 0s - loss: 8.3761e-05 - 14ms/epoch - 7ms/step
# Epoch 237/300
# 2/2 - 0s - loss: 7.8901e-05 - 15ms/epoch - 7ms/step
# Epoch 238/300
# 2/2 - 0s - loss: 7.7968e-05 - 15ms/epoch - 7ms/step
# Epoch 239/300
# 2/2 - 0s - loss: 7.3112e-05 - 15ms/epoch - 8ms/step
# Epoch 240/300
# 2/2 - 0s - loss: 7.0890e-05 - 15ms/epoch - 7ms/step
# Epoch 241/300
# 2/2 - 0s - loss: 6.9578e-05 - 15ms/epoch - 7ms/step
# Epoch 242/300
# 2/2 - 0s - loss: 6.4592e-05 - 15ms/epoch - 7ms/step
# Epoch 243/300
# 2/2 - 0s - loss: 6.2526e-05 - 15ms/epoch - 7ms/step
# Epoch 244/300
# 2/2 - 0s - loss: 5.9823e-05 - 14ms/epoch - 7ms/step
# Epoch 245/300
# 2/2 - 0s - loss: 5.5994e-05 - 14ms/epoch - 7ms/step
# Epoch 246/300
# 2/2 - 0s - loss: 5.4004e-05 - 15ms/epoch - 7ms/step
# Epoch 247/300
# 2/2 - 0s - loss: 5.1562e-05 - 15ms/epoch - 8ms/step
# Epoch 248/300
# 2/2 - 0s - loss: 4.8697e-05 - 14ms/epoch - 7ms/step
# Epoch 249/300
# 2/2 - 0s - loss: 4.7526e-05 - 14ms/epoch - 7ms/step
# Epoch 250/300
# 2/2 - 0s - loss: 4.4423e-05 - 14ms/epoch - 7ms/step
# Epoch 251/300
# 2/2 - 0s - loss: 4.2550e-05 - 15ms/epoch - 7ms/step
# Epoch 252/300
# 2/2 - 0s - loss: 4.0617e-05 - 15ms/epoch - 7ms/step
# Epoch 253/300
# 2/2 - 0s - loss: 3.8867e-05 - 14ms/epoch - 7ms/step
# Epoch 254/300
# 2/2 - 0s - loss: 3.7089e-05 - 16ms/epoch - 8ms/step
# Epoch 255/300
# 2/2 - 0s - loss: 3.5226e-05 - 15ms/epoch - 7ms/step
# Epoch 256/300
# 2/2 - 0s - loss: 3.3491e-05 - 14ms/epoch - 7ms/step
# Epoch 257/300
# 2/2 - 0s - loss: 3.1957e-05 - 15ms/epoch - 7ms/step
# Epoch 258/300
# 2/2 - 0s - loss: 3.0506e-05 - 16ms/epoch - 8ms/step
# Epoch 259/300
# 2/2 - 0s - loss: 2.8616e-05 - 14ms/epoch - 7ms/step
# Epoch 260/300
# 2/2 - 0s - loss: 2.7781e-05 - 15ms/epoch - 7ms/step
# Epoch 261/300
# 2/2 - 0s - loss: 2.6458e-05 - 13ms/epoch - 7ms/step
# Epoch 262/300
# 2/2 - 0s - loss: 2.4892e-05 - 14ms/epoch - 7ms/step
# Epoch 263/300
# 2/2 - 0s - loss: 2.3584e-05 - 15ms/epoch - 7ms/step
# Epoch 264/300
# 2/2 - 0s - loss: 2.2714e-05 - 14ms/epoch - 7ms/step
# Epoch 265/300
# 2/2 - 0s - loss: 2.1536e-05 - 14ms/epoch - 7ms/step
# Epoch 266/300
# 2/2 - 0s - loss: 2.0381e-05 - 16ms/epoch - 8ms/step
# Epoch 267/300
# 2/2 - 0s - loss: 1.9776e-05 - 14ms/epoch - 7ms/step
# Epoch 268/300
# 2/2 - 0s - loss: 1.8212e-05 - 15ms/epoch - 7ms/step
# Epoch 269/300
# 2/2 - 0s - loss: 1.7359e-05 - 15ms/epoch - 8ms/step
# Epoch 270/300
# 2/2 - 0s - loss: 1.6621e-05 - 14ms/epoch - 7ms/step
# Epoch 271/300
# 2/2 - 0s - loss: 1.5791e-05 - 14ms/epoch - 7ms/step
# Epoch 272/300
# 2/2 - 0s - loss: 1.5121e-05 - 15ms/epoch - 7ms/step
# Epoch 273/300
# 2/2 - 0s - loss: 1.4266e-05 - 16ms/epoch - 8ms/step
# Epoch 274/300
# 2/2 - 0s - loss: 1.3609e-05 - 15ms/epoch - 8ms/step
# Epoch 275/300
# 2/2 - 0s - loss: 1.2912e-05 - 14ms/epoch - 7ms/step
# Epoch 276/300
# 2/2 - 0s - loss: 1.2246e-05 - 14ms/epoch - 7ms/step
# Epoch 277/300
# 2/2 - 0s - loss: 1.1653e-05 - 14ms/epoch - 7ms/step
# Epoch 278/300
# 2/2 - 0s - loss: 1.1193e-05 - 15ms/epoch - 7ms/step
# Epoch 279/300
# 2/2 - 0s - loss: 1.0474e-05 - 15ms/epoch - 8ms/step
# Epoch 280/300
# 2/2 - 0s - loss: 1.0186e-05 - 15ms/epoch - 7ms/step
# Epoch 281/300
# 2/2 - 0s - loss: 9.7033e-06 - 15ms/epoch - 7ms/step
# Epoch 282/300
# 2/2 - 0s - loss: 9.0736e-06 - 16ms/epoch - 8ms/step
# Epoch 283/300
# 2/2 - 0s - loss: 8.6048e-06 - 15ms/epoch - 8ms/step
# Epoch 284/300
# 2/2 - 0s - loss: 8.3304e-06 - 14ms/epoch - 7ms/step
# Epoch 285/300
# 2/2 - 0s - loss: 7.8151e-06 - 15ms/epoch - 7ms/step
# Epoch 286/300
# 2/2 - 0s - loss: 7.5064e-06 - 13ms/epoch - 7ms/step
# Epoch 287/300
# 2/2 - 0s - loss: 7.2250e-06 - 15ms/epoch - 8ms/step
# Epoch 288/300
# 2/2 - 0s - loss: 6.9017e-06 - 15ms/epoch - 8ms/step
# Epoch 289/300
# 2/2 - 0s - loss: 6.6325e-06 - 14ms/epoch - 7ms/step
# Epoch 290/300
# 2/2 - 0s - loss: 6.2235e-06 - 13ms/epoch - 7ms/step
# Epoch 291/300
# 2/2 - 0s - loss: 6.0479e-06 - 13ms/epoch - 6ms/step
# Epoch 292/300
# 2/2 - 0s - loss: 5.7116e-06 - 15ms/epoch - 7ms/step
# Epoch 293/300
# 2/2 - 0s - loss: 5.5626e-06 - 15ms/epoch - 7ms/step
# Epoch 294/300
# 2/2 - 0s - loss: 5.3897e-06 - 14ms/epoch - 7ms/step
# Epoch 295/300
# 2/2 - 0s - loss: 4.9356e-06 - 14ms/epoch - 7ms/step
# Epoch 296/300
# 2/2 - 0s - loss: 4.8440e-06 - 14ms/epoch - 7ms/step
# Epoch 297/300
# 2/2 - 0s - loss: 4.6374e-06 - 14ms/epoch - 7ms/step
# Epoch 298/300
# 2/2 - 0s - loss: 4.4395e-06 - 16ms/epoch - 8ms/step
# Epoch 299/300
# 2/2 - 0s - loss: 4.3294e-06 - 14ms/epoch - 7ms/step
# Epoch 300/300
# 2/2 - 0s - loss: 3.9856e-06 - 16ms/epoch - 8ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 14/14 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710204074.4828575
# Tue Mar 12 00:41:14 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710204074.4950948
# Tue Mar 12 00:41:14 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2, batch_size=48)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 2/2 - 1s - loss: 0.6420 - 605ms/epoch - 303ms/step
# Epoch 2/300
# 2/2 - 0s - loss: 0.2294 - 15ms/epoch - 8ms/step
# Epoch 3/300
# 2/2 - 0s - loss: 0.0900 - 17ms/epoch - 9ms/step
# Epoch 4/300
# 2/2 - 0s - loss: 0.1238 - 18ms/epoch - 9ms/step
# Epoch 5/300
# 2/2 - 0s - loss: 0.0974 - 16ms/epoch - 8ms/step
# Epoch 6/300
# 2/2 - 0s - loss: 0.0799 - 16ms/epoch - 8ms/step
# Epoch 7/300
# 2/2 - 0s - loss: 0.0924 - 17ms/epoch - 8ms/step
# Epoch 8/300
# 2/2 - 0s - loss: 0.0654 - 18ms/epoch - 9ms/step
# Epoch 9/300
# 2/2 - 0s - loss: 0.0766 - 19ms/epoch - 9ms/step
# Epoch 10/300
# 2/2 - 0s - loss: 0.0727 - 20ms/epoch - 10ms/step
# Epoch 11/300
# 2/2 - 0s - loss: 0.0514 - 19ms/epoch - 10ms/step
# Epoch 12/300
# 2/2 - 0s - loss: 0.0690 - 20ms/epoch - 10ms/step
# Epoch 13/300
# 2/2 - 0s - loss: 0.0640 - 18ms/epoch - 9ms/step
# Epoch 14/300
# 2/2 - 0s - loss: 0.0578 - 18ms/epoch - 9ms/step
# Epoch 15/300
# 2/2 - 0s - loss: 0.0592 - 21ms/epoch - 10ms/step
# Epoch 16/300
# 2/2 - 0s - loss: 0.0515 - 17ms/epoch - 8ms/step
# Epoch 17/300
# 2/2 - 0s - loss: 0.0499 - 18ms/epoch - 9ms/step
# Epoch 18/300
# 2/2 - 0s - loss: 0.0516 - 18ms/epoch - 9ms/step
# Epoch 19/300
# 2/2 - 0s - loss: 0.0500 - 16ms/epoch - 8ms/step
# Epoch 20/300
# 2/2 - 0s - loss: 0.0464 - 17ms/epoch - 9ms/step
# Epoch 21/300
# 2/2 - 0s - loss: 0.0464 - 19ms/epoch - 10ms/step
# Epoch 22/300
# 2/2 - 0s - loss: 0.0427 - 19ms/epoch - 10ms/step
# Epoch 23/300
# 2/2 - 0s - loss: 0.0451 - 18ms/epoch - 9ms/step
# Epoch 24/300
# 2/2 - 0s - loss: 0.0441 - 18ms/epoch - 9ms/step
# Epoch 25/300
# 2/2 - 0s - loss: 0.0430 - 17ms/epoch - 8ms/step
# Epoch 26/300
# 2/2 - 0s - loss: 0.0445 - 21ms/epoch - 10ms/step
# Epoch 27/300
# 2/2 - 0s - loss: 0.0431 - 17ms/epoch - 8ms/step
# Epoch 28/300
# 2/2 - 0s - loss: 0.0419 - 18ms/epoch - 9ms/step
# Epoch 29/300
# 2/2 - 0s - loss: 0.0384 - 21ms/epoch - 10ms/step
# Epoch 30/300
# 2/2 - 0s - loss: 0.0383 - 18ms/epoch - 9ms/step
# Epoch 31/300
# 2/2 - 0s - loss: 0.0378 - 17ms/epoch - 9ms/step
# Epoch 32/300
# 2/2 - 0s - loss: 0.0368 - 19ms/epoch - 10ms/step
# Epoch 33/300
# 2/2 - 0s - loss: 0.0387 - 20ms/epoch - 10ms/step
# Epoch 34/300
# 2/2 - 0s - loss: 0.0348 - 21ms/epoch - 10ms/step
# Epoch 35/300
# 2/2 - 0s - loss: 0.0336 - 18ms/epoch - 9ms/step
# Epoch 36/300
# 2/2 - 0s - loss: 0.0354 - 20ms/epoch - 10ms/step
# Epoch 37/300
# 2/2 - 0s - loss: 0.0367 - 17ms/epoch - 9ms/step
# Epoch 38/300
# 2/2 - 0s - loss: 0.0369 - 16ms/epoch - 8ms/step
# Epoch 39/300
# 2/2 - 0s - loss: 0.0322 - 19ms/epoch - 9ms/step
# Epoch 40/300
# 2/2 - 0s - loss: 0.0365 - 15ms/epoch - 8ms/step
# Epoch 41/300
# 2/2 - 0s - loss: 0.0361 - 16ms/epoch - 8ms/step
# Epoch 42/300
# 2/2 - 0s - loss: 0.0308 - 18ms/epoch - 9ms/step
# Epoch 43/300
# 2/2 - 0s - loss: 0.0341 - 16ms/epoch - 8ms/step
# Epoch 44/300
# 2/2 - 0s - loss: 0.0317 - 18ms/epoch - 9ms/step
# Epoch 45/300
# 2/2 - 0s - loss: 0.0316 - 17ms/epoch - 9ms/step
# Epoch 46/300
# 2/2 - 0s - loss: 0.0303 - 18ms/epoch - 9ms/step
# Epoch 47/300
# 2/2 - 0s - loss: 0.0297 - 16ms/epoch - 8ms/step
# Epoch 48/300
# 2/2 - 0s - loss: 0.0301 - 22ms/epoch - 11ms/step
# Epoch 49/300
# 2/2 - 0s - loss: 0.0270 - 19ms/epoch - 10ms/step
# Epoch 50/300
# 2/2 - 0s - loss: 0.0284 - 18ms/epoch - 9ms/step
# Epoch 51/300
# 2/2 - 0s - loss: 0.0272 - 17ms/epoch - 9ms/step
# Epoch 52/300
# 2/2 - 0s - loss: 0.0236 - 19ms/epoch - 9ms/step
# Epoch 53/300
# 2/2 - 0s - loss: 0.0253 - 20ms/epoch - 10ms/step
# Epoch 54/300
# 2/2 - 0s - loss: 0.0250 - 18ms/epoch - 9ms/step
# Epoch 55/300
# 2/2 - 0s - loss: 0.0298 - 17ms/epoch - 8ms/step
# Epoch 56/300
# 2/2 - 0s - loss: 0.0284 - 17ms/epoch - 9ms/step
# Epoch 57/300
# 2/2 - 0s - loss: 0.0286 - 18ms/epoch - 9ms/step
# Epoch 58/300
# 2/2 - 0s - loss: 0.0258 - 18ms/epoch - 9ms/step
# Epoch 59/300
# 2/2 - 0s - loss: 0.0343 - 18ms/epoch - 9ms/step
# Epoch 60/300
# 2/2 - 0s - loss: 0.0461 - 17ms/epoch - 8ms/step
# Epoch 61/300
# 2/2 - 0s - loss: 0.0274 - 18ms/epoch - 9ms/step
# Epoch 62/300
# 2/2 - 0s - loss: 0.0391 - 17ms/epoch - 8ms/step
# Epoch 63/300
# 2/2 - 0s - loss: 0.0314 - 19ms/epoch - 10ms/step
# Epoch 64/300
# 2/2 - 0s - loss: 0.0280 - 17ms/epoch - 9ms/step
# Epoch 65/300
# 2/2 - 0s - loss: 0.0351 - 19ms/epoch - 9ms/step
# Epoch 66/300
# 2/2 - 0s - loss: 0.0278 - 15ms/epoch - 7ms/step
# Epoch 67/300
# 2/2 - 0s - loss: 0.0267 - 17ms/epoch - 8ms/step
# Epoch 68/300
# 2/2 - 0s - loss: 0.0211 - 16ms/epoch - 8ms/step
# Epoch 69/300
# 2/2 - 0s - loss: 0.0189 - 16ms/epoch - 8ms/step
# Epoch 70/300
# 2/2 - 0s - loss: 0.0247 - 17ms/epoch - 9ms/step
# Epoch 71/300
# 2/2 - 0s - loss: 0.0203 - 17ms/epoch - 8ms/step
# Epoch 72/300
# 2/2 - 0s - loss: 0.0160 - 20ms/epoch - 10ms/step
# Epoch 73/300
# 2/2 - 0s - loss: 0.0237 - 19ms/epoch - 9ms/step
# Epoch 74/300
# 2/2 - 0s - loss: 0.0181 - 16ms/epoch - 8ms/step
# Epoch 75/300
# 2/2 - 0s - loss: 0.0194 - 18ms/epoch - 9ms/step
# Epoch 76/300
# 2/2 - 0s - loss: 0.0155 - 20ms/epoch - 10ms/step
# Epoch 77/300
# 2/2 - 0s - loss: 0.0177 - 16ms/epoch - 8ms/step
# Epoch 78/300
# 2/2 - 0s - loss: 0.0143 - 19ms/epoch - 9ms/step
# Epoch 79/300
# 2/2 - 0s - loss: 0.0101 - 19ms/epoch - 9ms/step
# Epoch 80/300
# 2/2 - 0s - loss: 0.0115 - 18ms/epoch - 9ms/step
# Epoch 81/300
# 2/2 - 0s - loss: 0.0094 - 16ms/epoch - 8ms/step
# Epoch 82/300
# 2/2 - 0s - loss: 0.0082 - 17ms/epoch - 9ms/step
# Epoch 83/300
# 2/2 - 0s - loss: 0.0105 - 20ms/epoch - 10ms/step
# Epoch 84/300
# 2/2 - 0s - loss: 0.0089 - 19ms/epoch - 10ms/step
# Epoch 85/300
# 2/2 - 0s - loss: 0.0071 - 18ms/epoch - 9ms/step
# Epoch 86/300
# 2/2 - 0s - loss: 0.0082 - 18ms/epoch - 9ms/step
# Epoch 87/300
# 2/2 - 0s - loss: 0.0062 - 18ms/epoch - 9ms/step
# Epoch 88/300
# 2/2 - 0s - loss: 0.0088 - 18ms/epoch - 9ms/step
# Epoch 89/300
# 2/2 - 0s - loss: 0.0066 - 19ms/epoch - 10ms/step
# Epoch 90/300
# 2/2 - 0s - loss: 0.0073 - 18ms/epoch - 9ms/step
# Epoch 91/300
# 2/2 - 0s - loss: 0.0073 - 16ms/epoch - 8ms/step
# Epoch 92/300
# 2/2 - 0s - loss: 0.0061 - 18ms/epoch - 9ms/step
# Epoch 93/300
# 2/2 - 0s - loss: 0.0054 - 19ms/epoch - 10ms/step
# Epoch 94/300
# 2/2 - 0s - loss: 0.0049 - 21ms/epoch - 11ms/step
# Epoch 95/300
# 2/2 - 0s - loss: 0.0044 - 18ms/epoch - 9ms/step
# Epoch 96/300
# 2/2 - 0s - loss: 0.0044 - 20ms/epoch - 10ms/step
# Epoch 97/300
# 2/2 - 0s - loss: 0.0052 - 17ms/epoch - 8ms/step
# Epoch 98/300
# 2/2 - 0s - loss: 0.0039 - 17ms/epoch - 8ms/step
# Epoch 99/300
# 2/2 - 0s - loss: 0.0030 - 18ms/epoch - 9ms/step
# Epoch 100/300
# 2/2 - 0s - loss: 0.0026 - 19ms/epoch - 10ms/step
# Epoch 101/300
# 2/2 - 0s - loss: 0.0023 - 19ms/epoch - 9ms/step
# Epoch 102/300
# 2/2 - 0s - loss: 0.0029 - 18ms/epoch - 9ms/step
# Epoch 103/300
# 2/2 - 0s - loss: 0.0026 - 18ms/epoch - 9ms/step
# Epoch 104/300
# 2/2 - 0s - loss: 0.0028 - 19ms/epoch - 9ms/step
# Epoch 105/300
# 2/2 - 0s - loss: 0.0033 - 21ms/epoch - 11ms/step
# Epoch 106/300
# 2/2 - 0s - loss: 0.0025 - 18ms/epoch - 9ms/step
# Epoch 107/300
# 2/2 - 0s - loss: 0.0026 - 15ms/epoch - 7ms/step
# Epoch 108/300
# 2/2 - 0s - loss: 0.0026 - 19ms/epoch - 9ms/step
# Epoch 109/300
# 2/2 - 0s - loss: 0.0028 - 19ms/epoch - 9ms/step
# Epoch 110/300
# 2/2 - 0s - loss: 0.0017 - 22ms/epoch - 11ms/step
# Epoch 111/300
# 2/2 - 0s - loss: 0.0026 - 16ms/epoch - 8ms/step
# Epoch 112/300
# 2/2 - 0s - loss: 0.0032 - 20ms/epoch - 10ms/step
# Epoch 113/300
# 2/2 - 0s - loss: 0.0023 - 17ms/epoch - 9ms/step
# Epoch 114/300
# 2/2 - 0s - loss: 0.0030 - 20ms/epoch - 10ms/step
# Epoch 115/300
# 2/2 - 0s - loss: 0.0036 - 17ms/epoch - 8ms/step
# Epoch 116/300
# 2/2 - 0s - loss: 0.0037 - 16ms/epoch - 8ms/step
# Epoch 117/300
# 2/2 - 0s - loss: 0.0037 - 16ms/epoch - 8ms/step
# Epoch 118/300
# 2/2 - 0s - loss: 0.0027 - 16ms/epoch - 8ms/step
# Epoch 119/300
# 2/2 - 0s - loss: 0.0034 - 17ms/epoch - 8ms/step
# Epoch 120/300
# 2/2 - 0s - loss: 0.0028 - 15ms/epoch - 8ms/step
# Epoch 121/300
# 2/2 - 0s - loss: 0.0036 - 19ms/epoch - 9ms/step
# Epoch 122/300
# 2/2 - 0s - loss: 0.0034 - 18ms/epoch - 9ms/step
# Epoch 123/300
# 2/2 - 0s - loss: 0.0026 - 20ms/epoch - 10ms/step
# Epoch 124/300
# 2/2 - 0s - loss: 0.0024 - 16ms/epoch - 8ms/step
# Epoch 125/300
# 2/2 - 0s - loss: 0.0015 - 16ms/epoch - 8ms/step
# Epoch 126/300
# 2/2 - 0s - loss: 0.0026 - 16ms/epoch - 8ms/step
# Epoch 127/300
# 2/2 - 0s - loss: 0.0017 - 16ms/epoch - 8ms/step
# Epoch 128/300
# 2/2 - 0s - loss: 6.9500e-04 - 17ms/epoch - 8ms/step
# Epoch 129/300
# 2/2 - 0s - loss: 0.0012 - 17ms/epoch - 8ms/step
# Epoch 130/300
# 2/2 - 0s - loss: 8.8469e-04 - 19ms/epoch - 10ms/step
# Epoch 131/300
# 2/2 - 0s - loss: 8.9937e-04 - 15ms/epoch - 7ms/step
# Epoch 132/300
# 2/2 - 0s - loss: 4.9167e-04 - 15ms/epoch - 8ms/step
# Epoch 133/300
# 2/2 - 0s - loss: 8.6878e-04 - 17ms/epoch - 9ms/step
# Epoch 134/300
# 2/2 - 0s - loss: 8.4449e-04 - 18ms/epoch - 9ms/step
# Epoch 135/300
# 2/2 - 0s - loss: 6.5233e-04 - 16ms/epoch - 8ms/step
# Epoch 136/300
# 2/2 - 0s - loss: 6.5721e-04 - 21ms/epoch - 11ms/step
# Epoch 137/300
# 2/2 - 0s - loss: 6.5425e-04 - 17ms/epoch - 9ms/step
# Epoch 138/300
# 2/2 - 0s - loss: 0.0013 - 16ms/epoch - 8ms/step
# Epoch 139/300
# 2/2 - 0s - loss: 0.0011 - 16ms/epoch - 8ms/step
# Epoch 140/300
# 2/2 - 0s - loss: 7.6053e-04 - 18ms/epoch - 9ms/step
# Epoch 141/300
# 2/2 - 0s - loss: 0.0011 - 17ms/epoch - 9ms/step
# Epoch 142/300
# 2/2 - 0s - loss: 8.5594e-04 - 18ms/epoch - 9ms/step
# Epoch 143/300
# 2/2 - 0s - loss: 0.0013 - 19ms/epoch - 9ms/step
# Epoch 144/300
# 2/2 - 0s - loss: 0.0018 - 21ms/epoch - 11ms/step
# Epoch 145/300
# 2/2 - 0s - loss: 0.0011 - 18ms/epoch - 9ms/step
# Epoch 146/300
# 2/2 - 0s - loss: 0.0018 - 18ms/epoch - 9ms/step
# Epoch 147/300
# 2/2 - 0s - loss: 0.0022 - 16ms/epoch - 8ms/step
# Epoch 148/300
# 2/2 - 0s - loss: 0.0015 - 19ms/epoch - 9ms/step
# Epoch 149/300
# 2/2 - 0s - loss: 0.0012 - 17ms/epoch - 9ms/step
# Epoch 150/300
# 2/2 - 0s - loss: 0.0012 - 16ms/epoch - 8ms/step
# Epoch 151/300
# 2/2 - 0s - loss: 0.0018 - 17ms/epoch - 8ms/step
# Epoch 152/300
# 2/2 - 0s - loss: 0.0016 - 18ms/epoch - 9ms/step
# Epoch 153/300
# 2/2 - 0s - loss: 0.0012 - 18ms/epoch - 9ms/step
# Epoch 154/300
# 2/2 - 0s - loss: 0.0013 - 18ms/epoch - 9ms/step
# Epoch 155/300
# 2/2 - 0s - loss: 0.0012 - 21ms/epoch - 11ms/step
# Epoch 156/300
# 2/2 - 0s - loss: 7.5198e-04 - 18ms/epoch - 9ms/step
# Epoch 157/300
# 2/2 - 0s - loss: 8.0560e-04 - 18ms/epoch - 9ms/step
# Epoch 158/300
# 2/2 - 0s - loss: 6.0229e-04 - 19ms/epoch - 10ms/step
# Epoch 159/300
# 2/2 - 0s - loss: 5.2367e-04 - 19ms/epoch - 9ms/step
# Epoch 160/300
# 2/2 - 0s - loss: 5.5240e-04 - 18ms/epoch - 9ms/step
# Epoch 161/300
# 2/2 - 0s - loss: 3.7563e-04 - 18ms/epoch - 9ms/step
# Epoch 162/300
# 2/2 - 0s - loss: 2.9919e-04 - 19ms/epoch - 10ms/step
# Epoch 163/300
# 2/2 - 0s - loss: 2.6963e-04 - 19ms/epoch - 10ms/step
# Epoch 164/300
# 2/2 - 0s - loss: 2.3400e-04 - 19ms/epoch - 9ms/step
# Epoch 165/300
# 2/2 - 0s - loss: 3.0242e-04 - 18ms/epoch - 9ms/step
# Epoch 166/300
# 2/2 - 0s - loss: 3.3703e-04 - 17ms/epoch - 8ms/step
# Epoch 167/300
# 2/2 - 0s - loss: 2.6096e-04 - 18ms/epoch - 9ms/step
# Epoch 168/300
# 2/2 - 0s - loss: 1.0753e-04 - 17ms/epoch - 9ms/step
# Epoch 169/300
# 2/2 - 0s - loss: 4.4345e-04 - 17ms/epoch - 8ms/step
# Epoch 170/300
# 2/2 - 0s - loss: 3.9798e-04 - 18ms/epoch - 9ms/step
# Epoch 171/300
# 2/2 - 0s - loss: 4.1490e-04 - 16ms/epoch - 8ms/step
# Epoch 172/300
# 2/2 - 0s - loss: 5.2566e-04 - 18ms/epoch - 9ms/step
# Epoch 173/300
# 2/2 - 0s - loss: 3.7808e-04 - 16ms/epoch - 8ms/step
# Epoch 174/300
# 2/2 - 0s - loss: 2.7288e-04 - 16ms/epoch - 8ms/step
# Epoch 175/300
# 2/2 - 0s - loss: 4.3972e-04 - 17ms/epoch - 9ms/step
# Epoch 176/300
# 2/2 - 0s - loss: 3.7454e-04 - 16ms/epoch - 8ms/step
# Epoch 177/300
# 2/2 - 0s - loss: 4.5671e-04 - 18ms/epoch - 9ms/step
# Epoch 178/300
# 2/2 - 0s - loss: 4.9911e-04 - 21ms/epoch - 10ms/step
# Epoch 179/300
# 2/2 - 0s - loss: 2.4327e-04 - 17ms/epoch - 8ms/step
# Epoch 180/300
# 2/2 - 0s - loss: 1.2028e-04 - 19ms/epoch - 10ms/step
# Epoch 181/300
# 2/2 - 0s - loss: 1.5995e-04 - 19ms/epoch - 10ms/step
# Epoch 182/300
# 2/2 - 0s - loss: 1.6046e-04 - 17ms/epoch - 9ms/step
# Epoch 183/300
# 2/2 - 0s - loss: 1.3652e-04 - 21ms/epoch - 10ms/step
# Epoch 184/300
# 2/2 - 0s - loss: 1.0808e-04 - 18ms/epoch - 9ms/step
# Epoch 185/300
# 2/2 - 0s - loss: 8.1912e-05 - 20ms/epoch - 10ms/step
# Epoch 186/300
# 2/2 - 0s - loss: 6.3296e-05 - 20ms/epoch - 10ms/step
# Epoch 187/300
# 2/2 - 0s - loss: 6.4654e-05 - 16ms/epoch - 8ms/step
# Epoch 188/300
# 2/2 - 0s - loss: 6.7399e-05 - 19ms/epoch - 9ms/step
# Epoch 189/300
# 2/2 - 0s - loss: 5.6719e-05 - 18ms/epoch - 9ms/step
# Epoch 190/300
# 2/2 - 0s - loss: 4.1328e-05 - 17ms/epoch - 9ms/step
# Epoch 191/300
# 2/2 - 0s - loss: 3.9890e-05 - 19ms/epoch - 10ms/step
# Epoch 192/300
# 2/2 - 0s - loss: 3.9075e-05 - 17ms/epoch - 8ms/step
# Epoch 193/300
# 2/2 - 0s - loss: 4.3309e-05 - 17ms/epoch - 8ms/step
# Epoch 194/300
# 2/2 - 0s - loss: 6.0092e-05 - 18ms/epoch - 9ms/step
# Epoch 195/300
# 2/2 - 0s - loss: 8.5332e-05 - 17ms/epoch - 9ms/step
# Epoch 196/300
# 2/2 - 0s - loss: 7.7387e-05 - 17ms/epoch - 9ms/step
# Epoch 197/300
# 2/2 - 0s - loss: 8.5012e-05 - 18ms/epoch - 9ms/step
# Epoch 198/300
# 2/2 - 0s - loss: 8.3554e-05 - 18ms/epoch - 9ms/step
# Epoch 199/300
# 2/2 - 0s - loss: 1.0283e-04 - 14ms/epoch - 7ms/step
# Epoch 200/300
# 2/2 - 0s - loss: 1.0900e-04 - 16ms/epoch - 8ms/step
# Epoch 201/300
# 2/2 - 0s - loss: 1.3190e-04 - 18ms/epoch - 9ms/step
# Epoch 202/300
# 2/2 - 0s - loss: 1.9707e-04 - 16ms/epoch - 8ms/step
# Epoch 203/300
# 2/2 - 0s - loss: 1.5182e-04 - 16ms/epoch - 8ms/step
# Epoch 204/300
# 2/2 - 0s - loss: 1.9725e-04 - 17ms/epoch - 9ms/step
# Epoch 205/300
# 2/2 - 0s - loss: 1.5194e-04 - 18ms/epoch - 9ms/step
# Epoch 206/300
# 2/2 - 0s - loss: 2.3546e-04 - 18ms/epoch - 9ms/step
# Epoch 207/300
# 2/2 - 0s - loss: 2.6940e-04 - 18ms/epoch - 9ms/step
# Epoch 208/300
# 2/2 - 0s - loss: 3.2202e-04 - 18ms/epoch - 9ms/step
# Epoch 209/300
# 2/2 - 0s - loss: 2.3284e-04 - 19ms/epoch - 9ms/step
# Epoch 210/300
# 2/2 - 0s - loss: 1.8565e-04 - 18ms/epoch - 9ms/step
# Epoch 211/300
# 2/2 - 0s - loss: 1.4021e-04 - 16ms/epoch - 8ms/step
# Epoch 212/300
# 2/2 - 0s - loss: 2.3071e-04 - 20ms/epoch - 10ms/step
# Epoch 213/300
# 2/2 - 0s - loss: 2.0906e-04 - 18ms/epoch - 9ms/step
# Epoch 214/300
# 2/2 - 0s - loss: 1.6343e-04 - 16ms/epoch - 8ms/step
# Epoch 215/300
# 2/2 - 0s - loss: 2.3140e-04 - 16ms/epoch - 8ms/step
# Epoch 216/300
# 2/2 - 0s - loss: 3.2381e-04 - 18ms/epoch - 9ms/step
# Epoch 217/300
# 2/2 - 0s - loss: 3.2244e-04 - 20ms/epoch - 10ms/step
# Epoch 218/300
# 2/2 - 0s - loss: 2.8202e-04 - 18ms/epoch - 9ms/step
# Epoch 219/300
# 2/2 - 0s - loss: 2.1726e-04 - 16ms/epoch - 8ms/step
# Epoch 220/300
# 2/2 - 0s - loss: 2.2072e-04 - 16ms/epoch - 8ms/step
# Epoch 221/300
# 2/2 - 0s - loss: 2.8203e-04 - 18ms/epoch - 9ms/step
# Epoch 222/300
# 2/2 - 0s - loss: 4.1383e-04 - 17ms/epoch - 8ms/step
# Epoch 223/300
# 2/2 - 0s - loss: 5.8774e-04 - 18ms/epoch - 9ms/step
# Epoch 224/300
# 2/2 - 0s - loss: 3.8248e-04 - 18ms/epoch - 9ms/step
# Epoch 225/300
# 2/2 - 0s - loss: 3.9538e-04 - 16ms/epoch - 8ms/step
# Epoch 226/300
# 2/2 - 0s - loss: 3.4751e-04 - 18ms/epoch - 9ms/step
# Epoch 227/300
# 2/2 - 0s - loss: 3.1833e-04 - 18ms/epoch - 9ms/step
# Epoch 228/300
# 2/2 - 0s - loss: 1.9558e-04 - 17ms/epoch - 8ms/step
# Epoch 229/300
# 2/2 - 0s - loss: 1.6186e-04 - 16ms/epoch - 8ms/step
# Epoch 230/300
# 2/2 - 0s - loss: 2.5458e-04 - 16ms/epoch - 8ms/step
# Epoch 231/300
# 2/2 - 0s - loss: 1.7828e-04 - 19ms/epoch - 10ms/step
# Epoch 232/300
# 2/2 - 0s - loss: 2.8036e-04 - 17ms/epoch - 8ms/step
# Epoch 233/300
# 2/2 - 0s - loss: 3.2406e-04 - 22ms/epoch - 11ms/step
# Epoch 234/300
# 2/2 - 0s - loss: 1.9092e-04 - 21ms/epoch - 11ms/step
# Epoch 235/300
# 2/2 - 0s - loss: 1.5358e-04 - 18ms/epoch - 9ms/step
# Epoch 236/300
# 2/2 - 0s - loss: 2.0685e-04 - 17ms/epoch - 9ms/step
# Epoch 237/300
# 2/2 - 0s - loss: 1.4972e-04 - 17ms/epoch - 9ms/step
# Epoch 238/300
# 2/2 - 0s - loss: 1.7714e-04 - 17ms/epoch - 8ms/step
# Epoch 239/300
# 2/2 - 0s - loss: 1.7728e-04 - 20ms/epoch - 10ms/step
# Epoch 240/300
# 2/2 - 0s - loss: 1.5806e-04 - 16ms/epoch - 8ms/step
# Epoch 241/300
# 2/2 - 0s - loss: 1.4646e-04 - 17ms/epoch - 9ms/step
# Epoch 242/300
# 2/2 - 0s - loss: 1.1865e-04 - 17ms/epoch - 8ms/step
# Epoch 243/300
# 2/2 - 0s - loss: 8.8889e-05 - 18ms/epoch - 9ms/step
# Epoch 244/300
# 2/2 - 0s - loss: 1.3159e-04 - 21ms/epoch - 10ms/step
# Epoch 245/300
# 2/2 - 0s - loss: 2.2368e-04 - 17ms/epoch - 9ms/step
# Epoch 246/300
# 2/2 - 0s - loss: 1.8753e-04 - 17ms/epoch - 8ms/step
# Epoch 247/300
# 2/2 - 0s - loss: 1.0301e-04 - 16ms/epoch - 8ms/step
# Epoch 248/300
# 2/2 - 0s - loss: 9.6364e-05 - 15ms/epoch - 8ms/step
# Epoch 249/300
# 2/2 - 0s - loss: 5.0390e-05 - 19ms/epoch - 9ms/step
# Epoch 250/300
# 2/2 - 0s - loss: 6.9396e-05 - 18ms/epoch - 9ms/step
# Epoch 251/300
# 2/2 - 0s - loss: 1.0015e-04 - 18ms/epoch - 9ms/step
# Epoch 252/300
# 2/2 - 0s - loss: 1.2422e-04 - 18ms/epoch - 9ms/step
# Epoch 253/300
# 2/2 - 0s - loss: 1.9825e-04 - 17ms/epoch - 8ms/step
# Epoch 254/300
# 2/2 - 0s - loss: 1.7856e-04 - 21ms/epoch - 11ms/step
# Epoch 255/300
# 2/2 - 0s - loss: 1.7538e-04 - 18ms/epoch - 9ms/step
# Epoch 256/300
# 2/2 - 0s - loss: 2.1650e-04 - 20ms/epoch - 10ms/step
# Epoch 257/300
# 2/2 - 0s - loss: 2.3876e-04 - 18ms/epoch - 9ms/step
# Epoch 258/300
# 2/2 - 0s - loss: 1.3659e-04 - 17ms/epoch - 9ms/step
# Epoch 259/300
# 2/2 - 0s - loss: 1.5221e-04 - 19ms/epoch - 10ms/step
# Epoch 260/300
# 2/2 - 0s - loss: 1.8858e-04 - 18ms/epoch - 9ms/step
# Epoch 261/300
# 2/2 - 0s - loss: 2.1395e-04 - 18ms/epoch - 9ms/step
# Epoch 262/300
# 2/2 - 0s - loss: 3.7615e-04 - 17ms/epoch - 9ms/step
# Epoch 263/300
# 2/2 - 0s - loss: 7.4603e-04 - 16ms/epoch - 8ms/step
# Epoch 264/300
# 2/2 - 0s - loss: 7.0522e-04 - 17ms/epoch - 9ms/step
# Epoch 265/300
# 2/2 - 0s - loss: 8.2635e-04 - 16ms/epoch - 8ms/step
# Epoch 266/300
# 2/2 - 0s - loss: 6.5885e-04 - 17ms/epoch - 9ms/step
# Epoch 267/300
# 2/2 - 0s - loss: 3.6463e-04 - 18ms/epoch - 9ms/step
# Epoch 268/300
# 2/2 - 0s - loss: 2.2266e-04 - 17ms/epoch - 9ms/step
# Epoch 269/300
# 2/2 - 0s - loss: 1.7650e-04 - 16ms/epoch - 8ms/step
# Epoch 270/300
# 2/2 - 0s - loss: 1.8340e-04 - 17ms/epoch - 8ms/step
# Epoch 271/300
# 2/2 - 0s - loss: 1.7178e-04 - 16ms/epoch - 8ms/step
# Epoch 272/300
# 2/2 - 0s - loss: 2.1428e-04 - 22ms/epoch - 11ms/step
# Epoch 273/300
# 2/2 - 0s - loss: 2.1766e-04 - 18ms/epoch - 9ms/step
# Epoch 274/300
# 2/2 - 0s - loss: 1.8015e-04 - 16ms/epoch - 8ms/step
# Epoch 275/300
# 2/2 - 0s - loss: 2.3241e-04 - 16ms/epoch - 8ms/step
# Epoch 276/300
# 2/2 - 0s - loss: 3.0649e-04 - 19ms/epoch - 10ms/step
# Epoch 277/300
# 2/2 - 0s - loss: 2.2473e-04 - 20ms/epoch - 10ms/step
# Epoch 278/300
# 2/2 - 0s - loss: 2.0145e-04 - 21ms/epoch - 10ms/step
# Epoch 279/300
# 2/2 - 0s - loss: 2.3825e-04 - 17ms/epoch - 8ms/step
# Epoch 280/300
# 2/2 - 0s - loss: 1.3077e-04 - 16ms/epoch - 8ms/step
# Epoch 281/300
# 2/2 - 0s - loss: 1.1852e-04 - 20ms/epoch - 10ms/step
# Epoch 282/300
# 2/2 - 0s - loss: 9.4200e-05 - 19ms/epoch - 9ms/step
# Epoch 283/300
# 2/2 - 0s - loss: 8.7107e-05 - 21ms/epoch - 11ms/step
# Epoch 284/300
# 2/2 - 0s - loss: 1.4064e-04 - 17ms/epoch - 8ms/step
# Epoch 285/300
# 2/2 - 0s - loss: 1.9885e-04 - 19ms/epoch - 9ms/step
# Epoch 286/300
# 2/2 - 0s - loss: 1.4877e-04 - 17ms/epoch - 9ms/step
# Epoch 287/300
# 2/2 - 0s - loss: 7.3787e-05 - 19ms/epoch - 9ms/step
# Epoch 288/300
# 2/2 - 0s - loss: 8.0466e-05 - 19ms/epoch - 9ms/step
# Epoch 289/300
# 2/2 - 0s - loss: 8.0907e-05 - 17ms/epoch - 8ms/step
# Epoch 290/300
# 2/2 - 0s - loss: 8.6120e-05 - 17ms/epoch - 8ms/step
# Epoch 291/300
# 2/2 - 0s - loss: 6.4503e-05 - 22ms/epoch - 11ms/step
# Epoch 292/300
# 2/2 - 0s - loss: 4.6237e-05 - 17ms/epoch - 8ms/step
# Epoch 293/300
# 2/2 - 0s - loss: 4.3247e-05 - 18ms/epoch - 9ms/step
# Epoch 294/300
# 2/2 - 0s - loss: 2.3697e-05 - 18ms/epoch - 9ms/step
# Epoch 295/300
# 2/2 - 0s - loss: 1.8257e-05 - 18ms/epoch - 9ms/step
# Epoch 296/300
# 2/2 - 0s - loss: 1.4719e-05 - 17ms/epoch - 9ms/step
# Epoch 297/300
# 2/2 - 0s - loss: 2.0219e-05 - 19ms/epoch - 10ms/step
# Epoch 298/300
# 2/2 - 0s - loss: 1.7648e-05 - 20ms/epoch - 10ms/step
# Epoch 299/300
# 2/2 - 0s - loss: 2.9473e-05 - 22ms/epoch - 11ms/step
# Epoch 300/300
# 2/2 - 0s - loss: 1.6742e-05 - 19ms/epoch - 10ms/step
# 14/14 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710204081.5520484
# Tue Mar 12 00:41:21 2024
