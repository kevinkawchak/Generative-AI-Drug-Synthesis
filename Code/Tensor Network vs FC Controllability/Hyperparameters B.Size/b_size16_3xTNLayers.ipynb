# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 1024)              3072
#
#  dense_26 (Dense)            (None, 1024)              1049600
#
#  dense_27 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 1024)              3072
#
#  tn_layer_15 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_16 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_17 (TNLayer)       (None, 1024)              5120
#
#  dense_29 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(20, 2) + np.array([3, 3]),
                    np.random.randn(20, 2) + np.array([-3, -3]),
                    np.random.randn(20, 2) + np.array([-3, 3]),
                    np.random.randn(20, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((40)), -np.ones((40))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710203740.1449122
# Tue Mar 12 00:35:40 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2, batch_size=16)
# Out:
# Epoch 1/300
# 5/5 - 2s - loss: 1.0046 - 2s/epoch - 321ms/step
# Epoch 2/300
# 5/5 - 0s - loss: 1.0019 - 18ms/epoch - 4ms/step
# Epoch 3/300
# 5/5 - 0s - loss: 1.0014 - 17ms/epoch - 3ms/step
# Epoch 4/300
# 5/5 - 0s - loss: 0.9993 - 16ms/epoch - 3ms/step
# Epoch 5/300
# 5/5 - 0s - loss: 0.9982 - 17ms/epoch - 3ms/step
# Epoch 6/300
# 5/5 - 0s - loss: 0.9902 - 16ms/epoch - 3ms/step
# Epoch 7/300
# 5/5 - 0s - loss: 0.9582 - 17ms/epoch - 3ms/step
# Epoch 8/300
# 5/5 - 0s - loss: 0.8429 - 18ms/epoch - 4ms/step
# Epoch 9/300
# 5/5 - 0s - loss: 0.4702 - 17ms/epoch - 3ms/step
# Epoch 10/300
# 5/5 - 0s - loss: 0.1345 - 18ms/epoch - 4ms/step
# Epoch 11/300
# 5/5 - 0s - loss: 0.0571 - 17ms/epoch - 3ms/step
# Epoch 12/300
# 5/5 - 0s - loss: 0.0574 - 17ms/epoch - 3ms/step
# Epoch 13/300
# 5/5 - 0s - loss: 0.0353 - 17ms/epoch - 3ms/step
# Epoch 14/300
# 5/5 - 0s - loss: 0.0158 - 17ms/epoch - 3ms/step
# Epoch 15/300
# 5/5 - 0s - loss: 0.0204 - 17ms/epoch - 3ms/step
# Epoch 16/300
# 5/5 - 0s - loss: 0.0110 - 17ms/epoch - 3ms/step
# Epoch 17/300
# 5/5 - 0s - loss: 0.0122 - 20ms/epoch - 4ms/step
# Epoch 18/300
# 5/5 - 0s - loss: 0.0103 - 19ms/epoch - 4ms/step
# Epoch 19/300
# 5/5 - 0s - loss: 0.0098 - 17ms/epoch - 3ms/step
# Epoch 20/300
# 5/5 - 0s - loss: 0.0083 - 16ms/epoch - 3ms/step
# Epoch 21/300
# 5/5 - 0s - loss: 0.0079 - 17ms/epoch - 3ms/step
# Epoch 22/300
# 5/5 - 0s - loss: 0.0074 - 18ms/epoch - 4ms/step
# Epoch 23/300
# 5/5 - 0s - loss: 0.0071 - 17ms/epoch - 3ms/step
# Epoch 24/300
# 5/5 - 0s - loss: 0.0065 - 17ms/epoch - 3ms/step
# Epoch 25/300
# 5/5 - 0s - loss: 0.0061 - 17ms/epoch - 3ms/step
# Epoch 26/300
# 5/5 - 0s - loss: 0.0058 - 18ms/epoch - 4ms/step
# Epoch 27/300
# 5/5 - 0s - loss: 0.0056 - 17ms/epoch - 3ms/step
# Epoch 28/300
# 5/5 - 0s - loss: 0.0053 - 17ms/epoch - 3ms/step
# Epoch 29/300
# 5/5 - 0s - loss: 0.0049 - 16ms/epoch - 3ms/step
# Epoch 30/300
# 5/5 - 0s - loss: 0.0048 - 16ms/epoch - 3ms/step
# Epoch 31/300
# 5/5 - 0s - loss: 0.0045 - 17ms/epoch - 3ms/step
# Epoch 32/300
# 5/5 - 0s - loss: 0.0042 - 16ms/epoch - 3ms/step
# Epoch 33/300
# 5/5 - 0s - loss: 0.0041 - 16ms/epoch - 3ms/step
# Epoch 34/300
# 5/5 - 0s - loss: 0.0039 - 17ms/epoch - 3ms/step
# Epoch 35/300
# 5/5 - 0s - loss: 0.0037 - 16ms/epoch - 3ms/step
# Epoch 36/300
# 5/5 - 0s - loss: 0.0035 - 18ms/epoch - 4ms/step
# Epoch 37/300
# 5/5 - 0s - loss: 0.0034 - 18ms/epoch - 4ms/step
# Epoch 38/300
# 5/5 - 0s - loss: 0.0032 - 19ms/epoch - 4ms/step
# Epoch 39/300
# 5/5 - 0s - loss: 0.0031 - 17ms/epoch - 3ms/step
# Epoch 40/300
# 5/5 - 0s - loss: 0.0029 - 18ms/epoch - 4ms/step
# Epoch 41/300
# 5/5 - 0s - loss: 0.0028 - 19ms/epoch - 4ms/step
# Epoch 42/300
# 5/5 - 0s - loss: 0.0027 - 16ms/epoch - 3ms/step
# Epoch 43/300
# 5/5 - 0s - loss: 0.0025 - 18ms/epoch - 4ms/step
# Epoch 44/300
# 5/5 - 0s - loss: 0.0025 - 18ms/epoch - 4ms/step
# Epoch 45/300
# 5/5 - 0s - loss: 0.0023 - 17ms/epoch - 3ms/step
# Epoch 46/300
# 5/5 - 0s - loss: 0.0022 - 18ms/epoch - 4ms/step
# Epoch 47/300
# 5/5 - 0s - loss: 0.0021 - 17ms/epoch - 3ms/step
# Epoch 48/300
# 5/5 - 0s - loss: 0.0021 - 16ms/epoch - 3ms/step
# Epoch 49/300
# 5/5 - 0s - loss: 0.0020 - 17ms/epoch - 3ms/step
# Epoch 50/300
# 5/5 - 0s - loss: 0.0019 - 18ms/epoch - 4ms/step
# Epoch 51/300
# 5/5 - 0s - loss: 0.0018 - 17ms/epoch - 3ms/step
# Epoch 52/300
# 5/5 - 0s - loss: 0.0017 - 17ms/epoch - 3ms/step
# Epoch 53/300
# 5/5 - 0s - loss: 0.0017 - 18ms/epoch - 4ms/step
# Epoch 54/300
# 5/5 - 0s - loss: 0.0016 - 16ms/epoch - 3ms/step
# Epoch 55/300
# 5/5 - 0s - loss: 0.0016 - 15ms/epoch - 3ms/step
# Epoch 56/300
# 5/5 - 0s - loss: 0.0015 - 17ms/epoch - 3ms/step
# Epoch 57/300
# 5/5 - 0s - loss: 0.0014 - 17ms/epoch - 3ms/step
# Epoch 58/300
# 5/5 - 0s - loss: 0.0013 - 18ms/epoch - 4ms/step
# Epoch 59/300
# 5/5 - 0s - loss: 0.0013 - 16ms/epoch - 3ms/step
# Epoch 60/300
# 5/5 - 0s - loss: 0.0012 - 16ms/epoch - 3ms/step
# Epoch 61/300
# 5/5 - 0s - loss: 0.0012 - 16ms/epoch - 3ms/step
# Epoch 62/300
# 5/5 - 0s - loss: 0.0011 - 17ms/epoch - 3ms/step
# Epoch 63/300
# 5/5 - 0s - loss: 0.0011 - 17ms/epoch - 3ms/step
# Epoch 64/300
# 5/5 - 0s - loss: 0.0010 - 17ms/epoch - 3ms/step
# Epoch 65/300
# 5/5 - 0s - loss: 9.9491e-04 - 17ms/epoch - 3ms/step
# Epoch 66/300
# 5/5 - 0s - loss: 9.4005e-04 - 17ms/epoch - 3ms/step
# Epoch 67/300
# 5/5 - 0s - loss: 8.9319e-04 - 17ms/epoch - 3ms/step
# Epoch 68/300
# 5/5 - 0s - loss: 8.5302e-04 - 16ms/epoch - 3ms/step
# Epoch 69/300
# 5/5 - 0s - loss: 8.5720e-04 - 19ms/epoch - 4ms/step
# Epoch 70/300
# 5/5 - 0s - loss: 7.7765e-04 - 21ms/epoch - 4ms/step
# Epoch 71/300
# 5/5 - 0s - loss: 7.5017e-04 - 17ms/epoch - 3ms/step
# Epoch 72/300
# 5/5 - 0s - loss: 7.1406e-04 - 17ms/epoch - 3ms/step
# Epoch 73/300
# 5/5 - 0s - loss: 6.7293e-04 - 16ms/epoch - 3ms/step
# Epoch 74/300
# 5/5 - 0s - loss: 6.4620e-04 - 16ms/epoch - 3ms/step
# Epoch 75/300
# 5/5 - 0s - loss: 6.1755e-04 - 18ms/epoch - 4ms/step
# Epoch 76/300
# 5/5 - 0s - loss: 5.8247e-04 - 18ms/epoch - 4ms/step
# Epoch 77/300
# 5/5 - 0s - loss: 5.5713e-04 - 18ms/epoch - 4ms/step
# Epoch 78/300
# 5/5 - 0s - loss: 5.1979e-04 - 18ms/epoch - 4ms/step
# Epoch 79/300
# 5/5 - 0s - loss: 4.9331e-04 - 17ms/epoch - 3ms/step
# Epoch 80/300
# 5/5 - 0s - loss: 4.6735e-04 - 17ms/epoch - 3ms/step
# Epoch 81/300
# 5/5 - 0s - loss: 4.4136e-04 - 17ms/epoch - 3ms/step
# Epoch 82/300
# 5/5 - 0s - loss: 4.3684e-04 - 16ms/epoch - 3ms/step
# Epoch 83/300
# 5/5 - 0s - loss: 4.2682e-04 - 17ms/epoch - 3ms/step
# Epoch 84/300
# 5/5 - 0s - loss: 3.9172e-04 - 16ms/epoch - 3ms/step
# Epoch 85/300
# 5/5 - 0s - loss: 3.7023e-04 - 15ms/epoch - 3ms/step
# Epoch 86/300
# 5/5 - 0s - loss: 3.4485e-04 - 16ms/epoch - 3ms/step
# Epoch 87/300
# 5/5 - 0s - loss: 3.2641e-04 - 16ms/epoch - 3ms/step
# Epoch 88/300
# 5/5 - 0s - loss: 3.0152e-04 - 16ms/epoch - 3ms/step
# Epoch 89/300
# 5/5 - 0s - loss: 3.2767e-04 - 17ms/epoch - 3ms/step
# Epoch 90/300
# 5/5 - 0s - loss: 2.9122e-04 - 17ms/epoch - 3ms/step
# Epoch 91/300
# 5/5 - 0s - loss: 2.5447e-04 - 17ms/epoch - 3ms/step
# Epoch 92/300
# 5/5 - 0s - loss: 2.5159e-04 - 17ms/epoch - 3ms/step
# Epoch 93/300
# 5/5 - 0s - loss: 2.3850e-04 - 18ms/epoch - 4ms/step
# Epoch 94/300
# 5/5 - 0s - loss: 2.1154e-04 - 18ms/epoch - 4ms/step
# Epoch 95/300
# 5/5 - 0s - loss: 2.0852e-04 - 16ms/epoch - 3ms/step
# Epoch 96/300
# 5/5 - 0s - loss: 1.8207e-04 - 16ms/epoch - 3ms/step
# Epoch 97/300
# 5/5 - 0s - loss: 1.7101e-04 - 18ms/epoch - 4ms/step
# Epoch 98/300
# 5/5 - 0s - loss: 1.6027e-04 - 17ms/epoch - 3ms/step
# Epoch 99/300
# 5/5 - 0s - loss: 1.4651e-04 - 18ms/epoch - 4ms/step
# Epoch 100/300
# 5/5 - 0s - loss: 1.4935e-04 - 17ms/epoch - 3ms/step
# Epoch 101/300
# 5/5 - 0s - loss: 1.2981e-04 - 17ms/epoch - 3ms/step
# Epoch 102/300
# 5/5 - 0s - loss: 1.2318e-04 - 16ms/epoch - 3ms/step
# Epoch 103/300
# 5/5 - 0s - loss: 1.1501e-04 - 16ms/epoch - 3ms/step
# Epoch 104/300
# 5/5 - 0s - loss: 1.0244e-04 - 18ms/epoch - 4ms/step
# Epoch 105/300
# 5/5 - 0s - loss: 9.6026e-05 - 17ms/epoch - 3ms/step
# Epoch 106/300
# 5/5 - 0s - loss: 9.3204e-05 - 19ms/epoch - 4ms/step
# Epoch 107/300
# 5/5 - 0s - loss: 8.6788e-05 - 17ms/epoch - 3ms/step
# Epoch 108/300
# 5/5 - 0s - loss: 8.1756e-05 - 18ms/epoch - 4ms/step
# Epoch 109/300
# 5/5 - 0s - loss: 8.6161e-05 - 19ms/epoch - 4ms/step
# Epoch 110/300
# 5/5 - 0s - loss: 6.7778e-05 - 17ms/epoch - 3ms/step
# Epoch 111/300
# 5/5 - 0s - loss: 6.3077e-05 - 18ms/epoch - 4ms/step
# Epoch 112/300
# 5/5 - 0s - loss: 5.7247e-05 - 19ms/epoch - 4ms/step
# Epoch 113/300
# 5/5 - 0s - loss: 5.9130e-05 - 17ms/epoch - 3ms/step
# Epoch 114/300
# 5/5 - 0s - loss: 5.2861e-05 - 18ms/epoch - 4ms/step
# Epoch 115/300
# 5/5 - 0s - loss: 6.1338e-05 - 18ms/epoch - 4ms/step
# Epoch 116/300
# 5/5 - 0s - loss: 6.2064e-05 - 17ms/epoch - 3ms/step
# Epoch 117/300
# 5/5 - 0s - loss: 5.6015e-05 - 17ms/epoch - 3ms/step
# Epoch 118/300
# 5/5 - 0s - loss: 4.5175e-05 - 17ms/epoch - 3ms/step
# Epoch 119/300
# 5/5 - 0s - loss: 3.4199e-05 - 17ms/epoch - 3ms/step
# Epoch 120/300
# 5/5 - 0s - loss: 4.1079e-05 - 17ms/epoch - 3ms/step
# Epoch 121/300
# 5/5 - 0s - loss: 3.1354e-05 - 17ms/epoch - 3ms/step
# Epoch 122/300
# 5/5 - 0s - loss: 2.4801e-05 - 18ms/epoch - 4ms/step
# Epoch 123/300
# 5/5 - 0s - loss: 2.3989e-05 - 18ms/epoch - 4ms/step
# Epoch 124/300
# 5/5 - 0s - loss: 2.3312e-05 - 17ms/epoch - 3ms/step
# Epoch 125/300
# 5/5 - 0s - loss: 2.3038e-05 - 16ms/epoch - 3ms/step
# Epoch 126/300
# 5/5 - 0s - loss: 2.4191e-05 - 17ms/epoch - 3ms/step
# Epoch 127/300
# 5/5 - 0s - loss: 1.7934e-05 - 16ms/epoch - 3ms/step
# Epoch 128/300
# 5/5 - 0s - loss: 1.4810e-05 - 17ms/epoch - 3ms/step
# Epoch 129/300
# 5/5 - 0s - loss: 1.4673e-05 - 16ms/epoch - 3ms/step
# Epoch 130/300
# 5/5 - 0s - loss: 1.2942e-05 - 16ms/epoch - 3ms/step
# Epoch 131/300
# 5/5 - 0s - loss: 1.2497e-05 - 16ms/epoch - 3ms/step
# Epoch 132/300
# 5/5 - 0s - loss: 1.0580e-05 - 17ms/epoch - 3ms/step
# Epoch 133/300
# 5/5 - 0s - loss: 9.5940e-06 - 17ms/epoch - 3ms/step
# Epoch 134/300
# 5/5 - 0s - loss: 8.5509e-06 - 17ms/epoch - 3ms/step
# Epoch 135/300
# 5/5 - 0s - loss: 7.6624e-06 - 17ms/epoch - 3ms/step
# Epoch 136/300
# 5/5 - 0s - loss: 7.6875e-06 - 17ms/epoch - 3ms/step
# Epoch 137/300
# 5/5 - 0s - loss: 6.1354e-06 - 17ms/epoch - 3ms/step
# Epoch 138/300
# 5/5 - 0s - loss: 6.3729e-06 - 18ms/epoch - 4ms/step
# Epoch 139/300
# 5/5 - 0s - loss: 6.8644e-06 - 18ms/epoch - 4ms/step
# Epoch 140/300
# 5/5 - 0s - loss: 6.7006e-06 - 19ms/epoch - 4ms/step
# Epoch 141/300
# 5/5 - 0s - loss: 7.4465e-06 - 18ms/epoch - 4ms/step
# Epoch 142/300
# 5/5 - 0s - loss: 6.0727e-06 - 17ms/epoch - 3ms/step
# Epoch 143/300
# 5/5 - 0s - loss: 4.7020e-06 - 19ms/epoch - 4ms/step
# Epoch 144/300
# 5/5 - 0s - loss: 6.1084e-06 - 18ms/epoch - 4ms/step
# Epoch 145/300
# 5/5 - 0s - loss: 4.2977e-06 - 17ms/epoch - 3ms/step
# Epoch 146/300
# 5/5 - 0s - loss: 4.0896e-06 - 18ms/epoch - 4ms/step
# Epoch 147/300
# 5/5 - 0s - loss: 5.2993e-06 - 18ms/epoch - 4ms/step
# Epoch 148/300
# 5/5 - 0s - loss: 3.3227e-06 - 17ms/epoch - 3ms/step
# Epoch 149/300
# 5/5 - 0s - loss: 3.4864e-06 - 16ms/epoch - 3ms/step
# Epoch 150/300
# 5/5 - 0s - loss: 3.5981e-06 - 17ms/epoch - 3ms/step
# Epoch 151/300
# 5/5 - 0s - loss: 3.2729e-06 - 18ms/epoch - 4ms/step
# Epoch 152/300
# 5/5 - 0s - loss: 3.0375e-06 - 16ms/epoch - 3ms/step
# Epoch 153/300
# 5/5 - 0s - loss: 1.7304e-06 - 18ms/epoch - 4ms/step
# Epoch 154/300
# 5/5 - 0s - loss: 1.3199e-06 - 17ms/epoch - 3ms/step
# Epoch 155/300
# 5/5 - 0s - loss: 1.1591e-06 - 16ms/epoch - 3ms/step
# Epoch 156/300
# 5/5 - 0s - loss: 1.2303e-06 - 17ms/epoch - 3ms/step
# Epoch 157/300
# 5/5 - 0s - loss: 1.3693e-06 - 17ms/epoch - 3ms/step
# Epoch 158/300
# 5/5 - 0s - loss: 1.2080e-06 - 16ms/epoch - 3ms/step
# Epoch 159/300
# 5/5 - 0s - loss: 1.0075e-06 - 16ms/epoch - 3ms/step
# Epoch 160/300
# 5/5 - 0s - loss: 8.6968e-07 - 16ms/epoch - 3ms/step
# Epoch 161/300
# 5/5 - 0s - loss: 7.2186e-07 - 16ms/epoch - 3ms/step
# Epoch 162/300
# 5/5 - 0s - loss: 6.5402e-07 - 17ms/epoch - 3ms/step
# Epoch 163/300
# 5/5 - 0s - loss: 8.2155e-07 - 17ms/epoch - 3ms/step
# Epoch 164/300
# 5/5 - 0s - loss: 9.4648e-07 - 16ms/epoch - 3ms/step
# Epoch 165/300
# 5/5 - 0s - loss: 8.0663e-07 - 18ms/epoch - 4ms/step
# Epoch 166/300
# 5/5 - 0s - loss: 5.1738e-07 - 17ms/epoch - 3ms/step
# Epoch 167/300
# 5/5 - 0s - loss: 5.0161e-07 - 17ms/epoch - 3ms/step
# Epoch 168/300
# 5/5 - 0s - loss: 4.7480e-07 - 18ms/epoch - 4ms/step
# Epoch 169/300
# 5/5 - 0s - loss: 3.5084e-07 - 17ms/epoch - 3ms/step
# Epoch 170/300
# 5/5 - 0s - loss: 4.1663e-07 - 17ms/epoch - 3ms/step
# Epoch 171/300
# 5/5 - 0s - loss: 3.8376e-07 - 15ms/epoch - 3ms/step
# Epoch 172/300
# 5/5 - 0s - loss: 3.6631e-07 - 16ms/epoch - 3ms/step
# Epoch 173/300
# 5/5 - 0s - loss: 3.9854e-07 - 18ms/epoch - 4ms/step
# Epoch 174/300
# 5/5 - 0s - loss: 3.2138e-07 - 17ms/epoch - 3ms/step
# Epoch 175/300
# 5/5 - 0s - loss: 2.9481e-07 - 16ms/epoch - 3ms/step
# Epoch 176/300
# 5/5 - 0s - loss: 3.5539e-07 - 18ms/epoch - 4ms/step
# Epoch 177/300
# 5/5 - 0s - loss: 3.6579e-07 - 17ms/epoch - 3ms/step
# Epoch 178/300
# 5/5 - 0s - loss: 3.1201e-07 - 16ms/epoch - 3ms/step
# Epoch 179/300
# 5/5 - 0s - loss: 2.6708e-07 - 16ms/epoch - 3ms/step
# Epoch 180/300
# 5/5 - 0s - loss: 2.8095e-07 - 17ms/epoch - 3ms/step
# Epoch 181/300
# 5/5 - 0s - loss: 2.4783e-07 - 18ms/epoch - 4ms/step
# Epoch 182/300
# 5/5 - 0s - loss: 2.5497e-07 - 17ms/epoch - 3ms/step
# Epoch 183/300
# 5/5 - 0s - loss: 3.1327e-07 - 17ms/epoch - 3ms/step
# Epoch 184/300
# 5/5 - 0s - loss: 2.7614e-07 - 17ms/epoch - 3ms/step
# Epoch 185/300
# 5/5 - 0s - loss: 2.2570e-07 - 16ms/epoch - 3ms/step
# Epoch 186/300
# 5/5 - 0s - loss: 2.2747e-07 - 16ms/epoch - 3ms/step
# Epoch 187/300
# 5/5 - 0s - loss: 2.7459e-07 - 17ms/epoch - 3ms/step
# Epoch 188/300
# 5/5 - 0s - loss: 2.5514e-07 - 17ms/epoch - 3ms/step
# Epoch 189/300
# 5/5 - 0s - loss: 2.9660e-07 - 18ms/epoch - 4ms/step
# Epoch 190/300
# 5/5 - 0s - loss: 3.5589e-07 - 17ms/epoch - 3ms/step
# Epoch 191/300
# 5/5 - 0s - loss: 2.7345e-07 - 17ms/epoch - 3ms/step
# Epoch 192/300
# 5/5 - 0s - loss: 3.4841e-07 - 17ms/epoch - 3ms/step
# Epoch 193/300
# 5/5 - 0s - loss: 2.8885e-07 - 18ms/epoch - 4ms/step
# Epoch 194/300
# 5/5 - 0s - loss: 2.1589e-07 - 17ms/epoch - 3ms/step
# Epoch 195/300
# 5/5 - 0s - loss: 1.8729e-07 - 17ms/epoch - 3ms/step
# Epoch 196/300
# 5/5 - 0s - loss: 1.8958e-07 - 16ms/epoch - 3ms/step
# Epoch 197/300
# 5/5 - 0s - loss: 1.7920e-07 - 17ms/epoch - 3ms/step
# Epoch 198/300
# 5/5 - 0s - loss: 1.7936e-07 - 17ms/epoch - 3ms/step
# Epoch 199/300
# 5/5 - 0s - loss: 1.7062e-07 - 17ms/epoch - 3ms/step
# Epoch 200/300
# 5/5 - 0s - loss: 1.7428e-07 - 19ms/epoch - 4ms/step
# Epoch 201/300
# 5/5 - 0s - loss: 1.5415e-07 - 17ms/epoch - 3ms/step
# Epoch 202/300
# 5/5 - 0s - loss: 1.8965e-07 - 16ms/epoch - 3ms/step
# Epoch 203/300
# 5/5 - 0s - loss: 2.0741e-07 - 17ms/epoch - 3ms/step
# Epoch 204/300
# 5/5 - 0s - loss: 2.3193e-07 - 16ms/epoch - 3ms/step
# Epoch 205/300
# 5/5 - 0s - loss: 1.9910e-07 - 17ms/epoch - 3ms/step
# Epoch 206/300
# 5/5 - 0s - loss: 1.8346e-07 - 17ms/epoch - 3ms/step
# Epoch 207/300
# 5/5 - 0s - loss: 1.5762e-07 - 16ms/epoch - 3ms/step
# Epoch 208/300
# 5/5 - 0s - loss: 1.7025e-07 - 16ms/epoch - 3ms/step
# Epoch 209/300
# 5/5 - 0s - loss: 1.7452e-07 - 16ms/epoch - 3ms/step
# Epoch 210/300
# 5/5 - 0s - loss: 1.9796e-07 - 17ms/epoch - 3ms/step
# Epoch 211/300
# 5/5 - 0s - loss: 2.4230e-07 - 17ms/epoch - 3ms/step
# Epoch 212/300
# 5/5 - 0s - loss: 3.1279e-07 - 17ms/epoch - 3ms/step
# Epoch 213/300
# 5/5 - 0s - loss: 2.7044e-07 - 18ms/epoch - 4ms/step
# Epoch 214/300
# 5/5 - 0s - loss: 1.9864e-07 - 18ms/epoch - 4ms/step
# Epoch 215/300
# 5/5 - 0s - loss: 2.1087e-07 - 18ms/epoch - 4ms/step
# Epoch 216/300
# 5/5 - 0s - loss: 2.0112e-07 - 17ms/epoch - 3ms/step
# Epoch 217/300
# 5/5 - 0s - loss: 1.9271e-07 - 17ms/epoch - 3ms/step
# Epoch 218/300
# 5/5 - 0s - loss: 2.2945e-07 - 18ms/epoch - 4ms/step
# Epoch 219/300
# 5/5 - 0s - loss: 2.1496e-07 - 18ms/epoch - 4ms/step
# Epoch 220/300
# 5/5 - 0s - loss: 1.7119e-07 - 17ms/epoch - 3ms/step
# Epoch 221/300
# 5/5 - 0s - loss: 1.4311e-07 - 19ms/epoch - 4ms/step
# Epoch 222/300
# 5/5 - 0s - loss: 1.4820e-07 - 17ms/epoch - 3ms/step
# Epoch 223/300
# 5/5 - 0s - loss: 1.6153e-07 - 16ms/epoch - 3ms/step
# Epoch 224/300
# 5/5 - 0s - loss: 1.9061e-07 - 17ms/epoch - 3ms/step
# Epoch 225/300
# 5/5 - 0s - loss: 1.6169e-07 - 17ms/epoch - 3ms/step
# Epoch 226/300
# 5/5 - 0s - loss: 1.5313e-07 - 18ms/epoch - 4ms/step
# Epoch 227/300
# 5/5 - 0s - loss: 1.4016e-07 - 18ms/epoch - 4ms/step
# Epoch 228/300
# 5/5 - 0s - loss: 1.2324e-07 - 19ms/epoch - 4ms/step
# Epoch 229/300
# 5/5 - 0s - loss: 1.1225e-07 - 17ms/epoch - 3ms/step
# Epoch 230/300
# 5/5 - 0s - loss: 1.5255e-07 - 17ms/epoch - 3ms/step
# Epoch 231/300
# 5/5 - 0s - loss: 1.1183e-07 - 18ms/epoch - 4ms/step
# Epoch 232/300
# 5/5 - 0s - loss: 1.2984e-07 - 17ms/epoch - 3ms/step
# Epoch 233/300
# 5/5 - 0s - loss: 1.2015e-07 - 17ms/epoch - 3ms/step
# Epoch 234/300
# 5/5 - 0s - loss: 1.2425e-07 - 19ms/epoch - 4ms/step
# Epoch 235/300
# 5/5 - 0s - loss: 1.1731e-07 - 16ms/epoch - 3ms/step
# Epoch 236/300
# 5/5 - 0s - loss: 1.1310e-07 - 16ms/epoch - 3ms/step
# Epoch 237/300
# 5/5 - 0s - loss: 1.4025e-07 - 18ms/epoch - 4ms/step
# Epoch 238/300
# 5/5 - 0s - loss: 1.3834e-07 - 17ms/epoch - 3ms/step
# Epoch 239/300
# 5/5 - 0s - loss: 1.2491e-07 - 20ms/epoch - 4ms/step
# Epoch 240/300
# 5/5 - 0s - loss: 1.1743e-07 - 18ms/epoch - 4ms/step
# Epoch 241/300
# 5/5 - 0s - loss: 1.2015e-07 - 17ms/epoch - 3ms/step
# Epoch 242/300
# 5/5 - 0s - loss: 1.5568e-07 - 19ms/epoch - 4ms/step
# Epoch 243/300
# 5/5 - 0s - loss: 1.5759e-07 - 19ms/epoch - 4ms/step
# Epoch 244/300
# 5/5 - 0s - loss: 1.2324e-07 - 17ms/epoch - 3ms/step
# Epoch 245/300
# 5/5 - 0s - loss: 1.1172e-07 - 16ms/epoch - 3ms/step
# Epoch 246/300
# 5/5 - 0s - loss: 1.2226e-07 - 18ms/epoch - 4ms/step
# Epoch 247/300
# 5/5 - 0s - loss: 1.0597e-07 - 17ms/epoch - 3ms/step
# Epoch 248/300
# 5/5 - 0s - loss: 1.1354e-07 - 17ms/epoch - 3ms/step
# Epoch 249/300
# 5/5 - 0s - loss: 1.4757e-07 - 16ms/epoch - 3ms/step
# Epoch 250/300
# 5/5 - 0s - loss: 1.6768e-07 - 18ms/epoch - 4ms/step
# Epoch 251/300
# 5/5 - 0s - loss: 1.8463e-07 - 15ms/epoch - 3ms/step
# Epoch 252/300
# 5/5 - 0s - loss: 1.5759e-07 - 17ms/epoch - 3ms/step
# Epoch 253/300
# 5/5 - 0s - loss: 1.4933e-07 - 17ms/epoch - 3ms/step
# Epoch 254/300
# 5/5 - 0s - loss: 2.1775e-07 - 16ms/epoch - 3ms/step
# Epoch 255/300
# 5/5 - 0s - loss: 1.7219e-07 - 16ms/epoch - 3ms/step
# Epoch 256/300
# 5/5 - 0s - loss: 1.4682e-07 - 17ms/epoch - 3ms/step
# Epoch 257/300
# 5/5 - 0s - loss: 2.3776e-07 - 16ms/epoch - 3ms/step
# Epoch 258/300
# 5/5 - 0s - loss: 1.5875e-07 - 18ms/epoch - 4ms/step
# Epoch 259/300
# 5/5 - 0s - loss: 1.3994e-07 - 16ms/epoch - 3ms/step
# Epoch 260/300
# 5/5 - 0s - loss: 1.2343e-07 - 18ms/epoch - 4ms/step
# Epoch 261/300
# 5/5 - 0s - loss: 1.4815e-07 - 17ms/epoch - 3ms/step
# Epoch 262/300
# 5/5 - 0s - loss: 9.2620e-08 - 19ms/epoch - 4ms/step
# Epoch 263/300
# 5/5 - 0s - loss: 1.1581e-07 - 20ms/epoch - 4ms/step
# Epoch 264/300
# 5/5 - 0s - loss: 1.1440e-07 - 18ms/epoch - 4ms/step
# Epoch 265/300
# 5/5 - 0s - loss: 1.0101e-07 - 19ms/epoch - 4ms/step
# Epoch 266/300
# 5/5 - 0s - loss: 1.0612e-07 - 20ms/epoch - 4ms/step
# Epoch 267/300
# 5/5 - 0s - loss: 1.1836e-07 - 19ms/epoch - 4ms/step
# Epoch 268/300
# 5/5 - 0s - loss: 1.4389e-07 - 17ms/epoch - 3ms/step
# Epoch 269/300
# 5/5 - 0s - loss: 1.3760e-07 - 16ms/epoch - 3ms/step
# Epoch 270/300
# 5/5 - 0s - loss: 8.6354e-08 - 16ms/epoch - 3ms/step
# Epoch 271/300
# 5/5 - 0s - loss: 8.5608e-08 - 19ms/epoch - 4ms/step
# Epoch 272/300
# 5/5 - 0s - loss: 9.1693e-08 - 20ms/epoch - 4ms/step
# Epoch 273/300
# 5/5 - 0s - loss: 8.5105e-08 - 16ms/epoch - 3ms/step
# Epoch 274/300
# 5/5 - 0s - loss: 9.3719e-08 - 19ms/epoch - 4ms/step
# Epoch 275/300
# 5/5 - 0s - loss: 9.7595e-08 - 18ms/epoch - 4ms/step
# Epoch 276/300
# 5/5 - 0s - loss: 1.4681e-07 - 19ms/epoch - 4ms/step
# Epoch 277/300
# 5/5 - 0s - loss: 1.0725e-07 - 20ms/epoch - 4ms/step
# Epoch 278/300
# 5/5 - 0s - loss: 1.0601e-07 - 17ms/epoch - 3ms/step
# Epoch 279/300
# 5/5 - 0s - loss: 1.1370e-07 - 17ms/epoch - 3ms/step
# Epoch 280/300
# 5/5 - 0s - loss: 1.5243e-07 - 17ms/epoch - 3ms/step
# Epoch 281/300
# 5/5 - 0s - loss: 9.4172e-08 - 17ms/epoch - 3ms/step
# Epoch 282/300
# 5/5 - 0s - loss: 9.0311e-08 - 16ms/epoch - 3ms/step
# Epoch 283/300
# 5/5 - 0s - loss: 8.2364e-08 - 20ms/epoch - 4ms/step
# Epoch 284/300
# 5/5 - 0s - loss: 7.3144e-08 - 18ms/epoch - 4ms/step
# Epoch 285/300
# 5/5 - 0s - loss: 9.2338e-08 - 18ms/epoch - 4ms/step
# Epoch 286/300
# 5/5 - 0s - loss: 1.1636e-07 - 18ms/epoch - 4ms/step
# Epoch 287/300
# 5/5 - 0s - loss: 1.0318e-07 - 20ms/epoch - 4ms/step
# Epoch 288/300
# 5/5 - 0s - loss: 1.1009e-07 - 19ms/epoch - 4ms/step
# Epoch 289/300
# 5/5 - 0s - loss: 1.3789e-07 - 18ms/epoch - 4ms/step
# Epoch 290/300
# 5/5 - 0s - loss: 2.2813e-07 - 19ms/epoch - 4ms/step
# Epoch 291/300
# 5/5 - 0s - loss: 1.0863e-07 - 19ms/epoch - 4ms/step
# Epoch 292/300
# 5/5 - 0s - loss: 9.9801e-08 - 18ms/epoch - 4ms/step
# Epoch 293/300
# 5/5 - 0s - loss: 1.0162e-07 - 18ms/epoch - 4ms/step
# Epoch 294/300
# 5/5 - 0s - loss: 1.2388e-07 - 17ms/epoch - 3ms/step
# Epoch 295/300
# 5/5 - 0s - loss: 7.8118e-08 - 18ms/epoch - 4ms/step
# Epoch 296/300
# 5/5 - 0s - loss: 9.3952e-08 - 18ms/epoch - 4ms/step
# Epoch 297/300
# 5/5 - 0s - loss: 1.3657e-07 - 18ms/epoch - 4ms/step
# Epoch 298/300
# 5/5 - 0s - loss: 2.4611e-07 - 18ms/epoch - 4ms/step
# Epoch 299/300
# 5/5 - 0s - loss: 2.0326e-07 - 17ms/epoch - 3ms/step
# Epoch 300/300
# 5/5 - 0s - loss: 1.6030e-07 - 17ms/epoch - 3ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 14/14 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710203752.6563952
# Tue Mar 12 00:35:52 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710203752.6652684
# Tue Mar 12 00:35:52 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2, batch_size=16)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 5/5 - 1s - loss: 0.4406 - 606ms/epoch - 121ms/step
# Epoch 2/300
# 5/5 - 0s - loss: 0.1901 - 36ms/epoch - 7ms/step
# Epoch 3/300
# 5/5 - 0s - loss: 0.1373 - 34ms/epoch - 7ms/step
# Epoch 4/300
# 5/5 - 0s - loss: 0.1200 - 31ms/epoch - 6ms/step
# Epoch 5/300
# 5/5 - 0s - loss: 0.1039 - 36ms/epoch - 7ms/step
# Epoch 6/300
# 5/5 - 0s - loss: 0.0997 - 30ms/epoch - 6ms/step
# Epoch 7/300
# 5/5 - 0s - loss: 0.1033 - 33ms/epoch - 7ms/step
# Epoch 8/300
# 5/5 - 0s - loss: 0.0823 - 35ms/epoch - 7ms/step
# Epoch 9/300
# 5/5 - 0s - loss: 0.0681 - 35ms/epoch - 7ms/step
# Epoch 10/300
# 5/5 - 0s - loss: 0.0794 - 34ms/epoch - 7ms/step
# Epoch 11/300
# 5/5 - 0s - loss: 0.0635 - 34ms/epoch - 7ms/step
# Epoch 12/300
# 5/5 - 0s - loss: 0.0555 - 33ms/epoch - 7ms/step
# Epoch 13/300
# 5/5 - 0s - loss: 0.0501 - 35ms/epoch - 7ms/step
# Epoch 14/300
# 5/5 - 0s - loss: 0.0496 - 34ms/epoch - 7ms/step
# Epoch 15/300
# 5/5 - 0s - loss: 0.0540 - 38ms/epoch - 8ms/step
# Epoch 16/300
# 5/5 - 0s - loss: 0.0629 - 37ms/epoch - 7ms/step
# Epoch 17/300
# 5/5 - 0s - loss: 0.0649 - 36ms/epoch - 7ms/step
# Epoch 18/300
# 5/5 - 0s - loss: 0.0541 - 36ms/epoch - 7ms/step
# Epoch 19/300
# 5/5 - 0s - loss: 0.0409 - 31ms/epoch - 6ms/step
# Epoch 20/300
# 5/5 - 0s - loss: 0.0394 - 34ms/epoch - 7ms/step
# Epoch 21/300
# 5/5 - 0s - loss: 0.0454 - 30ms/epoch - 6ms/step
# Epoch 22/300
# 5/5 - 0s - loss: 0.0398 - 34ms/epoch - 7ms/step
# Epoch 23/300
# 5/5 - 0s - loss: 0.0434 - 33ms/epoch - 7ms/step
# Epoch 24/300
# 5/5 - 0s - loss: 0.0368 - 33ms/epoch - 7ms/step
# Epoch 25/300
# 5/5 - 0s - loss: 0.0327 - 31ms/epoch - 6ms/step
# Epoch 26/300
# 5/5 - 0s - loss: 0.0378 - 33ms/epoch - 7ms/step
# Epoch 27/300
# 5/5 - 0s - loss: 0.0358 - 31ms/epoch - 6ms/step
# Epoch 28/300
# 5/5 - 0s - loss: 0.0368 - 34ms/epoch - 7ms/step
# Epoch 29/300
# 5/5 - 0s - loss: 0.0361 - 33ms/epoch - 7ms/step
# Epoch 30/300
# 5/5 - 0s - loss: 0.0371 - 33ms/epoch - 7ms/step
# Epoch 31/300
# 5/5 - 0s - loss: 0.0350 - 37ms/epoch - 7ms/step
# Epoch 32/300
# 5/5 - 0s - loss: 0.0371 - 34ms/epoch - 7ms/step
# Epoch 33/300
# 5/5 - 0s - loss: 0.0369 - 34ms/epoch - 7ms/step
# Epoch 34/300
# 5/5 - 0s - loss: 0.0482 - 33ms/epoch - 7ms/step
# Epoch 35/300
# 5/5 - 0s - loss: 0.0534 - 32ms/epoch - 6ms/step
# Epoch 36/300
# 5/5 - 0s - loss: 0.0414 - 30ms/epoch - 6ms/step
# Epoch 37/300
# 5/5 - 0s - loss: 0.0487 - 37ms/epoch - 7ms/step
# Epoch 38/300
# 5/5 - 0s - loss: 0.0433 - 33ms/epoch - 7ms/step
# Epoch 39/300
# 5/5 - 0s - loss: 0.0369 - 31ms/epoch - 6ms/step
# Epoch 40/300
# 5/5 - 0s - loss: 0.0347 - 34ms/epoch - 7ms/step
# Epoch 41/300
# 5/5 - 0s - loss: 0.0307 - 32ms/epoch - 6ms/step
# Epoch 42/300
# 5/5 - 0s - loss: 0.0217 - 33ms/epoch - 7ms/step
# Epoch 43/300
# 5/5 - 0s - loss: 0.0182 - 37ms/epoch - 7ms/step
# Epoch 44/300
# 5/5 - 0s - loss: 0.0184 - 33ms/epoch - 7ms/step
# Epoch 45/300
# 5/5 - 0s - loss: 0.0172 - 31ms/epoch - 6ms/step
# Epoch 46/300
# 5/5 - 0s - loss: 0.0237 - 33ms/epoch - 7ms/step
# Epoch 47/300
# 5/5 - 0s - loss: 0.0170 - 31ms/epoch - 6ms/step
# Epoch 48/300
# 5/5 - 0s - loss: 0.0174 - 30ms/epoch - 6ms/step
# Epoch 49/300
# 5/5 - 0s - loss: 0.0156 - 32ms/epoch - 6ms/step
# Epoch 50/300
# 5/5 - 0s - loss: 0.0194 - 32ms/epoch - 6ms/step
# Epoch 51/300
# 5/5 - 0s - loss: 0.0164 - 32ms/epoch - 6ms/step
# Epoch 52/300
# 5/5 - 0s - loss: 0.0138 - 30ms/epoch - 6ms/step
# Epoch 53/300
# 5/5 - 0s - loss: 0.0110 - 32ms/epoch - 6ms/step
# Epoch 54/300
# 5/5 - 0s - loss: 0.0121 - 33ms/epoch - 7ms/step
# Epoch 55/300
# 5/5 - 0s - loss: 0.0092 - 32ms/epoch - 6ms/step
# Epoch 56/300
# 5/5 - 0s - loss: 0.0105 - 34ms/epoch - 7ms/step
# Epoch 57/300
# 5/5 - 0s - loss: 0.0139 - 35ms/epoch - 7ms/step
# Epoch 58/300
# 5/5 - 0s - loss: 0.0111 - 38ms/epoch - 8ms/step
# Epoch 59/300
# 5/5 - 0s - loss: 0.0099 - 33ms/epoch - 7ms/step
# Epoch 60/300
# 5/5 - 0s - loss: 0.0086 - 35ms/epoch - 7ms/step
# Epoch 61/300
# 5/5 - 0s - loss: 0.0064 - 39ms/epoch - 8ms/step
# Epoch 62/300
# 5/5 - 0s - loss: 0.0052 - 34ms/epoch - 7ms/step
# Epoch 63/300
# 5/5 - 0s - loss: 0.0047 - 37ms/epoch - 7ms/step
# Epoch 64/300
# 5/5 - 0s - loss: 0.0057 - 33ms/epoch - 7ms/step
# Epoch 65/300
# 5/5 - 0s - loss: 0.0069 - 34ms/epoch - 7ms/step
# Epoch 66/300
# 5/5 - 0s - loss: 0.0087 - 32ms/epoch - 6ms/step
# Epoch 67/300
# 5/5 - 0s - loss: 0.0109 - 33ms/epoch - 7ms/step
# Epoch 68/300
# 5/5 - 0s - loss: 0.0092 - 32ms/epoch - 6ms/step
# Epoch 69/300
# 5/5 - 0s - loss: 0.0115 - 32ms/epoch - 6ms/step
# Epoch 70/300
# 5/5 - 0s - loss: 0.0088 - 33ms/epoch - 7ms/step
# Epoch 71/300
# 5/5 - 0s - loss: 0.0132 - 35ms/epoch - 7ms/step
# Epoch 72/300
# 5/5 - 0s - loss: 0.0099 - 32ms/epoch - 6ms/step
# Epoch 73/300
# 5/5 - 0s - loss: 0.0147 - 32ms/epoch - 6ms/step
# Epoch 74/300
# 5/5 - 0s - loss: 0.0106 - 32ms/epoch - 6ms/step
# Epoch 75/300
# 5/5 - 0s - loss: 0.0136 - 35ms/epoch - 7ms/step
# Epoch 76/300
# 5/5 - 0s - loss: 0.0140 - 30ms/epoch - 6ms/step
# Epoch 77/300
# 5/5 - 0s - loss: 0.0180 - 33ms/epoch - 7ms/step
# Epoch 78/300
# 5/5 - 0s - loss: 0.0143 - 36ms/epoch - 7ms/step
# Epoch 79/300
# 5/5 - 0s - loss: 0.0078 - 32ms/epoch - 6ms/step
# Epoch 80/300
# 5/5 - 0s - loss: 0.0054 - 31ms/epoch - 6ms/step
# Epoch 81/300
# 5/5 - 0s - loss: 0.0074 - 33ms/epoch - 7ms/step
# Epoch 82/300
# 5/5 - 0s - loss: 0.0040 - 32ms/epoch - 6ms/step
# Epoch 83/300
# 5/5 - 0s - loss: 0.0025 - 35ms/epoch - 7ms/step
# Epoch 84/300
# 5/5 - 0s - loss: 0.0017 - 32ms/epoch - 6ms/step
# Epoch 85/300
# 5/5 - 0s - loss: 0.0018 - 31ms/epoch - 6ms/step
# Epoch 86/300
# 5/5 - 0s - loss: 0.0013 - 32ms/epoch - 6ms/step
# Epoch 87/300
# 5/5 - 0s - loss: 0.0011 - 30ms/epoch - 6ms/step
# Epoch 88/300
# 5/5 - 0s - loss: 8.3061e-04 - 37ms/epoch - 7ms/step
# Epoch 89/300
# 5/5 - 0s - loss: 7.1597e-04 - 35ms/epoch - 7ms/step
# Epoch 90/300
# 5/5 - 0s - loss: 9.5567e-04 - 32ms/epoch - 6ms/step
# Epoch 91/300
# 5/5 - 0s - loss: 6.8027e-04 - 34ms/epoch - 7ms/step
# Epoch 92/300
# 5/5 - 0s - loss: 4.6239e-04 - 32ms/epoch - 6ms/step
# Epoch 93/300
# 5/5 - 0s - loss: 3.3759e-04 - 30ms/epoch - 6ms/step
# Epoch 94/300
# 5/5 - 0s - loss: 2.8299e-04 - 34ms/epoch - 7ms/step
# Epoch 95/300
# 5/5 - 0s - loss: 2.7639e-04 - 34ms/epoch - 7ms/step
# Epoch 96/300
# 5/5 - 0s - loss: 3.8348e-04 - 33ms/epoch - 7ms/step
# Epoch 97/300
# 5/5 - 0s - loss: 3.4780e-04 - 32ms/epoch - 6ms/step
# Epoch 98/300
# 5/5 - 0s - loss: 3.0701e-04 - 33ms/epoch - 7ms/step
# Epoch 99/300
# 5/5 - 0s - loss: 3.5875e-04 - 35ms/epoch - 7ms/step
# Epoch 100/300
# 5/5 - 0s - loss: 8.6931e-04 - 35ms/epoch - 7ms/step
# Epoch 101/300
# 5/5 - 0s - loss: 3.0296e-04 - 32ms/epoch - 6ms/step
# Epoch 102/300
# 5/5 - 0s - loss: 3.2962e-04 - 34ms/epoch - 7ms/step
# Epoch 103/300
# 5/5 - 0s - loss: 2.5565e-04 - 37ms/epoch - 7ms/step
# Epoch 104/300
# 5/5 - 0s - loss: 3.0055e-04 - 36ms/epoch - 7ms/step
# Epoch 105/300
# 5/5 - 0s - loss: 1.9903e-04 - 31ms/epoch - 6ms/step
# Epoch 106/300
# 5/5 - 0s - loss: 1.9150e-04 - 33ms/epoch - 7ms/step
# Epoch 107/300
# 5/5 - 0s - loss: 3.0395e-04 - 29ms/epoch - 6ms/step
# Epoch 108/300
# 5/5 - 0s - loss: 2.7544e-04 - 31ms/epoch - 6ms/step
# Epoch 109/300
# 5/5 - 0s - loss: 2.3622e-04 - 35ms/epoch - 7ms/step
# Epoch 110/300
# 5/5 - 0s - loss: 2.7473e-04 - 32ms/epoch - 6ms/step
# Epoch 111/300
# 5/5 - 0s - loss: 2.9413e-04 - 30ms/epoch - 6ms/step
# Epoch 112/300
# 5/5 - 0s - loss: 5.1121e-04 - 31ms/epoch - 6ms/step
# Epoch 113/300
# 5/5 - 0s - loss: 7.7438e-04 - 31ms/epoch - 6ms/step
# Epoch 114/300
# 5/5 - 0s - loss: 4.7147e-04 - 31ms/epoch - 6ms/step
# Epoch 115/300
# 5/5 - 0s - loss: 2.7871e-04 - 31ms/epoch - 6ms/step
# Epoch 116/300
# 5/5 - 0s - loss: 3.7230e-04 - 31ms/epoch - 6ms/step
# Epoch 117/300
# 5/5 - 0s - loss: 2.9712e-04 - 32ms/epoch - 6ms/step
# Epoch 118/300
# 5/5 - 0s - loss: 1.8924e-04 - 30ms/epoch - 6ms/step
# Epoch 119/300
# 5/5 - 0s - loss: 3.4210e-04 - 32ms/epoch - 6ms/step
# Epoch 120/300
# 5/5 - 0s - loss: 4.3415e-04 - 32ms/epoch - 6ms/step
# Epoch 121/300
# 5/5 - 0s - loss: 3.1966e-04 - 34ms/epoch - 7ms/step
# Epoch 122/300
# 5/5 - 0s - loss: 3.2735e-04 - 31ms/epoch - 6ms/step
# Epoch 123/300
# 5/5 - 0s - loss: 4.0376e-04 - 30ms/epoch - 6ms/step
# Epoch 124/300
# 5/5 - 0s - loss: 4.3763e-04 - 33ms/epoch - 7ms/step
# Epoch 125/300
# 5/5 - 0s - loss: 4.6092e-04 - 41ms/epoch - 8ms/step
# Epoch 126/300
# 5/5 - 0s - loss: 6.3756e-04 - 34ms/epoch - 7ms/step
# Epoch 127/300
# 5/5 - 0s - loss: 5.8642e-04 - 33ms/epoch - 7ms/step
# Epoch 128/300
# 5/5 - 0s - loss: 8.4689e-04 - 32ms/epoch - 6ms/step
# Epoch 129/300
# 5/5 - 0s - loss: 0.0011 - 29ms/epoch - 6ms/step
# Epoch 130/300
# 5/5 - 0s - loss: 8.6662e-04 - 33ms/epoch - 7ms/step
# Epoch 131/300
# 5/5 - 0s - loss: 7.7698e-04 - 33ms/epoch - 7ms/step
# Epoch 132/300
# 5/5 - 0s - loss: 0.0012 - 31ms/epoch - 6ms/step
# Epoch 133/300
# 5/5 - 0s - loss: 9.6425e-04 - 32ms/epoch - 6ms/step
# Epoch 134/300
# 5/5 - 0s - loss: 8.1632e-04 - 35ms/epoch - 7ms/step
# Epoch 135/300
# 5/5 - 0s - loss: 7.0494e-04 - 41ms/epoch - 8ms/step
# Epoch 136/300
# 5/5 - 0s - loss: 6.5272e-04 - 32ms/epoch - 6ms/step
# Epoch 137/300
# 5/5 - 0s - loss: 3.0385e-04 - 30ms/epoch - 6ms/step
# Epoch 138/300
# 5/5 - 0s - loss: 2.1736e-04 - 31ms/epoch - 6ms/step
# Epoch 139/300
# 5/5 - 0s - loss: 2.2212e-04 - 33ms/epoch - 7ms/step
# Epoch 140/300
# 5/5 - 0s - loss: 3.5975e-04 - 31ms/epoch - 6ms/step
# Epoch 141/300
# 5/5 - 0s - loss: 1.6052e-04 - 35ms/epoch - 7ms/step
# Epoch 142/300
# 5/5 - 0s - loss: 1.6897e-04 - 32ms/epoch - 6ms/step
# Epoch 143/300
# 5/5 - 0s - loss: 4.0572e-04 - 33ms/epoch - 7ms/step
# Epoch 144/300
# 5/5 - 0s - loss: 3.0123e-04 - 32ms/epoch - 6ms/step
# Epoch 145/300
# 5/5 - 0s - loss: 2.6568e-04 - 35ms/epoch - 7ms/step
# Epoch 146/300
# 5/5 - 0s - loss: 1.7941e-04 - 36ms/epoch - 7ms/step
# Epoch 147/300
# 5/5 - 0s - loss: 3.1016e-04 - 35ms/epoch - 7ms/step
# Epoch 148/300
# 5/5 - 0s - loss: 2.3093e-04 - 32ms/epoch - 6ms/step
# Epoch 149/300
# 5/5 - 0s - loss: 4.0956e-04 - 32ms/epoch - 6ms/step
# Epoch 150/300
# 5/5 - 0s - loss: 5.9842e-04 - 33ms/epoch - 7ms/step
# Epoch 151/300
# 5/5 - 0s - loss: 5.0890e-04 - 33ms/epoch - 7ms/step
# Epoch 152/300
# 5/5 - 0s - loss: 4.5815e-04 - 34ms/epoch - 7ms/step
# Epoch 153/300
# 5/5 - 0s - loss: 3.1399e-04 - 30ms/epoch - 6ms/step
# Epoch 154/300
# 5/5 - 0s - loss: 4.0820e-04 - 34ms/epoch - 7ms/step
# Epoch 155/300
# 5/5 - 0s - loss: 3.3039e-04 - 34ms/epoch - 7ms/step
# Epoch 156/300
# 5/5 - 0s - loss: 1.9488e-04 - 35ms/epoch - 7ms/step
# Epoch 157/300
# 5/5 - 0s - loss: 1.4350e-04 - 30ms/epoch - 6ms/step
# Epoch 158/300
# 5/5 - 0s - loss: 1.7419e-04 - 31ms/epoch - 6ms/step
# Epoch 159/300
# 5/5 - 0s - loss: 1.8808e-04 - 34ms/epoch - 7ms/step
# Epoch 160/300
# 5/5 - 0s - loss: 2.9552e-04 - 35ms/epoch - 7ms/step
# Epoch 161/300
# 5/5 - 0s - loss: 6.1304e-04 - 35ms/epoch - 7ms/step
# Epoch 162/300
# 5/5 - 0s - loss: 7.0336e-04 - 32ms/epoch - 6ms/step
# Epoch 163/300
# 5/5 - 0s - loss: 8.0830e-04 - 32ms/epoch - 6ms/step
# Epoch 164/300
# 5/5 - 0s - loss: 0.0018 - 36ms/epoch - 7ms/step
# Epoch 165/300
# 5/5 - 0s - loss: 0.0018 - 32ms/epoch - 6ms/step
# Epoch 166/300
# 5/5 - 0s - loss: 0.0022 - 33ms/epoch - 7ms/step
# Epoch 167/300
# 5/5 - 0s - loss: 0.0018 - 33ms/epoch - 7ms/step
# Epoch 168/300
# 5/5 - 0s - loss: 0.0027 - 35ms/epoch - 7ms/step
# Epoch 169/300
# 5/5 - 0s - loss: 0.0026 - 32ms/epoch - 6ms/step
# Epoch 170/300
# 5/5 - 0s - loss: 0.0020 - 33ms/epoch - 7ms/step
# Epoch 171/300
# 5/5 - 0s - loss: 0.0015 - 36ms/epoch - 7ms/step
# Epoch 172/300
# 5/5 - 0s - loss: 0.0011 - 40ms/epoch - 8ms/step
# Epoch 173/300
# 5/5 - 0s - loss: 0.0012 - 35ms/epoch - 7ms/step
# Epoch 174/300
# 5/5 - 0s - loss: 0.0013 - 38ms/epoch - 8ms/step
# Epoch 175/300
# 5/5 - 0s - loss: 8.1560e-04 - 35ms/epoch - 7ms/step
# Epoch 176/300
# 5/5 - 0s - loss: 8.7845e-04 - 38ms/epoch - 8ms/step
# Epoch 177/300
# 5/5 - 0s - loss: 0.0011 - 33ms/epoch - 7ms/step
# Epoch 178/300
# 5/5 - 0s - loss: 0.0021 - 36ms/epoch - 7ms/step
# Epoch 179/300
# 5/5 - 0s - loss: 0.0032 - 33ms/epoch - 7ms/step
# Epoch 180/300
# 5/5 - 0s - loss: 0.0028 - 35ms/epoch - 7ms/step
# Epoch 181/300
# 5/5 - 0s - loss: 0.0032 - 33ms/epoch - 7ms/step
# Epoch 182/300
# 5/5 - 0s - loss: 0.0029 - 35ms/epoch - 7ms/step
# Epoch 183/300
# 5/5 - 0s - loss: 0.0046 - 33ms/epoch - 7ms/step
# Epoch 184/300
# 5/5 - 0s - loss: 0.0055 - 37ms/epoch - 7ms/step
# Epoch 185/300
# 5/5 - 0s - loss: 0.0037 - 33ms/epoch - 7ms/step
# Epoch 186/300
# 5/5 - 0s - loss: 0.0026 - 34ms/epoch - 7ms/step
# Epoch 187/300
# 5/5 - 0s - loss: 0.0030 - 32ms/epoch - 6ms/step
# Epoch 188/300
# 5/5 - 0s - loss: 0.0039 - 33ms/epoch - 7ms/step
# Epoch 189/300
# 5/5 - 0s - loss: 0.0031 - 35ms/epoch - 7ms/step
# Epoch 190/300
# 5/5 - 0s - loss: 0.0017 - 32ms/epoch - 6ms/step
# Epoch 191/300
# 5/5 - 0s - loss: 0.0012 - 36ms/epoch - 7ms/step
# Epoch 192/300
# 5/5 - 0s - loss: 9.4932e-04 - 34ms/epoch - 7ms/step
# Epoch 193/300
# 5/5 - 0s - loss: 0.0015 - 36ms/epoch - 7ms/step
# Epoch 194/300
# 5/5 - 0s - loss: 0.0044 - 34ms/epoch - 7ms/step
# Epoch 195/300
# 5/5 - 0s - loss: 0.0029 - 33ms/epoch - 7ms/step
# Epoch 196/300
# 5/5 - 0s - loss: 0.0132 - 30ms/epoch - 6ms/step
# Epoch 197/300
# 5/5 - 0s - loss: 0.0261 - 31ms/epoch - 6ms/step
# Epoch 198/300
# 5/5 - 0s - loss: 0.0163 - 34ms/epoch - 7ms/step
# Epoch 199/300
# 5/5 - 0s - loss: 0.0397 - 32ms/epoch - 6ms/step
# Epoch 200/300
# 5/5 - 0s - loss: 0.0207 - 29ms/epoch - 6ms/step
# Epoch 201/300
# 5/5 - 0s - loss: 0.0136 - 35ms/epoch - 7ms/step
# Epoch 202/300
# 5/5 - 0s - loss: 0.0098 - 34ms/epoch - 7ms/step
# Epoch 203/300
# 5/5 - 0s - loss: 0.0104 - 32ms/epoch - 6ms/step
# Epoch 204/300
# 5/5 - 0s - loss: 0.0104 - 35ms/epoch - 7ms/step
# Epoch 205/300
# 5/5 - 0s - loss: 0.0131 - 34ms/epoch - 7ms/step
# Epoch 206/300
# 5/5 - 0s - loss: 0.0245 - 33ms/epoch - 7ms/step
# Epoch 207/300
# 5/5 - 0s - loss: 0.0169 - 33ms/epoch - 7ms/step
# Epoch 208/300
# 5/5 - 0s - loss: 0.0144 - 32ms/epoch - 6ms/step
# Epoch 209/300
# 5/5 - 0s - loss: 0.0150 - 32ms/epoch - 6ms/step
# Epoch 210/300
# 5/5 - 0s - loss: 0.0137 - 35ms/epoch - 7ms/step
# Epoch 211/300
# 5/5 - 0s - loss: 0.0078 - 34ms/epoch - 7ms/step
# Epoch 212/300
# 5/5 - 0s - loss: 0.0066 - 36ms/epoch - 7ms/step
# Epoch 213/300
# 5/5 - 0s - loss: 0.0052 - 33ms/epoch - 7ms/step
# Epoch 214/300
# 5/5 - 0s - loss: 0.0048 - 36ms/epoch - 7ms/step
# Epoch 215/300
# 5/5 - 0s - loss: 0.0034 - 35ms/epoch - 7ms/step
# Epoch 216/300
# 5/5 - 0s - loss: 0.0030 - 34ms/epoch - 7ms/step
# Epoch 217/300
# 5/5 - 0s - loss: 0.0041 - 34ms/epoch - 7ms/step
# Epoch 218/300
# 5/5 - 0s - loss: 0.0036 - 36ms/epoch - 7ms/step
# Epoch 219/300
# 5/5 - 0s - loss: 0.0030 - 33ms/epoch - 7ms/step
# Epoch 220/300
# 5/5 - 0s - loss: 0.0014 - 34ms/epoch - 7ms/step
# Epoch 221/300
# 5/5 - 0s - loss: 9.8606e-04 - 34ms/epoch - 7ms/step
# Epoch 222/300
# 5/5 - 0s - loss: 7.8579e-04 - 31ms/epoch - 6ms/step
# Epoch 223/300
# 5/5 - 0s - loss: 7.1681e-04 - 30ms/epoch - 6ms/step
# Epoch 224/300
# 5/5 - 0s - loss: 5.7910e-04 - 32ms/epoch - 6ms/step
# Epoch 225/300
# 5/5 - 0s - loss: 5.5842e-04 - 36ms/epoch - 7ms/step
# Epoch 226/300
# 5/5 - 0s - loss: 6.1474e-04 - 33ms/epoch - 7ms/step
# Epoch 227/300
# 5/5 - 0s - loss: 5.1230e-04 - 33ms/epoch - 7ms/step
# Epoch 228/300
# 5/5 - 0s - loss: 3.3513e-04 - 34ms/epoch - 7ms/step
# Epoch 229/300
# 5/5 - 0s - loss: 2.9216e-04 - 33ms/epoch - 7ms/step
# Epoch 230/300
# 5/5 - 0s - loss: 1.3459e-04 - 34ms/epoch - 7ms/step
# Epoch 231/300
# 5/5 - 0s - loss: 1.2804e-04 - 34ms/epoch - 7ms/step
# Epoch 232/300
# 5/5 - 0s - loss: 8.6553e-05 - 34ms/epoch - 7ms/step
# Epoch 233/300
# 5/5 - 0s - loss: 9.4305e-05 - 33ms/epoch - 7ms/step
# Epoch 234/300
# 5/5 - 0s - loss: 8.2800e-05 - 31ms/epoch - 6ms/step
# Epoch 235/300
# 5/5 - 0s - loss: 8.8622e-05 - 33ms/epoch - 7ms/step
# Epoch 236/300
# 5/5 - 0s - loss: 1.0928e-04 - 33ms/epoch - 7ms/step
# Epoch 237/300
# 5/5 - 0s - loss: 1.0709e-04 - 32ms/epoch - 6ms/step
# Epoch 238/300
# 5/5 - 0s - loss: 7.6406e-05 - 30ms/epoch - 6ms/step
# Epoch 239/300
# 5/5 - 0s - loss: 7.3631e-05 - 30ms/epoch - 6ms/step
# Epoch 240/300
# 5/5 - 0s - loss: 6.9543e-05 - 33ms/epoch - 7ms/step
# Epoch 241/300
# 5/5 - 0s - loss: 6.3788e-05 - 31ms/epoch - 6ms/step
# Epoch 242/300
# 5/5 - 0s - loss: 7.7967e-05 - 31ms/epoch - 6ms/step
# Epoch 243/300
# 5/5 - 0s - loss: 1.0828e-04 - 34ms/epoch - 7ms/step
# Epoch 244/300
# 5/5 - 0s - loss: 8.9005e-05 - 35ms/epoch - 7ms/step
# Epoch 245/300
# 5/5 - 0s - loss: 1.5717e-04 - 33ms/epoch - 7ms/step
# Epoch 246/300
# 5/5 - 0s - loss: 1.8074e-04 - 31ms/epoch - 6ms/step
# Epoch 247/300
# 5/5 - 0s - loss: 1.9882e-04 - 35ms/epoch - 7ms/step
# Epoch 248/300
# 5/5 - 0s - loss: 1.0720e-04 - 32ms/epoch - 6ms/step
# Epoch 249/300
# 5/5 - 0s - loss: 1.0990e-04 - 32ms/epoch - 6ms/step
# Epoch 250/300
# 5/5 - 0s - loss: 1.5356e-04 - 29ms/epoch - 6ms/step
# Epoch 251/300
# 5/5 - 0s - loss: 1.0924e-04 - 32ms/epoch - 6ms/step
# Epoch 252/300
# 5/5 - 0s - loss: 7.3964e-05 - 33ms/epoch - 7ms/step
# Epoch 253/300
# 5/5 - 0s - loss: 1.0658e-04 - 30ms/epoch - 6ms/step
# Epoch 254/300
# 5/5 - 0s - loss: 1.2845e-04 - 33ms/epoch - 7ms/step
# Epoch 255/300
# 5/5 - 0s - loss: 8.6873e-05 - 31ms/epoch - 6ms/step
# Epoch 256/300
# 5/5 - 0s - loss: 7.9659e-05 - 31ms/epoch - 6ms/step
# Epoch 257/300
# 5/5 - 0s - loss: 8.1398e-05 - 32ms/epoch - 6ms/step
# Epoch 258/300
# 5/5 - 0s - loss: 8.0929e-05 - 34ms/epoch - 7ms/step
# Epoch 259/300
# 5/5 - 0s - loss: 4.6492e-05 - 38ms/epoch - 8ms/step
# Epoch 260/300
# 5/5 - 0s - loss: 5.3360e-05 - 34ms/epoch - 7ms/step
# Epoch 261/300
# 5/5 - 0s - loss: 3.4951e-05 - 33ms/epoch - 7ms/step
# Epoch 262/300
# 5/5 - 0s - loss: 3.9806e-05 - 31ms/epoch - 6ms/step
# Epoch 263/300
# 5/5 - 0s - loss: 4.2345e-05 - 32ms/epoch - 6ms/step
# Epoch 264/300
# 5/5 - 0s - loss: 4.6251e-05 - 33ms/epoch - 7ms/step
# Epoch 265/300
# 5/5 - 0s - loss: 2.6224e-05 - 32ms/epoch - 6ms/step
# Epoch 266/300
# 5/5 - 0s - loss: 4.1356e-05 - 32ms/epoch - 6ms/step
# Epoch 267/300
# 5/5 - 0s - loss: 3.3695e-05 - 30ms/epoch - 6ms/step
# Epoch 268/300
# 5/5 - 0s - loss: 3.6279e-05 - 33ms/epoch - 7ms/step
# Epoch 269/300
# 5/5 - 0s - loss: 3.0781e-05 - 31ms/epoch - 6ms/step
# Epoch 270/300
# 5/5 - 0s - loss: 3.7956e-05 - 31ms/epoch - 6ms/step
# Epoch 271/300
# 5/5 - 0s - loss: 2.6884e-05 - 32ms/epoch - 6ms/step
# Epoch 272/300
# 5/5 - 0s - loss: 2.5212e-05 - 31ms/epoch - 6ms/step
# Epoch 273/300
# 5/5 - 0s - loss: 3.7689e-05 - 32ms/epoch - 6ms/step
# Epoch 274/300
# 5/5 - 0s - loss: 2.4569e-05 - 31ms/epoch - 6ms/step
# Epoch 275/300
# 5/5 - 0s - loss: 2.1397e-05 - 32ms/epoch - 6ms/step
# Epoch 276/300
# 5/5 - 0s - loss: 2.2112e-05 - 34ms/epoch - 7ms/step
# Epoch 277/300
# 5/5 - 0s - loss: 4.4498e-05 - 32ms/epoch - 6ms/step
# Epoch 278/300
# 5/5 - 0s - loss: 2.0470e-05 - 35ms/epoch - 7ms/step
# Epoch 279/300
# 5/5 - 0s - loss: 3.2979e-05 - 31ms/epoch - 6ms/step
# Epoch 280/300
# 5/5 - 0s - loss: 6.7997e-05 - 33ms/epoch - 7ms/step
# Epoch 281/300
# 5/5 - 0s - loss: 5.8679e-05 - 32ms/epoch - 6ms/step
# Epoch 282/300
# 5/5 - 0s - loss: 3.9329e-05 - 31ms/epoch - 6ms/step
# Epoch 283/300
# 5/5 - 0s - loss: 8.0184e-05 - 30ms/epoch - 6ms/step
# Epoch 284/300
# 5/5 - 0s - loss: 7.8344e-05 - 35ms/epoch - 7ms/step
# Epoch 285/300
# 5/5 - 0s - loss: 5.7126e-05 - 30ms/epoch - 6ms/step
# Epoch 286/300
# 5/5 - 0s - loss: 4.9949e-05 - 31ms/epoch - 6ms/step
# Epoch 287/300
# 5/5 - 0s - loss: 4.7788e-05 - 35ms/epoch - 7ms/step
# Epoch 288/300
# 5/5 - 0s - loss: 4.5755e-05 - 33ms/epoch - 7ms/step
# Epoch 289/300
# 5/5 - 0s - loss: 7.9292e-05 - 35ms/epoch - 7ms/step
# Epoch 290/300
# 5/5 - 0s - loss: 9.2971e-05 - 32ms/epoch - 6ms/step
# Epoch 291/300
# 5/5 - 0s - loss: 7.7009e-05 - 33ms/epoch - 7ms/step
# Epoch 292/300
# 5/5 - 0s - loss: 1.2236e-04 - 30ms/epoch - 6ms/step
# Epoch 293/300
# 5/5 - 0s - loss: 9.7285e-05 - 30ms/epoch - 6ms/step
# Epoch 294/300
# 5/5 - 0s - loss: 1.0648e-04 - 35ms/epoch - 7ms/step
# Epoch 295/300
# 5/5 - 0s - loss: 6.8011e-05 - 32ms/epoch - 6ms/step
# Epoch 296/300
# 5/5 - 0s - loss: 8.2152e-05 - 31ms/epoch - 6ms/step
# Epoch 297/300
# 5/5 - 0s - loss: 1.2084e-04 - 31ms/epoch - 6ms/step
# Epoch 298/300
# 5/5 - 0s - loss: 1.2389e-04 - 34ms/epoch - 7ms/step
# Epoch 299/300
# 5/5 - 0s - loss: 1.0841e-04 - 33ms/epoch - 7ms/step
# Epoch 300/300
# 5/5 - 0s - loss: 1.8240e-04 - 30ms/epoch - 6ms/step
# 14/14 [==============================] - 0s 2ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710203764.265952
# Tue Mar 12 00:36:04 2024
