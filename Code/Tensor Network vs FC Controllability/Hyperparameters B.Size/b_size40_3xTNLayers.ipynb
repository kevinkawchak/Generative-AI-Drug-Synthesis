# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_45 (Dense)            (None, 1024)              3072
#
#  dense_46 (Dense)            (None, 1024)              1049600
#
#  dense_47 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 1024)              3072
#
#  tn_layer_27 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_28 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_29 (TNLayer)       (None, 1024)              5120
#
#  dense_49 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(20, 2) + np.array([3, 3]),
                    np.random.randn(20, 2) + np.array([-3, -3]),
                    np.random.randn(20, 2) + np.array([-3, 3]),
                    np.random.randn(20, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((40)), -np.ones((40))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710204004.9781735
# Tue Mar 12 00:40:04 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2, batch_size=40)
# Out:
# Epoch 1/300
# 2/2 - 2s - loss: 1.0018 - 2s/epoch - 1s/step
# Epoch 2/300
# 2/2 - 0s - loss: 1.0004 - 12ms/epoch - 6ms/step
# Epoch 3/300
# 2/2 - 0s - loss: 1.0008 - 14ms/epoch - 7ms/step
# Epoch 4/300
# 2/2 - 0s - loss: 0.9999 - 14ms/epoch - 7ms/step
# Epoch 5/300
# 2/2 - 0s - loss: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 6/300
# 2/2 - 0s - loss: 0.9998 - 13ms/epoch - 6ms/step
# Epoch 7/300
# 2/2 - 0s - loss: 0.9995 - 14ms/epoch - 7ms/step
# Epoch 8/300
# 2/2 - 0s - loss: 0.9991 - 14ms/epoch - 7ms/step
# Epoch 9/300
# 2/2 - 0s - loss: 0.9985 - 13ms/epoch - 6ms/step
# Epoch 10/300
# 2/2 - 0s - loss: 0.9975 - 11ms/epoch - 6ms/step
# Epoch 11/300
# 2/2 - 0s - loss: 0.9959 - 13ms/epoch - 7ms/step
# Epoch 12/300
# 2/2 - 0s - loss: 0.9929 - 14ms/epoch - 7ms/step
# Epoch 13/300
# 2/2 - 0s - loss: 0.9881 - 12ms/epoch - 6ms/step
# Epoch 14/300
# 2/2 - 0s - loss: 0.9805 - 13ms/epoch - 6ms/step
# Epoch 15/300
# 2/2 - 0s - loss: 0.9668 - 15ms/epoch - 8ms/step
# Epoch 16/300
# 2/2 - 0s - loss: 0.9444 - 13ms/epoch - 7ms/step
# Epoch 17/300
# 2/2 - 0s - loss: 0.9082 - 13ms/epoch - 7ms/step
# Epoch 18/300
# 2/2 - 0s - loss: 0.8516 - 13ms/epoch - 6ms/step
# Epoch 19/300
# 2/2 - 0s - loss: 0.7640 - 14ms/epoch - 7ms/step
# Epoch 20/300
# 2/2 - 0s - loss: 0.6352 - 13ms/epoch - 6ms/step
# Epoch 21/300
# 2/2 - 0s - loss: 0.4583 - 14ms/epoch - 7ms/step
# Epoch 22/300
# 2/2 - 0s - loss: 0.2467 - 13ms/epoch - 7ms/step
# Epoch 23/300
# 2/2 - 0s - loss: 0.0611 - 14ms/epoch - 7ms/step
# Epoch 24/300
# 2/2 - 0s - loss: 0.0909 - 12ms/epoch - 6ms/step
# Epoch 25/300
# 2/2 - 0s - loss: 0.1589 - 15ms/epoch - 8ms/step
# Epoch 26/300
# 2/2 - 0s - loss: 0.0718 - 14ms/epoch - 7ms/step
# Epoch 27/300
# 2/2 - 0s - loss: 0.0198 - 13ms/epoch - 7ms/step
# Epoch 28/300
# 2/2 - 0s - loss: 0.0233 - 13ms/epoch - 6ms/step
# Epoch 29/300
# 2/2 - 0s - loss: 0.0384 - 13ms/epoch - 6ms/step
# Epoch 30/300
# 2/2 - 0s - loss: 0.0446 - 14ms/epoch - 7ms/step
# Epoch 31/300
# 2/2 - 0s - loss: 0.0389 - 13ms/epoch - 6ms/step
# Epoch 32/300
# 2/2 - 0s - loss: 0.0265 - 13ms/epoch - 7ms/step
# Epoch 33/300
# 2/2 - 0s - loss: 0.0151 - 13ms/epoch - 7ms/step
# Epoch 34/300
# 2/2 - 0s - loss: 0.0107 - 13ms/epoch - 6ms/step
# Epoch 35/300
# 2/2 - 0s - loss: 0.0125 - 12ms/epoch - 6ms/step
# Epoch 36/300
# 2/2 - 0s - loss: 0.0158 - 14ms/epoch - 7ms/step
# Epoch 37/300
# 2/2 - 0s - loss: 0.0156 - 13ms/epoch - 6ms/step
# Epoch 38/300
# 2/2 - 0s - loss: 0.0120 - 13ms/epoch - 7ms/step
# Epoch 39/300
# 2/2 - 0s - loss: 0.0087 - 13ms/epoch - 7ms/step
# Epoch 40/300
# 2/2 - 0s - loss: 0.0076 - 13ms/epoch - 6ms/step
# Epoch 41/300
# 2/2 - 0s - loss: 0.0080 - 13ms/epoch - 7ms/step
# Epoch 42/300
# 2/2 - 0s - loss: 0.0088 - 13ms/epoch - 6ms/step
# Epoch 43/300
# 2/2 - 0s - loss: 0.0086 - 13ms/epoch - 7ms/step
# Epoch 44/300
# 2/2 - 0s - loss: 0.0080 - 14ms/epoch - 7ms/step
# Epoch 45/300
# 2/2 - 0s - loss: 0.0068 - 14ms/epoch - 7ms/step
# Epoch 46/300
# 2/2 - 0s - loss: 0.0062 - 15ms/epoch - 7ms/step
# Epoch 47/300
# 2/2 - 0s - loss: 0.0062 - 15ms/epoch - 7ms/step
# Epoch 48/300
# 2/2 - 0s - loss: 0.0062 - 13ms/epoch - 7ms/step
# Epoch 49/300
# 2/2 - 0s - loss: 0.0061 - 15ms/epoch - 7ms/step
# Epoch 50/300
# 2/2 - 0s - loss: 0.0059 - 14ms/epoch - 7ms/step
# Epoch 51/300
# 2/2 - 0s - loss: 0.0055 - 13ms/epoch - 7ms/step
# Epoch 52/300
# 2/2 - 0s - loss: 0.0053 - 14ms/epoch - 7ms/step
# Epoch 53/300
# 2/2 - 0s - loss: 0.0052 - 14ms/epoch - 7ms/step
# Epoch 54/300
# 2/2 - 0s - loss: 0.0051 - 12ms/epoch - 6ms/step
# Epoch 55/300
# 2/2 - 0s - loss: 0.0051 - 12ms/epoch - 6ms/step
# Epoch 56/300
# 2/2 - 0s - loss: 0.0050 - 12ms/epoch - 6ms/step
# Epoch 57/300
# 2/2 - 0s - loss: 0.0048 - 13ms/epoch - 6ms/step
# Epoch 58/300
# 2/2 - 0s - loss: 0.0047 - 14ms/epoch - 7ms/step
# Epoch 59/300
# 2/2 - 0s - loss: 0.0046 - 13ms/epoch - 6ms/step
# Epoch 60/300
# 2/2 - 0s - loss: 0.0045 - 13ms/epoch - 6ms/step
# Epoch 61/300
# 2/2 - 0s - loss: 0.0045 - 13ms/epoch - 6ms/step
# Epoch 62/300
# 2/2 - 0s - loss: 0.0044 - 13ms/epoch - 7ms/step
# Epoch 63/300
# 2/2 - 0s - loss: 0.0043 - 13ms/epoch - 7ms/step
# Epoch 64/300
# 2/2 - 0s - loss: 0.0042 - 12ms/epoch - 6ms/step
# Epoch 65/300
# 2/2 - 0s - loss: 0.0041 - 12ms/epoch - 6ms/step
# Epoch 66/300
# 2/2 - 0s - loss: 0.0041 - 12ms/epoch - 6ms/step
# Epoch 67/300
# 2/2 - 0s - loss: 0.0040 - 13ms/epoch - 6ms/step
# Epoch 68/300
# 2/2 - 0s - loss: 0.0039 - 13ms/epoch - 6ms/step
# Epoch 69/300
# 2/2 - 0s - loss: 0.0038 - 13ms/epoch - 7ms/step
# Epoch 70/300
# 2/2 - 0s - loss: 0.0038 - 13ms/epoch - 7ms/step
# Epoch 71/300
# 2/2 - 0s - loss: 0.0037 - 12ms/epoch - 6ms/step
# Epoch 72/300
# 2/2 - 0s - loss: 0.0036 - 12ms/epoch - 6ms/step
# Epoch 73/300
# 2/2 - 0s - loss: 0.0036 - 12ms/epoch - 6ms/step
# Epoch 74/300
# 2/2 - 0s - loss: 0.0035 - 13ms/epoch - 6ms/step
# Epoch 75/300
# 2/2 - 0s - loss: 0.0035 - 12ms/epoch - 6ms/step
# Epoch 76/300
# 2/2 - 0s - loss: 0.0034 - 11ms/epoch - 5ms/step
# Epoch 77/300
# 2/2 - 0s - loss: 0.0034 - 13ms/epoch - 7ms/step
# Epoch 78/300
# 2/2 - 0s - loss: 0.0033 - 15ms/epoch - 7ms/step
# Epoch 79/300
# 2/2 - 0s - loss: 0.0032 - 12ms/epoch - 6ms/step
# Epoch 80/300
# 2/2 - 0s - loss: 0.0032 - 13ms/epoch - 6ms/step
# Epoch 81/300
# 2/2 - 0s - loss: 0.0031 - 12ms/epoch - 6ms/step
# Epoch 82/300
# 2/2 - 0s - loss: 0.0031 - 11ms/epoch - 6ms/step
# Epoch 83/300
# 2/2 - 0s - loss: 0.0031 - 14ms/epoch - 7ms/step
# Epoch 84/300
# 2/2 - 0s - loss: 0.0030 - 13ms/epoch - 6ms/step
# Epoch 85/300
# 2/2 - 0s - loss: 0.0029 - 13ms/epoch - 7ms/step
# Epoch 86/300
# 2/2 - 0s - loss: 0.0029 - 16ms/epoch - 8ms/step
# Epoch 87/300
# 2/2 - 0s - loss: 0.0028 - 13ms/epoch - 7ms/step
# Epoch 88/300
# 2/2 - 0s - loss: 0.0028 - 13ms/epoch - 6ms/step
# Epoch 89/300
# 2/2 - 0s - loss: 0.0028 - 13ms/epoch - 6ms/step
# Epoch 90/300
# 2/2 - 0s - loss: 0.0027 - 13ms/epoch - 6ms/step
# Epoch 91/300
# 2/2 - 0s - loss: 0.0027 - 12ms/epoch - 6ms/step
# Epoch 92/300
# 2/2 - 0s - loss: 0.0026 - 13ms/epoch - 7ms/step
# Epoch 93/300
# 2/2 - 0s - loss: 0.0026 - 13ms/epoch - 7ms/step
# Epoch 94/300
# 2/2 - 0s - loss: 0.0025 - 13ms/epoch - 7ms/step
# Epoch 95/300
# 2/2 - 0s - loss: 0.0025 - 12ms/epoch - 6ms/step
# Epoch 96/300
# 2/2 - 0s - loss: 0.0025 - 13ms/epoch - 7ms/step
# Epoch 97/300
# 2/2 - 0s - loss: 0.0024 - 14ms/epoch - 7ms/step
# Epoch 98/300
# 2/2 - 0s - loss: 0.0024 - 14ms/epoch - 7ms/step
# Epoch 99/300
# 2/2 - 0s - loss: 0.0024 - 14ms/epoch - 7ms/step
# Epoch 100/300
# 2/2 - 0s - loss: 0.0023 - 12ms/epoch - 6ms/step
# Epoch 101/300
# 2/2 - 0s - loss: 0.0023 - 13ms/epoch - 7ms/step
# Epoch 102/300
# 2/2 - 0s - loss: 0.0023 - 12ms/epoch - 6ms/step
# Epoch 103/300
# 2/2 - 0s - loss: 0.0022 - 12ms/epoch - 6ms/step
# Epoch 104/300
# 2/2 - 0s - loss: 0.0022 - 12ms/epoch - 6ms/step
# Epoch 105/300
# 2/2 - 0s - loss: 0.0021 - 13ms/epoch - 7ms/step
# Epoch 106/300
# 2/2 - 0s - loss: 0.0021 - 12ms/epoch - 6ms/step
# Epoch 107/300
# 2/2 - 0s - loss: 0.0021 - 13ms/epoch - 6ms/step
# Epoch 108/300
# 2/2 - 0s - loss: 0.0020 - 12ms/epoch - 6ms/step
# Epoch 109/300
# 2/2 - 0s - loss: 0.0020 - 13ms/epoch - 6ms/step
# Epoch 110/300
# 2/2 - 0s - loss: 0.0020 - 13ms/epoch - 6ms/step
# Epoch 111/300
# 2/2 - 0s - loss: 0.0020 - 12ms/epoch - 6ms/step
# Epoch 112/300
# 2/2 - 0s - loss: 0.0019 - 12ms/epoch - 6ms/step
# Epoch 113/300
# 2/2 - 0s - loss: 0.0019 - 13ms/epoch - 6ms/step
# Epoch 114/300
# 2/2 - 0s - loss: 0.0019 - 13ms/epoch - 6ms/step
# Epoch 115/300
# 2/2 - 0s - loss: 0.0018 - 12ms/epoch - 6ms/step
# Epoch 116/300
# 2/2 - 0s - loss: 0.0018 - 13ms/epoch - 7ms/step
# Epoch 117/300
# 2/2 - 0s - loss: 0.0018 - 12ms/epoch - 6ms/step
# Epoch 118/300
# 2/2 - 0s - loss: 0.0018 - 13ms/epoch - 7ms/step
# Epoch 119/300
# 2/2 - 0s - loss: 0.0017 - 13ms/epoch - 6ms/step
# Epoch 120/300
# 2/2 - 0s - loss: 0.0017 - 12ms/epoch - 6ms/step
# Epoch 121/300
# 2/2 - 0s - loss: 0.0017 - 13ms/epoch - 7ms/step
# Epoch 122/300
# 2/2 - 0s - loss: 0.0016 - 13ms/epoch - 7ms/step
# Epoch 123/300
# 2/2 - 0s - loss: 0.0016 - 13ms/epoch - 6ms/step
# Epoch 124/300
# 2/2 - 0s - loss: 0.0016 - 12ms/epoch - 6ms/step
# Epoch 125/300
# 2/2 - 0s - loss: 0.0016 - 13ms/epoch - 6ms/step
# Epoch 126/300
# 2/2 - 0s - loss: 0.0015 - 13ms/epoch - 7ms/step
# Epoch 127/300
# 2/2 - 0s - loss: 0.0015 - 12ms/epoch - 6ms/step
# Epoch 128/300
# 2/2 - 0s - loss: 0.0015 - 12ms/epoch - 6ms/step
# Epoch 129/300
# 2/2 - 0s - loss: 0.0015 - 14ms/epoch - 7ms/step
# Epoch 130/300
# 2/2 - 0s - loss: 0.0014 - 13ms/epoch - 7ms/step
# Epoch 131/300
# 2/2 - 0s - loss: 0.0014 - 13ms/epoch - 6ms/step
# Epoch 132/300
# 2/2 - 0s - loss: 0.0014 - 13ms/epoch - 7ms/step
# Epoch 133/300
# 2/2 - 0s - loss: 0.0014 - 13ms/epoch - 6ms/step
# Epoch 134/300
# 2/2 - 0s - loss: 0.0014 - 12ms/epoch - 6ms/step
# Epoch 135/300
# 2/2 - 0s - loss: 0.0013 - 13ms/epoch - 7ms/step
# Epoch 136/300
# 2/2 - 0s - loss: 0.0013 - 12ms/epoch - 6ms/step
# Epoch 137/300
# 2/2 - 0s - loss: 0.0013 - 12ms/epoch - 6ms/step
# Epoch 138/300
# 2/2 - 0s - loss: 0.0013 - 12ms/epoch - 6ms/step
# Epoch 139/300
# 2/2 - 0s - loss: 0.0013 - 12ms/epoch - 6ms/step
# Epoch 140/300
# 2/2 - 0s - loss: 0.0012 - 11ms/epoch - 6ms/step
# Epoch 141/300
# 2/2 - 0s - loss: 0.0012 - 13ms/epoch - 6ms/step
# Epoch 142/300
# 2/2 - 0s - loss: 0.0012 - 12ms/epoch - 6ms/step
# Epoch 143/300
# 2/2 - 0s - loss: 0.0012 - 13ms/epoch - 6ms/step
# Epoch 144/300
# 2/2 - 0s - loss: 0.0012 - 13ms/epoch - 6ms/step
# Epoch 145/300
# 2/2 - 0s - loss: 0.0011 - 14ms/epoch - 7ms/step
# Epoch 146/300
# 2/2 - 0s - loss: 0.0011 - 12ms/epoch - 6ms/step
# Epoch 147/300
# 2/2 - 0s - loss: 0.0011 - 12ms/epoch - 6ms/step
# Epoch 148/300
# 2/2 - 0s - loss: 0.0011 - 13ms/epoch - 6ms/step
# Epoch 149/300
# 2/2 - 0s - loss: 0.0011 - 13ms/epoch - 6ms/step
# Epoch 150/300
# 2/2 - 0s - loss: 0.0011 - 12ms/epoch - 6ms/step
# Epoch 151/300
# 2/2 - 0s - loss: 0.0010 - 11ms/epoch - 6ms/step
# Epoch 152/300
# 2/2 - 0s - loss: 0.0010 - 12ms/epoch - 6ms/step
# Epoch 153/300
# 2/2 - 0s - loss: 9.9066e-04 - 13ms/epoch - 6ms/step
# Epoch 154/300
# 2/2 - 0s - loss: 9.9088e-04 - 12ms/epoch - 6ms/step
# Epoch 155/300
# 2/2 - 0s - loss: 9.6892e-04 - 13ms/epoch - 7ms/step
# Epoch 156/300
# 2/2 - 0s - loss: 9.4081e-04 - 12ms/epoch - 6ms/step
# Epoch 157/300
# 2/2 - 0s - loss: 9.5921e-04 - 12ms/epoch - 6ms/step
# Epoch 158/300
# 2/2 - 0s - loss: 9.2119e-04 - 11ms/epoch - 6ms/step
# Epoch 159/300
# 2/2 - 0s - loss: 9.0693e-04 - 11ms/epoch - 6ms/step
# Epoch 160/300
# 2/2 - 0s - loss: 8.7762e-04 - 13ms/epoch - 6ms/step
# Epoch 161/300
# 2/2 - 0s - loss: 8.7253e-04 - 12ms/epoch - 6ms/step
# Epoch 162/300
# 2/2 - 0s - loss: 8.4898e-04 - 12ms/epoch - 6ms/step
# Epoch 163/300
# 2/2 - 0s - loss: 8.4771e-04 - 13ms/epoch - 6ms/step
# Epoch 164/300
# 2/2 - 0s - loss: 8.2355e-04 - 12ms/epoch - 6ms/step
# Epoch 165/300
# 2/2 - 0s - loss: 8.1426e-04 - 13ms/epoch - 6ms/step
# Epoch 166/300
# 2/2 - 0s - loss: 7.8727e-04 - 13ms/epoch - 6ms/step
# Epoch 167/300
# 2/2 - 0s - loss: 7.7495e-04 - 13ms/epoch - 6ms/step
# Epoch 168/300
# 2/2 - 0s - loss: 7.5905e-04 - 13ms/epoch - 6ms/step
# Epoch 169/300
# 2/2 - 0s - loss: 7.4942e-04 - 12ms/epoch - 6ms/step
# Epoch 170/300
# 2/2 - 0s - loss: 7.3148e-04 - 12ms/epoch - 6ms/step
# Epoch 171/300
# 2/2 - 0s - loss: 7.1553e-04 - 13ms/epoch - 6ms/step
# Epoch 172/300
# 2/2 - 0s - loss: 7.0314e-04 - 14ms/epoch - 7ms/step
# Epoch 173/300
# 2/2 - 0s - loss: 6.9289e-04 - 13ms/epoch - 7ms/step
# Epoch 174/300
# 2/2 - 0s - loss: 6.8153e-04 - 13ms/epoch - 7ms/step
# Epoch 175/300
# 2/2 - 0s - loss: 6.6569e-04 - 13ms/epoch - 7ms/step
# Epoch 176/300
# 2/2 - 0s - loss: 6.5437e-04 - 13ms/epoch - 6ms/step
# Epoch 177/300
# 2/2 - 0s - loss: 6.4097e-04 - 13ms/epoch - 6ms/step
# Epoch 178/300
# 2/2 - 0s - loss: 6.2888e-04 - 12ms/epoch - 6ms/step
# Epoch 179/300
# 2/2 - 0s - loss: 6.1325e-04 - 13ms/epoch - 6ms/step
# Epoch 180/300
# 2/2 - 0s - loss: 6.0252e-04 - 13ms/epoch - 7ms/step
# Epoch 181/300
# 2/2 - 0s - loss: 5.9044e-04 - 13ms/epoch - 7ms/step
# Epoch 182/300
# 2/2 - 0s - loss: 5.7454e-04 - 14ms/epoch - 7ms/step
# Epoch 183/300
# 2/2 - 0s - loss: 5.6371e-04 - 13ms/epoch - 7ms/step
# Epoch 184/300
# 2/2 - 0s - loss: 5.5596e-04 - 14ms/epoch - 7ms/step
# Epoch 185/300
# 2/2 - 0s - loss: 5.4213e-04 - 12ms/epoch - 6ms/step
# Epoch 186/300
# 2/2 - 0s - loss: 5.2730e-04 - 12ms/epoch - 6ms/step
# Epoch 187/300
# 2/2 - 0s - loss: 5.2067e-04 - 12ms/epoch - 6ms/step
# Epoch 188/300
# 2/2 - 0s - loss: 5.0642e-04 - 15ms/epoch - 7ms/step
# Epoch 189/300
# 2/2 - 0s - loss: 4.9523e-04 - 13ms/epoch - 7ms/step
# Epoch 190/300
# 2/2 - 0s - loss: 4.8923e-04 - 13ms/epoch - 6ms/step
# Epoch 191/300
# 2/2 - 0s - loss: 4.8048e-04 - 13ms/epoch - 6ms/step
# Epoch 192/300
# 2/2 - 0s - loss: 4.6714e-04 - 12ms/epoch - 6ms/step
# Epoch 193/300
# 2/2 - 0s - loss: 4.5219e-04 - 12ms/epoch - 6ms/step
# Epoch 194/300
# 2/2 - 0s - loss: 4.4358e-04 - 14ms/epoch - 7ms/step
# Epoch 195/300
# 2/2 - 0s - loss: 4.3634e-04 - 13ms/epoch - 6ms/step
# Epoch 196/300
# 2/2 - 0s - loss: 4.2352e-04 - 12ms/epoch - 6ms/step
# Epoch 197/300
# 2/2 - 0s - loss: 4.1581e-04 - 13ms/epoch - 6ms/step
# Epoch 198/300
# 2/2 - 0s - loss: 4.0714e-04 - 12ms/epoch - 6ms/step
# Epoch 199/300
# 2/2 - 0s - loss: 3.9878e-04 - 12ms/epoch - 6ms/step
# Epoch 200/300
# 2/2 - 0s - loss: 3.9104e-04 - 13ms/epoch - 6ms/step
# Epoch 201/300
# 2/2 - 0s - loss: 3.8342e-04 - 13ms/epoch - 6ms/step
# Epoch 202/300
# 2/2 - 0s - loss: 3.6909e-04 - 11ms/epoch - 6ms/step
# Epoch 203/300
# 2/2 - 0s - loss: 3.6798e-04 - 13ms/epoch - 6ms/step
# Epoch 204/300
# 2/2 - 0s - loss: 3.5404e-04 - 13ms/epoch - 6ms/step
# Epoch 205/300
# 2/2 - 0s - loss: 3.5025e-04 - 13ms/epoch - 6ms/step
# Epoch 206/300
# 2/2 - 0s - loss: 3.4290e-04 - 15ms/epoch - 7ms/step
# Epoch 207/300
# 2/2 - 0s - loss: 3.3134e-04 - 12ms/epoch - 6ms/step
# Epoch 208/300
# 2/2 - 0s - loss: 3.2391e-04 - 13ms/epoch - 6ms/step
# Epoch 209/300
# 2/2 - 0s - loss: 3.1416e-04 - 13ms/epoch - 6ms/step
# Epoch 210/300
# 2/2 - 0s - loss: 3.0571e-04 - 13ms/epoch - 6ms/step
# Epoch 211/300
# 2/2 - 0s - loss: 3.0203e-04 - 12ms/epoch - 6ms/step
# Epoch 212/300
# 2/2 - 0s - loss: 2.9237e-04 - 14ms/epoch - 7ms/step
# Epoch 213/300
# 2/2 - 0s - loss: 2.8350e-04 - 13ms/epoch - 6ms/step
# Epoch 214/300
# 2/2 - 0s - loss: 2.7684e-04 - 12ms/epoch - 6ms/step
# Epoch 215/300
# 2/2 - 0s - loss: 2.6826e-04 - 13ms/epoch - 6ms/step
# Epoch 216/300
# 2/2 - 0s - loss: 2.6162e-04 - 12ms/epoch - 6ms/step
# Epoch 217/300
# 2/2 - 0s - loss: 2.6146e-04 - 12ms/epoch - 6ms/step
# Epoch 218/300
# 2/2 - 0s - loss: 2.5002e-04 - 12ms/epoch - 6ms/step
# Epoch 219/300
# 2/2 - 0s - loss: 2.5653e-04 - 12ms/epoch - 6ms/step
# Epoch 220/300
# 2/2 - 0s - loss: 2.4361e-04 - 13ms/epoch - 7ms/step
# Epoch 221/300
# 2/2 - 0s - loss: 2.3203e-04 - 14ms/epoch - 7ms/step
# Epoch 222/300
# 2/2 - 0s - loss: 2.2626e-04 - 12ms/epoch - 6ms/step
# Epoch 223/300
# 2/2 - 0s - loss: 2.1946e-04 - 13ms/epoch - 7ms/step
# Epoch 224/300
# 2/2 - 0s - loss: 2.1469e-04 - 13ms/epoch - 7ms/step
# Epoch 225/300
# 2/2 - 0s - loss: 2.1262e-04 - 13ms/epoch - 6ms/step
# Epoch 226/300
# 2/2 - 0s - loss: 2.0174e-04 - 13ms/epoch - 6ms/step
# Epoch 227/300
# 2/2 - 0s - loss: 1.9537e-04 - 13ms/epoch - 6ms/step
# Epoch 228/300
# 2/2 - 0s - loss: 1.9570e-04 - 13ms/epoch - 6ms/step
# Epoch 229/300
# 2/2 - 0s - loss: 1.8925e-04 - 13ms/epoch - 7ms/step
# Epoch 230/300
# 2/2 - 0s - loss: 1.8531e-04 - 13ms/epoch - 7ms/step
# Epoch 231/300
# 2/2 - 0s - loss: 1.8126e-04 - 12ms/epoch - 6ms/step
# Epoch 232/300
# 2/2 - 0s - loss: 1.7173e-04 - 13ms/epoch - 6ms/step
# Epoch 233/300
# 2/2 - 0s - loss: 1.6654e-04 - 13ms/epoch - 7ms/step
# Epoch 234/300
# 2/2 - 0s - loss: 1.6295e-04 - 12ms/epoch - 6ms/step
# Epoch 235/300
# 2/2 - 0s - loss: 1.5880e-04 - 12ms/epoch - 6ms/step
# Epoch 236/300
# 2/2 - 0s - loss: 1.5599e-04 - 13ms/epoch - 6ms/step
# Epoch 237/300
# 2/2 - 0s - loss: 1.5007e-04 - 11ms/epoch - 6ms/step
# Epoch 238/300
# 2/2 - 0s - loss: 1.4646e-04 - 12ms/epoch - 6ms/step
# Epoch 239/300
# 2/2 - 0s - loss: 1.4330e-04 - 12ms/epoch - 6ms/step
# Epoch 240/300
# 2/2 - 0s - loss: 1.3851e-04 - 12ms/epoch - 6ms/step
# Epoch 241/300
# 2/2 - 0s - loss: 1.3503e-04 - 12ms/epoch - 6ms/step
# Epoch 242/300
# 2/2 - 0s - loss: 1.3085e-04 - 12ms/epoch - 6ms/step
# Epoch 243/300
# 2/2 - 0s - loss: 1.2727e-04 - 14ms/epoch - 7ms/step
# Epoch 244/300
# 2/2 - 0s - loss: 1.2502e-04 - 12ms/epoch - 6ms/step
# Epoch 245/300
# 2/2 - 0s - loss: 1.2024e-04 - 12ms/epoch - 6ms/step
# Epoch 246/300
# 2/2 - 0s - loss: 1.1730e-04 - 13ms/epoch - 6ms/step
# Epoch 247/300
# 2/2 - 0s - loss: 1.1444e-04 - 12ms/epoch - 6ms/step
# Epoch 248/300
# 2/2 - 0s - loss: 1.0978e-04 - 13ms/epoch - 6ms/step
# Epoch 249/300
# 2/2 - 0s - loss: 1.0727e-04 - 13ms/epoch - 7ms/step
# Epoch 250/300
# 2/2 - 0s - loss: 1.0471e-04 - 13ms/epoch - 6ms/step
# Epoch 251/300
# 2/2 - 0s - loss: 1.0138e-04 - 12ms/epoch - 6ms/step
# Epoch 252/300
# 2/2 - 0s - loss: 9.8336e-05 - 12ms/epoch - 6ms/step
# Epoch 253/300
# 2/2 - 0s - loss: 9.7477e-05 - 12ms/epoch - 6ms/step
# Epoch 254/300
# 2/2 - 0s - loss: 9.3327e-05 - 12ms/epoch - 6ms/step
# Epoch 255/300
# 2/2 - 0s - loss: 9.1684e-05 - 13ms/epoch - 6ms/step
# Epoch 256/300
# 2/2 - 0s - loss: 8.7510e-05 - 14ms/epoch - 7ms/step
# Epoch 257/300
# 2/2 - 0s - loss: 8.4630e-05 - 13ms/epoch - 6ms/step
# Epoch 258/300
# 2/2 - 0s - loss: 8.5052e-05 - 12ms/epoch - 6ms/step
# Epoch 259/300
# 2/2 - 0s - loss: 8.0174e-05 - 13ms/epoch - 7ms/step
# Epoch 260/300
# 2/2 - 0s - loss: 7.8518e-05 - 13ms/epoch - 6ms/step
# Epoch 261/300
# 2/2 - 0s - loss: 7.5508e-05 - 13ms/epoch - 7ms/step
# Epoch 262/300
# 2/2 - 0s - loss: 7.3577e-05 - 13ms/epoch - 7ms/step
# Epoch 263/300
# 2/2 - 0s - loss: 7.1005e-05 - 13ms/epoch - 6ms/step
# Epoch 264/300
# 2/2 - 0s - loss: 6.9465e-05 - 13ms/epoch - 6ms/step
# Epoch 265/300
# 2/2 - 0s - loss: 6.6921e-05 - 12ms/epoch - 6ms/step
# Epoch 266/300
# 2/2 - 0s - loss: 6.4258e-05 - 12ms/epoch - 6ms/step
# Epoch 267/300
# 2/2 - 0s - loss: 6.2881e-05 - 13ms/epoch - 6ms/step
# Epoch 268/300
# 2/2 - 0s - loss: 6.0732e-05 - 12ms/epoch - 6ms/step
# Epoch 269/300
# 2/2 - 0s - loss: 5.8558e-05 - 13ms/epoch - 6ms/step
# Epoch 270/300
# 2/2 - 0s - loss: 5.7335e-05 - 12ms/epoch - 6ms/step
# Epoch 271/300
# 2/2 - 0s - loss: 5.5587e-05 - 13ms/epoch - 7ms/step
# Epoch 272/300
# 2/2 - 0s - loss: 5.3280e-05 - 14ms/epoch - 7ms/step
# Epoch 273/300
# 2/2 - 0s - loss: 5.2066e-05 - 13ms/epoch - 6ms/step
# Epoch 274/300
# 2/2 - 0s - loss: 4.9716e-05 - 13ms/epoch - 6ms/step
# Epoch 275/300
# 2/2 - 0s - loss: 4.8171e-05 - 12ms/epoch - 6ms/step
# Epoch 276/300
# 2/2 - 0s - loss: 4.6970e-05 - 13ms/epoch - 7ms/step
# Epoch 277/300
# 2/2 - 0s - loss: 4.5334e-05 - 13ms/epoch - 7ms/step
# Epoch 278/300
# 2/2 - 0s - loss: 4.3553e-05 - 12ms/epoch - 6ms/step
# Epoch 279/300
# 2/2 - 0s - loss: 4.2073e-05 - 12ms/epoch - 6ms/step
# Epoch 280/300
# 2/2 - 0s - loss: 4.1891e-05 - 14ms/epoch - 7ms/step
# Epoch 281/300
# 2/2 - 0s - loss: 3.9647e-05 - 12ms/epoch - 6ms/step
# Epoch 282/300
# 2/2 - 0s - loss: 3.8335e-05 - 14ms/epoch - 7ms/step
# Epoch 283/300
# 2/2 - 0s - loss: 3.6775e-05 - 14ms/epoch - 7ms/step
# Epoch 284/300
# 2/2 - 0s - loss: 3.6090e-05 - 13ms/epoch - 6ms/step
# Epoch 285/300
# 2/2 - 0s - loss: 3.4648e-05 - 14ms/epoch - 7ms/step
# Epoch 286/300
# 2/2 - 0s - loss: 3.3406e-05 - 12ms/epoch - 6ms/step
# Epoch 287/300
# 2/2 - 0s - loss: 3.2484e-05 - 12ms/epoch - 6ms/step
# Epoch 288/300
# 2/2 - 0s - loss: 3.0991e-05 - 15ms/epoch - 7ms/step
# Epoch 289/300
# 2/2 - 0s - loss: 3.0272e-05 - 14ms/epoch - 7ms/step
# Epoch 290/300
# 2/2 - 0s - loss: 2.9246e-05 - 13ms/epoch - 6ms/step
# Epoch 291/300
# 2/2 - 0s - loss: 2.7854e-05 - 14ms/epoch - 7ms/step
# Epoch 292/300
# 2/2 - 0s - loss: 2.7188e-05 - 16ms/epoch - 8ms/step
# Epoch 293/300
# 2/2 - 0s - loss: 2.6153e-05 - 14ms/epoch - 7ms/step
# Epoch 294/300
# 2/2 - 0s - loss: 2.5168e-05 - 14ms/epoch - 7ms/step
# Epoch 295/300
# 2/2 - 0s - loss: 2.4376e-05 - 14ms/epoch - 7ms/step
# Epoch 296/300
# 2/2 - 0s - loss: 2.3603e-05 - 13ms/epoch - 7ms/step
# Epoch 297/300
# 2/2 - 0s - loss: 2.2838e-05 - 14ms/epoch - 7ms/step
# Epoch 298/300
# 2/2 - 0s - loss: 2.1919e-05 - 14ms/epoch - 7ms/step
# Epoch 299/300
# 2/2 - 0s - loss: 2.1155e-05 - 15ms/epoch - 8ms/step
# Epoch 300/300
# 2/2 - 0s - loss: 2.0936e-05 - 13ms/epoch - 7ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 14/14 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710204012.778485
# Tue Mar 12 00:40:12 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710204012.787161
# Tue Mar 12 00:40:12 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2, batch_size=40)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 2/2 - 1s - loss: 0.5761 - 581ms/epoch - 291ms/step
# Epoch 2/300
# 2/2 - 0s - loss: 0.2703 - 17ms/epoch - 8ms/step
# Epoch 3/300
# 2/2 - 0s - loss: 0.1019 - 19ms/epoch - 10ms/step
# Epoch 4/300
# 2/2 - 0s - loss: 0.1255 - 20ms/epoch - 10ms/step
# Epoch 5/300
# 2/2 - 0s - loss: 0.1175 - 22ms/epoch - 11ms/step
# Epoch 6/300
# 2/2 - 0s - loss: 0.0735 - 23ms/epoch - 11ms/step
# Epoch 7/300
# 2/2 - 0s - loss: 0.1088 - 19ms/epoch - 9ms/step
# Epoch 8/300
# 2/2 - 0s - loss: 0.0766 - 18ms/epoch - 9ms/step
# Epoch 9/300
# 2/2 - 0s - loss: 0.0673 - 19ms/epoch - 9ms/step
# Epoch 10/300
# 2/2 - 0s - loss: 0.0821 - 17ms/epoch - 9ms/step
# Epoch 11/300
# 2/2 - 0s - loss: 0.0600 - 17ms/epoch - 8ms/step
# Epoch 12/300
# 2/2 - 0s - loss: 0.0596 - 21ms/epoch - 11ms/step
# Epoch 13/300
# 2/2 - 0s - loss: 0.0692 - 20ms/epoch - 10ms/step
# Epoch 14/300
# 2/2 - 0s - loss: 0.0589 - 17ms/epoch - 8ms/step
# Epoch 15/300
# 2/2 - 0s - loss: 0.0521 - 18ms/epoch - 9ms/step
# Epoch 16/300
# 2/2 - 0s - loss: 0.0582 - 20ms/epoch - 10ms/step
# Epoch 17/300
# 2/2 - 0s - loss: 0.0484 - 17ms/epoch - 8ms/step
# Epoch 18/300
# 2/2 - 0s - loss: 0.0515 - 17ms/epoch - 9ms/step
# Epoch 19/300
# 2/2 - 0s - loss: 0.0530 - 18ms/epoch - 9ms/step
# Epoch 20/300
# 2/2 - 0s - loss: 0.0459 - 17ms/epoch - 9ms/step
# Epoch 21/300
# 2/2 - 0s - loss: 0.0460 - 20ms/epoch - 10ms/step
# Epoch 22/300
# 2/2 - 0s - loss: 0.0476 - 17ms/epoch - 8ms/step
# Epoch 23/300
# 2/2 - 0s - loss: 0.0436 - 16ms/epoch - 8ms/step
# Epoch 24/300
# 2/2 - 0s - loss: 0.0481 - 15ms/epoch - 7ms/step
# Epoch 25/300
# 2/2 - 0s - loss: 0.0431 - 17ms/epoch - 8ms/step
# Epoch 26/300
# 2/2 - 0s - loss: 0.0432 - 17ms/epoch - 8ms/step
# Epoch 27/300
# 2/2 - 0s - loss: 0.0463 - 16ms/epoch - 8ms/step
# Epoch 28/300
# 2/2 - 0s - loss: 0.0434 - 17ms/epoch - 9ms/step
# Epoch 29/300
# 2/2 - 0s - loss: 0.0422 - 17ms/epoch - 9ms/step
# Epoch 30/300
# 2/2 - 0s - loss: 0.0421 - 18ms/epoch - 9ms/step
# Epoch 31/300
# 2/2 - 0s - loss: 0.0396 - 18ms/epoch - 9ms/step
# Epoch 32/300
# 2/2 - 0s - loss: 0.0404 - 17ms/epoch - 8ms/step
# Epoch 33/300
# 2/2 - 0s - loss: 0.0406 - 17ms/epoch - 8ms/step
# Epoch 34/300
# 2/2 - 0s - loss: 0.0367 - 20ms/epoch - 10ms/step
# Epoch 35/300
# 2/2 - 0s - loss: 0.0364 - 15ms/epoch - 7ms/step
# Epoch 36/300
# 2/2 - 0s - loss: 0.0343 - 18ms/epoch - 9ms/step
# Epoch 37/300
# 2/2 - 0s - loss: 0.0350 - 16ms/epoch - 8ms/step
# Epoch 38/300
# 2/2 - 0s - loss: 0.0392 - 19ms/epoch - 9ms/step
# Epoch 39/300
# 2/2 - 0s - loss: 0.0316 - 19ms/epoch - 10ms/step
# Epoch 40/300
# 2/2 - 0s - loss: 0.0366 - 17ms/epoch - 8ms/step
# Epoch 41/300
# 2/2 - 0s - loss: 0.0352 - 17ms/epoch - 9ms/step
# Epoch 42/300
# 2/2 - 0s - loss: 0.0338 - 17ms/epoch - 8ms/step
# Epoch 43/300
# 2/2 - 0s - loss: 0.0328 - 16ms/epoch - 8ms/step
# Epoch 44/300
# 2/2 - 0s - loss: 0.0354 - 17ms/epoch - 9ms/step
# Epoch 45/300
# 2/2 - 0s - loss: 0.0322 - 19ms/epoch - 10ms/step
# Epoch 46/300
# 2/2 - 0s - loss: 0.0301 - 17ms/epoch - 9ms/step
# Epoch 47/300
# 2/2 - 0s - loss: 0.0371 - 16ms/epoch - 8ms/step
# Epoch 48/300
# 2/2 - 0s - loss: 0.0339 - 18ms/epoch - 9ms/step
# Epoch 49/300
# 2/2 - 0s - loss: 0.0315 - 20ms/epoch - 10ms/step
# Epoch 50/300
# 2/2 - 0s - loss: 0.0315 - 17ms/epoch - 9ms/step
# Epoch 51/300
# 2/2 - 0s - loss: 0.0336 - 17ms/epoch - 9ms/step
# Epoch 52/300
# 2/2 - 0s - loss: 0.0270 - 16ms/epoch - 8ms/step
# Epoch 53/300
# 2/2 - 0s - loss: 0.0279 - 19ms/epoch - 9ms/step
# Epoch 54/300
# 2/2 - 0s - loss: 0.0298 - 20ms/epoch - 10ms/step
# Epoch 55/300
# 2/2 - 0s - loss: 0.0273 - 18ms/epoch - 9ms/step
# Epoch 56/300
# 2/2 - 0s - loss: 0.0354 - 18ms/epoch - 9ms/step
# Epoch 57/300
# 2/2 - 0s - loss: 0.0242 - 18ms/epoch - 9ms/step
# Epoch 58/300
# 2/2 - 0s - loss: 0.0288 - 20ms/epoch - 10ms/step
# Epoch 59/300
# 2/2 - 0s - loss: 0.0340 - 18ms/epoch - 9ms/step
# Epoch 60/300
# 2/2 - 0s - loss: 0.0292 - 18ms/epoch - 9ms/step
# Epoch 61/300
# 2/2 - 0s - loss: 0.0258 - 17ms/epoch - 9ms/step
# Epoch 62/300
# 2/2 - 0s - loss: 0.0244 - 18ms/epoch - 9ms/step
# Epoch 63/300
# 2/2 - 0s - loss: 0.0220 - 18ms/epoch - 9ms/step
# Epoch 64/300
# 2/2 - 0s - loss: 0.0227 - 18ms/epoch - 9ms/step
# Epoch 65/300
# 2/2 - 0s - loss: 0.0221 - 17ms/epoch - 9ms/step
# Epoch 66/300
# 2/2 - 0s - loss: 0.0229 - 18ms/epoch - 9ms/step
# Epoch 67/300
# 2/2 - 0s - loss: 0.0219 - 15ms/epoch - 8ms/step
# Epoch 68/300
# 2/2 - 0s - loss: 0.0217 - 17ms/epoch - 9ms/step
# Epoch 69/300
# 2/2 - 0s - loss: 0.0202 - 16ms/epoch - 8ms/step
# Epoch 70/300
# 2/2 - 0s - loss: 0.0241 - 17ms/epoch - 9ms/step
# Epoch 71/300
# 2/2 - 0s - loss: 0.0237 - 16ms/epoch - 8ms/step
# Epoch 72/300
# 2/2 - 0s - loss: 0.0165 - 17ms/epoch - 9ms/step
# Epoch 73/300
# 2/2 - 0s - loss: 0.0177 - 16ms/epoch - 8ms/step
# Epoch 74/300
# 2/2 - 0s - loss: 0.0186 - 19ms/epoch - 10ms/step
# Epoch 75/300
# 2/2 - 0s - loss: 0.0149 - 16ms/epoch - 8ms/step
# Epoch 76/300
# 2/2 - 0s - loss: 0.0200 - 19ms/epoch - 10ms/step
# Epoch 77/300
# 2/2 - 0s - loss: 0.0153 - 19ms/epoch - 10ms/step
# Epoch 78/300
# 2/2 - 0s - loss: 0.0166 - 17ms/epoch - 8ms/step
# Epoch 79/300
# 2/2 - 0s - loss: 0.0109 - 21ms/epoch - 11ms/step
# Epoch 80/300
# 2/2 - 0s - loss: 0.0140 - 17ms/epoch - 9ms/step
# Epoch 81/300
# 2/2 - 0s - loss: 0.0134 - 16ms/epoch - 8ms/step
# Epoch 82/300
# 2/2 - 0s - loss: 0.0106 - 20ms/epoch - 10ms/step
# Epoch 83/300
# 2/2 - 0s - loss: 0.0117 - 16ms/epoch - 8ms/step
# Epoch 84/300
# 2/2 - 0s - loss: 0.0150 - 16ms/epoch - 8ms/step
# Epoch 85/300
# 2/2 - 0s - loss: 0.0130 - 16ms/epoch - 8ms/step
# Epoch 86/300
# 2/2 - 0s - loss: 0.0147 - 18ms/epoch - 9ms/step
# Epoch 87/300
# 2/2 - 0s - loss: 0.0082 - 15ms/epoch - 7ms/step
# Epoch 88/300
# 2/2 - 0s - loss: 0.0085 - 16ms/epoch - 8ms/step
# Epoch 89/300
# 2/2 - 0s - loss: 0.0114 - 20ms/epoch - 10ms/step
# Epoch 90/300
# 2/2 - 0s - loss: 0.0078 - 17ms/epoch - 9ms/step
# Epoch 91/300
# 2/2 - 0s - loss: 0.0076 - 18ms/epoch - 9ms/step
# Epoch 92/300
# 2/2 - 0s - loss: 0.0083 - 19ms/epoch - 10ms/step
# Epoch 93/300
# 2/2 - 0s - loss: 0.0061 - 16ms/epoch - 8ms/step
# Epoch 94/300
# 2/2 - 0s - loss: 0.0048 - 19ms/epoch - 9ms/step
# Epoch 95/300
# 2/2 - 0s - loss: 0.0051 - 19ms/epoch - 9ms/step
# Epoch 96/300
# 2/2 - 0s - loss: 0.0051 - 18ms/epoch - 9ms/step
# Epoch 97/300
# 2/2 - 0s - loss: 0.0045 - 18ms/epoch - 9ms/step
# Epoch 98/300
# 2/2 - 0s - loss: 0.0034 - 19ms/epoch - 9ms/step
# Epoch 99/300
# 2/2 - 0s - loss: 0.0034 - 18ms/epoch - 9ms/step
# Epoch 100/300
# 2/2 - 0s - loss: 0.0035 - 19ms/epoch - 10ms/step
# Epoch 101/300
# 2/2 - 0s - loss: 0.0031 - 17ms/epoch - 8ms/step
# Epoch 102/300
# 2/2 - 0s - loss: 0.0025 - 19ms/epoch - 9ms/step
# Epoch 103/300
# 2/2 - 0s - loss: 0.0023 - 19ms/epoch - 10ms/step
# Epoch 104/300
# 2/2 - 0s - loss: 0.0018 - 18ms/epoch - 9ms/step
# Epoch 105/300
# 2/2 - 0s - loss: 0.0019 - 19ms/epoch - 10ms/step
# Epoch 106/300
# 2/2 - 0s - loss: 0.0019 - 16ms/epoch - 8ms/step
# Epoch 107/300
# 2/2 - 0s - loss: 0.0016 - 17ms/epoch - 9ms/step
# Epoch 108/300
# 2/2 - 0s - loss: 0.0011 - 18ms/epoch - 9ms/step
# Epoch 109/300
# 2/2 - 0s - loss: 0.0014 - 18ms/epoch - 9ms/step
# Epoch 110/300
# 2/2 - 0s - loss: 9.8313e-04 - 19ms/epoch - 9ms/step
# Epoch 111/300
# 2/2 - 0s - loss: 0.0012 - 18ms/epoch - 9ms/step
# Epoch 112/300
# 2/2 - 0s - loss: 0.0015 - 17ms/epoch - 9ms/step
# Epoch 113/300
# 2/2 - 0s - loss: 0.0017 - 19ms/epoch - 10ms/step
# Epoch 114/300
# 2/2 - 0s - loss: 0.0019 - 20ms/epoch - 10ms/step
# Epoch 115/300
# 2/2 - 0s - loss: 0.0017 - 17ms/epoch - 8ms/step
# Epoch 116/300
# 2/2 - 0s - loss: 0.0012 - 18ms/epoch - 9ms/step
# Epoch 117/300
# 2/2 - 0s - loss: 0.0011 - 19ms/epoch - 9ms/step
# Epoch 118/300
# 2/2 - 0s - loss: 6.8112e-04 - 21ms/epoch - 10ms/step
# Epoch 119/300
# 2/2 - 0s - loss: 4.7940e-04 - 19ms/epoch - 10ms/step
# Epoch 120/300
# 2/2 - 0s - loss: 6.4230e-04 - 15ms/epoch - 7ms/step
# Epoch 121/300
# 2/2 - 0s - loss: 4.0679e-04 - 16ms/epoch - 8ms/step
# Epoch 122/300
# 2/2 - 0s - loss: 4.1065e-04 - 19ms/epoch - 9ms/step
# Epoch 123/300
# 2/2 - 0s - loss: 2.1793e-04 - 16ms/epoch - 8ms/step
# Epoch 124/300
# 2/2 - 0s - loss: 2.2979e-04 - 18ms/epoch - 9ms/step
# Epoch 125/300
# 2/2 - 0s - loss: 2.8511e-04 - 17ms/epoch - 9ms/step
# Epoch 126/300
# 2/2 - 0s - loss: 2.5652e-04 - 18ms/epoch - 9ms/step
# Epoch 127/300
# 2/2 - 0s - loss: 3.3891e-04 - 16ms/epoch - 8ms/step
# Epoch 128/300
# 2/2 - 0s - loss: 2.2547e-04 - 17ms/epoch - 8ms/step
# Epoch 129/300
# 2/2 - 0s - loss: 2.1727e-04 - 18ms/epoch - 9ms/step
# Epoch 130/300
# 2/2 - 0s - loss: 2.6027e-04 - 18ms/epoch - 9ms/step
# Epoch 131/300
# 2/2 - 0s - loss: 2.5587e-04 - 19ms/epoch - 9ms/step
# Epoch 132/300
# 2/2 - 0s - loss: 2.5387e-04 - 20ms/epoch - 10ms/step
# Epoch 133/300
# 2/2 - 0s - loss: 3.2141e-04 - 17ms/epoch - 8ms/step
# Epoch 134/300
# 2/2 - 0s - loss: 2.5840e-04 - 17ms/epoch - 9ms/step
# Epoch 135/300
# 2/2 - 0s - loss: 1.7333e-04 - 17ms/epoch - 8ms/step
# Epoch 136/300
# 2/2 - 0s - loss: 1.7033e-04 - 19ms/epoch - 10ms/step
# Epoch 137/300
# 2/2 - 0s - loss: 1.2846e-04 - 18ms/epoch - 9ms/step
# Epoch 138/300
# 2/2 - 0s - loss: 1.3469e-04 - 17ms/epoch - 9ms/step
# Epoch 139/300
# 2/2 - 0s - loss: 1.6827e-04 - 21ms/epoch - 11ms/step
# Epoch 140/300
# 2/2 - 0s - loss: 1.2805e-04 - 17ms/epoch - 9ms/step
# Epoch 141/300
# 2/2 - 0s - loss: 9.8908e-05 - 19ms/epoch - 9ms/step
# Epoch 142/300
# 2/2 - 0s - loss: 1.7004e-04 - 19ms/epoch - 9ms/step
# Epoch 143/300
# 2/2 - 0s - loss: 2.4640e-04 - 17ms/epoch - 9ms/step
# Epoch 144/300
# 2/2 - 0s - loss: 3.2115e-04 - 16ms/epoch - 8ms/step
# Epoch 145/300
# 2/2 - 0s - loss: 4.4930e-04 - 17ms/epoch - 8ms/step
# Epoch 146/300
# 2/2 - 0s - loss: 4.8672e-04 - 19ms/epoch - 10ms/step
# Epoch 147/300
# 2/2 - 0s - loss: 4.0817e-04 - 18ms/epoch - 9ms/step
# Epoch 148/300
# 2/2 - 0s - loss: 4.0124e-04 - 20ms/epoch - 10ms/step
# Epoch 149/300
# 2/2 - 0s - loss: 4.2220e-04 - 17ms/epoch - 8ms/step
# Epoch 150/300
# 2/2 - 0s - loss: 6.7696e-04 - 17ms/epoch - 8ms/step
# Epoch 151/300
# 2/2 - 0s - loss: 8.1483e-04 - 17ms/epoch - 9ms/step
# Epoch 152/300
# 2/2 - 0s - loss: 6.6809e-04 - 16ms/epoch - 8ms/step
# Epoch 153/300
# 2/2 - 0s - loss: 7.0078e-04 - 18ms/epoch - 9ms/step
# Epoch 154/300
# 2/2 - 0s - loss: 9.1845e-04 - 19ms/epoch - 9ms/step
# Epoch 155/300
# 2/2 - 0s - loss: 7.3449e-04 - 19ms/epoch - 9ms/step
# Epoch 156/300
# 2/2 - 0s - loss: 6.5215e-04 - 15ms/epoch - 8ms/step
# Epoch 157/300
# 2/2 - 0s - loss: 5.5694e-04 - 18ms/epoch - 9ms/step
# Epoch 158/300
# 2/2 - 0s - loss: 7.1975e-04 - 15ms/epoch - 8ms/step
# Epoch 159/300
# 2/2 - 0s - loss: 5.5347e-04 - 15ms/epoch - 8ms/step
# Epoch 160/300
# 2/2 - 0s - loss: 8.1970e-04 - 16ms/epoch - 8ms/step
# Epoch 161/300
# 2/2 - 0s - loss: 0.0013 - 16ms/epoch - 8ms/step
# Epoch 162/300
# 2/2 - 0s - loss: 0.0011 - 17ms/epoch - 9ms/step
# Epoch 163/300
# 2/2 - 0s - loss: 9.5360e-04 - 18ms/epoch - 9ms/step
# Epoch 164/300
# 2/2 - 0s - loss: 8.6326e-04 - 17ms/epoch - 8ms/step
# Epoch 165/300
# 2/2 - 0s - loss: 0.0013 - 17ms/epoch - 8ms/step
# Epoch 166/300
# 2/2 - 0s - loss: 0.0015 - 20ms/epoch - 10ms/step
# Epoch 167/300
# 2/2 - 0s - loss: 0.0012 - 18ms/epoch - 9ms/step
# Epoch 168/300
# 2/2 - 0s - loss: 0.0014 - 15ms/epoch - 8ms/step
# Epoch 169/300
# 2/2 - 0s - loss: 8.4544e-04 - 18ms/epoch - 9ms/step
# Epoch 170/300
# 2/2 - 0s - loss: 5.8471e-04 - 15ms/epoch - 8ms/step
# Epoch 171/300
# 2/2 - 0s - loss: 4.3200e-04 - 16ms/epoch - 8ms/step
# Epoch 172/300
# 2/2 - 0s - loss: 3.1580e-04 - 16ms/epoch - 8ms/step
# Epoch 173/300
# 2/2 - 0s - loss: 2.3629e-04 - 17ms/epoch - 8ms/step
# Epoch 174/300
# 2/2 - 0s - loss: 2.3958e-04 - 15ms/epoch - 7ms/step
# Epoch 175/300
# 2/2 - 0s - loss: 2.9771e-04 - 16ms/epoch - 8ms/step
# Epoch 176/300
# 2/2 - 0s - loss: 5.1661e-04 - 20ms/epoch - 10ms/step
# Epoch 177/300
# 2/2 - 0s - loss: 5.8053e-04 - 17ms/epoch - 9ms/step
# Epoch 178/300
# 2/2 - 0s - loss: 5.7532e-04 - 18ms/epoch - 9ms/step
# Epoch 179/300
# 2/2 - 0s - loss: 4.6647e-04 - 17ms/epoch - 8ms/step
# Epoch 180/300
# 2/2 - 0s - loss: 5.0675e-04 - 17ms/epoch - 8ms/step
# Epoch 181/300
# 2/2 - 0s - loss: 5.2332e-04 - 16ms/epoch - 8ms/step
# Epoch 182/300
# 2/2 - 0s - loss: 6.3966e-04 - 16ms/epoch - 8ms/step
# Epoch 183/300
# 2/2 - 0s - loss: 6.5121e-04 - 20ms/epoch - 10ms/step
# Epoch 184/300
# 2/2 - 0s - loss: 4.9228e-04 - 20ms/epoch - 10ms/step
# Epoch 185/300
# 2/2 - 0s - loss: 3.7715e-04 - 20ms/epoch - 10ms/step
# Epoch 186/300
# 2/2 - 0s - loss: 3.1226e-04 - 16ms/epoch - 8ms/step
# Epoch 187/300
# 2/2 - 0s - loss: 2.5556e-04 - 20ms/epoch - 10ms/step
# Epoch 188/300
# 2/2 - 0s - loss: 1.7558e-04 - 17ms/epoch - 9ms/step
# Epoch 189/300
# 2/2 - 0s - loss: 1.0063e-04 - 19ms/epoch - 9ms/step
# Epoch 190/300
# 2/2 - 0s - loss: 1.0945e-04 - 19ms/epoch - 9ms/step
# Epoch 191/300
# 2/2 - 0s - loss: 1.1035e-04 - 18ms/epoch - 9ms/step
# Epoch 192/300
# 2/2 - 0s - loss: 5.6840e-05 - 16ms/epoch - 8ms/step
# Epoch 193/300
# 2/2 - 0s - loss: 7.8544e-05 - 15ms/epoch - 8ms/step
# Epoch 194/300
# 2/2 - 0s - loss: 7.9695e-05 - 18ms/epoch - 9ms/step
# Epoch 195/300
# 2/2 - 0s - loss: 9.5177e-05 - 19ms/epoch - 10ms/step
# Epoch 196/300
# 2/2 - 0s - loss: 1.7016e-04 - 18ms/epoch - 9ms/step
# Epoch 197/300
# 2/2 - 0s - loss: 2.0372e-04 - 16ms/epoch - 8ms/step
# Epoch 198/300
# 2/2 - 0s - loss: 1.7398e-04 - 16ms/epoch - 8ms/step
# Epoch 199/300
# 2/2 - 0s - loss: 2.0000e-04 - 17ms/epoch - 9ms/step
# Epoch 200/300
# 2/2 - 0s - loss: 1.8129e-04 - 18ms/epoch - 9ms/step
# Epoch 201/300
# 2/2 - 0s - loss: 2.9310e-04 - 17ms/epoch - 8ms/step
# Epoch 202/300
# 2/2 - 0s - loss: 2.7538e-04 - 21ms/epoch - 10ms/step
# Epoch 203/300
# 2/2 - 0s - loss: 2.2286e-04 - 16ms/epoch - 8ms/step
# Epoch 204/300
# 2/2 - 0s - loss: 3.8844e-04 - 17ms/epoch - 9ms/step
# Epoch 205/300
# 2/2 - 0s - loss: 2.4356e-04 - 16ms/epoch - 8ms/step
# Epoch 206/300
# 2/2 - 0s - loss: 2.4284e-04 - 22ms/epoch - 11ms/step
# Epoch 207/300
# 2/2 - 0s - loss: 3.0125e-04 - 19ms/epoch - 9ms/step
# Epoch 208/300
# 2/2 - 0s - loss: 2.7714e-04 - 21ms/epoch - 10ms/step
# Epoch 209/300
# 2/2 - 0s - loss: 4.6264e-04 - 18ms/epoch - 9ms/step
# Epoch 210/300
# 2/2 - 0s - loss: 7.1069e-04 - 19ms/epoch - 10ms/step
# Epoch 211/300
# 2/2 - 0s - loss: 3.7724e-04 - 17ms/epoch - 8ms/step
# Epoch 212/300
# 2/2 - 0s - loss: 5.1547e-04 - 21ms/epoch - 11ms/step
# Epoch 213/300
# 2/2 - 0s - loss: 5.3780e-04 - 17ms/epoch - 8ms/step
# Epoch 214/300
# 2/2 - 0s - loss: 7.2785e-04 - 17ms/epoch - 8ms/step
# Epoch 215/300
# 2/2 - 0s - loss: 0.0012 - 16ms/epoch - 8ms/step
# Epoch 216/300
# 2/2 - 0s - loss: 0.0013 - 17ms/epoch - 8ms/step
# Epoch 217/300
# 2/2 - 0s - loss: 0.0014 - 16ms/epoch - 8ms/step
# Epoch 218/300
# 2/2 - 0s - loss: 0.0012 - 19ms/epoch - 10ms/step
# Epoch 219/300
# 2/2 - 0s - loss: 0.0010 - 17ms/epoch - 9ms/step
# Epoch 220/300
# 2/2 - 0s - loss: 9.9521e-04 - 19ms/epoch - 10ms/step
# Epoch 221/300
# 2/2 - 0s - loss: 8.4029e-04 - 20ms/epoch - 10ms/step
# Epoch 222/300
# 2/2 - 0s - loss: 9.5189e-04 - 17ms/epoch - 9ms/step
# Epoch 223/300
# 2/2 - 0s - loss: 0.0010 - 16ms/epoch - 8ms/step
# Epoch 224/300
# 2/2 - 0s - loss: 9.0947e-04 - 18ms/epoch - 9ms/step
# Epoch 225/300
# 2/2 - 0s - loss: 6.4861e-04 - 16ms/epoch - 8ms/step
# Epoch 226/300
# 2/2 - 0s - loss: 6.5622e-04 - 18ms/epoch - 9ms/step
# Epoch 227/300
# 2/2 - 0s - loss: 6.2426e-04 - 19ms/epoch - 10ms/step
# Epoch 228/300
# 2/2 - 0s - loss: 8.3142e-04 - 17ms/epoch - 8ms/step
# Epoch 229/300
# 2/2 - 0s - loss: 5.6636e-04 - 18ms/epoch - 9ms/step
# Epoch 230/300
# 2/2 - 0s - loss: 5.9234e-04 - 15ms/epoch - 8ms/step
# Epoch 231/300
# 2/2 - 0s - loss: 7.8224e-04 - 18ms/epoch - 9ms/step
# Epoch 232/300
# 2/2 - 0s - loss: 0.0015 - 18ms/epoch - 9ms/step
# Epoch 233/300
# 2/2 - 0s - loss: 0.0023 - 19ms/epoch - 10ms/step
# Epoch 234/300
# 2/2 - 0s - loss: 0.0034 - 18ms/epoch - 9ms/step
# Epoch 235/300
# 2/2 - 0s - loss: 0.0028 - 19ms/epoch - 9ms/step
# Epoch 236/300
# 2/2 - 0s - loss: 0.0025 - 18ms/epoch - 9ms/step
# Epoch 237/300
# 2/2 - 0s - loss: 0.0018 - 18ms/epoch - 9ms/step
# Epoch 238/300
# 2/2 - 0s - loss: 0.0016 - 16ms/epoch - 8ms/step
# Epoch 239/300
# 2/2 - 0s - loss: 0.0012 - 17ms/epoch - 9ms/step
# Epoch 240/300
# 2/2 - 0s - loss: 0.0016 - 18ms/epoch - 9ms/step
# Epoch 241/300
# 2/2 - 0s - loss: 0.0020 - 19ms/epoch - 9ms/step
# Epoch 242/300
# 2/2 - 0s - loss: 0.0026 - 20ms/epoch - 10ms/step
# Epoch 243/300
# 2/2 - 0s - loss: 0.0023 - 15ms/epoch - 8ms/step
# Epoch 244/300
# 2/2 - 0s - loss: 0.0026 - 15ms/epoch - 7ms/step
# Epoch 245/300
# 2/2 - 0s - loss: 0.0037 - 18ms/epoch - 9ms/step
# Epoch 246/300
# 2/2 - 0s - loss: 0.0026 - 18ms/epoch - 9ms/step
# Epoch 247/300
# 2/2 - 0s - loss: 0.0014 - 17ms/epoch - 9ms/step
# Epoch 248/300
# 2/2 - 0s - loss: 0.0010 - 17ms/epoch - 9ms/step
# Epoch 249/300
# 2/2 - 0s - loss: 7.7428e-04 - 18ms/epoch - 9ms/step
# Epoch 250/300
# 2/2 - 0s - loss: 7.1926e-04 - 17ms/epoch - 8ms/step
# Epoch 251/300
# 2/2 - 0s - loss: 7.6987e-04 - 16ms/epoch - 8ms/step
# Epoch 252/300
# 2/2 - 0s - loss: 5.4741e-04 - 16ms/epoch - 8ms/step
# Epoch 253/300
# 2/2 - 0s - loss: 8.1161e-04 - 18ms/epoch - 9ms/step
# Epoch 254/300
# 2/2 - 0s - loss: 3.8969e-04 - 17ms/epoch - 8ms/step
# Epoch 255/300
# 2/2 - 0s - loss: 3.6603e-04 - 18ms/epoch - 9ms/step
# Epoch 256/300
# 2/2 - 0s - loss: 2.8711e-04 - 18ms/epoch - 9ms/step
# Epoch 257/300
# 2/2 - 0s - loss: 2.5608e-04 - 19ms/epoch - 10ms/step
# Epoch 258/300
# 2/2 - 0s - loss: 3.6065e-04 - 19ms/epoch - 10ms/step
# Epoch 259/300
# 2/2 - 0s - loss: 9.1989e-04 - 15ms/epoch - 8ms/step
# Epoch 260/300
# 2/2 - 0s - loss: 6.9794e-04 - 18ms/epoch - 9ms/step
# Epoch 261/300
# 2/2 - 0s - loss: 5.4513e-04 - 19ms/epoch - 9ms/step
# Epoch 262/300
# 2/2 - 0s - loss: 4.7473e-04 - 18ms/epoch - 9ms/step
# Epoch 263/300
# 2/2 - 0s - loss: 4.4398e-04 - 17ms/epoch - 9ms/step
# Epoch 264/300
# 2/2 - 0s - loss: 3.4221e-04 - 17ms/epoch - 9ms/step
# Epoch 265/300
# 2/2 - 0s - loss: 3.1358e-04 - 20ms/epoch - 10ms/step
# Epoch 266/300
# 2/2 - 0s - loss: 2.5597e-04 - 17ms/epoch - 8ms/step
# Epoch 267/300
# 2/2 - 0s - loss: 2.9848e-04 - 17ms/epoch - 8ms/step
# Epoch 268/300
# 2/2 - 0s - loss: 3.9539e-04 - 19ms/epoch - 10ms/step
# Epoch 269/300
# 2/2 - 0s - loss: 5.6431e-04 - 16ms/epoch - 8ms/step
# Epoch 270/300
# 2/2 - 0s - loss: 6.9464e-04 - 15ms/epoch - 8ms/step
# Epoch 271/300
# 2/2 - 0s - loss: 0.0010 - 15ms/epoch - 8ms/step
# Epoch 272/300
# 2/2 - 0s - loss: 0.0012 - 18ms/epoch - 9ms/step
# Epoch 273/300
# 2/2 - 0s - loss: 0.0012 - 19ms/epoch - 9ms/step
# Epoch 274/300
# 2/2 - 0s - loss: 9.2002e-04 - 17ms/epoch - 8ms/step
# Epoch 275/300
# 2/2 - 0s - loss: 7.7485e-04 - 19ms/epoch - 9ms/step
# Epoch 276/300
# 2/2 - 0s - loss: 6.7195e-04 - 18ms/epoch - 9ms/step
# Epoch 277/300
# 2/2 - 0s - loss: 5.7296e-04 - 16ms/epoch - 8ms/step
# Epoch 278/300
# 2/2 - 0s - loss: 9.6363e-04 - 17ms/epoch - 8ms/step
# Epoch 279/300
# 2/2 - 0s - loss: 0.0011 - 19ms/epoch - 10ms/step
# Epoch 280/300
# 2/2 - 0s - loss: 0.0011 - 17ms/epoch - 8ms/step
# Epoch 281/300
# 2/2 - 0s - loss: 0.0017 - 18ms/epoch - 9ms/step
# Epoch 282/300
# 2/2 - 0s - loss: 0.0015 - 19ms/epoch - 10ms/step
# Epoch 283/300
# 2/2 - 0s - loss: 0.0011 - 21ms/epoch - 11ms/step
# Epoch 284/300
# 2/2 - 0s - loss: 9.1847e-04 - 19ms/epoch - 9ms/step
# Epoch 285/300
# 2/2 - 0s - loss: 7.0603e-04 - 18ms/epoch - 9ms/step
# Epoch 286/300
# 2/2 - 0s - loss: 7.1454e-04 - 18ms/epoch - 9ms/step
# Epoch 287/300
# 2/2 - 0s - loss: 5.8694e-04 - 19ms/epoch - 10ms/step
# Epoch 288/300
# 2/2 - 0s - loss: 7.7288e-04 - 17ms/epoch - 8ms/step
# Epoch 289/300
# 2/2 - 0s - loss: 7.4140e-04 - 16ms/epoch - 8ms/step
# Epoch 290/300
# 2/2 - 0s - loss: 6.1771e-04 - 17ms/epoch - 8ms/step
# Epoch 291/300
# 2/2 - 0s - loss: 5.7988e-04 - 18ms/epoch - 9ms/step
# Epoch 292/300
# 2/2 - 0s - loss: 6.3946e-04 - 15ms/epoch - 8ms/step
# Epoch 293/300
# 2/2 - 0s - loss: 6.0580e-04 - 17ms/epoch - 9ms/step
# Epoch 294/300
# 2/2 - 0s - loss: 4.1514e-04 - 16ms/epoch - 8ms/step
# Epoch 295/300
# 2/2 - 0s - loss: 5.7407e-04 - 16ms/epoch - 8ms/step
# Epoch 296/300
# 2/2 - 0s - loss: 3.9468e-04 - 18ms/epoch - 9ms/step
# Epoch 297/300
# 2/2 - 0s - loss: 2.4635e-04 - 18ms/epoch - 9ms/step
# Epoch 298/300
# 2/2 - 0s - loss: 1.5949e-04 - 17ms/epoch - 8ms/step
# Epoch 299/300
# 2/2 - 0s - loss: 1.6746e-04 - 16ms/epoch - 8ms/step
# Epoch 300/300
# 2/2 - 0s - loss: 1.4358e-04 - 18ms/epoch - 9ms/step
# 14/14 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710204019.753506
# Tue Mar 12 00:40:19 2024
