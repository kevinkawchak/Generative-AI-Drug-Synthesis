# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_35 (Dense)            (None, 1024)              3072
#
#  dense_36 (Dense)            (None, 1024)              1049600
#
#  dense_37 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     TNLayer(),
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_38 (Dense)            (None, 1024)              3072
#
#  tn_layer_21 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_22 (TNLayer)       (None, 1024)              5120
#
#  tn_layer_23 (TNLayer)       (None, 1024)              5120
#
#  dense_39 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(20, 2) + np.array([3, 3]),
                    np.random.randn(20, 2) + np.array([-3, -3]),
                    np.random.randn(20, 2) + np.array([-3, 3]),
                    np.random.randn(20, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((40)), -np.ones((40))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710203873.568483
# Tue Mar 12 00:37:53 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2, batch_size=8)
# Out:
# Epoch 1/300
# 10/10 - 2s - loss: 1.0123 - 2s/epoch - 161ms/step
# Epoch 2/300
# 10/10 - 0s - loss: 1.0033 - 32ms/epoch - 3ms/step
# Epoch 3/300
# 10/10 - 0s - loss: 1.0007 - 31ms/epoch - 3ms/step
# Epoch 4/300
# 10/10 - 0s - loss: 0.9857 - 27ms/epoch - 3ms/step
# Epoch 5/300
# 10/10 - 0s - loss: 0.8303 - 27ms/epoch - 3ms/step
# Epoch 6/300
# 10/10 - 0s - loss: 0.2119 - 26ms/epoch - 3ms/step
# Epoch 7/300
# 10/10 - 0s - loss: 0.0514 - 27ms/epoch - 3ms/step
# Epoch 8/300
# 10/10 - 0s - loss: 0.0333 - 26ms/epoch - 3ms/step
# Epoch 9/300
# 10/10 - 0s - loss: 0.0187 - 27ms/epoch - 3ms/step
# Epoch 10/300
# 10/10 - 0s - loss: 0.0172 - 24ms/epoch - 2ms/step
# Epoch 11/300
# 10/10 - 0s - loss: 0.0135 - 24ms/epoch - 2ms/step
# Epoch 12/300
# 10/10 - 0s - loss: 0.0114 - 24ms/epoch - 2ms/step
# Epoch 13/300
# 10/10 - 0s - loss: 0.0099 - 23ms/epoch - 2ms/step
# Epoch 14/300
# 10/10 - 0s - loss: 0.0094 - 24ms/epoch - 2ms/step
# Epoch 15/300
# 10/10 - 0s - loss: 0.0074 - 23ms/epoch - 2ms/step
# Epoch 16/300
# 10/10 - 0s - loss: 0.0066 - 22ms/epoch - 2ms/step
# Epoch 17/300
# 10/10 - 0s - loss: 0.0060 - 23ms/epoch - 2ms/step
# Epoch 18/300
# 10/10 - 0s - loss: 0.0058 - 25ms/epoch - 2ms/step
# Epoch 19/300
# 10/10 - 0s - loss: 0.0054 - 23ms/epoch - 2ms/step
# Epoch 20/300
# 10/10 - 0s - loss: 0.0043 - 24ms/epoch - 2ms/step
# Epoch 21/300
# 10/10 - 0s - loss: 0.0040 - 25ms/epoch - 2ms/step
# Epoch 22/300
# 10/10 - 0s - loss: 0.0036 - 24ms/epoch - 2ms/step
# Epoch 23/300
# 10/10 - 0s - loss: 0.0034 - 24ms/epoch - 2ms/step
# Epoch 24/300
# 10/10 - 0s - loss: 0.0029 - 23ms/epoch - 2ms/step
# Epoch 25/300
# 10/10 - 0s - loss: 0.0027 - 22ms/epoch - 2ms/step
# Epoch 26/300
# 10/10 - 0s - loss: 0.0023 - 23ms/epoch - 2ms/step
# Epoch 27/300
# 10/10 - 0s - loss: 0.0020 - 22ms/epoch - 2ms/step
# Epoch 28/300
# 10/10 - 0s - loss: 0.0019 - 22ms/epoch - 2ms/step
# Epoch 29/300
# 10/10 - 0s - loss: 0.0017 - 23ms/epoch - 2ms/step
# Epoch 30/300
# 10/10 - 0s - loss: 0.0014 - 23ms/epoch - 2ms/step
# Epoch 31/300
# 10/10 - 0s - loss: 0.0017 - 25ms/epoch - 2ms/step
# Epoch 32/300
# 10/10 - 0s - loss: 0.0012 - 26ms/epoch - 3ms/step
# Epoch 33/300
# 10/10 - 0s - loss: 0.0011 - 25ms/epoch - 2ms/step
# Epoch 34/300
# 10/10 - 0s - loss: 8.3656e-04 - 25ms/epoch - 3ms/step
# Epoch 35/300
# 10/10 - 0s - loss: 7.1405e-04 - 23ms/epoch - 2ms/step
# Epoch 36/300
# 10/10 - 0s - loss: 6.6638e-04 - 22ms/epoch - 2ms/step
# Epoch 37/300
# 10/10 - 0s - loss: 4.8512e-04 - 24ms/epoch - 2ms/step
# Epoch 38/300
# 10/10 - 0s - loss: 4.0613e-04 - 24ms/epoch - 2ms/step
# Epoch 39/300
# 10/10 - 0s - loss: 3.6532e-04 - 23ms/epoch - 2ms/step
# Epoch 40/300
# 10/10 - 0s - loss: 3.7109e-04 - 22ms/epoch - 2ms/step
# Epoch 41/300
# 10/10 - 0s - loss: 2.8373e-04 - 22ms/epoch - 2ms/step
# Epoch 42/300
# 10/10 - 0s - loss: 2.1970e-04 - 24ms/epoch - 2ms/step
# Epoch 43/300
# 10/10 - 0s - loss: 1.3090e-04 - 23ms/epoch - 2ms/step
# Epoch 44/300
# 10/10 - 0s - loss: 9.6274e-05 - 23ms/epoch - 2ms/step
# Epoch 45/300
# 10/10 - 0s - loss: 9.3420e-05 - 24ms/epoch - 2ms/step
# Epoch 46/300
# 10/10 - 0s - loss: 1.0401e-04 - 22ms/epoch - 2ms/step
# Epoch 47/300
# 10/10 - 0s - loss: 6.0420e-05 - 24ms/epoch - 2ms/step
# Epoch 48/300
# 10/10 - 0s - loss: 3.1827e-05 - 22ms/epoch - 2ms/step
# Epoch 49/300
# 10/10 - 0s - loss: 2.2625e-05 - 23ms/epoch - 2ms/step
# Epoch 50/300
# 10/10 - 0s - loss: 1.5041e-05 - 24ms/epoch - 2ms/step
# Epoch 51/300
# 10/10 - 0s - loss: 1.7476e-05 - 24ms/epoch - 2ms/step
# Epoch 52/300
# 10/10 - 0s - loss: 9.6402e-06 - 24ms/epoch - 2ms/step
# Epoch 53/300
# 10/10 - 0s - loss: 7.9360e-06 - 23ms/epoch - 2ms/step
# Epoch 54/300
# 10/10 - 0s - loss: 1.0338e-05 - 22ms/epoch - 2ms/step
# Epoch 55/300
# 10/10 - 0s - loss: 7.8040e-06 - 23ms/epoch - 2ms/step
# Epoch 56/300
# 10/10 - 0s - loss: 8.7441e-06 - 24ms/epoch - 2ms/step
# Epoch 57/300
# 10/10 - 0s - loss: 6.7549e-06 - 22ms/epoch - 2ms/step
# Epoch 58/300
# 10/10 - 0s - loss: 5.5172e-06 - 23ms/epoch - 2ms/step
# Epoch 59/300
# 10/10 - 0s - loss: 3.8369e-06 - 22ms/epoch - 2ms/step
# Epoch 60/300
# 10/10 - 0s - loss: 4.7686e-06 - 22ms/epoch - 2ms/step
# Epoch 61/300
# 10/10 - 0s - loss: 5.2847e-06 - 24ms/epoch - 2ms/step
# Epoch 62/300
# 10/10 - 0s - loss: 8.3298e-06 - 23ms/epoch - 2ms/step
# Epoch 63/300
# 10/10 - 0s - loss: 5.2412e-06 - 23ms/epoch - 2ms/step
# Epoch 64/300
# 10/10 - 0s - loss: 7.7989e-06 - 22ms/epoch - 2ms/step
# Epoch 65/300
# 10/10 - 0s - loss: 5.1435e-06 - 23ms/epoch - 2ms/step
# Epoch 66/300
# 10/10 - 0s - loss: 3.2050e-06 - 24ms/epoch - 2ms/step
# Epoch 67/300
# 10/10 - 0s - loss: 2.5459e-06 - 23ms/epoch - 2ms/step
# Epoch 68/300
# 10/10 - 0s - loss: 2.7562e-06 - 24ms/epoch - 2ms/step
# Epoch 69/300
# 10/10 - 0s - loss: 4.2799e-06 - 22ms/epoch - 2ms/step
# Epoch 70/300
# 10/10 - 0s - loss: 4.6049e-06 - 22ms/epoch - 2ms/step
# Epoch 71/300
# 10/10 - 0s - loss: 3.7253e-06 - 22ms/epoch - 2ms/step
# Epoch 72/300
# 10/10 - 0s - loss: 3.4046e-06 - 22ms/epoch - 2ms/step
# Epoch 73/300
# 10/10 - 0s - loss: 2.7030e-06 - 24ms/epoch - 2ms/step
# Epoch 74/300
# 10/10 - 0s - loss: 2.3048e-06 - 24ms/epoch - 2ms/step
# Epoch 75/300
# 10/10 - 0s - loss: 2.1131e-06 - 24ms/epoch - 2ms/step
# Epoch 76/300
# 10/10 - 0s - loss: 2.0172e-06 - 25ms/epoch - 2ms/step
# Epoch 77/300
# 10/10 - 0s - loss: 2.5090e-06 - 24ms/epoch - 2ms/step
# Epoch 78/300
# 10/10 - 0s - loss: 2.5910e-06 - 23ms/epoch - 2ms/step
# Epoch 79/300
# 10/10 - 0s - loss: 2.0591e-06 - 23ms/epoch - 2ms/step
# Epoch 80/300
# 10/10 - 0s - loss: 2.3996e-06 - 26ms/epoch - 3ms/step
# Epoch 81/300
# 10/10 - 0s - loss: 2.2231e-06 - 23ms/epoch - 2ms/step
# Epoch 82/300
# 10/10 - 0s - loss: 2.2510e-06 - 23ms/epoch - 2ms/step
# Epoch 83/300
# 10/10 - 0s - loss: 3.7417e-06 - 24ms/epoch - 2ms/step
# Epoch 84/300
# 10/10 - 0s - loss: 2.7637e-06 - 24ms/epoch - 2ms/step
# Epoch 85/300
# 10/10 - 0s - loss: 4.1906e-06 - 22ms/epoch - 2ms/step
# Epoch 86/300
# 10/10 - 0s - loss: 4.3084e-06 - 24ms/epoch - 2ms/step
# Epoch 87/300
# 10/10 - 0s - loss: 3.9362e-06 - 23ms/epoch - 2ms/step
# Epoch 88/300
# 10/10 - 0s - loss: 3.2602e-06 - 25ms/epoch - 2ms/step
# Epoch 89/300
# 10/10 - 0s - loss: 2.7774e-06 - 25ms/epoch - 3ms/step
# Epoch 90/300
# 10/10 - 0s - loss: 2.3318e-06 - 25ms/epoch - 3ms/step
# Epoch 91/300
# 10/10 - 0s - loss: 2.3740e-06 - 24ms/epoch - 2ms/step
# Epoch 92/300
# 10/10 - 0s - loss: 1.7164e-06 - 24ms/epoch - 2ms/step
# Epoch 93/300
# 10/10 - 0s - loss: 1.6474e-06 - 24ms/epoch - 2ms/step
# Epoch 94/300
# 10/10 - 0s - loss: 1.8902e-06 - 23ms/epoch - 2ms/step
# Epoch 95/300
# 10/10 - 0s - loss: 2.4588e-06 - 24ms/epoch - 2ms/step
# Epoch 96/300
# 10/10 - 0s - loss: 1.7922e-06 - 24ms/epoch - 2ms/step
# Epoch 97/300
# 10/10 - 0s - loss: 1.3974e-06 - 22ms/epoch - 2ms/step
# Epoch 98/300
# 10/10 - 0s - loss: 1.4854e-06 - 23ms/epoch - 2ms/step
# Epoch 99/300
# 10/10 - 0s - loss: 2.2817e-06 - 23ms/epoch - 2ms/step
# Epoch 100/300
# 10/10 - 0s - loss: 1.3200e-06 - 23ms/epoch - 2ms/step
# Epoch 101/300
# 10/10 - 0s - loss: 2.7835e-06 - 24ms/epoch - 2ms/step
# Epoch 102/300
# 10/10 - 0s - loss: 1.6135e-06 - 23ms/epoch - 2ms/step
# Epoch 103/300
# 10/10 - 0s - loss: 1.3037e-06 - 23ms/epoch - 2ms/step
# Epoch 104/300
# 10/10 - 0s - loss: 1.4744e-06 - 25ms/epoch - 2ms/step
# Epoch 105/300
# 10/10 - 0s - loss: 1.9026e-06 - 24ms/epoch - 2ms/step
# Epoch 106/300
# 10/10 - 0s - loss: 1.3188e-06 - 23ms/epoch - 2ms/step
# Epoch 107/300
# 10/10 - 0s - loss: 1.2673e-06 - 23ms/epoch - 2ms/step
# Epoch 108/300
# 10/10 - 0s - loss: 1.5416e-06 - 22ms/epoch - 2ms/step
# Epoch 109/300
# 10/10 - 0s - loss: 1.2765e-06 - 22ms/epoch - 2ms/step
# Epoch 110/300
# 10/10 - 0s - loss: 1.4955e-06 - 23ms/epoch - 2ms/step
# Epoch 111/300
# 10/10 - 0s - loss: 2.1722e-06 - 23ms/epoch - 2ms/step
# Epoch 112/300
# 10/10 - 0s - loss: 2.8343e-06 - 24ms/epoch - 2ms/step
# Epoch 113/300
# 10/10 - 0s - loss: 2.0202e-06 - 25ms/epoch - 2ms/step
# Epoch 114/300
# 10/10 - 0s - loss: 1.3082e-06 - 23ms/epoch - 2ms/step
# Epoch 115/300
# 10/10 - 0s - loss: 9.5126e-07 - 24ms/epoch - 2ms/step
# Epoch 116/300
# 10/10 - 0s - loss: 9.2749e-07 - 23ms/epoch - 2ms/step
# Epoch 117/300
# 10/10 - 0s - loss: 8.7329e-07 - 24ms/epoch - 2ms/step
# Epoch 118/300
# 10/10 - 0s - loss: 8.6583e-07 - 23ms/epoch - 2ms/step
# Epoch 119/300
# 10/10 - 0s - loss: 1.0407e-06 - 23ms/epoch - 2ms/step
# Epoch 120/300
# 10/10 - 0s - loss: 1.7537e-06 - 23ms/epoch - 2ms/step
# Epoch 121/300
# 10/10 - 0s - loss: 2.3807e-06 - 26ms/epoch - 3ms/step
# Epoch 122/300
# 10/10 - 0s - loss: 1.5229e-06 - 22ms/epoch - 2ms/step
# Epoch 123/300
# 10/10 - 0s - loss: 1.0594e-06 - 22ms/epoch - 2ms/step
# Epoch 124/300
# 10/10 - 0s - loss: 1.4189e-06 - 23ms/epoch - 2ms/step
# Epoch 125/300
# 10/10 - 0s - loss: 9.4508e-07 - 23ms/epoch - 2ms/step
# Epoch 126/300
# 10/10 - 0s - loss: 2.3594e-06 - 25ms/epoch - 2ms/step
# Epoch 127/300
# 10/10 - 0s - loss: 2.3379e-06 - 25ms/epoch - 3ms/step
# Epoch 128/300
# 10/10 - 0s - loss: 1.0917e-06 - 25ms/epoch - 2ms/step
# Epoch 129/300
# 10/10 - 0s - loss: 9.6262e-07 - 24ms/epoch - 2ms/step
# Epoch 130/300
# 10/10 - 0s - loss: 1.5333e-06 - 23ms/epoch - 2ms/step
# Epoch 131/300
# 10/10 - 0s - loss: 1.3595e-06 - 25ms/epoch - 2ms/step
# Epoch 132/300
# 10/10 - 0s - loss: 1.5225e-06 - 23ms/epoch - 2ms/step
# Epoch 133/300
# 10/10 - 0s - loss: 1.3685e-06 - 25ms/epoch - 3ms/step
# Epoch 134/300
# 10/10 - 0s - loss: 1.2006e-06 - 25ms/epoch - 2ms/step
# Epoch 135/300
# 10/10 - 0s - loss: 1.9360e-06 - 24ms/epoch - 2ms/step
# Epoch 136/300
# 10/10 - 0s - loss: 8.7897e-07 - 23ms/epoch - 2ms/step
# Epoch 137/300
# 10/10 - 0s - loss: 8.7280e-07 - 23ms/epoch - 2ms/step
# Epoch 138/300
# 10/10 - 0s - loss: 3.0364e-06 - 24ms/epoch - 2ms/step
# Epoch 139/300
# 10/10 - 0s - loss: 1.3419e-06 - 24ms/epoch - 2ms/step
# Epoch 140/300
# 10/10 - 0s - loss: 1.4251e-06 - 24ms/epoch - 2ms/step
# Epoch 141/300
# 10/10 - 0s - loss: 1.8630e-06 - 23ms/epoch - 2ms/step
# Epoch 142/300
# 10/10 - 0s - loss: 1.1178e-06 - 23ms/epoch - 2ms/step
# Epoch 143/300
# 10/10 - 0s - loss: 8.0765e-07 - 23ms/epoch - 2ms/step
# Epoch 144/300
# 10/10 - 0s - loss: 1.6568e-06 - 24ms/epoch - 2ms/step
# Epoch 145/300
# 10/10 - 0s - loss: 1.1207e-06 - 23ms/epoch - 2ms/step
# Epoch 146/300
# 10/10 - 0s - loss: 1.2206e-06 - 23ms/epoch - 2ms/step
# Epoch 147/300
# 10/10 - 0s - loss: 1.1184e-06 - 23ms/epoch - 2ms/step
# Epoch 148/300
# 10/10 - 0s - loss: 1.8952e-06 - 23ms/epoch - 2ms/step
# Epoch 149/300
# 10/10 - 0s - loss: 1.0216e-06 - 25ms/epoch - 3ms/step
# Epoch 150/300
# 10/10 - 0s - loss: 7.1973e-07 - 23ms/epoch - 2ms/step
# Epoch 151/300
# 10/10 - 0s - loss: 7.1795e-07 - 22ms/epoch - 2ms/step
# Epoch 152/300
# 10/10 - 0s - loss: 7.0570e-07 - 24ms/epoch - 2ms/step
# Epoch 153/300
# 10/10 - 0s - loss: 6.0419e-07 - 23ms/epoch - 2ms/step
# Epoch 154/300
# 10/10 - 0s - loss: 9.1378e-07 - 24ms/epoch - 2ms/step
# Epoch 155/300
# 10/10 - 0s - loss: 7.6853e-07 - 23ms/epoch - 2ms/step
# Epoch 156/300
# 10/10 - 0s - loss: 4.4833e-07 - 24ms/epoch - 2ms/step
# Epoch 157/300
# 10/10 - 0s - loss: 4.1911e-07 - 24ms/epoch - 2ms/step
# Epoch 158/300
# 10/10 - 0s - loss: 7.9612e-07 - 23ms/epoch - 2ms/step
# Epoch 159/300
# 10/10 - 0s - loss: 1.2960e-06 - 22ms/epoch - 2ms/step
# Epoch 160/300
# 10/10 - 0s - loss: 6.4221e-07 - 24ms/epoch - 2ms/step
# Epoch 161/300
# 10/10 - 0s - loss: 7.0096e-07 - 24ms/epoch - 2ms/step
# Epoch 162/300
# 10/10 - 0s - loss: 5.3138e-07 - 23ms/epoch - 2ms/step
# Epoch 163/300
# 10/10 - 0s - loss: 7.5511e-07 - 24ms/epoch - 2ms/step
# Epoch 164/300
# 10/10 - 0s - loss: 8.3173e-07 - 23ms/epoch - 2ms/step
# Epoch 165/300
# 10/10 - 0s - loss: 7.3943e-07 - 22ms/epoch - 2ms/step
# Epoch 166/300
# 10/10 - 0s - loss: 6.3070e-07 - 23ms/epoch - 2ms/step
# Epoch 167/300
# 10/10 - 0s - loss: 5.5240e-07 - 22ms/epoch - 2ms/step
# Epoch 168/300
# 10/10 - 0s - loss: 5.2226e-07 - 23ms/epoch - 2ms/step
# Epoch 169/300
# 10/10 - 0s - loss: 4.7922e-07 - 23ms/epoch - 2ms/step
# Epoch 170/300
# 10/10 - 0s - loss: 3.6814e-07 - 23ms/epoch - 2ms/step
# Epoch 171/300
# 10/10 - 0s - loss: 5.9784e-07 - 23ms/epoch - 2ms/step
# Epoch 172/300
# 10/10 - 0s - loss: 9.4152e-07 - 24ms/epoch - 2ms/step
# Epoch 173/300
# 10/10 - 0s - loss: 1.6631e-06 - 23ms/epoch - 2ms/step
# Epoch 174/300
# 10/10 - 0s - loss: 9.8544e-07 - 24ms/epoch - 2ms/step
# Epoch 175/300
# 10/10 - 0s - loss: 7.7841e-07 - 24ms/epoch - 2ms/step
# Epoch 176/300
# 10/10 - 0s - loss: 6.4893e-07 - 24ms/epoch - 2ms/step
# Epoch 177/300
# 10/10 - 0s - loss: 8.5233e-07 - 23ms/epoch - 2ms/step
# Epoch 178/300
# 10/10 - 0s - loss: 3.0965e-06 - 23ms/epoch - 2ms/step
# Epoch 179/300
# 10/10 - 0s - loss: 2.5682e-06 - 23ms/epoch - 2ms/step
# Epoch 180/300
# 10/10 - 0s - loss: 3.4667e-06 - 25ms/epoch - 3ms/step
# Epoch 181/300
# 10/10 - 0s - loss: 3.4918e-06 - 22ms/epoch - 2ms/step
# Epoch 182/300
# 10/10 - 0s - loss: 2.0786e-06 - 23ms/epoch - 2ms/step
# Epoch 183/300
# 10/10 - 0s - loss: 3.4255e-06 - 23ms/epoch - 2ms/step
# Epoch 184/300
# 10/10 - 0s - loss: 3.4074e-06 - 23ms/epoch - 2ms/step
# Epoch 185/300
# 10/10 - 0s - loss: 1.9359e-06 - 24ms/epoch - 2ms/step
# Epoch 186/300
# 10/10 - 0s - loss: 1.8436e-06 - 22ms/epoch - 2ms/step
# Epoch 187/300
# 10/10 - 0s - loss: 2.8403e-06 - 22ms/epoch - 2ms/step
# Epoch 188/300
# 10/10 - 0s - loss: 3.1073e-06 - 25ms/epoch - 2ms/step
# Epoch 189/300
# 10/10 - 0s - loss: 1.6643e-06 - 25ms/epoch - 3ms/step
# Epoch 190/300
# 10/10 - 0s - loss: 1.4929e-06 - 23ms/epoch - 2ms/step
# Epoch 191/300
# 10/10 - 0s - loss: 9.9957e-07 - 25ms/epoch - 3ms/step
# Epoch 192/300
# 10/10 - 0s - loss: 8.5046e-07 - 25ms/epoch - 2ms/step
# Epoch 193/300
# 10/10 - 0s - loss: 3.7236e-07 - 24ms/epoch - 2ms/step
# Epoch 194/300
# 10/10 - 0s - loss: 7.4786e-07 - 27ms/epoch - 3ms/step
# Epoch 195/300
# 10/10 - 0s - loss: 1.6361e-06 - 26ms/epoch - 3ms/step
# Epoch 196/300
# 10/10 - 0s - loss: 4.1646e-06 - 25ms/epoch - 3ms/step
# Epoch 197/300
# 10/10 - 0s - loss: 1.1056e-05 - 24ms/epoch - 2ms/step
# Epoch 198/300
# 10/10 - 0s - loss: 1.3061e-05 - 23ms/epoch - 2ms/step
# Epoch 199/300
# 10/10 - 0s - loss: 4.5790e-06 - 25ms/epoch - 2ms/step
# Epoch 200/300
# 10/10 - 0s - loss: 8.8314e-06 - 22ms/epoch - 2ms/step
# Epoch 201/300
# 10/10 - 0s - loss: 1.1990e-05 - 23ms/epoch - 2ms/step
# Epoch 202/300
# 10/10 - 0s - loss: 5.8318e-06 - 22ms/epoch - 2ms/step
# Epoch 203/300
# 10/10 - 0s - loss: 3.9044e-06 - 25ms/epoch - 3ms/step
# Epoch 204/300
# 10/10 - 0s - loss: 2.4275e-06 - 24ms/epoch - 2ms/step
# Epoch 205/300
# 10/10 - 0s - loss: 3.0775e-06 - 23ms/epoch - 2ms/step
# Epoch 206/300
# 10/10 - 0s - loss: 2.8025e-06 - 23ms/epoch - 2ms/step
# Epoch 207/300
# 10/10 - 0s - loss: 2.4019e-06 - 23ms/epoch - 2ms/step
# Epoch 208/300
# 10/10 - 0s - loss: 3.6866e-06 - 24ms/epoch - 2ms/step
# Epoch 209/300
# 10/10 - 0s - loss: 2.0878e-06 - 25ms/epoch - 2ms/step
# Epoch 210/300
# 10/10 - 0s - loss: 4.9319e-07 - 25ms/epoch - 2ms/step
# Epoch 211/300
# 10/10 - 0s - loss: 4.0044e-07 - 23ms/epoch - 2ms/step
# Epoch 212/300
# 10/10 - 0s - loss: 2.2465e-07 - 23ms/epoch - 2ms/step
# Epoch 213/300
# 10/10 - 0s - loss: 3.7956e-07 - 23ms/epoch - 2ms/step
# Epoch 214/300
# 10/10 - 0s - loss: 4.1370e-07 - 24ms/epoch - 2ms/step
# Epoch 215/300
# 10/10 - 0s - loss: 3.5060e-07 - 24ms/epoch - 2ms/step
# Epoch 216/300
# 10/10 - 0s - loss: 2.6880e-07 - 23ms/epoch - 2ms/step
# Epoch 217/300
# 10/10 - 0s - loss: 3.5896e-07 - 24ms/epoch - 2ms/step
# Epoch 218/300
# 10/10 - 0s - loss: 5.0261e-07 - 27ms/epoch - 3ms/step
# Epoch 219/300
# 10/10 - 0s - loss: 3.5279e-07 - 27ms/epoch - 3ms/step
# Epoch 220/300
# 10/10 - 0s - loss: 5.1914e-07 - 25ms/epoch - 3ms/step
# Epoch 221/300
# 10/10 - 0s - loss: 4.9831e-07 - 23ms/epoch - 2ms/step
# Epoch 222/300
# 10/10 - 0s - loss: 4.8627e-07 - 23ms/epoch - 2ms/step
# Epoch 223/300
# 10/10 - 0s - loss: 5.1679e-07 - 22ms/epoch - 2ms/step
# Epoch 224/300
# 10/10 - 0s - loss: 1.0481e-06 - 22ms/epoch - 2ms/step
# Epoch 225/300
# 10/10 - 0s - loss: 4.6257e-07 - 23ms/epoch - 2ms/step
# Epoch 226/300
# 10/10 - 0s - loss: 6.0019e-07 - 23ms/epoch - 2ms/step
# Epoch 227/300
# 10/10 - 0s - loss: 1.0507e-06 - 24ms/epoch - 2ms/step
# Epoch 228/300
# 10/10 - 0s - loss: 6.1282e-06 - 23ms/epoch - 2ms/step
# Epoch 229/300
# 10/10 - 0s - loss: 4.9356e-06 - 23ms/epoch - 2ms/step
# Epoch 230/300
# 10/10 - 0s - loss: 3.8554e-06 - 22ms/epoch - 2ms/step
# Epoch 231/300
# 10/10 - 0s - loss: 5.9817e-06 - 24ms/epoch - 2ms/step
# Epoch 232/300
# 10/10 - 0s - loss: 1.8266e-06 - 25ms/epoch - 3ms/step
# Epoch 233/300
# 10/10 - 0s - loss: 2.5608e-06 - 23ms/epoch - 2ms/step
# Epoch 234/300
# 10/10 - 0s - loss: 1.3580e-06 - 23ms/epoch - 2ms/step
# Epoch 235/300
# 10/10 - 0s - loss: 6.7749e-07 - 24ms/epoch - 2ms/step
# Epoch 236/300
# 10/10 - 0s - loss: 5.4274e-07 - 24ms/epoch - 2ms/step
# Epoch 237/300
# 10/10 - 0s - loss: 6.3331e-07 - 24ms/epoch - 2ms/step
# Epoch 238/300
# 10/10 - 0s - loss: 7.1063e-07 - 24ms/epoch - 2ms/step
# Epoch 239/300
# 10/10 - 0s - loss: 2.6324e-06 - 24ms/epoch - 2ms/step
# Epoch 240/300
# 10/10 - 0s - loss: 2.5974e-06 - 23ms/epoch - 2ms/step
# Epoch 241/300
# 10/10 - 0s - loss: 2.1104e-06 - 24ms/epoch - 2ms/step
# Epoch 242/300
# 10/10 - 0s - loss: 1.9264e-06 - 24ms/epoch - 2ms/step
# Epoch 243/300
# 10/10 - 0s - loss: 1.5600e-06 - 24ms/epoch - 2ms/step
# Epoch 244/300
# 10/10 - 0s - loss: 1.2198e-06 - 23ms/epoch - 2ms/step
# Epoch 245/300
# 10/10 - 0s - loss: 2.4839e-07 - 24ms/epoch - 2ms/step
# Epoch 246/300
# 10/10 - 0s - loss: 3.1187e-07 - 22ms/epoch - 2ms/step
# Epoch 247/300
# 10/10 - 0s - loss: 4.8452e-07 - 24ms/epoch - 2ms/step
# Epoch 248/300
# 10/10 - 0s - loss: 2.4659e-07 - 24ms/epoch - 2ms/step
# Epoch 249/300
# 10/10 - 0s - loss: 2.7568e-07 - 25ms/epoch - 3ms/step
# Epoch 250/300
# 10/10 - 0s - loss: 5.8296e-07 - 24ms/epoch - 2ms/step
# Epoch 251/300
# 10/10 - 0s - loss: 1.2488e-06 - 24ms/epoch - 2ms/step
# Epoch 252/300
# 10/10 - 0s - loss: 7.6595e-07 - 24ms/epoch - 2ms/step
# Epoch 253/300
# 10/10 - 0s - loss: 1.4821e-06 - 25ms/epoch - 2ms/step
# Epoch 254/300
# 10/10 - 0s - loss: 3.9820e-06 - 24ms/epoch - 2ms/step
# Epoch 255/300
# 10/10 - 0s - loss: 2.8497e-06 - 25ms/epoch - 3ms/step
# Epoch 256/300
# 10/10 - 0s - loss: 6.4021e-06 - 24ms/epoch - 2ms/step
# Epoch 257/300
# 10/10 - 0s - loss: 2.4692e-05 - 24ms/epoch - 2ms/step
# Epoch 258/300
# 10/10 - 0s - loss: 3.3444e-05 - 22ms/epoch - 2ms/step
# Epoch 259/300
# 10/10 - 0s - loss: 1.6083e-05 - 23ms/epoch - 2ms/step
# Epoch 260/300
# 10/10 - 0s - loss: 6.8736e-06 - 22ms/epoch - 2ms/step
# Epoch 261/300
# 10/10 - 0s - loss: 3.4794e-05 - 24ms/epoch - 2ms/step
# Epoch 262/300
# 10/10 - 0s - loss: 3.9340e-05 - 24ms/epoch - 2ms/step
# Epoch 263/300
# 10/10 - 0s - loss: 6.0694e-05 - 22ms/epoch - 2ms/step
# Epoch 264/300
# 10/10 - 0s - loss: 3.9185e-05 - 24ms/epoch - 2ms/step
# Epoch 265/300
# 10/10 - 0s - loss: 8.0084e-05 - 23ms/epoch - 2ms/step
# Epoch 266/300
# 10/10 - 0s - loss: 1.8383e-04 - 24ms/epoch - 2ms/step
# Epoch 267/300
# 10/10 - 0s - loss: 1.2103e-04 - 26ms/epoch - 3ms/step
# Epoch 268/300
# 10/10 - 0s - loss: 5.2964e-05 - 25ms/epoch - 2ms/step
# Epoch 269/300
# 10/10 - 0s - loss: 2.7783e-05 - 24ms/epoch - 2ms/step
# Epoch 270/300
# 10/10 - 0s - loss: 1.6086e-05 - 24ms/epoch - 2ms/step
# Epoch 271/300
# 10/10 - 0s - loss: 3.6215e-06 - 24ms/epoch - 2ms/step
# Epoch 272/300
# 10/10 - 0s - loss: 2.4499e-06 - 25ms/epoch - 2ms/step
# Epoch 273/300
# 10/10 - 0s - loss: 2.9512e-06 - 23ms/epoch - 2ms/step
# Epoch 274/300
# 10/10 - 0s - loss: 2.2784e-06 - 24ms/epoch - 2ms/step
# Epoch 275/300
# 10/10 - 0s - loss: 4.8997e-06 - 22ms/epoch - 2ms/step
# Epoch 276/300
# 10/10 - 0s - loss: 6.1885e-06 - 24ms/epoch - 2ms/step
# Epoch 277/300
# 10/10 - 0s - loss: 7.2964e-06 - 23ms/epoch - 2ms/step
# Epoch 278/300
# 10/10 - 0s - loss: 2.6976e-06 - 23ms/epoch - 2ms/step
# Epoch 279/300
# 10/10 - 0s - loss: 3.3807e-06 - 24ms/epoch - 2ms/step
# Epoch 280/300
# 10/10 - 0s - loss: 3.8041e-06 - 23ms/epoch - 2ms/step
# Epoch 281/300
# 10/10 - 0s - loss: 4.5013e-06 - 23ms/epoch - 2ms/step
# Epoch 282/300
# 10/10 - 0s - loss: 4.1285e-06 - 26ms/epoch - 3ms/step
# Epoch 283/300
# 10/10 - 0s - loss: 4.1288e-06 - 24ms/epoch - 2ms/step
# Epoch 284/300
# 10/10 - 0s - loss: 1.0112e-06 - 23ms/epoch - 2ms/step
# Epoch 285/300
# 10/10 - 0s - loss: 4.5806e-07 - 24ms/epoch - 2ms/step
# Epoch 286/300
# 10/10 - 0s - loss: 3.4036e-07 - 23ms/epoch - 2ms/step
# Epoch 287/300
# 10/10 - 0s - loss: 4.5304e-07 - 25ms/epoch - 2ms/step
# Epoch 288/300
# 10/10 - 0s - loss: 8.5184e-07 - 25ms/epoch - 2ms/step
# Epoch 289/300
# 10/10 - 0s - loss: 9.8389e-07 - 22ms/epoch - 2ms/step
# Epoch 290/300
# 10/10 - 0s - loss: 3.7541e-07 - 23ms/epoch - 2ms/step
# Epoch 291/300
# 10/10 - 0s - loss: 4.1663e-07 - 24ms/epoch - 2ms/step
# Epoch 292/300
# 10/10 - 0s - loss: 8.1943e-07 - 24ms/epoch - 2ms/step
# Epoch 293/300
# 10/10 - 0s - loss: 9.4992e-07 - 23ms/epoch - 2ms/step
# Epoch 294/300
# 10/10 - 0s - loss: 1.7211e-06 - 25ms/epoch - 2ms/step
# Epoch 295/300
# 10/10 - 0s - loss: 1.6198e-06 - 24ms/epoch - 2ms/step
# Epoch 296/300
# 10/10 - 0s - loss: 8.0545e-07 - 24ms/epoch - 2ms/step
# Epoch 297/300
# 10/10 - 0s - loss: 7.5296e-07 - 23ms/epoch - 2ms/step
# Epoch 298/300
# 10/10 - 0s - loss: 1.4727e-06 - 23ms/epoch - 2ms/step
# Epoch 299/300
# 10/10 - 0s - loss: 7.3377e-06 - 24ms/epoch - 2ms/step
# Epoch 300/300
# 10/10 - 0s - loss: 9.8444e-06 - 23ms/epoch - 2ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 14/14 [==============================] - 0s 4ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710203886.0942152
# Tue Mar 12 00:38:06 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1710203886.106453
# Tue Mar 12 00:38:06 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2, batch_size=8)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 10/10 - 1s - loss: 0.4814 - 645ms/epoch - 64ms/step
# Epoch 2/300
# 10/10 - 0s - loss: 0.1585 - 70ms/epoch - 7ms/step
# Epoch 3/300
# 10/10 - 0s - loss: 0.0900 - 71ms/epoch - 7ms/step
# Epoch 4/300
# 10/10 - 0s - loss: 0.0908 - 61ms/epoch - 6ms/step
# Epoch 5/300
# 10/10 - 0s - loss: 0.0709 - 70ms/epoch - 7ms/step
# Epoch 6/300
# 10/10 - 0s - loss: 0.0592 - 71ms/epoch - 7ms/step
# Epoch 7/300
# 10/10 - 0s - loss: 0.0644 - 66ms/epoch - 7ms/step
# Epoch 8/300
# 10/10 - 0s - loss: 0.0669 - 67ms/epoch - 7ms/step
# Epoch 9/300
# 10/10 - 0s - loss: 0.0640 - 71ms/epoch - 7ms/step
# Epoch 10/300
# 10/10 - 0s - loss: 0.0616 - 65ms/epoch - 6ms/step
# Epoch 11/300
# 10/10 - 0s - loss: 0.0709 - 62ms/epoch - 6ms/step
# Epoch 12/300
# 10/10 - 0s - loss: 0.0574 - 61ms/epoch - 6ms/step
# Epoch 13/300
# 10/10 - 0s - loss: 0.0777 - 56ms/epoch - 6ms/step
# Epoch 14/300
# 10/10 - 0s - loss: 0.0644 - 68ms/epoch - 7ms/step
# Epoch 15/300
# 10/10 - 0s - loss: 0.0649 - 60ms/epoch - 6ms/step
# Epoch 16/300
# 10/10 - 0s - loss: 0.0796 - 66ms/epoch - 7ms/step
# Epoch 17/300
# 10/10 - 0s - loss: 0.1090 - 65ms/epoch - 7ms/step
# Epoch 18/300
# 10/10 - 0s - loss: 0.1343 - 57ms/epoch - 6ms/step
# Epoch 19/300
# 10/10 - 0s - loss: 0.1180 - 61ms/epoch - 6ms/step
# Epoch 20/300
# 10/10 - 0s - loss: 0.0572 - 59ms/epoch - 6ms/step
# Epoch 21/300
# 10/10 - 0s - loss: 0.0575 - 67ms/epoch - 7ms/step
# Epoch 22/300
# 10/10 - 0s - loss: 0.0451 - 59ms/epoch - 6ms/step
# Epoch 23/300
# 10/10 - 0s - loss: 0.0438 - 64ms/epoch - 6ms/step
# Epoch 24/300
# 10/10 - 0s - loss: 0.0406 - 67ms/epoch - 7ms/step
# Epoch 25/300
# 10/10 - 0s - loss: 0.0369 - 67ms/epoch - 7ms/step
# Epoch 26/300
# 10/10 - 0s - loss: 0.0367 - 65ms/epoch - 6ms/step
# Epoch 27/300
# 10/10 - 0s - loss: 0.0349 - 59ms/epoch - 6ms/step
# Epoch 28/300
# 10/10 - 0s - loss: 0.0374 - 63ms/epoch - 6ms/step
# Epoch 29/300
# 10/10 - 0s - loss: 0.0311 - 61ms/epoch - 6ms/step
# Epoch 30/300
# 10/10 - 0s - loss: 0.0268 - 64ms/epoch - 6ms/step
# Epoch 31/300
# 10/10 - 0s - loss: 0.0317 - 59ms/epoch - 6ms/step
# Epoch 32/300
# 10/10 - 0s - loss: 0.0246 - 59ms/epoch - 6ms/step
# Epoch 33/300
# 10/10 - 0s - loss: 0.0234 - 62ms/epoch - 6ms/step
# Epoch 34/300
# 10/10 - 0s - loss: 0.0219 - 60ms/epoch - 6ms/step
# Epoch 35/300
# 10/10 - 0s - loss: 0.0204 - 60ms/epoch - 6ms/step
# Epoch 36/300
# 10/10 - 0s - loss: 0.0190 - 64ms/epoch - 6ms/step
# Epoch 37/300
# 10/10 - 0s - loss: 0.0233 - 61ms/epoch - 6ms/step
# Epoch 38/300
# 10/10 - 0s - loss: 0.0240 - 61ms/epoch - 6ms/step
# Epoch 39/300
# 10/10 - 0s - loss: 0.0283 - 63ms/epoch - 6ms/step
# Epoch 40/300
# 10/10 - 0s - loss: 0.0173 - 64ms/epoch - 6ms/step
# Epoch 41/300
# 10/10 - 0s - loss: 0.0112 - 58ms/epoch - 6ms/step
# Epoch 42/300
# 10/10 - 0s - loss: 0.0153 - 63ms/epoch - 6ms/step
# Epoch 43/300
# 10/10 - 0s - loss: 0.0106 - 60ms/epoch - 6ms/step
# Epoch 44/300
# 10/10 - 0s - loss: 0.0102 - 62ms/epoch - 6ms/step
# Epoch 45/300
# 10/10 - 0s - loss: 0.0076 - 60ms/epoch - 6ms/step
# Epoch 46/300
# 10/10 - 0s - loss: 0.0119 - 63ms/epoch - 6ms/step
# Epoch 47/300
# 10/10 - 0s - loss: 0.0136 - 63ms/epoch - 6ms/step
# Epoch 48/300
# 10/10 - 0s - loss: 0.0111 - 55ms/epoch - 6ms/step
# Epoch 49/300
# 10/10 - 0s - loss: 0.0065 - 60ms/epoch - 6ms/step
# Epoch 50/300
# 10/10 - 0s - loss: 0.0060 - 58ms/epoch - 6ms/step
# Epoch 51/300
# 10/10 - 0s - loss: 0.0048 - 58ms/epoch - 6ms/step
# Epoch 52/300
# 10/10 - 0s - loss: 0.0035 - 62ms/epoch - 6ms/step
# Epoch 53/300
# 10/10 - 0s - loss: 0.0030 - 58ms/epoch - 6ms/step
# Epoch 54/300
# 10/10 - 0s - loss: 0.0028 - 61ms/epoch - 6ms/step
# Epoch 55/300
# 10/10 - 0s - loss: 0.0022 - 69ms/epoch - 7ms/step
# Epoch 56/300
# 10/10 - 0s - loss: 0.0023 - 68ms/epoch - 7ms/step
# Epoch 57/300
# 10/10 - 0s - loss: 0.0016 - 67ms/epoch - 7ms/step
# Epoch 58/300
# 10/10 - 0s - loss: 0.0019 - 63ms/epoch - 6ms/step
# Epoch 59/300
# 10/10 - 0s - loss: 0.0020 - 62ms/epoch - 6ms/step
# Epoch 60/300
# 10/10 - 0s - loss: 0.0021 - 62ms/epoch - 6ms/step
# Epoch 61/300
# 10/10 - 0s - loss: 0.0016 - 62ms/epoch - 6ms/step
# Epoch 62/300
# 10/10 - 0s - loss: 0.0013 - 61ms/epoch - 6ms/step
# Epoch 63/300
# 10/10 - 0s - loss: 9.9823e-04 - 61ms/epoch - 6ms/step
# Epoch 64/300
# 10/10 - 0s - loss: 0.0013 - 61ms/epoch - 6ms/step
# Epoch 65/300
# 10/10 - 0s - loss: 0.0014 - 63ms/epoch - 6ms/step
# Epoch 66/300
# 10/10 - 0s - loss: 9.8379e-04 - 65ms/epoch - 6ms/step
# Epoch 67/300
# 10/10 - 0s - loss: 0.0015 - 65ms/epoch - 7ms/step
# Epoch 68/300
# 10/10 - 0s - loss: 0.0021 - 60ms/epoch - 6ms/step
# Epoch 69/300
# 10/10 - 0s - loss: 0.0028 - 60ms/epoch - 6ms/step
# Epoch 70/300
# 10/10 - 0s - loss: 0.0026 - 59ms/epoch - 6ms/step
# Epoch 71/300
# 10/10 - 0s - loss: 0.0017 - 59ms/epoch - 6ms/step
# Epoch 72/300
# 10/10 - 0s - loss: 0.0017 - 61ms/epoch - 6ms/step
# Epoch 73/300
# 10/10 - 0s - loss: 0.0016 - 58ms/epoch - 6ms/step
# Epoch 74/300
# 10/10 - 0s - loss: 0.0016 - 62ms/epoch - 6ms/step
# Epoch 75/300
# 10/10 - 0s - loss: 0.0018 - 58ms/epoch - 6ms/step
# Epoch 76/300
# 10/10 - 0s - loss: 8.8525e-04 - 65ms/epoch - 6ms/step
# Epoch 77/300
# 10/10 - 0s - loss: 0.0010 - 60ms/epoch - 6ms/step
# Epoch 78/300
# 10/10 - 0s - loss: 8.0716e-04 - 65ms/epoch - 6ms/step
# Epoch 79/300
# 10/10 - 0s - loss: 7.0996e-04 - 63ms/epoch - 6ms/step
# Epoch 80/300
# 10/10 - 0s - loss: 6.3380e-04 - 61ms/epoch - 6ms/step
# Epoch 81/300
# 10/10 - 0s - loss: 7.3273e-04 - 60ms/epoch - 6ms/step
# Epoch 82/300
# 10/10 - 0s - loss: 3.6685e-04 - 61ms/epoch - 6ms/step
# Epoch 83/300
# 10/10 - 0s - loss: 1.7402e-04 - 57ms/epoch - 6ms/step
# Epoch 84/300
# 10/10 - 0s - loss: 1.6492e-04 - 62ms/epoch - 6ms/step
# Epoch 85/300
# 10/10 - 0s - loss: 2.0461e-04 - 58ms/epoch - 6ms/step
# Epoch 86/300
# 10/10 - 0s - loss: 1.6749e-04 - 58ms/epoch - 6ms/step
# Epoch 87/300
# 10/10 - 0s - loss: 2.6620e-04 - 56ms/epoch - 6ms/step
# Epoch 88/300
# 10/10 - 0s - loss: 1.4295e-04 - 56ms/epoch - 6ms/step
# Epoch 89/300
# 10/10 - 0s - loss: 6.9355e-05 - 62ms/epoch - 6ms/step
# Epoch 90/300
# 10/10 - 0s - loss: 1.3512e-04 - 63ms/epoch - 6ms/step
# Epoch 91/300
# 10/10 - 0s - loss: 1.1210e-04 - 62ms/epoch - 6ms/step
# Epoch 92/300
# 10/10 - 0s - loss: 1.3393e-04 - 63ms/epoch - 6ms/step
# Epoch 93/300
# 10/10 - 0s - loss: 1.2028e-04 - 59ms/epoch - 6ms/step
# Epoch 94/300
# 10/10 - 0s - loss: 1.2448e-04 - 59ms/epoch - 6ms/step
# Epoch 95/300
# 10/10 - 0s - loss: 7.9193e-05 - 61ms/epoch - 6ms/step
# Epoch 96/300
# 10/10 - 0s - loss: 7.8975e-05 - 56ms/epoch - 6ms/step
# Epoch 97/300
# 10/10 - 0s - loss: 4.7886e-05 - 59ms/epoch - 6ms/step
# Epoch 98/300
# 10/10 - 0s - loss: 3.0325e-05 - 60ms/epoch - 6ms/step
# Epoch 99/300
# 10/10 - 0s - loss: 3.1222e-05 - 63ms/epoch - 6ms/step
# Epoch 100/300
# 10/10 - 0s - loss: 1.0590e-04 - 67ms/epoch - 7ms/step
# Epoch 101/300
# 10/10 - 0s - loss: 2.6176e-04 - 57ms/epoch - 6ms/step
# Epoch 102/300
# 10/10 - 0s - loss: 5.2635e-04 - 60ms/epoch - 6ms/step
# Epoch 103/300
# 10/10 - 0s - loss: 0.0012 - 61ms/epoch - 6ms/step
# Epoch 104/300
# 10/10 - 0s - loss: 0.0012 - 59ms/epoch - 6ms/step
# Epoch 105/300
# 10/10 - 0s - loss: 4.3441e-04 - 67ms/epoch - 7ms/step
# Epoch 106/300
# 10/10 - 0s - loss: 2.1039e-04 - 60ms/epoch - 6ms/step
# Epoch 107/300
# 10/10 - 0s - loss: 1.1376e-04 - 59ms/epoch - 6ms/step
# Epoch 108/300
# 10/10 - 0s - loss: 9.0386e-05 - 66ms/epoch - 7ms/step
# Epoch 109/300
# 10/10 - 0s - loss: 7.6327e-05 - 67ms/epoch - 7ms/step
# Epoch 110/300
# 10/10 - 0s - loss: 8.2171e-05 - 62ms/epoch - 6ms/step
# Epoch 111/300
# 10/10 - 0s - loss: 7.7882e-05 - 63ms/epoch - 6ms/step
# Epoch 112/300
# 10/10 - 0s - loss: 8.8628e-05 - 55ms/epoch - 6ms/step
# Epoch 113/300
# 10/10 - 0s - loss: 1.1773e-04 - 62ms/epoch - 6ms/step
# Epoch 114/300
# 10/10 - 0s - loss: 9.3107e-05 - 62ms/epoch - 6ms/step
# Epoch 115/300
# 10/10 - 0s - loss: 5.5193e-05 - 63ms/epoch - 6ms/step
# Epoch 116/300
# 10/10 - 0s - loss: 6.7921e-05 - 63ms/epoch - 6ms/step
# Epoch 117/300
# 10/10 - 0s - loss: 4.7559e-05 - 68ms/epoch - 7ms/step
# Epoch 118/300
# 10/10 - 0s - loss: 4.9899e-05 - 67ms/epoch - 7ms/step
# Epoch 119/300
# 10/10 - 0s - loss: 7.5710e-05 - 61ms/epoch - 6ms/step
# Epoch 120/300
# 10/10 - 0s - loss: 3.6173e-05 - 58ms/epoch - 6ms/step
# Epoch 121/300
# 10/10 - 0s - loss: 7.6801e-05 - 61ms/epoch - 6ms/step
# Epoch 122/300
# 10/10 - 0s - loss: 1.4837e-04 - 62ms/epoch - 6ms/step
# Epoch 123/300
# 10/10 - 0s - loss: 2.8539e-04 - 65ms/epoch - 6ms/step
# Epoch 124/300
# 10/10 - 0s - loss: 3.8643e-04 - 66ms/epoch - 7ms/step
# Epoch 125/300
# 10/10 - 0s - loss: 3.9515e-04 - 60ms/epoch - 6ms/step
# Epoch 126/300
# 10/10 - 0s - loss: 3.8472e-04 - 58ms/epoch - 6ms/step
# Epoch 127/300
# 10/10 - 0s - loss: 5.8936e-04 - 56ms/epoch - 6ms/step
# Epoch 128/300
# 10/10 - 0s - loss: 7.4944e-04 - 67ms/epoch - 7ms/step
# Epoch 129/300
# 10/10 - 0s - loss: 0.0021 - 60ms/epoch - 6ms/step
# Epoch 130/300
# 10/10 - 0s - loss: 0.0043 - 62ms/epoch - 6ms/step
# Epoch 131/300
# 10/10 - 0s - loss: 0.0041 - 62ms/epoch - 6ms/step
# Epoch 132/300
# 10/10 - 0s - loss: 0.0047 - 67ms/epoch - 7ms/step
# Epoch 133/300
# 10/10 - 0s - loss: 0.0045 - 60ms/epoch - 6ms/step
# Epoch 134/300
# 10/10 - 0s - loss: 0.0087 - 64ms/epoch - 6ms/step
# Epoch 135/300
# 10/10 - 0s - loss: 0.0266 - 58ms/epoch - 6ms/step
# Epoch 136/300
# 10/10 - 0s - loss: 0.0206 - 63ms/epoch - 6ms/step
# Epoch 137/300
# 10/10 - 0s - loss: 0.0133 - 61ms/epoch - 6ms/step
# Epoch 138/300
# 10/10 - 0s - loss: 0.0083 - 59ms/epoch - 6ms/step
# Epoch 139/300
# 10/10 - 0s - loss: 0.0125 - 57ms/epoch - 6ms/step
# Epoch 140/300
# 10/10 - 0s - loss: 0.0151 - 60ms/epoch - 6ms/step
# Epoch 141/300
# 10/10 - 0s - loss: 0.0069 - 55ms/epoch - 5ms/step
# Epoch 142/300
# 10/10 - 0s - loss: 0.0036 - 58ms/epoch - 6ms/step
# Epoch 143/300
# 10/10 - 0s - loss: 0.0028 - 57ms/epoch - 6ms/step
# Epoch 144/300
# 10/10 - 0s - loss: 0.0038 - 63ms/epoch - 6ms/step
# Epoch 145/300
# 10/10 - 0s - loss: 0.0022 - 63ms/epoch - 6ms/step
# Epoch 146/300
# 10/10 - 0s - loss: 0.0011 - 69ms/epoch - 7ms/step
# Epoch 147/300
# 10/10 - 0s - loss: 0.0031 - 60ms/epoch - 6ms/step
# Epoch 148/300
# 10/10 - 0s - loss: 0.0042 - 65ms/epoch - 7ms/step
# Epoch 149/300
# 10/10 - 0s - loss: 0.0046 - 63ms/epoch - 6ms/step
# Epoch 150/300
# 10/10 - 0s - loss: 0.0019 - 66ms/epoch - 7ms/step
# Epoch 151/300
# 10/10 - 0s - loss: 0.0011 - 58ms/epoch - 6ms/step
# Epoch 152/300
# 10/10 - 0s - loss: 0.0019 - 60ms/epoch - 6ms/step
# Epoch 153/300
# 10/10 - 0s - loss: 0.0011 - 61ms/epoch - 6ms/step
# Epoch 154/300
# 10/10 - 0s - loss: 5.1403e-04 - 61ms/epoch - 6ms/step
# Epoch 155/300
# 10/10 - 0s - loss: 7.9305e-04 - 61ms/epoch - 6ms/step
# Epoch 156/300
# 10/10 - 0s - loss: 2.9551e-04 - 61ms/epoch - 6ms/step
# Epoch 157/300
# 10/10 - 0s - loss: 9.7063e-04 - 63ms/epoch - 6ms/step
# Epoch 158/300
# 10/10 - 0s - loss: 0.0062 - 58ms/epoch - 6ms/step
# Epoch 159/300
# 10/10 - 0s - loss: 0.0526 - 59ms/epoch - 6ms/step
# Epoch 160/300
# 10/10 - 0s - loss: 0.0193 - 67ms/epoch - 7ms/step
# Epoch 161/300
# 10/10 - 0s - loss: 0.0073 - 67ms/epoch - 7ms/step
# Epoch 162/300
# 10/10 - 0s - loss: 0.0089 - 66ms/epoch - 7ms/step
# Epoch 163/300
# 10/10 - 0s - loss: 0.0071 - 59ms/epoch - 6ms/step
# Epoch 164/300
# 10/10 - 0s - loss: 0.0074 - 60ms/epoch - 6ms/step
# Epoch 165/300
# 10/10 - 0s - loss: 0.0097 - 66ms/epoch - 7ms/step
# Epoch 166/300
# 10/10 - 0s - loss: 0.0072 - 66ms/epoch - 7ms/step
# Epoch 167/300
# 10/10 - 0s - loss: 0.0089 - 65ms/epoch - 7ms/step
# Epoch 168/300
# 10/10 - 0s - loss: 0.0045 - 58ms/epoch - 6ms/step
# Epoch 169/300
# 10/10 - 0s - loss: 0.0043 - 71ms/epoch - 7ms/step
# Epoch 170/300
# 10/10 - 0s - loss: 0.0031 - 64ms/epoch - 6ms/step
# Epoch 171/300
# 10/10 - 0s - loss: 0.0013 - 63ms/epoch - 6ms/step
# Epoch 172/300
# 10/10 - 0s - loss: 0.0015 - 63ms/epoch - 6ms/step
# Epoch 173/300
# 10/10 - 0s - loss: 0.0016 - 61ms/epoch - 6ms/step
# Epoch 174/300
# 10/10 - 0s - loss: 0.0011 - 63ms/epoch - 6ms/step
# Epoch 175/300
# 10/10 - 0s - loss: 7.4162e-04 - 67ms/epoch - 7ms/step
# Epoch 176/300
# 10/10 - 0s - loss: 0.0011 - 72ms/epoch - 7ms/step
# Epoch 177/300
# 10/10 - 0s - loss: 0.0019 - 69ms/epoch - 7ms/step
# Epoch 178/300
# 10/10 - 0s - loss: 0.0016 - 63ms/epoch - 6ms/step
# Epoch 179/300
# 10/10 - 0s - loss: 0.0011 - 65ms/epoch - 6ms/step
# Epoch 180/300
# 10/10 - 0s - loss: 3.2362e-04 - 66ms/epoch - 7ms/step
# Epoch 181/300
# 10/10 - 0s - loss: 1.9312e-04 - 61ms/epoch - 6ms/step
# Epoch 182/300
# 10/10 - 0s - loss: 2.0894e-04 - 66ms/epoch - 7ms/step
# Epoch 183/300
# 10/10 - 0s - loss: 1.5952e-04 - 69ms/epoch - 7ms/step
# Epoch 184/300
# 10/10 - 0s - loss: 2.4961e-04 - 75ms/epoch - 7ms/step
# Epoch 185/300
# 10/10 - 0s - loss: 1.9456e-04 - 70ms/epoch - 7ms/step
# Epoch 186/300
# 10/10 - 0s - loss: 1.7262e-04 - 59ms/epoch - 6ms/step
# Epoch 187/300
# 10/10 - 0s - loss: 1.2937e-04 - 61ms/epoch - 6ms/step
# Epoch 188/300
# 10/10 - 0s - loss: 1.9882e-04 - 66ms/epoch - 7ms/step
# Epoch 189/300
# 10/10 - 0s - loss: 1.1779e-04 - 70ms/epoch - 7ms/step
# Epoch 190/300
# 10/10 - 0s - loss: 1.0411e-04 - 56ms/epoch - 6ms/step
# Epoch 191/300
# 10/10 - 0s - loss: 1.2807e-04 - 69ms/epoch - 7ms/step
# Epoch 192/300
# 10/10 - 0s - loss: 1.6719e-04 - 65ms/epoch - 7ms/step
# Epoch 193/300
# 10/10 - 0s - loss: 3.9431e-04 - 60ms/epoch - 6ms/step
# Epoch 194/300
# 10/10 - 0s - loss: 5.8155e-04 - 66ms/epoch - 7ms/step
# Epoch 195/300
# 10/10 - 0s - loss: 2.4504e-04 - 64ms/epoch - 6ms/step
# Epoch 196/300
# 10/10 - 0s - loss: 3.6073e-04 - 62ms/epoch - 6ms/step
# Epoch 197/300
# 10/10 - 0s - loss: 4.3806e-04 - 63ms/epoch - 6ms/step
# Epoch 198/300
# 10/10 - 0s - loss: 7.6961e-04 - 62ms/epoch - 6ms/step
# Epoch 199/300
# 10/10 - 0s - loss: 4.7221e-04 - 62ms/epoch - 6ms/step
# Epoch 200/300
# 10/10 - 0s - loss: 6.3601e-04 - 66ms/epoch - 7ms/step
# Epoch 201/300
# 10/10 - 0s - loss: 3.4115e-04 - 68ms/epoch - 7ms/step
# Epoch 202/300
# 10/10 - 0s - loss: 1.9059e-04 - 62ms/epoch - 6ms/step
# Epoch 203/300
# 10/10 - 0s - loss: 1.1551e-04 - 72ms/epoch - 7ms/step
# Epoch 204/300
# 10/10 - 0s - loss: 8.4554e-05 - 68ms/epoch - 7ms/step
# Epoch 205/300
# 10/10 - 0s - loss: 4.7110e-05 - 62ms/epoch - 6ms/step
# Epoch 206/300
# 10/10 - 0s - loss: 4.4799e-05 - 66ms/epoch - 7ms/step
# Epoch 207/300
# 10/10 - 0s - loss: 2.6288e-05 - 61ms/epoch - 6ms/step
# Epoch 208/300
# 10/10 - 0s - loss: 4.1428e-05 - 67ms/epoch - 7ms/step
# Epoch 209/300
# 10/10 - 0s - loss: 6.8021e-05 - 63ms/epoch - 6ms/step
# Epoch 210/300
# 10/10 - 0s - loss: 1.4944e-04 - 62ms/epoch - 6ms/step
# Epoch 211/300
# 10/10 - 0s - loss: 2.1401e-04 - 61ms/epoch - 6ms/step
# Epoch 212/300
# 10/10 - 0s - loss: 1.9988e-04 - 60ms/epoch - 6ms/step
# Epoch 213/300
# 10/10 - 0s - loss: 1.8710e-04 - 64ms/epoch - 6ms/step
# Epoch 214/300
# 10/10 - 0s - loss: 1.8963e-04 - 67ms/epoch - 7ms/step
# Epoch 215/300
# 10/10 - 0s - loss: 1.7650e-04 - 69ms/epoch - 7ms/step
# Epoch 216/300
# 10/10 - 0s - loss: 3.3457e-04 - 67ms/epoch - 7ms/step
# Epoch 217/300
# 10/10 - 0s - loss: 3.4261e-04 - 66ms/epoch - 7ms/step
# Epoch 218/300
# 10/10 - 0s - loss: 2.9528e-04 - 61ms/epoch - 6ms/step
# Epoch 219/300
# 10/10 - 0s - loss: 1.8885e-04 - 58ms/epoch - 6ms/step
# Epoch 220/300
# 10/10 - 0s - loss: 3.6356e-04 - 60ms/epoch - 6ms/step
# Epoch 221/300
# 10/10 - 0s - loss: 3.9613e-04 - 61ms/epoch - 6ms/step
# Epoch 222/300
# 10/10 - 0s - loss: 4.8063e-04 - 62ms/epoch - 6ms/step
# Epoch 223/300
# 10/10 - 0s - loss: 6.1707e-04 - 60ms/epoch - 6ms/step
# Epoch 224/300
# 10/10 - 0s - loss: 3.7042e-04 - 60ms/epoch - 6ms/step
# Epoch 225/300
# 10/10 - 0s - loss: 2.7986e-04 - 69ms/epoch - 7ms/step
# Epoch 226/300
# 10/10 - 0s - loss: 8.0786e-05 - 61ms/epoch - 6ms/step
# Epoch 227/300
# 10/10 - 0s - loss: 8.1750e-05 - 61ms/epoch - 6ms/step
# Epoch 228/300
# 10/10 - 0s - loss: 3.3959e-05 - 62ms/epoch - 6ms/step
# Epoch 229/300
# 10/10 - 0s - loss: 2.5861e-05 - 62ms/epoch - 6ms/step
# Epoch 230/300
# 10/10 - 0s - loss: 1.9187e-05 - 57ms/epoch - 6ms/step
# Epoch 231/300
# 10/10 - 0s - loss: 2.7471e-05 - 58ms/epoch - 6ms/step
# Epoch 232/300
# 10/10 - 0s - loss: 4.4816e-05 - 68ms/epoch - 7ms/step
# Epoch 233/300
# 10/10 - 0s - loss: 1.3900e-04 - 67ms/epoch - 7ms/step
# Epoch 234/300
# 10/10 - 0s - loss: 3.2106e-04 - 63ms/epoch - 6ms/step
# Epoch 235/300
# 10/10 - 0s - loss: 1.2959e-04 - 66ms/epoch - 7ms/step
# Epoch 236/300
# 10/10 - 0s - loss: 1.3834e-04 - 66ms/epoch - 7ms/step
# Epoch 237/300
# 10/10 - 0s - loss: 9.3561e-05 - 63ms/epoch - 6ms/step
# Epoch 238/300
# 10/10 - 0s - loss: 1.3500e-04 - 68ms/epoch - 7ms/step
# Epoch 239/300
# 10/10 - 0s - loss: 1.1925e-04 - 59ms/epoch - 6ms/step
# Epoch 240/300
# 10/10 - 0s - loss: 6.1660e-05 - 64ms/epoch - 6ms/step
# Epoch 241/300
# 10/10 - 0s - loss: 1.5567e-04 - 68ms/epoch - 7ms/step
# Epoch 242/300
# 10/10 - 0s - loss: 3.3625e-04 - 60ms/epoch - 6ms/step
# Epoch 243/300
# 10/10 - 0s - loss: 7.1564e-04 - 64ms/epoch - 6ms/step
# Epoch 244/300
# 10/10 - 0s - loss: 3.4606e-04 - 64ms/epoch - 6ms/step
# Epoch 245/300
# 10/10 - 0s - loss: 6.2803e-04 - 63ms/epoch - 6ms/step
# Epoch 246/300
# 10/10 - 0s - loss: 1.9626e-04 - 59ms/epoch - 6ms/step
# Epoch 247/300
# 10/10 - 0s - loss: 1.4697e-04 - 62ms/epoch - 6ms/step
# Epoch 248/300
# 10/10 - 0s - loss: 2.5571e-04 - 63ms/epoch - 6ms/step
# Epoch 249/300
# 10/10 - 0s - loss: 1.7612e-04 - 71ms/epoch - 7ms/step
# Epoch 250/300
# 10/10 - 0s - loss: 6.7726e-05 - 65ms/epoch - 6ms/step
# Epoch 251/300
# 10/10 - 0s - loss: 1.0971e-04 - 61ms/epoch - 6ms/step
# Epoch 252/300
# 10/10 - 0s - loss: 8.9589e-05 - 61ms/epoch - 6ms/step
# Epoch 253/300
# 10/10 - 0s - loss: 5.2036e-05 - 59ms/epoch - 6ms/step
# Epoch 254/300
# 10/10 - 0s - loss: 2.9806e-05 - 61ms/epoch - 6ms/step
# Epoch 255/300
# 10/10 - 0s - loss: 5.6947e-05 - 66ms/epoch - 7ms/step
# Epoch 256/300
# 10/10 - 0s - loss: 8.1278e-05 - 63ms/epoch - 6ms/step
# Epoch 257/300
# 10/10 - 0s - loss: 5.9613e-05 - 62ms/epoch - 6ms/step
# Epoch 258/300
# 10/10 - 0s - loss: 2.8347e-05 - 56ms/epoch - 6ms/step
# Epoch 259/300
# 10/10 - 0s - loss: 4.7032e-05 - 59ms/epoch - 6ms/step
# Epoch 260/300
# 10/10 - 0s - loss: 3.4788e-05 - 65ms/epoch - 7ms/step
# Epoch 261/300
# 10/10 - 0s - loss: 2.7617e-05 - 64ms/epoch - 6ms/step
# Epoch 262/300
# 10/10 - 0s - loss: 1.9814e-05 - 63ms/epoch - 6ms/step
# Epoch 263/300
# 10/10 - 0s - loss: 2.3201e-05 - 66ms/epoch - 7ms/step
# Epoch 264/300
# 10/10 - 0s - loss: 1.7803e-05 - 60ms/epoch - 6ms/step
# Epoch 265/300
# 10/10 - 0s - loss: 1.2739e-05 - 59ms/epoch - 6ms/step
# Epoch 266/300
# 10/10 - 0s - loss: 1.1558e-05 - 65ms/epoch - 6ms/step
# Epoch 267/300
# 10/10 - 0s - loss: 1.2337e-05 - 63ms/epoch - 6ms/step
# Epoch 268/300
# 10/10 - 0s - loss: 1.8505e-05 - 67ms/epoch - 7ms/step
# Epoch 269/300
# 10/10 - 0s - loss: 4.9465e-05 - 69ms/epoch - 7ms/step
# Epoch 270/300
# 10/10 - 0s - loss: 1.6557e-04 - 61ms/epoch - 6ms/step
# Epoch 271/300
# 10/10 - 0s - loss: 1.7872e-04 - 63ms/epoch - 6ms/step
# Epoch 272/300
# 10/10 - 0s - loss: 5.1176e-04 - 67ms/epoch - 7ms/step
# Epoch 273/300
# 10/10 - 0s - loss: 0.0022 - 65ms/epoch - 6ms/step
# Epoch 274/300
# 10/10 - 0s - loss: 0.0104 - 59ms/epoch - 6ms/step
# Epoch 275/300
# 10/10 - 0s - loss: 0.0115 - 62ms/epoch - 6ms/step
# Epoch 276/300
# 10/10 - 0s - loss: 0.0148 - 59ms/epoch - 6ms/step
# Epoch 277/300
# 10/10 - 0s - loss: 0.0110 - 60ms/epoch - 6ms/step
# Epoch 278/300
# 10/10 - 0s - loss: 0.0352 - 62ms/epoch - 6ms/step
# Epoch 279/300
# 10/10 - 0s - loss: 0.0303 - 72ms/epoch - 7ms/step
# Epoch 280/300
# 10/10 - 0s - loss: 0.0175 - 62ms/epoch - 6ms/step
# Epoch 281/300
# 10/10 - 0s - loss: 0.0264 - 60ms/epoch - 6ms/step
# Epoch 282/300
# 10/10 - 0s - loss: 0.0174 - 61ms/epoch - 6ms/step
# Epoch 283/300
# 10/10 - 0s - loss: 0.0185 - 60ms/epoch - 6ms/step
# Epoch 284/300
# 10/10 - 0s - loss: 0.0113 - 68ms/epoch - 7ms/step
# Epoch 285/300
# 10/10 - 0s - loss: 0.0081 - 62ms/epoch - 6ms/step
# Epoch 286/300
# 10/10 - 0s - loss: 0.0038 - 63ms/epoch - 6ms/step
# Epoch 287/300
# 10/10 - 0s - loss: 0.0017 - 70ms/epoch - 7ms/step
# Epoch 288/300
# 10/10 - 0s - loss: 0.0026 - 60ms/epoch - 6ms/step
# Epoch 289/300
# 10/10 - 0s - loss: 0.0022 - 58ms/epoch - 6ms/step
# Epoch 290/300
# 10/10 - 0s - loss: 0.0014 - 65ms/epoch - 7ms/step
# Epoch 291/300
# 10/10 - 0s - loss: 0.0012 - 64ms/epoch - 6ms/step
# Epoch 292/300
# 10/10 - 0s - loss: 5.4920e-04 - 68ms/epoch - 7ms/step
# Epoch 293/300
# 10/10 - 0s - loss: 3.3475e-04 - 62ms/epoch - 6ms/step
# Epoch 294/300
# 10/10 - 0s - loss: 3.4194e-04 - 64ms/epoch - 6ms/step
# Epoch 295/300
# 10/10 - 0s - loss: 4.6883e-04 - 67ms/epoch - 7ms/step
# Epoch 296/300
# 10/10 - 0s - loss: 3.5040e-04 - 62ms/epoch - 6ms/step
# Epoch 297/300
# 10/10 - 0s - loss: 3.3700e-04 - 70ms/epoch - 7ms/step
# Epoch 298/300
# 10/10 - 0s - loss: 2.5220e-04 - 63ms/epoch - 6ms/step
# Epoch 299/300
# 10/10 - 0s - loss: 2.0967e-04 - 60ms/epoch - 6ms/step
# Epoch 300/300
# 10/10 - 0s - loss: 3.0726e-04 - 61ms/epoch - 6ms/step
# 14/14 [==============================] - 0s 2ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1710203906.59561
# Tue Mar 12 00:38:26 2024
