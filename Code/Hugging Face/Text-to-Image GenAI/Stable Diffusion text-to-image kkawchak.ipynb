# %%
# !pip install diffusers
# !pip install accelerate

# %%
# doctor helping another patient

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "doctor helping another patient"
image = pipe(prompt).images[0]

image.save("doctor helping another patient_1.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "doctor helping another patient"
image = pipe(prompt).images[0]

image.save("doctor helping another patient_2.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "doctor helping another patient"
image = pipe(prompt).images[0]

image.save("doctor helping another patient_3.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# nurses utilizing medical ai at the hospital

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "nurses utilizing medical ai at the hospital"
image = pipe(prompt).images[0]

image.save("nurses utilizing medical ai at the hospital_1.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "nurses utilizing medical ai at the hospital"
image = pipe(prompt).images[0]

image.save("nurses utilizing medical ai at the hospital_2.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "nurses utilizing medical ai at the hospital"
image = pipe(prompt).images[0]

image.save("nurses utilizing medical ai at the hospital_3.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# hospital staff using generative ai in safe and effective ways

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "hospital staff using generative ai in safe and effective ways"
image = pipe(prompt).images[0]

image.save("hospital staff using generative ai in safe and effective ways_1.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "hospital staff using generative ai in safe and effective ways"
image = pipe(prompt).images[0]

image.save("hospital staff using generative ai in safe and effective ways_2.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "hospital staff using generative ai in safe and effective ways"
image = pipe(prompt).images[0]

image.save("hospital staff using generative ai in safe and effective ways_3.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
