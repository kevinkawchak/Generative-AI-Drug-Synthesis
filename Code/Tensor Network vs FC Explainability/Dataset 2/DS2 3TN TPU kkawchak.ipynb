# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
import pandas as pd
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)
# Explainability code assistance aided by ChatGPT3.5
# 2021 Kelly, D. TensorFlow Explainable AI tutorial https://www.youtube.com/watch?v=6xePkn3-LME

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(32, 32, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(32, 32)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (32, 32))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1024)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     # Start Modified Layers
     TNLayer(),
     TNLayer(),
     TNLayer(),
     # Finish Modified Layers
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1024)              3072
#
#  tn_layer_3 (TNLayer)        (None, 1024)              5120
#
#  tn_layer_4 (TNLayer)        (None, 1024)              5120
#
#  tn_layer_5 (TNLayer)        (None, 1024)              5120
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 19457 (76.00 KB)
# Trainable params: 19457 (76.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
# Generate points forming concentric circles
num_points = 240  # Number of points for each circle

# Inner circle
r1 = np.random.rand(num_points)
theta1 = np.random.rand(num_points) * 2 * np.pi
x1 = r1 * np.cos(theta1)
y1 = r1 * np.sin(theta1)

# Outer circle
r2 = np.random.rand(num_points) + 1
theta2 = np.random.rand(num_points) * 2 * np.pi
x2 = r2 * np.cos(theta2)
y2 = r2 * np.sin(theta2)

# Concatenate the points and labels
X = np.concatenate([np.column_stack((x1, y1)), np.column_stack((x2, y2))])
Y = np.concatenate([np.ones(num_points), -np.ones(num_points)])

# Shuffle the data
shuffle_index = np.random.permutation(len(X))
X_shuffled = X[shuffle_index]
Y_shuffled = Y[shuffle_index]

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1712716567.3322396
# Wed Apr 10 02:36:07 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 15/15 - 1s - loss: 1.0020 - 1s/epoch - 93ms/step
# Epoch 2/300
# 15/15 - 0s - loss: 1.0001 - 73ms/epoch - 5ms/step
# Epoch 3/300
# 15/15 - 0s - loss: 1.0001 - 69ms/epoch - 5ms/step
# Epoch 4/300
# 15/15 - 0s - loss: 0.9859 - 71ms/epoch - 5ms/step
# Epoch 5/300
# 15/15 - 0s - loss: 0.6123 - 66ms/epoch - 4ms/step
# Epoch 6/300
# 15/15 - 0s - loss: 0.1755 - 67ms/epoch - 4ms/step
# Epoch 7/300
# 15/15 - 0s - loss: 0.1300 - 69ms/epoch - 5ms/step
# Epoch 8/300
# 15/15 - 0s - loss: 0.0891 - 65ms/epoch - 4ms/step
# Epoch 9/300
# 15/15 - 0s - loss: 0.0545 - 65ms/epoch - 4ms/step
# Epoch 10/300
# 15/15 - 0s - loss: 0.0403 - 62ms/epoch - 4ms/step
# Epoch 11/300
# 15/15 - 0s - loss: 0.0571 - 62ms/epoch - 4ms/step
# Epoch 12/300
# 15/15 - 0s - loss: 0.0454 - 63ms/epoch - 4ms/step
# Epoch 13/300
# 15/15 - 0s - loss: 0.0230 - 60ms/epoch - 4ms/step
# Epoch 14/300
# 15/15 - 0s - loss: 0.0144 - 63ms/epoch - 4ms/step
# Epoch 15/300
# 15/15 - 0s - loss: 0.0127 - 64ms/epoch - 4ms/step
# Epoch 16/300
# 15/15 - 0s - loss: 0.0046 - 65ms/epoch - 4ms/step
# Epoch 17/300
# 15/15 - 0s - loss: 0.0318 - 62ms/epoch - 4ms/step
# Epoch 18/300
# 15/15 - 0s - loss: 0.0448 - 62ms/epoch - 4ms/step
# Epoch 19/300
# 15/15 - 0s - loss: 0.0293 - 62ms/epoch - 4ms/step
# Epoch 20/300
# 15/15 - 0s - loss: 0.0698 - 61ms/epoch - 4ms/step
# Epoch 21/300
# 15/15 - 0s - loss: 0.0366 - 62ms/epoch - 4ms/step
# Epoch 22/300
# 15/15 - 0s - loss: 0.0088 - 64ms/epoch - 4ms/step
# Epoch 23/300
# 15/15 - 0s - loss: 0.0093 - 63ms/epoch - 4ms/step
# Epoch 24/300
# 15/15 - 0s - loss: 0.0031 - 61ms/epoch - 4ms/step
# Epoch 25/300
# 15/15 - 0s - loss: 0.0251 - 59ms/epoch - 4ms/step
# Epoch 26/300
# 15/15 - 0s - loss: 0.0152 - 62ms/epoch - 4ms/step
# Epoch 27/300
# 15/15 - 0s - loss: 0.0117 - 62ms/epoch - 4ms/step
# Epoch 28/300
# 15/15 - 0s - loss: 0.0030 - 62ms/epoch - 4ms/step
# Epoch 29/300
# 15/15 - 0s - loss: 0.0036 - 62ms/epoch - 4ms/step
# Epoch 30/300
# 15/15 - 0s - loss: 0.0285 - 62ms/epoch - 4ms/step
# Epoch 31/300
# 15/15 - 0s - loss: 0.0172 - 63ms/epoch - 4ms/step
# Epoch 32/300
# 15/15 - 0s - loss: 0.0076 - 61ms/epoch - 4ms/step
# Epoch 33/300
# 15/15 - 0s - loss: 0.0243 - 59ms/epoch - 4ms/step
# Epoch 34/300
# 15/15 - 0s - loss: 0.0516 - 66ms/epoch - 4ms/step
# Epoch 35/300
# 15/15 - 0s - loss: 0.0503 - 61ms/epoch - 4ms/step
# Epoch 36/300
# 15/15 - 0s - loss: 0.0563 - 62ms/epoch - 4ms/step
# Epoch 37/300
# 15/15 - 0s - loss: 0.0496 - 64ms/epoch - 4ms/step
# Epoch 38/300
# 15/15 - 0s - loss: 0.0280 - 62ms/epoch - 4ms/step
# Epoch 39/300
# 15/15 - 0s - loss: 0.0103 - 61ms/epoch - 4ms/step
# Epoch 40/300
# 15/15 - 0s - loss: 0.0142 - 61ms/epoch - 4ms/step
# Epoch 41/300
# 15/15 - 0s - loss: 0.0049 - 60ms/epoch - 4ms/step
# Epoch 42/300
# 15/15 - 0s - loss: 0.0022 - 62ms/epoch - 4ms/step
# Epoch 43/300
# 15/15 - 0s - loss: 0.0019 - 63ms/epoch - 4ms/step
# Epoch 44/300
# 15/15 - 0s - loss: 0.0016 - 61ms/epoch - 4ms/step
# Epoch 45/300
# 15/15 - 0s - loss: 0.0021 - 61ms/epoch - 4ms/step
# Epoch 46/300
# 15/15 - 0s - loss: 9.6352e-04 - 67ms/epoch - 4ms/step
# Epoch 47/300
# 15/15 - 0s - loss: 0.0032 - 66ms/epoch - 4ms/step
# Epoch 48/300
# 15/15 - 0s - loss: 0.0030 - 64ms/epoch - 4ms/step
# Epoch 49/300
# 15/15 - 0s - loss: 0.0077 - 63ms/epoch - 4ms/step
# Epoch 50/300
# 15/15 - 0s - loss: 0.0176 - 64ms/epoch - 4ms/step
# Epoch 51/300
# 15/15 - 0s - loss: 0.0272 - 64ms/epoch - 4ms/step
# Epoch 52/300
# 15/15 - 0s - loss: 0.0140 - 66ms/epoch - 4ms/step
# Epoch 53/300
# 15/15 - 0s - loss: 9.1025e-04 - 66ms/epoch - 4ms/step
# Epoch 54/300
# 15/15 - 0s - loss: 3.5181e-04 - 62ms/epoch - 4ms/step
# Epoch 55/300
# 15/15 - 0s - loss: 2.9596e-04 - 64ms/epoch - 4ms/step
# Epoch 56/300
# 15/15 - 0s - loss: 5.7676e-04 - 64ms/epoch - 4ms/step
# Epoch 57/300
# 15/15 - 0s - loss: 0.0017 - 63ms/epoch - 4ms/step
# Epoch 58/300
# 15/15 - 0s - loss: 0.0223 - 65ms/epoch - 4ms/step
# Epoch 59/300
# 15/15 - 0s - loss: 0.0139 - 70ms/epoch - 5ms/step
# Epoch 60/300
# 15/15 - 0s - loss: 0.0107 - 64ms/epoch - 4ms/step
# Epoch 61/300
# 15/15 - 0s - loss: 0.0049 - 64ms/epoch - 4ms/step
# Epoch 62/300
# 15/15 - 0s - loss: 0.0041 - 62ms/epoch - 4ms/step
# Epoch 63/300
# 15/15 - 0s - loss: 5.6507e-04 - 61ms/epoch - 4ms/step
# Epoch 64/300
# 15/15 - 0s - loss: 3.3021e-05 - 62ms/epoch - 4ms/step
# Epoch 65/300
# 15/15 - 0s - loss: 2.5001e-05 - 64ms/epoch - 4ms/step
# Epoch 66/300
# 15/15 - 0s - loss: 9.2927e-06 - 63ms/epoch - 4ms/step
# Epoch 67/300
# 15/15 - 0s - loss: 8.3121e-06 - 62ms/epoch - 4ms/step
# Epoch 68/300
# 15/15 - 0s - loss: 7.3248e-06 - 62ms/epoch - 4ms/step
# Epoch 69/300
# 15/15 - 0s - loss: 6.8689e-06 - 64ms/epoch - 4ms/step
# Epoch 70/300
# 15/15 - 0s - loss: 6.1659e-06 - 64ms/epoch - 4ms/step
# Epoch 71/300
# 15/15 - 0s - loss: 6.3707e-06 - 61ms/epoch - 4ms/step
# Epoch 72/300
# 15/15 - 0s - loss: 6.7043e-06 - 63ms/epoch - 4ms/step
# Epoch 73/300
# 15/15 - 0s - loss: 7.0160e-06 - 63ms/epoch - 4ms/step
# Epoch 74/300
# 15/15 - 0s - loss: 1.6381e-05 - 65ms/epoch - 4ms/step
# Epoch 75/300
# 15/15 - 0s - loss: 3.5327e-05 - 62ms/epoch - 4ms/step
# Epoch 76/300
# 15/15 - 0s - loss: 1.2444e-05 - 60ms/epoch - 4ms/step
# Epoch 77/300
# 15/15 - 0s - loss: 3.8970e-05 - 60ms/epoch - 4ms/step
# Epoch 78/300
# 15/15 - 0s - loss: 1.6786e-05 - 62ms/epoch - 4ms/step
# Epoch 79/300
# 15/15 - 0s - loss: 7.4567e-06 - 61ms/epoch - 4ms/step
# Epoch 80/300
# 15/15 - 0s - loss: 4.5950e-06 - 61ms/epoch - 4ms/step
# Epoch 81/300
# 15/15 - 0s - loss: 3.7222e-06 - 60ms/epoch - 4ms/step
# Epoch 82/300
# 15/15 - 0s - loss: 4.1815e-06 - 65ms/epoch - 4ms/step
# Epoch 83/300
# 15/15 - 0s - loss: 3.5488e-06 - 59ms/epoch - 4ms/step
# Epoch 84/300
# 15/15 - 0s - loss: 4.9459e-06 - 67ms/epoch - 4ms/step
# Epoch 85/300
# 15/15 - 0s - loss: 4.1310e-05 - 59ms/epoch - 4ms/step
# Epoch 86/300
# 15/15 - 0s - loss: 6.6234e-05 - 59ms/epoch - 4ms/step
# Epoch 87/300
# 15/15 - 0s - loss: 2.6201e-04 - 61ms/epoch - 4ms/step
# Epoch 88/300
# 15/15 - 0s - loss: 8.6702e-05 - 61ms/epoch - 4ms/step
# Epoch 89/300
# 15/15 - 0s - loss: 6.5770e-05 - 59ms/epoch - 4ms/step
# Epoch 90/300
# 15/15 - 0s - loss: 1.5363e-04 - 60ms/epoch - 4ms/step
# Epoch 91/300
# 15/15 - 0s - loss: 6.2001e-04 - 61ms/epoch - 4ms/step
# Epoch 92/300
# 15/15 - 0s - loss: 1.2238e-04 - 61ms/epoch - 4ms/step
# Epoch 93/300
# 15/15 - 0s - loss: 6.2949e-05 - 56ms/epoch - 4ms/step
# Epoch 94/300
# 15/15 - 0s - loss: 3.9266e-05 - 57ms/epoch - 4ms/step
# Epoch 95/300
# 15/15 - 0s - loss: 1.4139e-05 - 58ms/epoch - 4ms/step
# Epoch 96/300
# 15/15 - 0s - loss: 5.1852e-05 - 60ms/epoch - 4ms/step
# Epoch 97/300
# 15/15 - 0s - loss: 4.3538e-04 - 56ms/epoch - 4ms/step
# Epoch 98/300
# 15/15 - 0s - loss: 0.0011 - 63ms/epoch - 4ms/step
# Epoch 99/300
# 15/15 - 0s - loss: 5.7030e-04 - 57ms/epoch - 4ms/step
# Epoch 100/300
# 15/15 - 0s - loss: 1.7217e-04 - 60ms/epoch - 4ms/step
# Epoch 101/300
# 15/15 - 0s - loss: 1.9581e-04 - 60ms/epoch - 4ms/step
# Epoch 102/300
# 15/15 - 0s - loss: 2.1176e-04 - 57ms/epoch - 4ms/step
# Epoch 103/300
# 15/15 - 0s - loss: 9.3841e-05 - 58ms/epoch - 4ms/step
# Epoch 104/300
# 15/15 - 0s - loss: 7.4221e-05 - 59ms/epoch - 4ms/step
# Epoch 105/300
# 15/15 - 0s - loss: 7.4860e-05 - 60ms/epoch - 4ms/step
# Epoch 106/300
# 15/15 - 0s - loss: 1.1438e-05 - 58ms/epoch - 4ms/step
# Epoch 107/300
# 15/15 - 0s - loss: 9.3763e-06 - 61ms/epoch - 4ms/step
# Epoch 108/300
# 15/15 - 0s - loss: 6.7289e-06 - 59ms/epoch - 4ms/step
# Epoch 109/300
# 15/15 - 0s - loss: 4.4462e-06 - 58ms/epoch - 4ms/step
# Epoch 110/300
# 15/15 - 0s - loss: 5.5895e-06 - 61ms/epoch - 4ms/step
# Epoch 111/300
# 15/15 - 0s - loss: 4.4527e-06 - 58ms/epoch - 4ms/step
# Epoch 112/300
# 15/15 - 0s - loss: 3.3966e-06 - 58ms/epoch - 4ms/step
# Epoch 113/300
# 15/15 - 0s - loss: 3.9234e-06 - 58ms/epoch - 4ms/step
# Epoch 114/300
# 15/15 - 0s - loss: 5.1331e-06 - 60ms/epoch - 4ms/step
# Epoch 115/300
# 15/15 - 0s - loss: 2.5952e-06 - 56ms/epoch - 4ms/step
# Epoch 116/300
# 15/15 - 0s - loss: 7.2392e-06 - 58ms/epoch - 4ms/step
# Epoch 117/300
# 15/15 - 0s - loss: 8.9844e-06 - 58ms/epoch - 4ms/step
# Epoch 118/300
# 15/15 - 0s - loss: 4.6455e-06 - 62ms/epoch - 4ms/step
# Epoch 119/300
# 15/15 - 0s - loss: 2.7713e-06 - 59ms/epoch - 4ms/step
# Epoch 120/300
# 15/15 - 0s - loss: 2.1972e-06 - 59ms/epoch - 4ms/step
# Epoch 121/300
# 15/15 - 0s - loss: 1.9717e-06 - 58ms/epoch - 4ms/step
# Epoch 122/300
# 15/15 - 0s - loss: 2.0014e-06 - 61ms/epoch - 4ms/step
# Epoch 123/300
# 15/15 - 0s - loss: 3.2962e-06 - 60ms/epoch - 4ms/step
# Epoch 124/300
# 15/15 - 0s - loss: 4.9576e-06 - 57ms/epoch - 4ms/step
# Epoch 125/300
# 15/15 - 0s - loss: 4.1290e-06 - 56ms/epoch - 4ms/step
# Epoch 126/300
# 15/15 - 0s - loss: 2.8701e-06 - 57ms/epoch - 4ms/step
# Epoch 127/300
# 15/15 - 0s - loss: 2.1037e-06 - 57ms/epoch - 4ms/step
# Epoch 128/300
# 15/15 - 0s - loss: 1.3764e-06 - 56ms/epoch - 4ms/step
# Epoch 129/300
# 15/15 - 0s - loss: 1.6044e-06 - 55ms/epoch - 4ms/step
# Epoch 130/300
# 15/15 - 0s - loss: 1.3200e-06 - 56ms/epoch - 4ms/step
# Epoch 131/300
# 15/15 - 0s - loss: 1.7474e-06 - 62ms/epoch - 4ms/step
# Epoch 132/300
# 15/15 - 0s - loss: 3.2121e-06 - 62ms/epoch - 4ms/step
# Epoch 133/300
# 15/15 - 0s - loss: 3.3384e-06 - 59ms/epoch - 4ms/step
# Epoch 134/300
# 15/15 - 0s - loss: 1.6330e-06 - 56ms/epoch - 4ms/step
# Epoch 135/300
# 15/15 - 0s - loss: 1.7302e-06 - 61ms/epoch - 4ms/step
# Epoch 136/300
# 15/15 - 0s - loss: 1.3628e-06 - 59ms/epoch - 4ms/step
# Epoch 137/300
# 15/15 - 0s - loss: 1.9833e-06 - 59ms/epoch - 4ms/step
# Epoch 138/300
# 15/15 - 0s - loss: 1.7483e-06 - 58ms/epoch - 4ms/step
# Epoch 139/300
# 15/15 - 0s - loss: 2.1749e-06 - 55ms/epoch - 4ms/step
# Epoch 140/300
# 15/15 - 0s - loss: 1.4342e-06 - 65ms/epoch - 4ms/step
# Epoch 141/300
# 15/15 - 0s - loss: 1.0627e-06 - 63ms/epoch - 4ms/step
# Epoch 142/300
# 15/15 - 0s - loss: 3.9627e-06 - 63ms/epoch - 4ms/step
# Epoch 143/300
# 15/15 - 0s - loss: 8.8668e-06 - 61ms/epoch - 4ms/step
# Epoch 144/300
# 15/15 - 0s - loss: 8.4250e-05 - 60ms/epoch - 4ms/step
# Epoch 145/300
# 15/15 - 0s - loss: 5.8676e-05 - 62ms/epoch - 4ms/step
# Epoch 146/300
# 15/15 - 0s - loss: 3.5250e-05 - 62ms/epoch - 4ms/step
# Epoch 147/300
# 15/15 - 0s - loss: 4.3214e-04 - 60ms/epoch - 4ms/step
# Epoch 148/300
# 15/15 - 0s - loss: 2.4251e-04 - 61ms/epoch - 4ms/step
# Epoch 149/300
# 15/15 - 0s - loss: 2.0778e-04 - 61ms/epoch - 4ms/step
# Epoch 150/300
# 15/15 - 0s - loss: 9.8481e-04 - 60ms/epoch - 4ms/step
# Epoch 151/300
# 15/15 - 0s - loss: 0.0012 - 62ms/epoch - 4ms/step
# Epoch 152/300
# 15/15 - 0s - loss: 0.0036 - 62ms/epoch - 4ms/step
# Epoch 153/300
# 15/15 - 0s - loss: 0.0201 - 62ms/epoch - 4ms/step
# Epoch 154/300
# 15/15 - 0s - loss: 0.0965 - 60ms/epoch - 4ms/step
# Epoch 155/300
# 15/15 - 0s - loss: 0.1713 - 59ms/epoch - 4ms/step
# Epoch 156/300
# 15/15 - 0s - loss: 0.1076 - 60ms/epoch - 4ms/step
# Epoch 157/300
# 15/15 - 0s - loss: 0.0670 - 61ms/epoch - 4ms/step
# Epoch 158/300
# 15/15 - 0s - loss: 0.0261 - 59ms/epoch - 4ms/step
# Epoch 159/300
# 15/15 - 0s - loss: 0.0374 - 58ms/epoch - 4ms/step
# Epoch 160/300
# 15/15 - 0s - loss: 0.0271 - 55ms/epoch - 4ms/step
# Epoch 161/300
# 15/15 - 0s - loss: 0.0166 - 54ms/epoch - 4ms/step
# Epoch 162/300
# 15/15 - 0s - loss: 0.0241 - 57ms/epoch - 4ms/step
# Epoch 163/300
# 15/15 - 0s - loss: 0.0058 - 61ms/epoch - 4ms/step
# Epoch 164/300
# 15/15 - 0s - loss: 0.0029 - 56ms/epoch - 4ms/step
# Epoch 165/300
# 15/15 - 0s - loss: 0.0095 - 58ms/epoch - 4ms/step
# Epoch 166/300
# 15/15 - 0s - loss: 0.0071 - 58ms/epoch - 4ms/step
# Epoch 167/300
# 15/15 - 0s - loss: 0.0032 - 56ms/epoch - 4ms/step
# Epoch 168/300
# 15/15 - 0s - loss: 0.0211 - 58ms/epoch - 4ms/step
# Epoch 169/300
# 15/15 - 0s - loss: 0.0387 - 58ms/epoch - 4ms/step
# Epoch 170/300
# 15/15 - 0s - loss: 0.0388 - 58ms/epoch - 4ms/step
# Epoch 171/300
# 15/15 - 0s - loss: 0.0273 - 58ms/epoch - 4ms/step
# Epoch 172/300
# 15/15 - 0s - loss: 0.0056 - 57ms/epoch - 4ms/step
# Epoch 173/300
# 15/15 - 0s - loss: 0.0018 - 57ms/epoch - 4ms/step
# Epoch 174/300
# 15/15 - 0s - loss: 0.0035 - 56ms/epoch - 4ms/step
# Epoch 175/300
# 15/15 - 0s - loss: 0.0078 - 55ms/epoch - 4ms/step
# Epoch 176/300
# 15/15 - 0s - loss: 0.0073 - 58ms/epoch - 4ms/step
# Epoch 177/300
# 15/15 - 0s - loss: 0.0114 - 55ms/epoch - 4ms/step
# Epoch 178/300
# 15/15 - 0s - loss: 0.0106 - 56ms/epoch - 4ms/step
# Epoch 179/300
# 15/15 - 0s - loss: 0.0471 - 55ms/epoch - 4ms/step
# Epoch 180/300
# 15/15 - 0s - loss: 0.0274 - 56ms/epoch - 4ms/step
# Epoch 181/300
# 15/15 - 0s - loss: 0.0735 - 56ms/epoch - 4ms/step
# Epoch 182/300
# 15/15 - 0s - loss: 0.0902 - 57ms/epoch - 4ms/step
# Epoch 183/300
# 15/15 - 0s - loss: 0.0307 - 55ms/epoch - 4ms/step
# Epoch 184/300
# 15/15 - 0s - loss: 0.0173 - 55ms/epoch - 4ms/step
# Epoch 185/300
# 15/15 - 0s - loss: 0.0117 - 55ms/epoch - 4ms/step
# Epoch 186/300
# 15/15 - 0s - loss: 0.0036 - 55ms/epoch - 4ms/step
# Epoch 187/300
# 15/15 - 0s - loss: 0.0020 - 55ms/epoch - 4ms/step
# Epoch 188/300
# 15/15 - 0s - loss: 0.0017 - 55ms/epoch - 4ms/step
# Epoch 189/300
# 15/15 - 0s - loss: 8.1168e-04 - 55ms/epoch - 4ms/step
# Epoch 190/300
# 15/15 - 0s - loss: 6.1157e-04 - 58ms/epoch - 4ms/step
# Epoch 191/300
# 15/15 - 0s - loss: 3.6213e-04 - 57ms/epoch - 4ms/step
# Epoch 192/300
# 15/15 - 0s - loss: 4.6052e-05 - 56ms/epoch - 4ms/step
# Epoch 193/300
# 15/15 - 0s - loss: 4.5173e-05 - 56ms/epoch - 4ms/step
# Epoch 194/300
# 15/15 - 0s - loss: 2.4787e-05 - 58ms/epoch - 4ms/step
# Epoch 195/300
# 15/15 - 0s - loss: 1.5432e-05 - 58ms/epoch - 4ms/step
# Epoch 196/300
# 15/15 - 0s - loss: 1.3391e-05 - 56ms/epoch - 4ms/step
# Epoch 197/300
# 15/15 - 0s - loss: 1.2296e-05 - 55ms/epoch - 4ms/step
# Epoch 198/300
# 15/15 - 0s - loss: 9.1417e-06 - 56ms/epoch - 4ms/step
# Epoch 199/300
# 15/15 - 0s - loss: 8.1251e-06 - 58ms/epoch - 4ms/step
# Epoch 200/300
# 15/15 - 0s - loss: 7.0672e-06 - 57ms/epoch - 4ms/step
# Epoch 201/300
# 15/15 - 0s - loss: 5.8134e-06 - 57ms/epoch - 4ms/step
# Epoch 202/300
# 15/15 - 0s - loss: 5.2286e-06 - 57ms/epoch - 4ms/step
# Epoch 203/300
# 15/15 - 0s - loss: 4.9304e-06 - 58ms/epoch - 4ms/step
# Epoch 204/300
# 15/15 - 0s - loss: 4.5814e-06 - 58ms/epoch - 4ms/step
# Epoch 205/300
# 15/15 - 0s - loss: 4.1609e-06 - 58ms/epoch - 4ms/step
# Epoch 206/300
# 15/15 - 0s - loss: 4.0069e-06 - 58ms/epoch - 4ms/step
# Epoch 207/300
# 15/15 - 0s - loss: 3.9654e-06 - 58ms/epoch - 4ms/step
# Epoch 208/300
# 15/15 - 0s - loss: 3.4443e-06 - 56ms/epoch - 4ms/step
# Epoch 209/300
# 15/15 - 0s - loss: 3.6692e-06 - 57ms/epoch - 4ms/step
# Epoch 210/300
# 15/15 - 0s - loss: 3.7334e-06 - 56ms/epoch - 4ms/step
# Epoch 211/300
# 15/15 - 0s - loss: 4.3913e-06 - 55ms/epoch - 4ms/step
# Epoch 212/300
# 15/15 - 0s - loss: 3.8205e-06 - 57ms/epoch - 4ms/step
# Epoch 213/300
# 15/15 - 0s - loss: 2.7151e-06 - 57ms/epoch - 4ms/step
# Epoch 214/300
# 15/15 - 0s - loss: 2.3159e-06 - 57ms/epoch - 4ms/step
# Epoch 215/300
# 15/15 - 0s - loss: 2.3168e-06 - 59ms/epoch - 4ms/step
# Epoch 216/300
# 15/15 - 0s - loss: 3.4111e-06 - 56ms/epoch - 4ms/step
# Epoch 217/300
# 15/15 - 0s - loss: 3.3034e-06 - 59ms/epoch - 4ms/step
# Epoch 218/300
# 15/15 - 0s - loss: 2.1755e-06 - 60ms/epoch - 4ms/step
# Epoch 219/300
# 15/15 - 0s - loss: 2.0316e-06 - 62ms/epoch - 4ms/step
# Epoch 220/300
# 15/15 - 0s - loss: 1.8873e-06 - 58ms/epoch - 4ms/step
# Epoch 221/300
# 15/15 - 0s - loss: 1.8478e-06 - 57ms/epoch - 4ms/step
# Epoch 222/300
# 15/15 - 0s - loss: 1.6226e-06 - 57ms/epoch - 4ms/step
# Epoch 223/300
# 15/15 - 0s - loss: 1.5378e-06 - 60ms/epoch - 4ms/step
# Epoch 224/300
# 15/15 - 0s - loss: 1.7001e-06 - 60ms/epoch - 4ms/step
# Epoch 225/300
# 15/15 - 0s - loss: 1.6512e-06 - 59ms/epoch - 4ms/step
# Epoch 226/300
# 15/15 - 0s - loss: 1.6189e-06 - 59ms/epoch - 4ms/step
# Epoch 227/300
# 15/15 - 0s - loss: 1.5912e-06 - 58ms/epoch - 4ms/step
# Epoch 228/300
# 15/15 - 0s - loss: 1.5548e-06 - 60ms/epoch - 4ms/step
# Epoch 229/300
# 15/15 - 0s - loss: 2.0701e-06 - 61ms/epoch - 4ms/step
# Epoch 230/300
# 15/15 - 0s - loss: 1.5425e-06 - 59ms/epoch - 4ms/step
# Epoch 231/300
# 15/15 - 0s - loss: 1.4968e-06 - 61ms/epoch - 4ms/step
# Epoch 232/300
# 15/15 - 0s - loss: 1.6313e-06 - 58ms/epoch - 4ms/step
# Epoch 233/300
# 15/15 - 0s - loss: 2.0655e-06 - 56ms/epoch - 4ms/step
# Epoch 234/300
# 15/15 - 0s - loss: 1.1052e-06 - 60ms/epoch - 4ms/step
# Epoch 235/300
# 15/15 - 0s - loss: 1.9129e-06 - 60ms/epoch - 4ms/step
# Epoch 236/300
# 15/15 - 0s - loss: 2.0871e-06 - 59ms/epoch - 4ms/step
# Epoch 237/300
# 15/15 - 0s - loss: 1.3979e-06 - 59ms/epoch - 4ms/step
# Epoch 238/300
# 15/15 - 0s - loss: 1.6935e-06 - 57ms/epoch - 4ms/step
# Epoch 239/300
# 15/15 - 0s - loss: 4.2097e-06 - 55ms/epoch - 4ms/step
# Epoch 240/300
# 15/15 - 0s - loss: 4.0676e-06 - 56ms/epoch - 4ms/step
# Epoch 241/300
# 15/15 - 0s - loss: 1.0932e-06 - 54ms/epoch - 4ms/step
# Epoch 242/300
# 15/15 - 0s - loss: 9.9956e-07 - 57ms/epoch - 4ms/step
# Epoch 243/300
# 15/15 - 0s - loss: 2.5620e-06 - 57ms/epoch - 4ms/step
# Epoch 244/300
# 15/15 - 0s - loss: 1.3255e-06 - 57ms/epoch - 4ms/step
# Epoch 245/300
# 15/15 - 0s - loss: 1.6808e-06 - 57ms/epoch - 4ms/step
# Epoch 246/300
# 15/15 - 0s - loss: 6.9664e-06 - 58ms/epoch - 4ms/step
# Epoch 247/300
# 15/15 - 0s - loss: 1.2377e-05 - 57ms/epoch - 4ms/step
# Epoch 248/300
# 15/15 - 0s - loss: 7.7628e-06 - 57ms/epoch - 4ms/step
# Epoch 249/300
# 15/15 - 0s - loss: 9.1102e-06 - 56ms/epoch - 4ms/step
# Epoch 250/300
# 15/15 - 0s - loss: 2.4488e-05 - 59ms/epoch - 4ms/step
# Epoch 251/300
# 15/15 - 0s - loss: 3.4085e-05 - 60ms/epoch - 4ms/step
# Epoch 252/300
# 15/15 - 0s - loss: 7.8207e-05 - 59ms/epoch - 4ms/step
# Epoch 253/300
# 15/15 - 0s - loss: 4.2830e-06 - 58ms/epoch - 4ms/step
# Epoch 254/300
# 15/15 - 0s - loss: 6.2197e-06 - 55ms/epoch - 4ms/step
# Epoch 255/300
# 15/15 - 0s - loss: 1.3699e-06 - 55ms/epoch - 4ms/step
# Epoch 256/300
# 15/15 - 0s - loss: 8.6856e-07 - 53ms/epoch - 4ms/step
# Epoch 257/300
# 15/15 - 0s - loss: 3.5474e-06 - 58ms/epoch - 4ms/step
# Epoch 258/300
# 15/15 - 0s - loss: 6.9940e-06 - 56ms/epoch - 4ms/step
# Epoch 259/300
# 15/15 - 0s - loss: 1.2018e-05 - 56ms/epoch - 4ms/step
# Epoch 260/300
# 15/15 - 0s - loss: 8.9503e-06 - 57ms/epoch - 4ms/step
# Epoch 261/300
# 15/15 - 0s - loss: 1.9238e-05 - 57ms/epoch - 4ms/step
# Epoch 262/300
# 15/15 - 0s - loss: 4.3505e-05 - 54ms/epoch - 4ms/step
# Epoch 263/300
# 15/15 - 0s - loss: 2.6366e-05 - 57ms/epoch - 4ms/step
# Epoch 264/300
# 15/15 - 0s - loss: 2.8519e-05 - 56ms/epoch - 4ms/step
# Epoch 265/300
# 15/15 - 0s - loss: 3.2493e-05 - 56ms/epoch - 4ms/step
# Epoch 266/300
# 15/15 - 0s - loss: 3.3674e-05 - 56ms/epoch - 4ms/step
# Epoch 267/300
# 15/15 - 0s - loss: 3.9570e-05 - 57ms/epoch - 4ms/step
# Epoch 268/300
# 15/15 - 0s - loss: 1.4406e-04 - 57ms/epoch - 4ms/step
# Epoch 269/300
# 15/15 - 0s - loss: 0.0018 - 58ms/epoch - 4ms/step
# Epoch 270/300
# 15/15 - 0s - loss: 8.4657e-04 - 59ms/epoch - 4ms/step
# Epoch 271/300
# 15/15 - 0s - loss: 4.8473e-04 - 56ms/epoch - 4ms/step
# Epoch 272/300
# 15/15 - 0s - loss: 0.0054 - 56ms/epoch - 4ms/step
# Epoch 273/300
# 15/15 - 0s - loss: 0.0308 - 55ms/epoch - 4ms/step
# Epoch 274/300
# 15/15 - 0s - loss: 0.0239 - 57ms/epoch - 4ms/step
# Epoch 275/300
# 15/15 - 0s - loss: 0.0143 - 56ms/epoch - 4ms/step
# Epoch 276/300
# 15/15 - 0s - loss: 0.0257 - 57ms/epoch - 4ms/step
# Epoch 277/300
# 15/15 - 0s - loss: 0.0376 - 56ms/epoch - 4ms/step
# Epoch 278/300
# 15/15 - 0s - loss: 0.0163 - 56ms/epoch - 4ms/step
# Epoch 279/300
# 15/15 - 0s - loss: 0.0040 - 59ms/epoch - 4ms/step
# Epoch 280/300
# 15/15 - 0s - loss: 0.0080 - 56ms/epoch - 4ms/step
# Epoch 281/300
# 15/15 - 0s - loss: 0.0077 - 56ms/epoch - 4ms/step
# Epoch 282/300
# 15/15 - 0s - loss: 0.0248 - 57ms/epoch - 4ms/step
# Epoch 283/300
# 15/15 - 0s - loss: 0.1453 - 56ms/epoch - 4ms/step
# Epoch 284/300
# 15/15 - 0s - loss: 0.1600 - 57ms/epoch - 4ms/step
# Epoch 285/300
# 15/15 - 0s - loss: 0.1050 - 60ms/epoch - 4ms/step
# Epoch 286/300
# 15/15 - 0s - loss: 0.0217 - 58ms/epoch - 4ms/step
# Epoch 287/300
# 15/15 - 0s - loss: 0.0091 - 57ms/epoch - 4ms/step
# Epoch 288/300
# 15/15 - 0s - loss: 0.0064 - 55ms/epoch - 4ms/step
# Epoch 289/300
# 15/15 - 0s - loss: 0.0048 - 57ms/epoch - 4ms/step
# Epoch 290/300
# 15/15 - 0s - loss: 0.0035 - 55ms/epoch - 4ms/step
# Epoch 291/300
# 15/15 - 0s - loss: 0.0042 - 57ms/epoch - 4ms/step
# Epoch 292/300
# 15/15 - 0s - loss: 0.0018 - 60ms/epoch - 4ms/step
# Epoch 293/300
# 15/15 - 0s - loss: 0.0033 - 60ms/epoch - 4ms/step
# Epoch 294/300
# 15/15 - 0s - loss: 5.8991e-04 - 58ms/epoch - 4ms/step
# Epoch 295/300
# 15/15 - 0s - loss: 0.0012 - 59ms/epoch - 4ms/step
# Epoch 296/300
# 15/15 - 0s - loss: 0.0043 - 60ms/epoch - 4ms/step
# Epoch 297/300
# 15/15 - 0s - loss: 0.0121 - 58ms/epoch - 4ms/step
# Epoch 298/300
# 15/15 - 0s - loss: 7.1038e-04 - 58ms/epoch - 4ms/step
# Epoch 299/300
# 15/15 - 0s - loss: 0.0083 - 60ms/epoch - 4ms/step
# Epoch 300/300
# 15/15 - 0s - loss: 0.0050 - 59ms/epoch - 4ms/step

# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1712716587.853165
# Wed Apr 10 02:36:27 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1712716587.859266
# Wed Apr 10 02:36:27 2024

# %%
# Function to compute saliency map
@tf.function
def compute_saliency(input_image):
    with tf.GradientTape() as tape:
        tape.watch(input_image)
        predictions = tn_model(input_image)
    grads = tape.gradient(predictions, input_image)
    saliency_map = tf.reduce_max(tf.abs(grads), axis=-1)
    return saliency_map

# Function to compute saliency map using Gradient
@tf.function
def compute_gradient_saliency(input_image):
    with tf.GradientTape() as tape:
        tape.watch(input_image)
        predictions = tn_model(input_image)
    grads = tape.gradient(predictions, input_image)
    saliency_map = tf.reduce_max(tf.abs(grads), axis=-1)
    return saliency_map

# Compute saliency map for the entire grid
def compute_saliency_map_grid():
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    input_image = np.c_[xx.ravel(), yy.ravel()]
    saliency_map = compute_saliency(tf.constant(input_image, dtype=tf.float32)).numpy()
    saliency_map = saliency_map.reshape(xx.shape)
    return xx, yy, saliency_map

# Compute and plot saliency map for the entire grid
xx, yy, saliency_map = compute_saliency_map_grid()

# Compute saliency maps for all data points
def compute_saliency_maps():
    saliency_maps = []
    for data_point in X:
        saliency_map = compute_gradient_saliency(tf.constant(data_point[None, :], dtype=tf.float32)).numpy()
        saliency_maps.append(saliency_map)
    return saliency_maps

# Find the indices of the data points with the highest saliency values
def find_top_indices(saliency_maps, top_k):
    top_indices = np.argsort(np.max(saliency_maps, axis=1))[-top_k:]
    return top_indices

def plot_most_diagnostic(top_indices, top_k, normalized_saliency_values):
    plt.figure(figsize=(8, 6))
    plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
    plt.scatter(X[top_indices, 0], X[top_indices, 1], marker='o', s=200, facecolors='none', edgecolors='r', linewidths=2)
    for i, index in enumerate(top_indices):
        plt.annotate(f'{normalized_saliency_values.iloc[index]["Saliency"]:.4f}', (X[index, 0], X[index, 1]), xytext=(X[index, 0]+0.35, X[index, 1]+0.25), arrowprops=dict(facecolor='black', arrowstyle='->'))
    plt.title(f'Saliency Most Diagnostic Data Points (Top {top_k})')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.grid(True)
    plt.axis('equal')
    plt.show()

# Compute saliency maps for all data points
saliency_maps = compute_saliency_maps()

# Find the indices of the data points with the highest saliency values
top_k = 5  # Number of top diagnostic data points to select
top_indices = find_top_indices(saliency_maps, top_k)

# Create a DataFrame to store the saliency values
saliency_df = pd.DataFrame(data=saliency_maps, columns=["Saliency"])

# Save the saliency values to a CSV file
saliency_df.to_csv("saliency_values.csv", index=False)

print("Saliency values saved to saliency_values.csv")

# Normalizing the saliency values
normalized_saliency = (saliency_df - saliency_df.min()) / (saliency_df.max() - saliency_df.min())

# Saving the normalized saliency values to a new CSV file
normalized_saliency.to_csv("normalized_saliency_values.csv", index=False)

# Plot the most diagnostic data points
plot_most_diagnostic(top_indices, top_k, normalized_saliency)

print("Normalized saliency values saved to normalized_saliency_values.csv")
print("Normalized Saliency Top-k:")
print(normalized_saliency.nlargest(top_k, 'Saliency'))
print("Normalized Saliency Max:", normalized_saliency.max())
print("Normalized Saliency Min:", normalized_saliency.min())
print("Normalized Saliency Mean:", normalized_saliency.mean())
print("Normalized Saliency Median:", normalized_saliency.median())
print("Normalized Saliency Mode:", normalized_saliency.mode())
sum_normalized_values = normalized_saliency.sum()
print("Normalized Saliency Sum:", sum_normalized_values)
print("#")
print("#")
print("#")
print("Normalized Saliency Standard Deviation:", normalized_saliency.std())
print("Normalized Saliency Skewness:", normalized_saliency.skew())
print("Normalized Saliency Kurtosis:", normalized_saliency.kurtosis())
print("Normalized Saliency Variance:", normalized_saliency.var())
coefficient_variation = (normalized_saliency.std() / normalized_saliency.mean()) * 100
print("Normalized Saliency Coefficient of Variation:", coefficient_variation)
print("#")
print("#")
print("#")
cumulative_sum = normalized_saliency.cumsum()
print("Cumulative Sum of Normalized Saliency Values:", cumulative_sum)
mean_cumulative_sum = cumulative_sum / len(normalized_saliency)
print("Mean of Cumulative Sum of Normalized Saliency Values:", mean_cumulative_sum)
rms = np.sqrt(np.mean(normalized_saliency**2))
print("Normalized Saliency Root Mean Square:", rms)
q1 = normalized_saliency.quantile(0.25)
q2 = normalized_saliency.quantile(0.75)
iqr = q2 - q1
print("Normalized Saliency 25th Percentile:", q1)
print("Normalized Saliency 75th Percentile:", q2)
print("Normalized Saliency Interquartile Range:", iqr)
# Out:
# Saliency values saved to saliency_values.csv
# Normalized saliency values saved to normalized_saliency_values.csv
# Normalized Saliency Top-k:
#      Saliency
# 50   1.000000
# 1    0.954330
# 191  0.945628
# 134  0.907147
# 154  0.885093
# Normalized Saliency Max: Saliency    1.0
# dtype: float32
# Normalized Saliency Min: Saliency    0.0
# dtype: float32
# Normalized Saliency Mean: Saliency    0.015005
# dtype: float32
# Normalized Saliency Median: Saliency    0.000211
# dtype: float32
# Normalized Saliency Mode:    Saliency
# 0       0.0
# Normalized Saliency Sum: Saliency    7.202397
# dtype: float32
# #
# #
# #
# Normalized Saliency Standard Deviation: Saliency    0.110564
# dtype: float32
# Normalized Saliency Skewness: Saliency    7.867597
# dtype: float32
# Normalized Saliency Kurtosis: Saliency    61.21925
# dtype: float32
# Normalized Saliency Variance: Saliency    0.012224
# dtype: float32
# Normalized Saliency Coefficient of Variation: Saliency    736.846069
# dtype: float32
# #
# #
# #
# Cumulative Sum of Normalized Saliency Values:      Saliency
# 0    0.000307
# 1    0.954637
# 2    0.955035
# 3    0.955484
# 4    0.955484
# ..        ...
# 475  7.201847
# 476  7.201897
# 477  7.201949
# 478  7.202342
# 479  7.202398
#
# [480 rows x 1 columns]
# Mean of Cumulative Sum of Normalized Saliency Values:          Saliency
# 0    6.405893e-07
# 1    1.988828e-03
# 2    1.989657e-03
# 3    1.990592e-03
# 4    1.990592e-03
# ..            ...
# 475  1.500385e-02
# 476  1.500395e-02
# 477  1.500406e-02
# 478  1.500488e-02
# 479  1.500500e-02
#
# [480 rows x 1 columns]
# Normalized Saliency Root Mean Square: 0.11146307
# Normalized Saliency 25th Percentile: Saliency    0.000065
# Name: 0.25, dtype: float64
# Normalized Saliency 75th Percentile: Saliency    0.000425
# Name: 0.75, dtype: float64
# Normalized Saliency Interquartile Range: Saliency    0.000361
# dtype: float64

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1712716589.2574239
# Wed Apr 10 02:36:29 2024
