# %% [markdown]
# # TensorNetworks in Neural Networks.
#
# Here, we have a small toy example of how to use a TN inside of a fully connected neural network.
#
# First off, let's install tensornetwork

# %%
# !pip install tensornetwork

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Import tensornetwork
import tensornetwork as tn
import random
import time
# Set the backend to tesorflow
# (default is numpy)
tn.set_default_backend("tensorflow")
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # TensorNetwork layer definition
#
# Here, we define the TensorNetwork layer we wish to use to replace the fully connected layer. Here, we simply use a 2 node Matrix Product Operator network to replace the normal dense weight matrix.
#
# We TensorNetwork's NCon API to keep the code short.

# %%
class TNLayer(tf.keras.layers.Layer):

  def __init__(self):
    super(TNLayer, self).__init__()
    # Create the variables for the layer.
    self.a_var = tf.Variable(tf.random.normal(shape=(36, 36, 2),
                                              stddev=1.0/32.0),
                             name="a", trainable=True)
    self.b_var = tf.Variable(tf.random.normal(shape=(36, 36, 2),
                                              stddev=1.0/32.0),
                             name="b", trainable=True)
    self.bias = tf.Variable(tf.zeros(shape=(36, 36)),
                            name="bias", trainable=True)

  def call(self, inputs):
    # Define the contraction.
    # We break it out so we can parallelize a batch using
    # tf.vectorized_map (see below).
    def f(input_vec, a_var, b_var, bias_var):
      # Reshape to a matrix instead of a vector.
      input_vec = tf.reshape(input_vec, (36, 36))

      # Now we create the network.
      a = tn.Node(a_var)
      b = tn.Node(b_var)
      x_node = tn.Node(input_vec)
      a[1] ^ x_node[0]
      b[1] ^ x_node[1]
      a[2] ^ b[2]

      # The TN should now look like this
      #   |     |
      #   a --- b
      #    \   /
      #      x

      # Now we begin the contraction.
      c = a @ x_node
      result = (c @ b).tensor

      # To make the code shorter, we also could've used Ncon.
      # The above few lines of code is the same as this:
      # result = tn.ncon([x, a_var, b_var], [[1, 2], [-1, 1, 3], [-2, 2, 3]])

      # Finally, add bias.
      return result + bias_var

    # To deal with a batch of items, we can use the tf.vectorized_map
    # function.
    # https://www.tensorflow.org/api_docs/python/tf/vectorized_map
    result = tf.vectorized_map(
        lambda vec: f(vec, self.a_var, self.b_var, self.bias), inputs)
    return tf.nn.relu(tf.reshape(result, (-1, 1296)))

# %% [markdown]
# # Smaller model
# These two models are effectively the same, but notice how the TN layer has nearly 10x fewer parameters.

# %%
Dense = tf.keras.layers.Dense
fc_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1024, activation=tf.nn.relu),
     Dense(1024, activation=tf.nn.relu),
     Dense(1, activation=None)])
fc_model.summary()
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_70 (Dense)            (None, 1024)              3072
#
#  dense_71 (Dense)            (None, 1024)              1049600
#
#  dense_72 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 1053697 (4.02 MB)
# Trainable params: 1053697 (4.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tn_model = tf.keras.Sequential(
    [
     tf.keras.Input(shape=(2,)),
     Dense(1296, activation=tf.nn.relu),
     # Here, we replace the dense layer with our MPS.
     TNLayer(),
     Dense(1, activation=None)])
tn_model.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_73 (Dense)            (None, 1296)              3888
#
#  tn_layer_14 (TNLayer)       (None, 1296)              6480
#
#  dense_74 (Dense)            (None, 1)                 1297
#
# =================================================================
# Total params: 11665 (45.57 KB)
# Trainable params: 11665 (45.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training a model
#
# You can train the TN model just as you would a normal neural network model! Here, we give an example of how to do it in Keras.

# %%
X = np.concatenate([np.random.randn(20, 2) + np.array([3, 3]),
                    np.random.randn(20, 2) + np.array([-3, -3]),
                    np.random.randn(20, 2) + np.array([-3, 3]),
                    np.random.randn(20, 2) + np.array([3, -3])])

Y = np.concatenate([np.ones((40)), -np.ones((40))])

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1709521478.0400538
# Mon Mar  4 03:04:38 2024

# %%
tn_model.compile(optimizer="adam", loss="mean_squared_error")
tn_model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 3/3 - 1s - loss: 0.9843 - 1s/epoch - 409ms/step
# Epoch 2/300
# 3/3 - 0s - loss: 0.9221 - 18ms/epoch - 6ms/step
# Epoch 3/300
# 3/3 - 0s - loss: 0.8659 - 18ms/epoch - 6ms/step
# Epoch 4/300
# 3/3 - 0s - loss: 0.8026 - 19ms/epoch - 6ms/step
# Epoch 5/300
# 3/3 - 0s - loss: 0.7287 - 18ms/epoch - 6ms/step
# Epoch 6/300
# 3/3 - 0s - loss: 0.6376 - 18ms/epoch - 6ms/step
# Epoch 7/300
# 3/3 - 0s - loss: 0.5310 - 20ms/epoch - 7ms/step
# Epoch 8/300
# 3/3 - 0s - loss: 0.4107 - 22ms/epoch - 7ms/step
# Epoch 9/300
# 3/3 - 0s - loss: 0.2839 - 18ms/epoch - 6ms/step
# Epoch 10/300
# 3/3 - 0s - loss: 0.1661 - 19ms/epoch - 6ms/step
# Epoch 11/300
# 3/3 - 0s - loss: 0.0828 - 18ms/epoch - 6ms/step
# Epoch 12/300
# 3/3 - 0s - loss: 0.0533 - 19ms/epoch - 6ms/step
# Epoch 13/300
# 3/3 - 0s - loss: 0.0731 - 20ms/epoch - 7ms/step
# Epoch 14/300
# 3/3 - 0s - loss: 0.0874 - 20ms/epoch - 7ms/step
# Epoch 15/300
# 3/3 - 0s - loss: 0.
# %%
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = tn_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# 14/14 [==============================] - 0s 4ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1709521486.3740191
# Mon Mar  4 03:04:46 2024

# %%
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1709521486.3876336
# Mon Mar  4 03:04:46 2024

# %% [markdown]
# # VS Fully Connected

# %%
fc_model.compile(optimizer="adam", loss="mean_squared_error")
fc_model.fit(X, Y, epochs=300, verbose=2)
# Plotting code, feel free to ignore.
h = 1.0
x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = fc_model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
# Out:
# Epoch 1/300
# 3/3 - 1s - loss: 0.5656 - 851ms/epoch - 284ms/step
# Epoch 2/300
# 3/3 - 0s - loss: 0.1959 - 35ms/epoch - 12ms/step
# Epoch 3/300
# 3/3 - 0s - loss: 0.1423 - 36ms/epoch - 12ms/step
# Epoch 4/300
# 3/3 - 0s - loss: 0.0917 - 31ms/epoch - 10ms/step
# Epoch 5/300
# 3/3 - 0s - loss: 0.0828 - 31ms/epoch - 10ms/step
# Epoch 6/300
# 3/3 - 0s - loss: 0.0827 - 36ms/epoch - 12ms/step
# Epoch 7/300
# 3/3 - 0s - loss: 0.0680 - 31ms/epoch - 10ms/step
# Epoch 8/300
# 3/3 - 0s - loss: 0.0680 - 32ms/epoch - 11ms/step
# Epoch 9/300
# 3/3 - 0s - loss: 0.0605 - 32ms/epoch - 11ms/step
# Epoch 10/300
# 3/3 - 0s - loss: 0.0632 - 32ms/epoch - 11ms/step
# Epoch 11/300
# 3/3 - 0s - loss: 0.0537 - 28ms/epoch - 9ms/step
# Epoch 12/300
# 3/3 - 0s - loss: 0.0523 - 34ms/epoch - 11ms/step
# Epoch 13/300
# 3/3 - 0s - loss: 0.0522 - 33ms/epoch - 11ms/step
# Epoch 14/300
# 3/3 - 0s - loss: 0.0483 - 28ms/epoch - 9ms/step
# Epoch 15/300
# 3/3 - 0s - loss: 0.0498 - 36ms/epoch - 12ms/step
# Epoch 16/300
# 3/3 - 0s - loss: 0.0444 - 31ms/epoch - 10ms/step
# Epoch 17/300
# 3/3 - 0s - loss: 0.0487 - 31ms/epoch - 10ms/step
# Epoch 18/300
# 3/3 - 0s - loss: 0.0467 - 30ms/epoch - 10ms/step
# Epoch 19/300
# 3/3 - 0s - loss: 0.0419 - 34ms/epoch - 11ms/step
# Epoch 20/300
# 3/3 - 0s - loss: 0.0439 - 29ms/epoch - 10ms/step
# Epoch 21/300
# 3/3 - 0s - loss: 0.0406 - 30ms/epoch - 10ms/step
# Epoch 22/300
# 3/3 - 0s - loss: 0.0414 - 29ms/epoch - 10ms/step
# Epoch 23/300
# 3/3 - 0s - loss: 0.0421 - 33ms/epoch - 11ms/step
# Epoch 24/300
# 3/3 - 0s - loss: 0.0378 - 34ms/epoch - 11ms/step
# Epoch 25/300
# 3/3 - 0s - loss: 0.0382 - 36ms/epoch - 12ms/step
# Epoch 26/300
# 3/3 - 0s - loss: 0.0425 - 34ms/epoch - 11ms/step
# Epoch 27/300
# 3/3 - 0s - loss: 0.0505 - 33ms/epoch - 11ms/step
# Epoch 28/300
# 3/3 - 0s - loss: 0.0423 - 36ms/epoch - 12ms/step
# Epoch 29/300
# 3/3 - 0s - loss: 0.0513 - 32ms/epoch - 11ms/step
# Epoch 30/300
# 3/3 - 0s - loss: 0.0385 - 28ms/epoch - 9ms/step
# Epoch 31/300
# 3/3 - 0s - loss: 0.0392 - 34ms/epoch - 11ms/step
# Epoch 32/300
# 3/3 - 0s - loss: 0.0417 - 33ms/epoch - 11ms/step
# Epoch 33/300
# 3/3 - 0s - loss: 0.0414 - 30ms/epoch - 10ms/step
# Epoch 34/300
# 3/3 - 0s - loss: 0.0374 - 32ms/epoch - 11ms/step
# Epoch 35/300
# 3/3 - 0s - loss: 0.0348 - 32ms/epoch - 11ms/step
# Epoch 36/300
# 3/3 - 0s - loss: 0.0319 - 34ms/epoch - 11ms/step
# Epoch 37/300
# 3/3 - 0s - loss: 0.0429 - 33ms/epoch - 11ms/step
# Epoch 38/300
# 3/3 - 0s - loss: 0.0382 - 29ms/epoch - 10ms/step
# Epoch 39/300
# 3/3 - 0s - loss: 0.0266 - 33ms/epoch - 11ms/step
# Epoch 40/300
# 3/3 - 0s - loss: 0.0399 - 34ms/epoch - 11ms/step
# Epoch 41/300
# 3/3 - 0s - loss: 0.0336 - 34ms/epoch - 11ms/step
# Epoch 42/300
# 3/3 - 0s - loss: 0.0293 - 26ms/epoch - 9ms/step
# Epoch 43/300
# 3/3 - 0s - loss: 0.0304 - 30ms/epoch - 10ms/step
# Epoch 44/300
# 3/3 - 0s - loss: 0.0370 - 31ms/epoch - 10ms/step
# Epoch 45/300
# 3/3 - 0s - loss: 0.0295 - 30ms/epoch - 10ms/step
# Epoch 46/300
# 3/3 - 0s - loss: 0.0278 - 35ms/epoch - 12ms/step
# Epoch 47/300
# 3/3 - 0s - loss: 0.0298 - 33ms/epoch - 11ms/step
# Epoch 48/300
# 3/3 - 0s - loss: 0.0244 - 31ms/epoch - 10ms/step
# Epoch 49/300
# 3/3 - 0s - loss: 0.0270 - 35ms/epoch - 12ms/step
# Epoch 50/300
# 3/3 - 0s - loss: 0.0191 - 29ms/epoch - 10ms/step
# Epoch 51/300
# 3/3 - 0s - loss: 0.0257 - 28ms/epoch - 9ms/step
# Epoch 52/300
# 3/3 - 0s - loss: 0.0229 - 32ms/epoch - 11ms/step
# Epoch 53/300
# 3/3 - 0s - loss: 0.0226 - 30ms/epoch - 10ms/step
# Epoch 54/300
# 3/3 - 0s - loss: 0.0251 - 32ms/epoch - 11ms/step
# Epoch 55/300
# 3/3 - 0s - loss: 0.0231 - 27ms/epoch - 9ms/step
# Epoch 56/300
# 3/3 - 0s - loss: 0.0268 - 26ms/epoch - 9ms/step
# Epoch 57/300
# 3/3 - 0s - loss: 0.0274 - 30ms/epoch - 10ms/step
# Epoch 58/300
# 3/3 - 0s - loss: 0.0182 - 29ms/epoch - 10ms/step
# Epoch 59/300
# 3/3 - 0s - loss: 0.0233 - 35ms/epoch - 12ms/step
# Epoch 60/300
# 3/3 - 0s - loss: 0.0189 - 30ms/epoch - 10ms/step
# Epoch 61/300
# 3/3 - 0s - loss: 0.0133 - 33ms/epoch - 11ms/step
# Epoch 62/300
# 3/3 - 0s - loss: 0.0144 - 31ms/epoch - 10ms/step
# Epoch 63/300
# 3/3 - 0s - loss: 0.0157 - 35ms/epoch - 12ms/step
# Epoch 64/300
# 3/3 - 0s - loss: 0.0119 - 27ms/epoch - 9ms/step
# Epoch 65/300
# 3/3 - 0s - loss: 0.0188 - 28ms/epoch - 9ms/step
# Epoch 66/300
# 3/3 - 0s - loss: 0.0130 - 34ms/epoch - 11ms/step
# Epoch 67/300
# 3/3 - 0s - loss: 0.0116 - 39ms/epoch - 13ms/step
# Epoch 68/300
# 3/3 - 0s - loss: 0.0110 - 33ms/epoch - 11ms/step
# Epoch 69/300
# 3/3 - 0s - loss: 0.0073 - 31ms/epoch - 10ms/step
# Epoch 70/300
# 3/3 - 0s - loss: 0.0097 - 36ms/epoch - 12ms/step
# Epoch 71/300
# 3/3 - 0s - loss: 0.0088 - 42ms/epoch - 14ms/step
# Epoch 72/300
# 3/3 - 0s - loss: 0.0063 - 35ms/epoch - 12ms/step
# Epoch 73/300
# 3/3 - 0s - loss: 0.0058 - 38ms/epoch - 13ms/step
# Epoch 74/300
# 3/3 - 0s - loss: 0.0060 - 35ms/epoch - 12ms/step
# Epoch 75/300
# 3/3 - 0s - loss: 0.0094 - 32ms/epoch - 11ms/step
# Epoch 76/300
# 3/3 - 0s - loss: 0.0106 - 36ms/epoch - 12ms/step
# Epoch 77/300
# 3/3 - 0s - loss: 0.0083 - 35ms/epoch - 12ms/step
# Epoch 78/300
# 3/3 - 0s - loss: 0.0048 - 35ms/epoch - 12ms/step
# Epoch 79/300
# 3/3 - 0s - loss: 0.
ms/step
# Epoch 228/300
# 3/3 - 0s - loss: 3.5742e-04 - 30ms/epoch - 10ms/step
# Epoch 229/300
# 3/3 - 0s - loss: 3.2267e-04 - 31ms/epoch - 10ms/step
# Epoch 230/300
# 3/3 - 0s - loss: 2.6533e-04 - 31ms/epoch - 10ms/step
# Epoch 231/300
# 3/3 - 0s - loss: 3.3579e-04 - 30ms/epoch - 10ms/step
# Epoch 232/300
# 3/3 - 0s - loss: 2.2141e-04 - 32ms/epoch - 11ms/step
# Epoch 233/300
# 3/3 - 0s - loss: 1.3816e-04 - 34ms/epoch - 11ms/step
# Epoch 234/300
# 3/3 - 0s - loss: 1.2997e-04 - 37ms/epoch - 12ms/step
# Epoch 235/300
# 3/3 - 0s - loss: 1.2696e-04 - 32ms/epoch - 11ms/step
# Epoch 236/300
# 3/3 - 0s - loss: 7.3166e-05 - 31ms/epoch - 10ms/step
# Epoch 237/300
# 3/3 - 0s - loss: 4.9531e-05 - 28ms/epoch - 9ms/step
# Epoch 238/300
# 3/3 - 0s - loss: 5.9576e-05 - 31ms/epoch - 10ms/step
# Epoch 239/300
# 3/3 - 0s - loss: 6.9014e-05 - 28ms/epoch - 9ms/step
# Epoch 240/300
# 3/3 - 0s - loss: 1.2079e-04 - 34ms/epoch - 11ms/step
# Epoch 241/300
# 3/3 - 0s - loss: 1.0165e-04 - 30ms/epoch - 10ms/step
# Epoch 242/300
# 3/3 - 0s - loss: 1.1189e-04 - 29ms/epoch - 10ms/step
# Epoch 243/300
# 3/3 - 0s - loss: 1.2715e-04 - 32ms/epoch - 11ms/step
# Epoch 244/300
# 3/3 - 0s - loss: 2.3746e-04 - 33ms/epoch - 11ms/step
# Epoch 245/300
# 3/3 - 0s - loss: 7.2393e-04 - 28ms/epoch - 9ms/step
# Epoch 246/300
# 3/3 - 0s - loss: 8.1162e-04 - 29ms/epoch - 10ms/step
# Epoch 247/300
# 3/3 - 0s - loss: 6.6941e-04 - 31ms/epoch - 10ms/step
# Epoch 248/300
# 3/3 - 0s - loss: 6.1267e-04 - 33ms/epoch - 11ms/step
# Epoch 249/300
# 3/3 - 0s - loss: 5.4795e-04 - 29ms/epoch - 10ms/step
# Epoch 250/300
# 3/3 - 0s - loss: 8.4581e-04 - 29ms/epoch - 10ms/step
# Epoch 251/300
# 3/3 - 0s - loss: 4.3189e-04 - 32ms/epoch - 11ms/step
# Epoch 252/300
# 3/3 - 0s - loss: 6.3720e-04 - 32ms/epoch - 11ms/step
# Epoch 253/300
# 3/3 - 0s - loss: 8.4664e-04 - 27ms/epoch - 9ms/step
# Epoch 254/300
# 3/3 - 0s - loss: 0.0025 - 31ms/epoch - 10ms/step
# Epoch 255/300
# 3/3 - 0s - loss: 0.0032 - 33ms/epoch - 11ms/step
# Epoch 256/300
# 3/3 - 0s - loss: 0.0040 - 31ms/epoch - 10ms/step
# Epoch 257/300
# 3/3 - 0s - loss: 0.0021 - 29ms/epoch - 10ms/step
# Epoch 258/300
# 3/3 - 0s - loss: 0.0023 - 32ms/epoch - 11ms/step
# Epoch 259/300
# 3/3 - 0s - loss: 0.0034 - 30ms/epoch - 10ms/step
# Epoch 260/300
# 3/3 - 0s - loss: 0.0045 - 31ms/epoch - 10ms/step
# Epoch 261/300
# 3/3 - 0s - loss: 0.0064 - 29ms/epoch - 10ms/step
# Epoch 262/300
# 3/3 - 0s - loss: 0.0050 - 33ms/epoch - 11ms/step
# Epoch 263/300
# 3/3 - 0s - loss: 0.0068 - 33ms/epoch - 11ms/step
# Epoch 264/300
# 3/3 - 0s - loss: 0.0042 - 30ms/epoch - 10ms/step
# Epoch 265/300
# 3/3 - 0s - loss: 0.0047 - 31ms/epoch - 10ms/step
# Epoch 266/300
# 3/3 - 0s - loss: 0.0045 - 29ms/epoch - 10ms/step
# Epoch 267/300
# 3/3 - 0s - loss: 0.0046 - 27ms/epoch - 9ms/step
# Epoch 268/300
# 3/3 - 0s - loss: 0.0032 - 32ms/epoch - 11ms/step
# Epoch 269/300
# 3/3 - 0s - loss: 0.0031 - 32ms/epoch - 11ms/step
# Epoch 270/300
# 3/3 - 0s - loss: 0.0041 - 33ms/epoch - 11ms/step
# Epoch 271/300
# 3/3 - 0s - loss: 0.0034 - 27ms/epoch - 9ms/step
# Epoch 272/300
# 3/3 - 0s - loss: 0.0043 - 30ms/epoch - 10ms/step
# Epoch 273/300
# 3/3 - 0s - loss: 0.0034 - 27ms/epoch - 9ms/step
# Epoch 274/300
# 3/3 - 0s - loss: 0.0036 - 35ms/epoch - 12ms/step
# Epoch 275/300
# 3/3 - 0s - loss: 0.0030 - 29ms/epoch - 10ms/step
# Epoch 276/300
# 3/3 - 0s - loss: 0.0027 - 31ms/epoch - 10ms/step
# Epoch 277/300
# 3/3 - 0s - loss: 0.0033 - 33ms/epoch - 11ms/step
# Epoch 278/300
# 3/3 - 0s - loss: 0.0024 - 34ms/epoch - 11ms/step
# Epoch 279/300
# 3/3 - 0s - loss: 0.0017 - 28ms/epoch - 9ms/step
# Epoch 280/300
# 3/3 - 0s - loss: 0.0017 - 34ms/epoch - 11ms/step
# Epoch 281/300
# 3/3 - 0s - loss: 0.0015 - 37ms/epoch - 12ms/step
# Epoch 282/300
# 3/3 - 0s - loss: 0.0015 - 36ms/epoch - 12ms/step
# Epoch 283/300
# 3/3 - 0s - loss: 0.0019 - 29ms/epoch - 10ms/step
# Epoch 284/300
# 3/3 - 0s - loss: 0.0042 - 31ms/epoch - 10ms/step
# Epoch 285/300
# 3/3 - 0s - loss: 0.0026 - 34ms/epoch - 11ms/step
# Epoch 286/300
# 3/3 - 0s - loss: 0.0035 - 30ms/epoch - 10ms/step
# Epoch 287/300
# 3/3 - 0s - loss: 0.0033 - 29ms/epoch - 10ms/step
# Epoch 288/300
# 3/3 - 0s - loss: 0.0059 - 31ms/epoch - 10ms/step
# Epoch 289/300
# 3/3 - 0s - loss: 0.0073 - 36ms/epoch - 12ms/step
# Epoch 290/300
# 3/3 - 0s - loss: 0.0060 - 34ms/epoch - 11ms/step
# Epoch 291/300
# 3/3 - 0s - loss: 0.0032 - 37ms/epoch - 12ms/step
# Epoch 292/300
# 3/3 - 0s - loss: 0.0022 - 39ms/epoch - 13ms/step
# Epoch 293/300
# 3/3 - 0s - loss: 0.0021 - 32ms/epoch - 11ms/step
# Epoch 294/300
# 3/3 - 0s - loss: 0.0025 - 33ms/epoch - 11ms/step
# Epoch 295/300
# 3/3 - 0s - loss: 0.0011 - 37ms/epoch - 12ms/step
# Epoch 296/300
# 3/3 - 0s - loss: 6.3007e-04 - 33ms/epoch - 11ms/step
# Epoch 297/300
# 3/3 - 0s - loss: 4.8764e-04 - 35ms/epoch - 12ms/step
# Epoch 298/300
# 3/3 - 0s - loss: 5.1926e-04 - 33ms/epoch - 11ms/step
# Epoch 299/300
# 3/3 - 0s - loss: 7.6698e-04 - 30ms/epoch - 10ms/step
# Epoch 300/300
# 3/3 - 0s - loss: 7.6851e-04 - 30ms/epoch - 10ms/step
# 14/14 [==============================] - 0s 5ms/step

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1709521498.0294228
# Mon Mar  4 03:04:58 2024
